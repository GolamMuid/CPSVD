# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Qemu -> Test on FFmpeg
SMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(-1), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(-1), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Qemu -> Testing on FFmpeg (SMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codet5/qemu_codet5p_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codet5/qemu_codet5p_labels.npy')
    print(f"      Qemu: {qmu_emb.shape} | FFmpeg: {ffm_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Applying SMOTE...")
    smote                       = SMOTE(random_state=SEED)
    qmu_emb_smote, qmu_lbl_smote = smote.fit_resample(qmu_emb, qmu_lbl)
    print(f"      Before SMOTE: {qmu_emb.shape} | After SMOTE: {qmu_emb_smote.shape}")
    unique, counts = np.unique(qmu_lbl_smote, return_counts=True)
    print(f"      Class distribution after SMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb_smote, qmu_lbl_smote,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_qmu_t      = torch.tensor(qmu_emb_smote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_qmu_t).squeeze(-1).cpu().numpy()

        sample_weights = np.where(qmu_lbl_smote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(qmu_emb_smote, qmu_lbl_smote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "smote",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "smote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_smote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Qemu -> Testing on FFmpeg (SMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Qemu: (17549, 256) | FFmpeg: (9769, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SMOTE...
#       Before SMOTE: (17549, 256) | After SMOTE: (20140, 256)
#       Class distribution after SMOTE: {np.int64(0): np.int64(10070), np.int64(1): np.int64(10070)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6949
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6944
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6940
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6936
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6932
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6927
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6922
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6916
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6909
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6902
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6895
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6888
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6881
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6873
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6865
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6855
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6845
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6834
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6824
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6812
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6801
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6791
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6781
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6771
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6762
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6753
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6744
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6736
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6727
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6721
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6713
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6705
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6700
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6692
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.6684
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.6679
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.6673
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.6667
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.6662
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.6659
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.6651
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.6644
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.6641
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.6633
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.6631
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.6629
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.6624
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.6617
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.6612
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.6611
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.6676
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.6682
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.6700
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.6701
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.6704
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.6681
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.6661
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.6632
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.6623
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.6599
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.6583
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.6552
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.6538
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.6511
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.6505
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.6474
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.6455
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.6436
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.6416
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.6395
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.6366
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.6342
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.6325
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.6311
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.6293
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.6269
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.6250
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.6231
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.6213
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.6196
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6933
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6932
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6931
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6930
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6929
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6927
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6925
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6922
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6919
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6915
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6910
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6905
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6899
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6892
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6885
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6877
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6868
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6859
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6849
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6837
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6826
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6813
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.6800
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.6788
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.6775
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.6763
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.6751
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.6739
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.6727
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.6716
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.6706
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.6695
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.6685
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.6676
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.6669
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.6661
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.6653
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.6645
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.6639
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.6633
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.6626
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.6619
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.6615
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.6609
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.6602
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.6598
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.6593
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.6586
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.6580
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.6574
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6641
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.6652
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.6657
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.6644
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.6623
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.6612
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.6589
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.6581
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.6561
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.6533
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.6510
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.6495
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.6463
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.6446
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.6416
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.6398
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.6369
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.6354
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.6315
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.6300
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.6277
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.6254
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.6227
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.6213
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.6192
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.6171
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.6157
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.6137
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.6119
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.6096
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6930
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6929
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6929
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6928
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6926
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6925
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6922
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6919
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6916
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6911
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6907
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6901
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6895
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6888
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6881
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6871
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6862
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6850
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6836
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6822
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.6809
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.6796
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.6782
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.6770
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.6758
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.6746
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.6735
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.6723
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.6713
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.6703
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.6693
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.6687
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.6675
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.6667
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.6662
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.6654
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.6646
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.6641
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.6634
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.6629
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.6621
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.6618
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.6611
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.6606
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.6602
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.6596
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.6590
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.6591
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.6583
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.6577
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.6643
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.6663
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.6644
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.6644
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.6628
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.6621
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.6596
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.6592
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.6576
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.6545
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.6525
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.6498
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.6467
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.6456
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.6428
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.6410
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.6395
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.6369
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.6339
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.6318
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.6294
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.6266
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.6249
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.6227
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.6200
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.6173
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.6156
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.6138
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.6112
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.6092
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.506
# Precision:  0.527
# Recall:     0.300
# F1-score:   0.382
# AUC:        0.515
# G-mean:     0.465
# PF value:   0.280
#
# Confusion Matrix:
# TN: 3446  FP: 1342
# FN: 3487  TP: 1494
#
# Results saved to results/smote.json
# Confusion matrix saved as results/confusion_matrix_smote.png
