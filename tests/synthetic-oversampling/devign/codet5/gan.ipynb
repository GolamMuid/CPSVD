# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Qemu -> Test on FFmpeg
GAN Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(-1), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(-1), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Qemu -> Testing on FFmpeg (GAN) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codet5/qemu_codet5p_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codet5/qemu_codet5p_labels.npy')
    print(f"      Qemu: {qmu_emb.shape} | FFmpeg: {ffm_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Applying GAN...")
    minority_data = qmu_emb[qmu_lbl == 1]
    majority_data = qmu_emb[qmu_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority samples: {n_minority} | Majority samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate)
    qmu_emb_gan       = np.vstack((qmu_emb, synthetic_samples))
    qmu_lbl_gan       = np.concatenate((qmu_lbl, synthetic_labels))
    print(f"      Before GAN: {qmu_emb.shape} | After GAN: {qmu_emb_gan.shape}")
    unique, counts = np.unique(qmu_lbl_gan, return_counts=True)
    print(f"      Class distribution after GAN: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb_gan, qmu_lbl_gan,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb      = train_base_model_xgb(qmu_emb_gan, qmu_lbl_gan)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "gan",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "gan.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_gan.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Qemu -> Testing on FFmpeg (GAN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Qemu: (17549, 256) | FFmpeg: (9769, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying GAN...
#       Minority samples: 7479 | Majority samples: 10070
# GAN Training:   0%|          | 0/5000 [00:00<?, ?epoch/s]
#       GAN Epoch 0/5000 - d_loss: 0.6954 | g_loss: 0.7020
#       GAN Epoch 500/5000 - d_loss: 0.3012 | g_loss: 2.0470
#       GAN Epoch 1000/5000 - d_loss: 0.2244 | g_loss: 3.4893
#       GAN Epoch 1500/5000 - d_loss: 0.0499 | g_loss: 4.1156
#       GAN Epoch 2000/5000 - d_loss: 0.0933 | g_loss: 4.7476
#       GAN Epoch 2500/5000 - d_loss: 0.0875 | g_loss: 4.5106
#       GAN Epoch 3000/5000 - d_loss: 0.0515 | g_loss: 5.1181
#       GAN Epoch 3500/5000 - d_loss: 0.1838 | g_loss: 4.1413
#       GAN Epoch 4000/5000 - d_loss: 0.3765 | g_loss: 3.8343
#       GAN Epoch 4500/5000 - d_loss: 0.1446 | g_loss: 3.9257
#       Before GAN: (17549, 256) | After GAN: (20140, 256)
#       Class distribution after GAN: {np.int64(0): np.int64(10070), np.int64(1): np.int64(10070)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6949
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6946
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6943
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6940
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6936
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6930
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6922
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6909
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6887
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6863
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6838
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6812
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6786
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6759
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6731
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6702
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6672
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6640
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6605
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6566
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6525
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6480
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6429
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6378
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6326
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6274
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6228
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6186
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6147
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6114
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6086
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6060
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6033
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6012
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.5990
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.5974
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.5957
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.5941
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.5923
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.5908
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.5894
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.5880
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.5875
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.5863
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.5853
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.5844
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.5832
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.5824
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.5819
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.5806
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5959
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5917
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5881
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.5856
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.5811
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.5782
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.5766
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.5710
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.5686
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.5661
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.5643
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.5609
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.5595
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.5555
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.5538
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.5510
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.5482
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.5460
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.5435
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.5436
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.5402
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.5376
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.5365
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.5346
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.5326
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.5315
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.5287
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.5277
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.5259
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.5240
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6981
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6970
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6958
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6942
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6923
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6897
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6864
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6821
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6769
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6706
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6636
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6572
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6504
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6427
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6348
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6276
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6212
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6157
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6111
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6070
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6039
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6014
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.5991
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.5968
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.5951
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.5933
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.5920
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.5907
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.5896
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.5886
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.5876
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.5869
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.5861
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.5852
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.5846
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.5840
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.5833
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.5826
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.5820
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.5818
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.5813
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.5810
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.5804
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.5801
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.5797
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.5790
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.5787
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.5783
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.5776
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.5772
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6032
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.6002
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5952
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.5917
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.5865
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.5838
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.5799
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.5763
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.5725
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.5698
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.5670
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.5667
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.5622
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.5610
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.5580
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.5556
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.5527
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.5508
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.5488
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.5474
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.5444
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.5423
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.5429
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.5390
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.5399
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.5361
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.5332
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.5316
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.5287
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.5271
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6970
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6964
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6958
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6948
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6934
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6911
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6863
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6785
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6682
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6570
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6460
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6364
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6284
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6217
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6164
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6119
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6079
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6046
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6016
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.5993
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.5973
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.5957
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.5941
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.5928
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.5920
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.5912
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.5903
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.5899
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.5895
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.5892
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.5887
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.5882
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.5877
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.5872
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.5870
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.5865
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.5867
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.5861
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.5861
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.5858
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.5859
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.5860
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.5854
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.5853
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.5851
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.5850
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.5845
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.5846
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.5843
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.5842
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5991
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.6060
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.6056
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.6005
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.5967
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.5912
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.5877
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.5829
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.5805
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.5762
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.5742
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.5707
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.5688
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.5659
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.5634
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.5607
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.5584
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.5552
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.5548
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.5515
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.5501
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.5471
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.5460
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.5435
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.5414
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.5401
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.5377
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.5362
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.5352
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.5320
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.491
# Precision:  0.504
# Recall:     0.170
# F1-score:   0.254
# AUC:        0.501
# G-mean:     0.375
# PF value:   0.175
#
# Confusion Matrix:
# TN: 3952  FP: 836
# FN: 4133  TP: 848
#
# Results saved to results/gan.json
# Confusion matrix saved as results/confusion_matrix_gan.png
