# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on QEMU -> Test on FFmpeg
SVMSMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SVMSMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on QEMU -> Testing on FFmpeg (SVMSMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codet5/ffmpeg_codet5p_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codet5/qemu_codet5p_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codet5/qemu_codet5p_labels.npy')
    print(f"      QEMU: {qmu_emb.shape} | FFmpeg: {ffm_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Applying SVMSMOTE...")
    svmsmote                          = SVMSMOTE(random_state=SEED)
    qmu_emb_svm, qmu_lbl_svm         = svmsmote.fit_resample(qmu_emb, qmu_lbl)
    print(f"      Before SVMSMOTE: {qmu_emb.shape} | After SVMSMOTE: {qmu_emb_svm.shape}")
    unique, counts = np.unique(qmu_lbl_svm, return_counts=True)
    print(f"      Class distribution after SVMSMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb_svm, qmu_lbl_svm,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_qmu_t      = torch.tensor(qmu_emb_svm, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_qmu_t).squeeze().cpu().numpy()

        sample_weights = np.where(qmu_lbl_svm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(qmu_emb_svm, qmu_lbl_svm, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "svmsmote",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "svmsmote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_svmsmote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-78' coro=<_async_in_context.<locals>.run_in_context_pre311() done, defined at /opt/miniconda3/envs/ml/lib/python3.10/site-packages/ipykernel/utils.py:76> wait_for=<Task pending name='Task-79' coro=<_async_in_context.<locals>.preserve_context() running at /opt/miniconda3/envs/ml/lib/python3.10/site-packages/ipykernel/utils.py:68> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /opt/miniconda3/envs/ml/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py:563]>
# Exception ignored in: <coroutine object _async_in_context.<locals>.preserve_context at 0x30c5142e0>
# Traceback (most recent call last):
#   File "<string>", line 1, in <lambda>
# KeyError: '__import__'
# Task was destroyed but it is pending!
# task: <Task pending name='Task-79' coro=<_async_in_context.<locals>.preserve_context() running at /opt/miniconda3/envs/ml/lib/python3.10/site-packages/ipykernel/utils.py:68> cb=[Task.task_wakeup()]>
# === Training on QEMU -> Testing on FFmpeg (SVMSMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       QEMU: (17549, 256) | FFmpeg: (9769, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SVMSMOTE...
#       Before SVMSMOTE: (17549, 256) | After SVMSMOTE: (20140, 256)
#       Class distribution after SVMSMOTE: {np.int64(0): np.int64(10070), np.int64(1): np.int64(10070)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6950
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6945
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6941
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6938
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6935
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6931
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6927
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6922
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6917
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6911
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6906
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6899
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6893
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6886
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6878
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6870
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6861
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6851
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6841
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6830
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6820
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6809
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6800
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6790
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6782
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6774
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6765
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6757
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6749
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6744
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6737
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6730
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6726
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6718
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.6711
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.6708
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.6701
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.6697
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.6693
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.6690
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.6681
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.6676
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.6674
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.6667
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.6666
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.6665
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.6659
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.6652
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.6648
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.6646
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.6725
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.6722
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.6740
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.6746
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.6739
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.6714
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.6697
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.6674
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.6662
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.6641
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.6615
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.6600
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.6578
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.6562
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.6542
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.6519
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.6500
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.6473
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.6461
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.6434
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.6416
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.6394
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.6372
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.6351
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.6332
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.6312
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.6292
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.6275
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.6251
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.6237
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6933
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6932
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6932
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6931
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6930
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6929
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6927
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6924
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6921
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6918
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6913
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6908
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6903
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6897
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6890
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6883
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6875
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6866
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6857
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6846
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6834
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6823
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.6811
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.6799
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.6788
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.6776
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.6765
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.6753
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.6743
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.6733
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.6724
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.6715
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.6705
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.6695
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.6689
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.6682
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.6677
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.6671
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.6666
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.6659
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.6653
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.6646
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.6642
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.6635
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.6631
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.6630
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.6624
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.6619
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.6615
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.6609
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6685
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.6705
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.6700
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.6690
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.6669
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.6655
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.6639
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.6631
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.6615
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.6583
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.6566
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.6543
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.6519
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.6506
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.6475
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.6465
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.6436
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.6412
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.6384
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.6374
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.6350
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.6326
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.6304
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.6290
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.6265
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.6243
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.6227
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.6209
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.6196
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.6171
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6930
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6929
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6929
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6928
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6927
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6926
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6924
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6922
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6919
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6915
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6911
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6906
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6901
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6895
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6888
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6881
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6872
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6863
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6854
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6843
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.6831
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.6819
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.6807
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.6794
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.6783
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.6771
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.6760
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.6749
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.6738
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.6729
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.6719
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.6713
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.6702
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.6695
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.6691
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.6684
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.6676
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.6672
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.6667
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.6662
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.6656
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.6654
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.6651
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.6646
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.6642
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.6636
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.6630
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.6631
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.6624
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.6618
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.6691
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.6699
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.6689
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.6689
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.6673
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.6657
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.6637
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.6622
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.6607
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.6579
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.6568
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.6539
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.6503
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.6491
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.6463
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.6446
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.6433
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.6410
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.6378
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.6359
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.6335
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.6306
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.6286
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.6265
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.6241
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.6215
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.6199
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.6176
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.6152
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.6137
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.503
# Precision:  0.520
# Recall:     0.336
# F1-score:   0.408
# AUC:        0.517
# G-mean:     0.477
# PF value:   0.324
#
# Confusion Matrix:
# TN: 3238  FP: 1550
# FN: 3305  TP: 1676
#
# Results saved to results/svmsmote.json
# Confusion matrix saved as results/confusion_matrix_svmsmote.png
