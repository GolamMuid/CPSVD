# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Qemu -> Test on FFmpeg
GAN Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(-1), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(-1), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Qemu -> Testing on FFmpeg (GAN) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codebert/ffmpeg_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codebert/ffmpeg_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codebert/qemu_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codebert/qemu_labels.npy')
    print(f"      Qemu: {qmu_emb.shape} | FFmpeg: {ffm_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Applying GAN...")
    minority_data = qmu_emb[qmu_lbl == 1]
    majority_data = qmu_emb[qmu_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority samples: {n_minority} | Majority samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate)
    qmu_emb_gan       = np.vstack((qmu_emb, synthetic_samples))
    qmu_lbl_gan       = np.concatenate((qmu_lbl, synthetic_labels))
    print(f"      Before GAN: {qmu_emb.shape} | After GAN: {qmu_emb_gan.shape}")
    unique, counts = np.unique(qmu_lbl_gan, return_counts=True)
    print(f"      Class distribution after GAN: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb_gan, qmu_lbl_gan,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb      = train_base_model_xgb(qmu_emb_gan, qmu_lbl_gan)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "gan",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "gan.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_gan.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Qemu -> Testing on FFmpeg (GAN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Qemu: (17549, 768) | FFmpeg: (9769, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying GAN...
#       Minority samples: 7479 | Majority samples: 10070
# GAN Training:   0%|          | 0/5000 [00:00<?, ?epoch/s]
#       GAN Epoch 0/5000 - d_loss: 0.6997 | g_loss: 0.7312
#       GAN Epoch 500/5000 - d_loss: 0.2035 | g_loss: 3.2480
#       GAN Epoch 1000/5000 - d_loss: 0.1224 | g_loss: 4.2659
#       GAN Epoch 1500/5000 - d_loss: 0.2266 | g_loss: 4.1610
#       GAN Epoch 2000/5000 - d_loss: 0.1941 | g_loss: 3.2985
#       GAN Epoch 2500/5000 - d_loss: 0.0808 | g_loss: 3.4021
#       GAN Epoch 3000/5000 - d_loss: 0.1275 | g_loss: 3.1480
#       GAN Epoch 3500/5000 - d_loss: 0.2396 | g_loss: 3.0883
#       GAN Epoch 4000/5000 - d_loss: 0.1101 | g_loss: 3.0285
#       GAN Epoch 4500/5000 - d_loss: 0.3647 | g_loss: 2.6520
#       Before GAN: (17549, 768) | After GAN: (20140, 768)
#       Class distribution after GAN: {np.int64(0): np.int64(10070), np.int64(1): np.int64(10070)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6925
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6920
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6912
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6902
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6888
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6869
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6841
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6794
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6723
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6629
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6511
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6392
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6285
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6192
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6100
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6033
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.5965
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.5909
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.5861
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.5818
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.5795
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.5767
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.5739
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.5727
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.5704
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.5698
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.5677
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.5666
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.5656
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.5657
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.5646
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.5639
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.5637
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.5624
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.5616
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.5615
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.5609
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.5612
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.5599
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.5603
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.5613
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.5598
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.5586
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.5611
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.5592
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.5592
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.5594
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.5583
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.5589
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.5594
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5700
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5702
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5702
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.5693
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.5677
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.5682
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.5638
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.5635
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.5663
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.5586
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.5595
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.5553
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.5544
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.5518
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.5499
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.5458
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.5439
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.5404
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.5392
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.5380
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.5337
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.5352
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.5320
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.5304
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.5262
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.5236
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.5239
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.5207
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.5225
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.5170
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6927
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6922
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6917
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6910
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6901
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6888
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6868
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6840
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6796
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6733
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6637
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6515
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6382
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6253
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6148
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6057
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.5982
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.5922
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.5875
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.5835
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.5801
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.5767
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.5750
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.5734
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.5717
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.5700
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.5687
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.5685
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.5669
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.5669
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.5662
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.5663
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.5651
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.5646
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.5647
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.5635
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.5625
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.5626
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.5617
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.5609
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.5615
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.5610
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.5610
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.5615
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.5610
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.5610
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.5610
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.5606
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.5607
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.5600
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.5718
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.5729
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5750
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.5700
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.5684
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.5671
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.5642
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.5621
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.5606
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.5598
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.5579
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.5573
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.5555
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.5518
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.5515
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.5468
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.5452
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.5446
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.5424
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.5422
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.5374
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.5382
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.5338
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.5332
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.5294
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.5295
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.5275
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.5252
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.5217
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.5234
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.7005
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6996
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6985
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6968
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6946
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6919
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6886
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6845
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6797
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6740
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6673
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6601
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6526
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6451
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6372
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6296
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6230
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6151
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6083
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6019
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.5963
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.5913
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.5873
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.5841
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.5814
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.5800
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.5771
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.5761
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.5745
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.5735
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.5721
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.5718
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.5711
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.5695
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.5687
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.5684
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.5678
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.5680
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.5673
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.5667
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.5669
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.5658
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.5670
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.5656
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.5654
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.5655
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.5646
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.5647
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.5645
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.5635
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5720
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.5754
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.5766
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.5734
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.5716
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.5720
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.5691
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.5679
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.5681
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.5643
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.5619
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.5618
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.5590
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.5542
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.5538
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.5537
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.5506
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.5486
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.5460
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.5425
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.5398
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.5389
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.5374
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.5345
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.5306
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.5277
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.5260
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.5237
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.5218
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.5205
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.522
# Precision:  0.542
# Recall:     0.408
# F1-score:   0.465
# AUC:        0.543
# G-mean:     0.512
# PF value:   0.358
#
# Confusion Matrix:
# TN: 3073  FP: 1715
# FN: 2950  TP: 2031
#
# Results saved to results/gan.json
# Confusion matrix saved as results/confusion_matrix_gan.png
