# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Qemu -> Test on FFmpeg
SMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(-1), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(-1), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Qemu -> Testing on FFmpeg (SMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codebert/ffmpeg_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codebert/ffmpeg_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codebert/qemu_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codebert/qemu_labels.npy')
    print(f"      Qemu: {qmu_emb.shape} | FFmpeg: {ffm_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Applying SMOTE...")
    smote                       = SMOTE(random_state=SEED)
    qmu_emb_smote, qmu_lbl_smote = smote.fit_resample(qmu_emb, qmu_lbl)
    print(f"      Before SMOTE: {qmu_emb.shape} | After SMOTE: {qmu_emb_smote.shape}")
    unique, counts = np.unique(qmu_lbl_smote, return_counts=True)
    print(f"      Class distribution after SMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb_smote, qmu_lbl_smote,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_qmu_t      = torch.tensor(qmu_emb_smote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_qmu_t).squeeze(-1).cpu().numpy()

        sample_weights = np.where(qmu_lbl_smote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(qmu_emb_smote, qmu_lbl_smote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "smote",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "smote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_smote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Qemu -> Testing on FFmpeg (SMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Qemu: (17549, 768) | FFmpeg: (9769, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SMOTE...
#       Before SMOTE: (17549, 768) | After SMOTE: (20140, 768)
#       Class distribution after SMOTE: {np.int64(0): np.int64(10070), np.int64(1): np.int64(10070)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6937
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6933
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6929
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6924
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6918
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6909
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6898
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6886
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6873
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6859
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6844
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6829
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6814
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6796
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6779
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6763
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6748
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6731
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6715
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6701
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6682
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6669
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6651
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6634
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6623
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6607
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6589
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6572
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6555
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6538
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6525
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6509
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6495
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6477
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.6465
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.6451
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.6433
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.6424
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.6410
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.6396
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.6384
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.6377
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.6362
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.6351
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.6339
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.6325
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.6319
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.6319
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.6303
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.6302
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.6350
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.6374
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.6358
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.6349
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.6316
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.6314
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.6303
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.6268
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.6257
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.6222
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.6173
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.6150
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.6144
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.6102
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.6092
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.6057
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.6023
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.5990
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.5970
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.5958
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.5921
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.5895
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.5853
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.5833
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.5816
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.5794
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.5763
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.5751
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.5730
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.5686
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6939
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6934
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6929
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6923
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6916
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6908
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6898
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6888
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6876
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6863
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6850
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6836
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6823
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6809
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6795
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6782
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6766
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6750
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6732
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6716
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6698
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6678
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.6663
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.6647
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.6628
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.6616
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.6596
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.6576
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.6563
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.6545
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.6535
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.6517
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.6499
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.6486
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.6467
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.6459
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.6446
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.6433
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.6415
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.6407
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.6391
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.6384
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.6376
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.6366
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.6348
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.6341
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.6339
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.6326
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.6319
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.6310
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6391
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.6405
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.6385
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.6381
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.6375
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.6364
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.6328
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.6281
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.6272
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.6241
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.6200
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.6190
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.6154
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.6121
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.6100
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.6062
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.6011
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.6002
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.5981
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.5954
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.5931
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.5893
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.5880
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.5835
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.5795
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.5793
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.5749
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.5734
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.5692
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.5673
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6948
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6943
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6938
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6929
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6911
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6888
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6868
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6852
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6839
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6827
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6817
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6807
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6797
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6789
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6779
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6771
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6760
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6752
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6741
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6730
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.6717
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.6700
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.6693
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.6674
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.6660
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.6641
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.6625
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.6605
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.6591
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.6577
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.6551
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.6533
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.6519
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.6502
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.6484
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.6472
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.6452
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.6442
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.6437
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.6412
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.6400
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.6394
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.6381
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.6362
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.6346
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.6348
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.6329
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.6332
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.6315
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.6312
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.6376
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.6376
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.6374
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.6378
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.6332
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.6308
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.6273
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.6268
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.6227
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.6205
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.6184
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.6138
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.6134
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.6073
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.6067
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.6040
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.6009
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.5997
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.5963
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.5916
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.5902
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.5893
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.5844
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.5822
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.5813
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.5783
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.5755
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.5714
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.5703
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.5660
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.538
# Precision:  0.546
# Recall:     0.557
# F1-score:   0.551
# AUC:        0.562
# G-mean:     0.537
# PF value:   0.482
#
# Confusion Matrix:
# TN: 2482  FP: 2306
# FN: 2209  TP: 2772
#
# Results saved to results/smote.json
# Confusion matrix saved as results/confusion_matrix_smote.png
