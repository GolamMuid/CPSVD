# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on FFmpeg -> Test on Qemu
No Oversampling Baseline (Devign)
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation and Class Weights
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze()
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (criterion(val_preds, y_val) * weights).mean().item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss(reduction='none')

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Qemu Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on FFmpeg -> Testing on Qemu ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    ffm_emb = np.load('../../../../embedding/devign/codebert/ffmpeg_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codebert/ffmpeg_labels.npy')
    qmu_emb = np.load('../../../../embedding/devign/codebert/qemu_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codebert/qemu_labels.npy')
    print(f"      FFmpeg: {ffm_emb.shape} | Qemu: {qmu_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    ffm_emb = scaler.fit_transform(ffm_emb)
    qmu_emb = scaler.transform(qmu_emb)

    print("\n[3/5] Computing class weights...")
    classes           = np.unique(ffm_lbl)
    class_weights     = compute_class_weight(class_weight='balanced', classes=classes, y=ffm_lbl)
    class_weight_dict = {int(cls): float(w) for cls, w in zip(classes, class_weights)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(qmu_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            ffm_emb, ffm_lbl,
            qmu_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_ffm_t      = torch.tensor(ffm_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_ffm_t).squeeze().cpu().numpy()

        sample_weights = np.where(ffm_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(ffm_emb, ffm_lbl, class_weight_dict, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(qmu_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(qmu_lbl, y_pred_final)
    recall    = recall_score(qmu_lbl, y_pred_final)
    precision = precision_score(qmu_lbl, y_pred_final)
    auc       = roc_auc_score(qmu_lbl, ensemble_avg)
    f1        = f1_score(qmu_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(qmu_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Qemu Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "no_oversampling",
        "train"      : "ffmpeg",
        "test"       : "qemu",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "no_oversampling.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_no_oversampling.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on FFmpeg -> Testing on Qemu ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       FFmpeg: (9769, 768) | Qemu: (17549, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing class weights...
#       Class weights: {0: 1.02015455304929, 1: 0.9806263802449308}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6935
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6933
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6931
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6929
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6926
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6924
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6920
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6916
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6912
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6907
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6900
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6893
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6884
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6875
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6865
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6854
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6841
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6829
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6816
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6803
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6791
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6776
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6762
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6747
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6734
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6720
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6707
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6694
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6681
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6668
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6655
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6645
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6633
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6623
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.6615
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.6607
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.6598
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.6592
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.6585
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.6577
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.6570
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.6566
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.6559
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.6555
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.6550
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.6546
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.6540
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.6535
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.6532
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.6529
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.6925
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.7135
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.7271
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.7308
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.7369
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.7372
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.7347
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.7341
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.7342
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.7329
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.7315
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.7300
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.7255
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.7260
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.7226
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.7200
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.7157
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.7103
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.7096
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.7075
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.7054
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.7012
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.6976
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.6916
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.6897
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.6900
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.6839
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.6846
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.6801
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.6801
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6937
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6933
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6929
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6926
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6923
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6919
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6915
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6912
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6907
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6902
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6897
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6890
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6883
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6874
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6866
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6855
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6844
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6831
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6818
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6805
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6791
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6776
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.6762
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.6747
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.6732
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.6718
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.6704
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.6690
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.6674
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.6658
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.6644
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.6631
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.6620
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.6606
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.6599
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.6590
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.6578
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.6569
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.6562
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.6556
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.6547
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.6544
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.6538
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.6532
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.6528
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.6526
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.6520
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.6513
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.6510
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.6509
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6953
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.7204
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.7277
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.7290
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.7338
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.7337
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.7303
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.7309
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.7294
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.7256
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.7217
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.7222
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.7197
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.7150
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.7148
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.7109
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.7071
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.7007
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.6982
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.6978
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.6901
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.6873
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.6863
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.6838
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.6792
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.6797
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.6766
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.6732
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.6687
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.6660
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6955
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6953
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6951
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6949
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6946
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6943
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6940
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6935
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6927
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6917
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6904
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6886
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6866
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6847
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6827
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6809
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6791
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6775
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6759
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6745
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.6731
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.6720
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.6706
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.6693
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.6682
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.6672
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.6661
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.6650
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.6640
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.6629
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.6620
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.6611
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.6601
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.6591
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.6583
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.6576
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.6569
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.6560
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.6553
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.6547
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.6541
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.6535
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.6529
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.6525
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.6518
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.6512
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.6510
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.6509
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.6505
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.6500
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.7159
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.7324
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.7411
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.7327
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.7319
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.7284
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.7275
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.7252
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.7216
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.7166
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.7145
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.7115
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.7069
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.7030
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.6996
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.6976
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.6912
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.6902
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.6850
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.6812
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.6806
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.6721
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.6724
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.6692
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.6679
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.6636
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.6614
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.6612
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.6574
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.6569
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Qemu Test Set) ===
# Accuracy:   0.570
# Precision:  0.492
# Recall:     0.298
# F1-score:   0.371
# AUC:        0.553
# G-mean:     0.479
# PF value:   0.228
#
# Confusion Matrix:
# TN: 7776  FP: 2294
# FN: 5253  TP: 2226
#
# Results saved to results/no_oversampling.json
# Confusion matrix saved as results/confusion_matrix_no_oversampling.png
