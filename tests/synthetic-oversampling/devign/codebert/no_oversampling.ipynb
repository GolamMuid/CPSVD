# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on QEMU -> Test on FFmpeg
No Oversampling Baseline (Devign)
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(-1), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(
                model(x_val).squeeze(-1), y_val
            ).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} "
                  f"- val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1 — train on source (QEMU) only
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Generate pseudo-labels for target (FFmpeg)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2 — train on source + pseudo-labelled target
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost (no class weighting)
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Train: QEMU  |  Test: FFmpeg  |  No Oversampling ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    qmu_emb = np.load('../../../../embedding/devign/codebert/qemu_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codebert/qemu_labels.npy')
    ffm_emb = np.load('../../../../embedding/devign/codebert/ffmpeg_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codebert/ffmpeg_labels.npy')
    print(f"      QEMU (train): {qmu_emb.shape} | FFmpeg (test): {ffm_emb.shape}")

    print("\n[2/5] Normalising embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)   
    ffm_emb = scaler.transform(ffm_emb)        

    print("\n[3/5] Class distribution check...")
    unique, counts = np.unique(qmu_lbl, return_counts=True)
    print(f"      QEMU class distribution: {dict(zip(unique.astype(int), counts))}")
    unique, counts = np.unique(ffm_lbl, return_counts=True)
    print(f"      FFmpeg class distribution: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb, qmu_lbl,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_qmu_t      = torch.tensor(qmu_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_qmu_t).squeeze(-1).cpu().numpy()

        sample_weights = np.where(qmu_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(qmu_emb, qmu_lbl, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "no_oversampling",
        "train"      : "qemu",
        "test"       : "ffmpeg",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "no_oversampling.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_no_oversampling.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Train: QEMU  |  Test: FFmpeg  |  No Oversampling ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       QEMU (train): (17549, 768) | FFmpeg (test): (9769, 768)
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       QEMU class distribution: {np.int64(0): np.int64(10070), np.int64(1): np.int64(7479)}
#       FFmpeg class distribution: {np.int64(0): np.int64(4788), np.int64(1): np.int64(4981)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6882
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6870
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6855
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6837
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6817
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6798
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6785
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6773
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6763
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6754
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6746
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6739
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.6733
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.6726
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.6720
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.6713
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.6707
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.6700
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.6693
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.6689
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.6682
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.6674
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.6666
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.6664
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.6651
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.6648
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.6638
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.6630
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.6623
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.6617
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.6608
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.6601
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.6599
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.6589
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.6580
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.6576
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.6570
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.6559
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.6551
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.6546
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.6542
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.6538
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.6524
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.6528
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.6513
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.6510
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.6502
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.6488
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.6491
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.6480
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.6576
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.6615
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.6638
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.6637
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.6641
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.6620
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.6604
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.6590
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.6599
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.6557
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.6524
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.6499
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.6484
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.6476
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.6444
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.6448
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.6400
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.6375
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.6361
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.6336
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.6319
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.6297
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.6257
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.6228
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.6189
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.6183
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.6172
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.6140
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.6128
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.6109
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6878
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6864
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6850
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6833
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6817
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6801
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6788
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6777
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6768
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6760
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6752
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6744
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6740
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.6733
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.6727
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.6722
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.6716
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.6710
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.6705
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.6700
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.6696
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.6690
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.6684
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.6679
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.6675
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.6667
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.6660
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.6656
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.6649
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.6645
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.6640
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.6637
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.6628
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.6625
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.6612
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.6610
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.6600
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.6600
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.6592
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.6586
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.6580
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.6572
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.6568
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.6561
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.6545
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.6547
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.6536
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.6534
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.6522
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.6512
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6635
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.6626
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.6614
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.6628
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.6631
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.6640
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.6614
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.6584
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.6596
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.6549
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.6507
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.6526
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.6503
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.6471
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.6432
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.6405
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.6394
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.6346
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.6324
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.6315
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.6297
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.6273
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.6244
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.6250
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.6213
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.6163
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.6158
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.6129
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.6108
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.6073
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.7051
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.7035
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.7011
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6938
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6847
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6799
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6780
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6769
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6758
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6751
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6743
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6735
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.6728
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.6723
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.6716
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.6710
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.6707
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.6702
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.6695
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.6690
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.6684
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.6679
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.6673
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.6667
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.6663
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.6657
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.6650
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.6644
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.6639
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.6633
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.6625
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.6620
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.6609
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.6601
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.6594
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.6586
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.6578
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.6568
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.6566
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.6560
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.6552
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.6549
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.6543
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.6536
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.6525
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.6522
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.6514
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.6504
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.6501
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.6499
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.6654
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.6684
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.6682
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.6680
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.6652
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.6665
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.6632
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.6584
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.6570
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.6553
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.6532
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.6512
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.6497
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.6471
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.6451
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.6419
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.6410
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.6353
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.6337
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.6318
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.6299
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.6253
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.6246
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.6209
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.6192
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.6170
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.6137
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.6107
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.6093
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.6084
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.532
# Precision:  0.596
# Recall:     0.256
# F1-score:   0.358
# AUC:        0.569
# G-mean:     0.458
# PF value:   0.181
#
# Confusion Matrix:
# TN: 3923  FP: 865
# FN: 3705  TP: 1276
#
# Results saved to results/no_oversampling.json
# Confusion matrix saved as results/confusion_matrix_no_oversampling.png
