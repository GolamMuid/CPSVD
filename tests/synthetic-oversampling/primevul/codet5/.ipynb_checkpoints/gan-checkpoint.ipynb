# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux -> Test on linux
GAN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
TEST_PROJ  = "linux"
TRAIN_FILE  = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/gan"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on GAN-oversampled source (all-except-linux)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (linux)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled linux
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux -> Test on linux (GAN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT linux
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only linux from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (linux)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply GAN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying GAN...")
    minority_data = train_emb[train_lbl == 1]
    majority_data = train_emb[train_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority (vuln)  samples : {n_minority}")
    print(f"      Majority (benign) samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate, dtype=np.int32)
    train_emb_gan     = np.vstack((train_emb, synthetic_samples)).astype(np.float32)
    train_lbl_gan     = np.concatenate((train_lbl, synthetic_labels)).astype(np.int32)

    print(f"      Before GAN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After GAN  : {train_emb_gan.shape}  "
          f"vuln={train_lbl_gan.sum()}  benign={int((train_lbl_gan == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_gan, train_lbl_gan,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb             = train_base_model_xgb(train_emb_gan, train_lbl_gan)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "gan",
        "train"            : "all_except_linux",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_gan"      : int(len(train_lbl_gan)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_gan" : int(train_lbl_gan.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "gan_linux.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_gan_linux.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux -> Test on linux (GAN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Training pool             : (132585, 256)  vuln=3860  benign=128725
#       Projects in training pool : 630
#       Test set (linux)          : (4140, 256)  vuln=70  benign=4070
#       Training imbalance ratio  : 0.0291
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying GAN...
#       Minority (vuln)  samples : 3860
#       Majority (benign) samples: 128725
# GAN Training:   0%|          | 0/5000 [00:00<?, ?epoch/s]
#       GAN Epoch 0/5000 - d_loss: 0.6926 | g_loss: 0.7027
#       GAN Epoch 500/5000 - d_loss: 0.2336 | g_loss: 2.1605
#       GAN Epoch 1000/5000 - d_loss: 0.1322 | g_loss: 3.9583
#       GAN Epoch 1500/5000 - d_loss: 0.1040 | g_loss: 4.4187
#       GAN Epoch 2000/5000 - d_loss: 0.1027 | g_loss: 4.2413
#       GAN Epoch 2500/5000 - d_loss: 0.0442 | g_loss: 4.5564
#       GAN Epoch 3000/5000 - d_loss: 0.1243 | g_loss: 5.4649
#       GAN Epoch 3500/5000 - d_loss: 0.0138 | g_loss: 4.7087
#       GAN Epoch 4000/5000 - d_loss: 0.1596 | g_loss: 4.6474
#       GAN Epoch 4500/5000 - d_loss: 0.1056 | g_loss: 3.7952
#       Before GAN : (132585, 256)  vuln=3860  benign=128725
#       After GAN  : (257450, 256)  vuln=128725  benign=128725
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0686
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0627
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0603
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0592
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0583
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0577
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0574
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0571
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0570
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0568
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0566
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0564
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0564
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0565
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0550
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0543
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0539
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0534
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0532
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0526
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0523
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0519
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0515
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0511
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0508
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0504
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0499
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0495
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0487
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0486
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0482
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0478
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0473
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0468
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0464
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0461
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0460
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0457
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0452
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0452
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0446
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0851
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0650
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0615
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0600
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0590
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0582
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0578
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0574
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0571
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0570
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0569
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0568
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0568
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0569
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0570
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0570
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0570
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0571
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0576
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0557
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0551
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0547
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0545
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0537
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0535
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0529
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0525
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0524
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0518
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0518
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0511
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0507
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0503
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0502
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0500
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0492
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0489
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0478
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0473
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0470
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0467
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0462
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0464
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0451
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0450
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0449
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0442
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0683
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0626
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0607
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0592
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0583
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0580
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0575
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0573
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0571
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0569
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0569
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0568
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0568
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0568
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0568
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0569
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0569
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0571
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0571
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0573
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0572
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0574
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0573
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0556
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0552
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0543
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0534
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0527
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0525
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0521
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0517
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0505
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0502
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0498
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0497
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0495
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0481
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0482
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0480
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0473
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0471
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0464
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0463
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0450
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0446
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux Test Set) ===
# Accuracy  : 0.982
# Precision : 0.000
# Recall    : 0.000
# F1-score  : 0.000
# AUC       : 0.652
# G-mean    : 0.000
# PF value  : 0.001
#
# Confusion Matrix:
#   TN: 4067  FP: 3
#   FN: 70  TP: 0
#
# Results saved to results/gan_linux.json
# Confusion matrix saved as results/confusion_matrix_gan_linux.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT tensorflow -> Test on tensorflow
GAN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
TEST_PROJ  = "tensorflow"
TRAIN_FILE  = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/gan"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on GAN-oversampled source (all-except-tensorflow)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (tensorflow)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled tensorflow
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (tensorflow Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except tensorflow -> Test on tensorflow (GAN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT tensorflow
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only tensorflow from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (tensorflow)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply GAN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying GAN...")
    minority_data = train_emb[train_lbl == 1]
    majority_data = train_emb[train_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority (vuln)  samples : {n_minority}")
    print(f"      Majority (benign) samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate, dtype=np.int32)
    train_emb_gan     = np.vstack((train_emb, synthetic_samples)).astype(np.float32)
    train_lbl_gan     = np.concatenate((train_lbl, synthetic_labels)).astype(np.int32)

    print(f"      Before GAN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After GAN  : {train_emb_gan.shape}  "
          f"vuln={train_lbl_gan.sum()}  benign={int((train_lbl_gan == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_gan, train_lbl_gan,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb             = train_base_model_xgb(train_emb_gan, train_lbl_gan)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (tensorflow Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "gan",
        "train"            : "all_except_tensorflow",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_gan"      : int(len(train_lbl_gan)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_gan" : int(train_lbl_gan.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "gan_tensorflow.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_gan_tensorflow.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except tensorflow -> Test on tensorflow (GAN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Training pool             : (174708, 256)  vuln=4786  benign=169922
#       Projects in training pool : 630
#       Test set (tensorflow)          : (1313, 256)  vuln=91  benign=1222
#       Training imbalance ratio  : 0.0274
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying GAN...
#       Minority (vuln)  samples : 4786
#       Majority (benign) samples: 169922
# GAN Training:   0%|          | 0/5000 [00:00<?, ?epoch/s]
#       GAN Epoch 0/5000 - d_loss: 0.6749 | g_loss: 0.7039
#       GAN Epoch 500/5000 - d_loss: 0.2109 | g_loss: 2.1731
#       GAN Epoch 1000/5000 - d_loss: 0.1551 | g_loss: 3.5195
#       GAN Epoch 1500/5000 - d_loss: 0.1157 | g_loss: 4.0805
#       GAN Epoch 2000/5000 - d_loss: 0.0578 | g_loss: 4.4823
#       GAN Epoch 2500/5000 - d_loss: 0.0170 | g_loss: 4.7725
#       GAN Epoch 3000/5000 - d_loss: 0.1023 | g_loss: 4.2608
#       GAN Epoch 3500/5000 - d_loss: 0.0934 | g_loss: 4.0454
#       GAN Epoch 4000/5000 - d_loss: 0.0908 | g_loss: 4.4792
#       GAN Epoch 4500/5000 - d_loss: 0.0604 | g_loss: 4.3691
#       Before GAN : (174708, 256)  vuln=4786  benign=169922
#       After GAN  : (339844, 256)  vuln=169922  benign=169922
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0886
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0626
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0600
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0586
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0580
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0574
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0573
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0569
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0568
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0567
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0564
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0557
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0557
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0546
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0540
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0536
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0531
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0526
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0522
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0518
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0515
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0510
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0507
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0504
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0499
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0496
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0492
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0489
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0486
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0482
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0479
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0475
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0473
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0469
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0465
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0463
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0460
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0453
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0449
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0446
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0441
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0439
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0667
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0620
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0598
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0587
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0582
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0578
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0574
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0571
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0572
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0569
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0570
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0558
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0565
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0550
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0549
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0543
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0533
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0529
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0526
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0520
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0515
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0513
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0511
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0505
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0499
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0495
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0494
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0495
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0489
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0485
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0480
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0476
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0472
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0473
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0464
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0463
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0460
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0452
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0449
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0444
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0442
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0437
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0660
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0609
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0593
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0582
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0579
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0575
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0573
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0571
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0569
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0563
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0561
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0561
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0561
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0560
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0560
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0555
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0558
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0546
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0537
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0524
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0520
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0517
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0513
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0511
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0506
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0502
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0499
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0495
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0493
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0490
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0482
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0480
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0476
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0472
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0470
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0466
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0464
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0461
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0457
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0453
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0450
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0446
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0443
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (tensorflow Test Set) ===
# Accuracy  : 0.931
# Precision : 0.000
# Recall    : 0.000
# F1-score  : 0.000
# AUC       : 0.762
# G-mean    : 0.000
# PF value  : 0.000
#
# Confusion Matrix:
#   TN: 1222  FP: 0
#   FN: 91  TP: 0
#
# Results saved to results/gan_tensorflow.json
# Confusion matrix saved as results/confusion_matrix_gan_tensorflow.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
GAN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
TEST_PROJ  = "vim"
TRAIN_FILE  = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/gan"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on GAN-oversampled source (all-except-vim)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (vim)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled vim
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (GAN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT vim
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only vim from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply GAN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying GAN...")
    minority_data = train_emb[train_lbl == 1]
    majority_data = train_emb[train_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority (vuln)  samples : {n_minority}")
    print(f"      Majority (benign) samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate, dtype=np.int32)
    train_emb_gan     = np.vstack((train_emb, synthetic_samples)).astype(np.float32)
    train_lbl_gan     = np.concatenate((train_lbl, synthetic_labels)).astype(np.int32)

    print(f"      Before GAN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After GAN  : {train_emb_gan.shape}  "
          f"vuln={train_lbl_gan.sum()}  benign={int((train_lbl_gan == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_gan, train_lbl_gan,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb             = train_base_model_xgb(train_emb_gan, train_lbl_gan)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "gan",
        "train"            : "all_except_vim",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_gan"      : int(len(train_lbl_gan)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_gan" : int(train_lbl_gan.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "gan_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_gan_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (GAN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Training pool             : (174846, 256)  vuln=4824  benign=170022
#       Projects in training pool : 630
#       Test set (vim)          : (1669, 256)  vuln=61  benign=1608
#       Training imbalance ratio  : 0.0276
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying GAN...
#       Minority (vuln)  samples : 4824
#       Majority (benign) samples: 170022
# GAN Training:   0%|          | 0/5000 [00:00<?, ?epoch/s]
#       GAN Epoch 0/5000 - d_loss: 0.6929 | g_loss: 0.7033
#       GAN Epoch 500/5000 - d_loss: 0.2256 | g_loss: 2.0322
#       GAN Epoch 1000/5000 - d_loss: 0.1291 | g_loss: 3.8620
#       GAN Epoch 1500/5000 - d_loss: 0.0646 | g_loss: 3.8298
#       GAN Epoch 2000/5000 - d_loss: 0.0461 | g_loss: 4.4999
#       GAN Epoch 2500/5000 - d_loss: 0.1070 | g_loss: 4.4099
#       GAN Epoch 3000/5000 - d_loss: 0.1199 | g_loss: 4.7794
#       GAN Epoch 3500/5000 - d_loss: 0.0443 | g_loss: 5.1351
#       GAN Epoch 4000/5000 - d_loss: 0.1533 | g_loss: 5.2675
#       GAN Epoch 4500/5000 - d_loss: 0.0434 | g_loss: 4.0353
#       Before GAN : (174846, 256)  vuln=4824  benign=170022
#       After GAN  : (340044, 256)  vuln=170022  benign=170022
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0657
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0613
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0597
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0586
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0580
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0576
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0574
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0572
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0570
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0569
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0568
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0568
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0566
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0564
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0559
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0562
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0564
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0550
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0541
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0536
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0529
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0524
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0520
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0515
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0512
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0508
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0504
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0500
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0496
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0491
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0485
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0481
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0475
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0471
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0469
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0466
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0465
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0458
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0459
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0453
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0450
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0446
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0443
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0441
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0437
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0435
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0665
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0618
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0601
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0590
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0584
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0578
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0576
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0573
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0572
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0569
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0569
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0567
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0566
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0558
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0558
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0560
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0564
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0562
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0566
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0551
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0544
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0538
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0532
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0527
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0522
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0517
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0510
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0505
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0504
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0495
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0495
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0491
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0486
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0486
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0480
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0479
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0476
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0468
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0468
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0464
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0458
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0457
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0450
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0452
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0443
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0443
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0438
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0436
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0429
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0644
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0607
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0591
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0585
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0579
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0576
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0574
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0572
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0571
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0570
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0568
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0567
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0565
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0563
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0564
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0562
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0560
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0560
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0555
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0555
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0559
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0544
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0538
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0529
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0525
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0518
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0515
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0511
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0505
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0503
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0500
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0494
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0490
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0482
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0481
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0476
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0472
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0472
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0467
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0458
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0460
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0454
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0448
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0443
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0444
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0442
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0440
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0436
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (vim Test Set) ===
# Accuracy  : 0.962
# Precision : 0.200
# Recall    : 0.016
# F1-score  : 0.030
# AUC       : 0.709
# G-mean    : 0.128
# PF value  : 0.002
#
# Confusion Matrix:
#   TN: 1604  FP: 4
#   FN: 60  TP: 1
#
# Results saved to results/gan_vim.json
# Confusion matrix saved as results/confusion_matrix_gan_vim.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT gpac -> Test on gpac
GAN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
TEST_PROJ  = "gpac"
TRAIN_FILE  = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/gan"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on GAN-oversampled source (all-except-gpac)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (gpac)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled gpac
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (gpac Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except gpac -> Test on gpac (GAN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT gpac
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only gpac from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (gpac)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply GAN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying GAN...")
    minority_data = train_emb[train_lbl == 1]
    majority_data = train_emb[train_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority (vuln)  samples : {n_minority}")
    print(f"      Majority (benign) samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate, dtype=np.int32)
    train_emb_gan     = np.vstack((train_emb, synthetic_samples)).astype(np.float32)
    train_lbl_gan     = np.concatenate((train_lbl, synthetic_labels)).astype(np.int32)

    print(f"      Before GAN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After GAN  : {train_emb_gan.shape}  "
          f"vuln={train_lbl_gan.sum()}  benign={int((train_lbl_gan == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_gan, train_lbl_gan,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0475
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0474
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0470
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0467
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (gpac Test Set) ===
# Accuracy  : 0.990
# Precision : 0.000
# Recall    : 0.000
# F1-score  : 0.000
# AUC       : 0.812
# G-mean    : 0.000
# PF value  : 0.001
#
# Confusion Matrix:
#   TN: 1865  FP: 1
#   FN: 18  TP: 0
#
# Results saved to results/gan_gpac.json
# Confusion matrix saved as results/confusion_matrix_gan_gpac.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FreeRDP -> Test on FreeRDP
GAN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
TEST_PROJ  = "FreeRDP"
TRAIN_FILE  = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/gan"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Vulnerability Classifier
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# GAN
# =========================================================
class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.network(x)


class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_gan(minority_data, latent_dim=100, epochs=5000, batch_size=64):
    input_dim       = minority_data.shape[1]
    generator       = Generator(latent_dim, input_dim).to(DEVICE)
    discriminator   = Discriminator(input_dim).to(DEVICE)
    optimizer_g     = torch.optim.Adam(generator.parameters(),     lr=0.0002)
    optimizer_d     = torch.optim.Adam(discriminator.parameters(), lr=0.0002)
    criterion       = nn.BCELoss()
    minority_tensor = torch.tensor(minority_data, dtype=torch.float32).to(DEVICE)
    half_batch      = batch_size // 2

    for epoch in tqdm(range(epochs), desc="GAN Training", unit="epoch"):
        idx          = torch.randint(0, minority_tensor.shape[0], (half_batch,))
        real_samples = minority_tensor[idx]
        noise        = torch.randn(half_batch, latent_dim).to(DEVICE)
        fake_samples = generator(noise).detach()

        optimizer_d.zero_grad()
        real_loss = criterion(discriminator(real_samples), torch.ones(half_batch,  1).to(DEVICE))
        fake_loss = criterion(discriminator(fake_samples), torch.zeros(half_batch, 1).to(DEVICE))
        d_loss    = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_d.step()

        noise = torch.randn(batch_size, latent_dim).to(DEVICE)
        optimizer_g.zero_grad()
        g_loss = criterion(discriminator(generator(noise)), torch.ones(batch_size, 1).to(DEVICE))
        g_loss.backward()
        optimizer_g.step()

        if epoch % 500 == 0:
            print(f"      GAN Epoch {epoch}/{epochs} - d_loss: {d_loss.item():.4f} | g_loss: {g_loss.item():.4f}")

    return generator


def generate_synthetic_samples(generator, n_samples, latent_dim=100):
    generator.eval()
    with torch.no_grad():
        noise     = torch.randn(n_samples, latent_dim).to(DEVICE)
        synthetic = generator(noise).cpu().numpy()
    return synthetic


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on GAN-oversampled source (all-except-FreeRDP)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (FreeRDP)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled FreeRDP
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FreeRDP Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FreeRDP -> Test on FreeRDP (GAN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT FreeRDP
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only FreeRDP from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (FreeRDP)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply GAN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying GAN...")
    minority_data = train_emb[train_lbl == 1]
    majority_data = train_emb[train_lbl == 0]
    n_minority    = len(minority_data)
    n_majority    = len(majority_data)
    print(f"      Minority (vuln)  samples : {n_minority}")
    print(f"      Majority (benign) samples: {n_majority}")

    generator         = train_gan(minority_data)
    n_generate        = n_majority - n_minority
    synthetic_samples = generate_synthetic_samples(generator, n_generate)
    synthetic_labels  = np.ones(n_generate, dtype=np.int32)
    train_emb_gan     = np.vstack((train_emb, synthetic_samples)).astype(np.float32)
    train_lbl_gan     = np.concatenate((train_lbl, synthetic_labels)).astype(np.int32)

    print(f"      Before GAN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After GAN  : {train_emb_gan.shape}  "
          f"vuln={train_lbl_gan.sum()}  benign={int((train_lbl_gan == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_gan, train_lbl_gan,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_xgb             = train_base_model_xgb(train_emb_gan, train_lbl_gan)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FreeRDP Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "gan",
        "train"            : "all_except_FreeRDP",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_gan"      : int(len(train_lbl_gan)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_gan" : int(train_lbl_gan.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc