# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl"
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/smote/{HELD_OUT_CWE}"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup 
# =========================================================
def load_cwe_lookup(raw_path):
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading 
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on SMOTE-oversampled source
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the held-out CWE test set
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled target
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | LOCO (SMOTE): Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/7] Build CWE lookup and load combined embeddings
    # ----------------------------------------------------------
    print("\n[1/7] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/7] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    # ----------------------------------------------------------
    # [3/7] Build LOCO split
    # ----------------------------------------------------------
    print(f"\n[3/7] Splitting by CWE (held-out: {HELD_OUT_CWE})...")

    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set ({HELD_OUT_CWE})         : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [4/7] Normalize
    # ----------------------------------------------------------
    print("\n[4/7] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [5/7] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[5/7] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [6/7] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[6/7] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_sm, train_lbl_sm,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_sm, train_lbl_sm, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [7/7] Metrics
    # ----------------------------------------------------------
    print("\n[7/7] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "smote",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | LOCO (SMOTE): Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/7] Building CWE lookup from raw file...
#
# [2/7] Loading combined embeddings with CWE join...
#
# [3/7] Splitting by CWE (held-out: CWE-787)...
#       Training pool             : (180323, 768)  vuln=5500  benign=174823
#       Test set (CWE-787)         : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio  : 0.0305
#
# [4/7] Normalizing embeddings...
#
# [5/7] Applying SMOTE oversampling...
#       Before SMOTE : (180323, 768)  vuln=5500  benign=174823
#       After SMOTE  : (349646, 768)  vuln=174823  benign=174823
#
# [6/7] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5346
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4861
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4505
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4234
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3969
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3743
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3529
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3322
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.3107
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2936
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2765
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2620
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2489
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2392
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.2248
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.2198
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.2048
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1972
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1895
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1837
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1761
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1689
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1616
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1584
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1548
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1485
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1416
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1416
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1361
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1326
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1283
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1278
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1214
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1223
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1191
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1157
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1151
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1094
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1076
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0983
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0986
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0966
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0957
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0953
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0926
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0915
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0889
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0905
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0857
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0813
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0794
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0785
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0728
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0703
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0702
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0656
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0699
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0642
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0684
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0671
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0666
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0595
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0552
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0580
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0590
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0579
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0535
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0515
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0510
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0503
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0478
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0487
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0480
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0480
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0462
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0465
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0468
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5265
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4732
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4363
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.4087
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3847
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3570
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3349
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.3158
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2955
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2783
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2626
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2484
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2410
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.2234
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.2137
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.2020
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1927
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1889
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1833
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1701
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1630
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1563
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1527
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1490
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1426
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1406
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1345
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1307
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1327
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1254
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1223
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1164
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1133
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1185
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1137
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1062
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1087
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1067
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1024
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1008
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0951
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0994
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0958
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0904
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0916
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0876
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0874
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0857
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0917
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0760
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0773
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0700
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0713
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0683
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0711
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0775
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0629
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0610
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0587
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0594
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0574
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0570
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0559
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0575
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0550
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0544
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0515
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0508
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0512
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0493
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0495
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0477
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0475
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0474
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0467
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0593
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0487
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0443
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5291
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4822
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4479
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4236
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.4024
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3797
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3591
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3389
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.3174
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.3004
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2827
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2672
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2605
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2395
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.2278
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.2163
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.2068
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1972
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1905
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1812
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1795
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1685
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1620
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1611
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1547
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1477
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1525
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1375
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1349
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1301
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1318
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1293
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1251
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1252
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1149
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1120
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1106
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1033
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1008
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0973
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1117
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0955
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0976
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0917
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0945
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1015
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0882
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0845
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0799
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0829
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0938
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0739
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0765
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0667
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0666
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0641
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0638
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0611
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0667
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0584
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0603
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0636
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0574
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0572
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0518
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0530
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0513
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0470
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0552
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0568
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0471
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0474
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0439
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [7/7] Computing metrics...
#
# === Evaluation Results (CWE-787 Test Set) ===
# Accuracy  : 0.791
# Precision : 0.038
# Recall    : 0.706
# F1-score  : 0.072
# AUC       : 0.824
# G-mean    : 0.748
# PF value  : 0.208
#
# Confusion Matrix:
#   TN: 34622  FP: 9084
#   FN: 148  TP: 356
#
# Results saved to results/smote/CWE-787/smote_CWE-787.json
# Confusion matrix saved as results/smote/CWE-787/confusion_matrix_smote_CWE-787.png
