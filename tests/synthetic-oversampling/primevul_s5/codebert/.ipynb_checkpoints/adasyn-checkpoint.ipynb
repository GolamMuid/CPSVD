# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl"
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/adasyn/{HELD_OUT_CWE}"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup 
# =========================================================
def load_cwe_lookup(raw_path):
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading 
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the held-out CWE test set
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled target
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | LOCO (ADASYN): Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/7] Build CWE lookup and load combined embeddings
    # ----------------------------------------------------------
    print("\n[1/7] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/7] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    # ----------------------------------------------------------
    # [3/7] Build LOCO split
    # ----------------------------------------------------------
    print(f"\n[3/7] Splitting by CWE (held-out: {HELD_OUT_CWE})...")

    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set ({HELD_OUT_CWE})         : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [4/7] Normalize
    # ----------------------------------------------------------
    print("\n[4/7] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [5/7] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[5/7] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [6/7] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[6/7] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [7/7] Metrics
    # ----------------------------------------------------------
    print("\n[7/7] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "adasyn",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"adasyn_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_adasyn_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | LOCO (ADASYN): Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/7] Building CWE lookup from raw file...
#
# [2/7] Loading combined embeddings with CWE join...
#
# [3/7] Splitting by CWE (held-out: CWE-787)...
#       Training pool             : (180323, 768)  vuln=5500  benign=174823
#       Test set (CWE-787)         : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio  : 0.0305
#
# [4/7] Normalizing embeddings...
#
# [5/7] Applying ADASYN oversampling...
#       Before ADASYN : (180323, 768)  vuln=5500  benign=174823
#       After ADASYN  : (348873, 768)  vuln=174050  benign=174823
#
# [6/7] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5517
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4953
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4575
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4307
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3997
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3746
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3501
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3277
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.3085
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2899
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2762
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2593
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2451
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2349
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.2229
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.2127
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.2019
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1954
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1875
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1825
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1733
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1681
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1631
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1657
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1498
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1459
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1427
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1366
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1357
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1292
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1279
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1217
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1174
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1158
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1122
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1096
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1022
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0984
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0969
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0962
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0956
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0929
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0900
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0897
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0972
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0882
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0826
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0840
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0792
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0740
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0752
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0719
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0675
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0687
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0645
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0613
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0702
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0668
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0582
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0577
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0564
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0532
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0538
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0533
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0561
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0542
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0495
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0484
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0521
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0494
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0460
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0448
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0432
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0455
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0433
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5444
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4818
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4435
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.4109
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3811
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3552
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3328
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.3113
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2909
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2728
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2565
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2450
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2306
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.2243
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.2065
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1978
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1878
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1899
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1735
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1654
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1649
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1641
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1490
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1427
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1424
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1430
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1291
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1261
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1246
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1193
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1163
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1135
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1124
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1103
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0980
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1005
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0968
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0988
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0933
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0944
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0900
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0892
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0899
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0839
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0824
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0812
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0843
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0877
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0782
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0714
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0717
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0739
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0690
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0655
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0662
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0616
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0598
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0577
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0688
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0575
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0580
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0540
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0537
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0604
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0521
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0515
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0508
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0589
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0496
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0489
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0491
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0477
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0472
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0468
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0451
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0445
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5483
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4939
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4572
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4308
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.4046
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3816
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3574
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3333
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.3125
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2980
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2762
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2594
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2458
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2402
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.2193
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.2114
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.2001
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1912
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1822
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1763
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1688
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1633
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1572
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1557
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1463
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1472
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1363
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1335
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1309
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1256
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1224
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1250
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1152
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1126
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1110
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1070
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1140
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1013
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0981
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0966
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0937
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0954
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0918
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0917
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0966
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0880
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0850
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0838
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0883
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0768
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0767
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0759
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0724
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0677
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0730
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0630
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0645
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0597
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0580
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0603
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0630
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0590
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0554
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0576
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0525
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0507
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0494
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0503
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0496
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0448
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0451
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0483
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0497
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0531
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0433
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [7/7] Computing metrics...
#
# === Evaluation Results (CWE-787 Test Set) ===
# Accuracy  : 0.779
# Precision : 0.035
# Recall    : 0.692
# F1-score  : 0.067
# AUC       : 0.815
# G-mean    : 0.735
# PF value  : 0.220
#
# Confusion Matrix:
#   TN: 34070  FP: 9636
#   FN: 155  TP: 349
#
# Results saved to results/adasyn/CWE-787/adasyn_CWE-787.json
# Confusion matrix saved as results/adasyn/CWE-787/confusion_matrix_adasyn_CWE-787.png
