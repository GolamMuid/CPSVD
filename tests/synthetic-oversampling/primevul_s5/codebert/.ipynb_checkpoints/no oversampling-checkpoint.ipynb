# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
No Oversampling, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl" 
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/no_oversampling_with_classweight/{HELD_OUT_CWE}"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup (from raw PrimeVul file)
# =========================================================
def load_cwe_lookup(raw_path):
    """
    Builds a dict {idx: cwe_string_or_None} from the raw PrimeVul JSONL,
    which contains 'cwe' (and 'cve') fields not present in the embedding file.
    """
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            # PrimeVul stores cwe as a list, e.g. ["CWE-787"]; take the first if present
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading (with CWE join)
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Neural Network (unchanged)
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation and Class Weights (unchanged)
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze()
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning (unchanged logic)
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss(reduction='none')

    # Phase 1: Train on source (all CWEs except held-out)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1",
        class_weights=class_weights
    )

    # Pseudo-label the held-out CWE test set
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled target
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost (unchanged)
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Leave-One-CWE-Out: Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Build CWE lookup and load combined embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/6] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    # ----------------------------------------------------------
    # [3/6] Build LOCO split
    # ----------------------------------------------------------
    print(f"\n[3/6] Splitting by CWE (held-out: {HELD_OUT_CWE})...")

    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set ({HELD_OUT_CWE})         : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [4/6] Normalize
    # ----------------------------------------------------------
    print("\n[4/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [5/6] Class weights
    # ----------------------------------------------------------
    print("\n[5/6] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [6/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[6/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # Metrics
    # ----------------------------------------------------------
    print("\n[Metrics] Computing evaluation metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "no_oversampling_with_classweight",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"no_oversampling_with_classweight_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_no_oversampling_with_classweight_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Leave-One-CWE-Out: Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/6] Building CWE lookup from raw file...
#
# [2/6] Loading combined embeddings with CWE join...
#
# [3/6] Splitting by CWE (held-out: CWE-787)...
#       Training pool             : (180323, 768)  vuln=5500  benign=174823
#       Test set (CWE-787)         : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio  : 0.0305
#
# [4/6] Normalizing embeddings...
#
# [5/6] Computing class weights...
#       Class weights: {0: 0.5157301956836343, 1: 16.393}
#
# [6/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6097
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.5785
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.5715
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.5629
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.5568
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.5511
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.5456
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.5422
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.5375
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.5348
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.5309
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.5273
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.5249
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.5249
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.5198
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.5193
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.5166
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.5142
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.5137
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.5117
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.5107
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.5096
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.5089
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.5096
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.5095
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.5082
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.5073
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.5116
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.5096
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.5099
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.5100
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.5115
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.5112
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.5116
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.5128
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.5150
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.5134
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.5175
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.5161
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.5169
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.5218
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.5206
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.5176
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.5211
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.5244
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.5295
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.5277
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.5307
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.5317
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.5370
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5796
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5732
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5785
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.5474
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.5519
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.5393
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.5365
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.5364
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.5253
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.5190
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.5050
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.5193
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.5204
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.5222
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.5072
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.4969
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.4939
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.4939
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.4942
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.4810
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.4741
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.4849
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.4692
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.4788
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.4628
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.4605
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.4639
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.4532
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.4623
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.4548
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5892
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.5754
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.5672
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.5606
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.5545
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.5488
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.5427
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.5386
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.5348
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.5306
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.5285
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.5250
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.5216
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.5190
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.5182
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.5149
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.5126
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.5113
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.5101
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.5105
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.5100
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.5075
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.5084
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.5083
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.5083
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.5093
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.5095
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.5106
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.5086
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.5081
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.5122
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.5117
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.5115
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.5140
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.5211
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.5165
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.5260
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.5202
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.5168
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.5215
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.5389
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.5287
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.5275
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.5281
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.5393
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.5297
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.5399
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.5407
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.5428
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.5573
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.6033
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.5785
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5669
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.5730
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.5510
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.5425
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.5402
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.5298
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.5136
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.5137
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.5099
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.4983
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.4941
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.4901
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.4869
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.4901
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.4859
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.4920
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.4678
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.4702
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.4632
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.4678
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.4564
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.4519
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.4509
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.4699
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.4445
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.4406
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.4314
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.4328
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5937
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.5778
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.5663
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.5595
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.5540
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.5490
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.5437
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.5397
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.5367
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.5320
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.5295
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.5291
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.5230
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.5202
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.5181
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.5174
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.5144
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.5146
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.5136
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.5107
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.5093
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.5087
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.5076
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.5076
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.5081
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.5066
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.5089
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.5066
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.5061
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.5071
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.5074
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.5094
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.5092
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.5104
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.5122
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.5105
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.5098
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.5090
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.5117
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.5114
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.5118
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.5132
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.5206
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.5178
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.5154
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.5218
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.5212
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.5215
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.5270
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.5252
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5691
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.5529
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.5360
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.5594
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.5467
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.5181
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.5428
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.5197
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.5192
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.5164
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.5171
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.5219
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.5099
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.4889
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.5098
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.4954
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.5108
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.4862
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.4846
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.4659
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.4873
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.4591
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.4622
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.4564
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.4592
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.4408
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.4422
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.4306
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.4275
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.4316
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [Metrics] Computing evaluation metrics...
#
# === Evaluation Results (CWE-787 Test Set) ===
# Accuracy  : 0.693
# Precision : 0.031
# Recall    : 0.843
# F1-score  : 0.059
# AUC       : 0.842
# G-mean    : 0.763
# PF value  : 0.309
#
# Confusion Matrix:
#   TN: 30207  FP: 13499
#   FN: 79  TP: 425
#
# Results saved to results/no_oversampling_with_classweight/CWE-787/no_oversampling_with_classweight_CWE-787.json
# Confusion matrix saved as results/no_oversampling_with_classweight/CWE-787/confusion_matrix_no_oversampling_with_classweight_CWE-787.png
