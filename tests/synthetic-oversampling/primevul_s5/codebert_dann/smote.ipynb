# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
SMOTE Oversampling, With Class Weighting, WITH Domain-Adversarial Neural Network (DANN)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl"
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/smote_with_classweight_dann/{HELD_OUT_CWE}"

# DANN-specific
LAMBDA_MAX   = 1.0   # max weight for domain loss (GRL strength ceiling)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup 
# =========================================================
def load_cwe_lookup(raw_path):
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading 
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.lambda_ * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self, lambda_=1.0):
        super().__init__()
        self.lambda_ = lambda_

    def forward(self, x):
        return GradientReversalFunction.apply(x, self.lambda_)

    def set_lambda(self, lambda_):
        self.lambda_ = lambda_


# =========================================================
# DANN Architecture: FeatureExtractor + ClassifierHead + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # shared embedding, dim=64


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.grl = GradientReversalLayer(lambda_=1.0)
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        reversed_features = self.grl(features)
        return self.network(reversed_features)


# =========================================================
# DANN Training Loop
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val,
                class_weights, epochs, desc):
    """
    x_source/y_source : SMOTE-oversampled labeled training pool (source domain)
    x_target          : UNLABELED held-out CWE test set (used only for domain adaptation)
    """
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    label_criterion  = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    source_dataset = TensorDataset(
        torch.tensor(x_source, dtype=torch.float32),
        torch.tensor(y_source, dtype=torch.float32)
    )
    target_dataset = TensorDataset(
        torch.tensor(x_target, dtype=torch.float32)
    )

    batch_size = 64
    source_loader = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=batch_size, shuffle=True)

    n_batches = max(len(source_loader), len(target_loader))

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        p = epoch / max(epochs - 1, 1)
        lambda_ = (2.0 / (1.0 + np.exp(-10 * p)) - 1.0) * LAMBDA_MAX
        domain_discriminator.grl.set_lambda(lambda_)

        source_iter = iter(source_loader)
        target_iter = iter(target_loader)

        for _ in range(n_batches):
            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(source_loader)
                x_s, y_s = next(source_iter)
            try:
                (x_t,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (x_t,) = next(target_iter)

            x_s, y_s = x_s.to(DEVICE), y_s.to(DEVICE)
            x_t = x_t.to(DEVICE)

            optimizer.zero_grad()

            # --- Label prediction loss (source only) ---
            features_s = feature_extractor(x_s)
            label_pred = classifier_head(features_s).squeeze()
            weights    = torch.where(y_s == 1, pos_weight, neg_weight)
            label_loss = (label_criterion(label_pred, y_s) * weights).mean()

            # --- Domain discrimination loss (source + target) ---
            features_t = feature_extractor(x_t)
            domain_pred_s = domain_discriminator(features_s).squeeze()
            domain_pred_t = domain_discriminator(features_t).squeeze()

            domain_labels_s = torch.zeros(domain_pred_s.shape[0]).to(DEVICE)  # source = 0
            domain_labels_t = torch.ones(domain_pred_t.shape[0]).to(DEVICE)   # target = 1

            domain_loss = (domain_criterion(domain_pred_s, domain_labels_s) +
                            domain_criterion(domain_pred_t, domain_labels_t))

            total_loss = label_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (label_criterion(val_preds, y_val) * weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"label_loss: {label_loss.item():.4f} - domain_loss: {domain_loss.item():.4f} - "
              f"val_loss: {val_loss:.4f} - lambda: {lambda_:.3f}")

    return feature_extractor, classifier_head, domain_discriminator


# =========================================================
# XGBoost (trained on domain-invariant FEATURES, not raw embeddings)
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])
    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set) - SMOTE + DANN")
    plt.colorbar(img, ax=ax)
    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | LOCO + SMOTE + DANN: Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/7] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/7] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    print(f"\n[3/7] Splitting by CWE (held-out: {HELD_OUT_CWE})...")
    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)  # only used for FINAL evaluation, never during training

    print(f"      Training pool (source, pre-SMOTE) : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set / target ({HELD_OUT_CWE})        : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio          : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[4/7] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    print("\n[5/7] Applying SMOTE to source training pool...")
    smote = SMOTE(random_state=SEED)
    train_emb, train_lbl = smote.fit_resample(train_emb, train_lbl)
    train_emb = train_emb.astype(np.float32)
    train_lbl = train_lbl.astype(np.int32)
    print(f"      Training pool (post-SMOTE)        : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")

    print("\n[6/7] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(class_weight='balanced', classes=classes, y=train_lbl)
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[7/7] Running DANN + ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN...")

        x_tr, x_val, y_tr, y_val = train_test_split(
            train_emb, train_lbl, test_size=0.2, random_state=SEED
        )
        x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
        y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

        feature_extractor     = FeatureExtractor(train_emb.shape[1]).to(DEVICE)
        classifier_head       = ClassifierHead(feature_dim=64).to(DEVICE)
        domain_discriminator  = DomainDiscriminator(feature_dim=64).to(DEVICE)

        feature_extractor, classifier_head, domain_discriminator = train_dann(
            feature_extractor, classifier_head, domain_discriminator,
            x_source=x_tr, y_source=y_tr,
            x_target=test_emb,          # unlabeled target domain, used only for domain loss
            x_val=x_val_t, y_val=y_val_t,
            class_weights=class_weight_dict,
            epochs=50,
            desc=f"Iter {i+1} - DANN"
        )

        feature_extractor.eval()
        with torch.no_grad():
            train_features = feature_extractor(
                torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()
            test_features = feature_extractor(
                torch.tensor(test_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()

            y_train_pred = classifier_head(
                torch.tensor(train_features, dtype=torch.float32).to(DEVICE)
            ).squeeze().cpu().numpy()

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost on DANN features...")
        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(
            train_features, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_features)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[Metrics] Computing evaluation metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) - SMOTE + DANN ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "smote_with_classweight_dann",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_with_classweight_dann_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_with_classweight_dann_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | LOCO + SMOTE + DANN: Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/7] Building CWE lookup from raw file...
#
# [2/7] Loading combined embeddings with CWE join...
#
# [3/7] Splitting by CWE (held-out: CWE-787)...
#       Training pool (source, pre-SMOTE) : (180323, 768)  vuln=5500  benign=174823
#       Test set / target (CWE-787)        : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio          : 0.0305
#
# [4/7] Normalizing embeddings...
#
# [5/7] Applying SMOTE to source training pool...
#       Training pool (post-SMOTE)        : (349646, 768)  vuln=174823  benign=174823
#
# [6/7] Computing class weights...
#       Class weights: {0: 1.0, 1: 1.0}
#
# [7/7] Running DANN + ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN...
# Iter 1 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - DANN | Epoch 1/50 - label_loss: 0.5737 - domain_loss: 1.2765 - val_loss: 0.5297 - lambda: 0.000
#       Iter 1 - DANN | Epoch 2/50 - label_loss: 0.6916 - domain_loss: 1.3029 - val_loss: 0.4835 - lambda: 0.102
#       Iter 1 - DANN | Epoch 3/50 - label_loss: 0.4234 - domain_loss: 1.2950 - val_loss: 0.4459 - lambda: 0.201
#       Iter 1 - DANN | Epoch 4/50 - label_loss: 0.4005 - domain_loss: 1.1678 - val_loss: 0.4244 - lambda: 0.297
#       Iter 1 - DANN | Epoch 5/50 - label_loss: 0.3979 - domain_loss: 1.1460 - val_loss: 0.4022 - lambda: 0.387
#       Iter 1 - DANN | Epoch 6/50 - label_loss: 0.4107 - domain_loss: 1.2509 - val_loss: 0.3828 - lambda: 0.470
#       Iter 1 - DANN | Epoch 7/50 - label_loss: 0.4822 - domain_loss: 1.2015 - val_loss: 0.3656 - lambda: 0.546
#       Iter 1 - DANN | Epoch 8/50 - label_loss: 0.3182 - domain_loss: 1.3005 - val_loss: 0.3568 - lambda: 0.613
#       Iter 1 - DANN | Epoch 9/50 - label_loss: 0.3313 - domain_loss: 1.2690 - val_loss: 0.3408 - lambda: 0.673
#       Iter 1 - DANN | Epoch 10/50 - label_loss: 0.3797 - domain_loss: 1.3524 - val_loss: 0.3454 - lambda: 0.725
#       Iter 1 - DANN | Epoch 11/50 - label_loss: 0.3700 - domain_loss: 1.3303 - val_loss: 0.3216 - lambda: 0.770
#       Iter 1 - DANN | Epoch 12/50 - label_loss: 0.2543 - domain_loss: 1.3864 - val_loss: 0.3039 - lambda: 0.808
#       Iter 1 - DANN | Epoch 13/50 - label_loss: 0.3756 - domain_loss: 1.3011 - val_loss: 0.2922 - lambda: 0.841
#       Iter 1 - DANN | Epoch 14/50 - label_loss: 0.3601 - domain_loss: 1.3616 - val_loss: 0.2869 - lambda: 0.868
#       Iter 1 - DANN | Epoch 15/50 - label_loss: 0.4376 - domain_loss: 1.3074 - val_loss: 0.2727 - lambda: 0.891
#       Iter 1 - DANN | Epoch 16/50 - label_loss: 0.3631 - domain_loss: 1.2755 - val_loss: 0.2641 - lambda: 0.911
#       Iter 1 - DANN | Epoch 17/50 - label_loss: 0.1716 - domain_loss: 1.3175 - val_loss: 0.2570 - lambda: 0.926
#       Iter 1 - DANN | Epoch 18/50 - label_loss: 0.3862 - domain_loss: 1.2670 - val_loss: 0.2493 - lambda: 0.940
#       Iter 1 - DANN | Epoch 19/50 - label_loss: 0.3425 - domain_loss: 1.2297 - val_loss: 0.2421 - lambda: 0.950
#       Iter 1 - DANN | Epoch 20/50 - label_loss: 0.1835 - domain_loss: 1.3894 - val_loss: 0.2339 - lambda: 0.959
#       Iter 1 - DANN | Epoch 21/50 - label_loss: 0.3603 - domain_loss: 1.3073 - val_loss: 0.2348 - lambda: 0.967
#       Iter 1 - DANN | Epoch 22/50 - label_loss: 0.1428 - domain_loss: 1.4342 - val_loss: 0.2187 - lambda: 0.973
#       Iter 1 - DANN | Epoch 23/50 - label_loss: 0.3549 - domain_loss: 1.3172 - val_loss: 0.2149 - lambda: 0.978
#       Iter 1 - DANN | Epoch 24/50 - label_loss: 0.2350 - domain_loss: 1.3630 - val_loss: 0.2248 - lambda: 0.982
#       Iter 1 - DANN | Epoch 25/50 - label_loss: 0.2594 - domain_loss: 1.4000 - val_loss: 0.2079 - lambda: 0.985
#       Iter 1 - DANN | Epoch 26/50 - label_loss: 0.2774 - domain_loss: 1.4019 - val_loss: 0.2062 - lambda: 0.988
#       Iter 1 - DANN | Epoch 27/50 - label_loss: 0.2227 - domain_loss: 1.3511 - val_loss: 0.2069 - lambda: 0.990
#       Iter 1 - DANN | Epoch 28/50 - label_loss: 0.3864 - domain_loss: 1.3276 - val_loss: 0.2001 - lambda: 0.992
#       Iter 1 - DANN | Epoch 29/50 - label_loss: 0.1295 - domain_loss: 1.3041 - val_loss: 0.1949 - lambda: 0.993
#       Iter 1 - DANN | Epoch 30/50 - label_loss: 0.2526 - domain_loss: 1.3389 - val_loss: 0.2174 - lambda: 0.995
#       Iter 1 - DANN | Epoch 31/50 - label_loss: 0.2201 - domain_loss: 1.3079 - val_loss: 0.1980 - lambda: 0.996
#       Iter 1 - DANN | Epoch 32/50 - label_loss: 0.1592 - domain_loss: 1.5727 - val_loss: 0.1904 - lambda: 0.996
#       Iter 1 - DANN | Epoch 33/50 - label_loss: 0.1133 - domain_loss: 1.1839 - val_loss: 0.2006 - lambda: 0.997
#       Iter 1 - DANN | Epoch 34/50 - label_loss: 0.2524 - domain_loss: 1.2896 - val_loss: 0.2113 - lambda: 0.998
#       Iter 1 - DANN | Epoch 35/50 - label_loss: 0.2093 - domain_loss: 1.2149 - val_loss: 0.2048 - lambda: 0.998
#       Iter 1 - DANN | Epoch 36/50 - label_loss: 0.1960 - domain_loss: 1.3581 - val_loss: 0.2348 - lambda: 0.998
#       Iter 1 - DANN | Epoch 37/50 - label_loss: 0.1556 - domain_loss: 1.3286 - val_loss: 0.2073 - lambda: 0.999
#       Iter 1 - DANN | Epoch 38/50 - label_loss: 0.1778 - domain_loss: 1.3255 - val_loss: 0.2272 - lambda: 0.999
#       Iter 1 - DANN | Epoch 39/50 - label_loss: 0.3246 - domain_loss: 1.1521 - val_loss: 0.2178 - lambda: 0.999
#       Iter 1 - DANN | Epoch 40/50 - label_loss: 0.2329 - domain_loss: 1.2221 - val_loss: 0.2115 - lambda: 0.999
#       Iter 1 - DANN | Epoch 41/50 - label_loss: 0.2479 - domain_loss: 1.2367 - val_loss: 0.2231 - lambda: 0.999
#       Iter 1 - DANN | Epoch 42/50 - label_loss: 0.0565 - domain_loss: 1.4514 - val_loss: 0.2032 - lambda: 1.000
#       Iter 1 - DANN | Epoch 43/50 - label_loss: 0.1485 - domain_loss: 1.2455 - val_loss: 0.2223 - lambda: 1.000
#       Iter 1 - DANN | Epoch 44/50 - label_loss: 0.0863 - domain_loss: 1.1997 - val_loss: 0.1921 - lambda: 1.000
#       Iter 1 - DANN | Epoch 45/50 - label_loss: 0.4765 - domain_loss: 1.1964 - val_loss: 0.1991 - lambda: 1.000
#       Iter 1 - DANN | Epoch 46/50 - label_loss: 0.2069 - domain_loss: 1.2193 - val_loss: 0.1975 - lambda: 1.000
#       Iter 1 - DANN | Epoch 47/50 - label_loss: 0.3046 - domain_loss: 1.1516 - val_loss: 0.2078 - lambda: 1.000
#       Iter 1 - DANN | Epoch 48/50 - label_loss: 0.1492 - domain_loss: 1.2936 - val_loss: 0.2215 - lambda: 1.000
#       Iter 1 - DANN | Epoch 49/50 - label_loss: 0.2331 - domain_loss: 1.3653 - val_loss: 0.2111 - lambda: 1.000
#       Iter 1 - DANN | Epoch 50/50 - label_loss: 0.3086 - domain_loss: 1.2153 - val_loss: 0.2055 - lambda: 1.000
#       [Iteration 1/3] Training XGBoost on DANN features...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN...
# Iter 2 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - DANN | Epoch 1/50 - label_loss: 0.4699 - domain_loss: 1.2335 - val_loss: 0.5239 - lambda: 0.000
#       Iter 2 - DANN | Epoch 2/50 - label_loss: 0.4361 - domain_loss: 1.3568 - val_loss: 0.4803 - lambda: 0.102
#       Iter 2 - DANN | Epoch 3/50 - label_loss: 0.5112 - domain_loss: 1.2687 - val_loss: 0.4489 - lambda: 0.201
#       Iter 2 - DANN | Epoch 4/50 - label_loss: 0.3177 - domain_loss: 1.3935 - val_loss: 0.4244 - lambda: 0.297
#       Iter 2 - DANN | Epoch 5/50 - label_loss: 0.3254 - domain_loss: 1.4400 - val_loss: 0.4034 - lambda: 0.387
#       Iter 2 - DANN | Epoch 6/50 - label_loss: 0.3577 - domain_loss: 1.2033 - val_loss: 0.3872 - lambda: 0.470
#       Iter 2 - DANN | Epoch 7/50 - label_loss: 0.4686 - domain_loss: 1.2113 - val_loss: 0.3712 - lambda: 0.546
#       Iter 2 - DANN | Epoch 8/50 - label_loss: 0.5694 - domain_loss: 1.3669 - val_loss: 0.3591 - lambda: 0.613
#       Iter 2 - DANN | Epoch 9/50 - label_loss: 0.4436 - domain_loss: 1.3679 - val_loss: 0.3699 - lambda: 0.673
#       Iter 2 - DANN | Epoch 10/50 - label_loss: 0.4827 - domain_loss: 1.3952 - val_loss: 0.3503 - lambda: 0.725
#       Iter 2 - DANN | Epoch 11/50 - label_loss: 0.3623 - domain_loss: 1.2370 - val_loss: 0.3290 - lambda: 0.770
#       Iter 2 - DANN | Epoch 12/50 - label_loss: 0.2835 - domain_loss: 1.3935 - val_loss: 0.3136 - lambda: 0.808
#       Iter 2 - DANN | Epoch 13/50 - label_loss: 0.2192 - domain_loss: 1.3960 - val_loss: 0.3001 - lambda: 0.841
#       Iter 2 - DANN | Epoch 14/50 - label_loss: 0.1760 - domain_loss: 1.3796 - val_loss: 0.2884 - lambda: 0.868
#       Iter 2 - DANN | Epoch 15/50 - label_loss: 0.3171 - domain_loss: 1.1959 - val_loss: 0.2804 - lambda: 0.891
#       Iter 2 - DANN | Epoch 16/50 - label_loss: 0.1614 - domain_loss: 1.2720 - val_loss: 0.2707 - lambda: 0.911
#       Iter 2 - DANN | Epoch 17/50 - label_loss: 0.3471 - domain_loss: 1.2828 - val_loss: 0.2585 - lambda: 0.926
#       Iter 2 - DANN | Epoch 18/50 - label_loss: 0.1992 - domain_loss: 1.3379 - val_loss: 0.2482 - lambda: 0.940
#       Iter 2 - DANN | Epoch 19/50 - label_loss: 0.2155 - domain_loss: 1.2990 - val_loss: 0.2378 - lambda: 0.950
#       Iter 2 - DANN | Epoch 20/50 - label_loss: 0.3373 - domain_loss: 1.4971 - val_loss: 0.2326 - lambda: 0.959
#       Iter 2 - DANN | Epoch 21/50 - label_loss: 0.2995 - domain_loss: 1.4692 - val_loss: 0.2283 - lambda: 0.967
#       Iter 2 - DANN | Epoch 22/50 - label_loss: 0.3113 - domain_loss: 1.3211 - val_loss: 0.2143 - lambda: 0.973
#       Iter 2 - DANN | Epoch 23/50 - label_loss: 0.2798 - domain_loss: 1.3574 - val_loss: 0.2119 - lambda: 0.978
#       Iter 2 - DANN | Epoch 24/50 - label_loss: 0.1661 - domain_loss: 1.4346 - val_loss: 0.2029 - lambda: 0.982
#       Iter 2 - DANN | Epoch 25/50 - label_loss: 0.1801 - domain_loss: 1.2707 - val_loss: 0.2027 - lambda: 0.985
#       Iter 2 - DANN | Epoch 26/50 - label_loss: 0.2225 - domain_loss: 1.4360 - val_loss: 0.2005 - lambda: 0.988
#       Iter 2 - DANN | Epoch 27/50 - label_loss: 0.0799 - domain_loss: 1.3891 - val_loss: 0.2014 - lambda: 0.990
#       Iter 2 - DANN | Epoch 28/50 - label_loss: 0.4103 - domain_loss: 1.3791 - val_loss: 0.1922 - lambda: 0.992
#       Iter 2 - DANN | Epoch 29/50 - label_loss: 0.2044 - domain_loss: 1.3031 - val_loss: 0.1851 - lambda: 0.993
#       Iter 2 - DANN | Epoch 30/50 - label_loss: 0.1475 - domain_loss: 1.5733 - val_loss: 0.1785 - lambda: 0.995
#       Iter 2 - DANN | Epoch 31/50 - label_loss: 0.2055 - domain_loss: 1.5002 - val_loss: 0.1817 - lambda: 0.996
#       Iter 2 - DANN | Epoch 32/50 - label_loss: 0.1193 - domain_loss: 1.4607 - val_loss: 0.1952 - lambda: 0.996
#       Iter 2 - DANN | Epoch 33/50 - label_loss: 0.1758 - domain_loss: 1.5070 - val_loss: 0.1757 - lambda: 0.997
#       Iter 2 - DANN | Epoch 34/50 - label_loss: 0.1904 - domain_loss: 1.7539 - val_loss: 0.1681 - lambda: 0.998
#       Iter 2 - DANN | Epoch 35/50 - label_loss: 0.3310 - domain_loss: 1.2972 - val_loss: 0.1813 - lambda: 0.998
#       Iter 2 - DANN | Epoch 36/50 - label_loss: 0.2375 - domain_loss: 1.4741 - val_loss: 0.1664 - lambda: 0.998
#       Iter 2 - DANN | Epoch 37/50 - label_loss: 0.1981 - domain_loss: 1.3955 - val_loss: 0.1723 - lambda: 0.999
#       Iter 2 - DANN | Epoch 38/50 - label_loss: 0.2019 - domain_loss: 1.2227 - val_loss: 0.1631 - lambda: 0.999
#       Iter 2 - DANN | Epoch 39/50 - label_loss: 0.1260 - domain_loss: 1.4079 - val_loss: 0.1545 - lambda: 0.999
#       Iter 2 - DANN | Epoch 40/50 - label_loss: 0.1778 - domain_loss: 1.2544 - val_loss: 0.1592 - lambda: 0.999
#       Iter 2 - DANN | Epoch 41/50 - label_loss: 0.2866 - domain_loss: 1.2902 - val_loss: 0.1596 - lambda: 0.999
#       Iter 2 - DANN | Epoch 42/50 - label_loss: 0.1609 - domain_loss: 1.3416 - val_loss: 0.1699 - lambda: 1.000
#       Iter 2 - DANN | Epoch 43/50 - label_loss: 0.1539 - domain_loss: 1.2688 - val_loss: 0.1442 - lambda: 1.000
#       Iter 2 - DANN | Epoch 44/50 - label_loss: 0.1123 - domain_loss: 1.2350 - val_loss: 0.1486 - lambda: 1.000
#       Iter 2 - DANN | Epoch 45/50 - label_loss: 0.0415 - domain_loss: 1.6812 - val_loss: 0.1508 - lambda: 1.000
#       Iter 2 - DANN | Epoch 46/50 - label_loss: 0.1872 - domain_loss: 1.2303 - val_loss: 0.1700 - lambda: 1.000
#       Iter 2 - DANN | Epoch 47/50 - label_loss: 0.6358 - domain_loss: 1.1219 - val_loss: 0.1513 - lambda: 1.000
#       Iter 2 - DANN | Epoch 48/50 - label_loss: 0.1658 - domain_loss: 1.0869 - val_loss: 0.1731 - lambda: 1.000
#       Iter 2 - DANN | Epoch 49/50 - label_loss: 0.1603 - domain_loss: 1.1921 - val_loss: 0.1659 - lambda: 1.000
#       Iter 2 - DANN | Epoch 50/50 - label_loss: 0.1435 - domain_loss: 1.4768 - val_loss: 0.1907 - lambda: 1.000
#       [Iteration 2/3] Training XGBoost on DANN features...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN...
# Iter 3 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - DANN | Epoch 1/50 - label_loss: 0.4932 - domain_loss: 1.2761 - val_loss: 0.5260 - lambda: 0.000
#       Iter 3 - DANN | Epoch 2/50 - label_loss: 0.4570 - domain_loss: 1.2851 - val_loss: 0.4841 - lambda: 0.102
#       Iter 3 - DANN | Epoch 3/50 - label_loss: 0.4867 - domain_loss: 1.3045 - val_loss: 0.4512 - lambda: 0.201
#       Iter 3 - DANN | Epoch 4/50 - label_loss: 0.3339 - domain_loss: 1.3205 - val_loss: 0.4264 - lambda: 0.297
#       Iter 3 - DANN | Epoch 5/50 - label_loss: 0.3943 - domain_loss: 1.2049 - val_loss: 0.4067 - lambda: 0.387
#       Iter 3 - DANN | Epoch 6/50 - label_loss: 0.3341 - domain_loss: 1.0894 - val_loss: 0.3883 - lambda: 0.470
#       Iter 3 - DANN | Epoch 7/50 - label_loss: 0.2539 - domain_loss: 1.2240 - val_loss: 0.3767 - lambda: 0.546
#       Iter 3 - DANN | Epoch 8/50 - label_loss: 0.3784 - domain_loss: 1.2038 - val_loss: 0.3640 - lambda: 0.613
#       Iter 3 - DANN | Epoch 9/50 - label_loss: 0.4492 - domain_loss: 1.1088 - val_loss: 0.3566 - lambda: 0.673
#       Iter 3 - DANN | Epoch 10/50 - label_loss: 0.4135 - domain_loss: 1.3526 - val_loss: 0.3471 - lambda: 0.725
#       Iter 3 - DANN | Epoch 11/50 - label_loss: 0.3227 - domain_loss: 1.2811 - val_loss: 0.3328 - lambda: 0.770
#       Iter 3 - DANN | Epoch 12/50 - label_loss: 0.5313 - domain_loss: 1.2637 - val_loss: 0.3189 - lambda: 0.808
#       Iter 3 - DANN | Epoch 13/50 - label_loss: 0.4084 - domain_loss: 1.1965 - val_loss: 0.3087 - lambda: 0.841
#       Iter 3 - DANN | Epoch 14/50 - label_loss: 0.3491 - domain_loss: 1.4210 - val_loss: 0.2996 - lambda: 0.868
#       Iter 3 - DANN | Epoch 15/50 - label_loss: 0.3933 - domain_loss: 1.3243 - val_loss: 0.2949 - lambda: 0.891
#       Iter 3 - DANN | Epoch 16/50 - label_loss: 0.2715 - domain_loss: 1.4033 - val_loss: 0.2875 - lambda: 0.911
#       Iter 3 - DANN | Epoch 17/50 - label_loss: 0.1997 - domain_loss: 1.3424 - val_loss: 0.2746 - lambda: 0.926
#       Iter 3 - DANN | Epoch 18/50 - label_loss: 0.2220 - domain_loss: 1.2959 - val_loss: 0.2690 - lambda: 0.940
#       Iter 3 - DANN | Epoch 19/50 - label_loss: 0.2344 - domain_loss: 1.3583 - val_loss: 0.2655 - lambda: 0.950
#       Iter 3 - DANN | Epoch 20/50 - label_loss: 0.2025 - domain_loss: 1.3197 - val_loss: 0.2557 - lambda: 0.959
#       Iter 3 - DANN | Epoch 21/50 - label_loss: 0.3853 - domain_loss: 1.5188 - val_loss: 0.2491 - lambda: 0.967
#       Iter 3 - DANN | Epoch 22/50 - label_loss: 0.3112 - domain_loss: 1.2733 - val_loss: 0.2432 - lambda: 0.973
#       Iter 3 - DANN | Epoch 23/50 - label_loss: 0.2471 - domain_loss: 1.3884 - val_loss: 0.2314 - lambda: 0.978
#       Iter 3 - DANN | Epoch 24/50 - label_loss: 0.1809 - domain_loss: 1.4409 - val_loss: 0.2264 - lambda: 0.982
#       Iter 3 - DANN | Epoch 25/50 - label_loss: 0.1412 - domain_loss: 1.4341 - val_loss: 0.2141 - lambda: 0.985
#       Iter 3 - DANN | Epoch 26/50 - label_loss: 0.2103 - domain_loss: 1.2930 - val_loss: 0.2160 - lambda: 0.988
#       Iter 3 - DANN | Epoch 27/50 - label_loss: 0.1233 - domain_loss: 1.3868 - val_loss: 0.2098 - lambda: 0.990
#       Iter 3 - DANN | Epoch 28/50 - label_loss: 0.2155 - domain_loss: 1.3624 - val_loss: 0.2199 - lambda: 0.992
#       Iter 3 - DANN | Epoch 29/50 - label_loss: 0.2331 - domain_loss: 1.3349 - val_loss: 0.2252 - lambda: 0.993
#       Iter 3 - DANN | Epoch 30/50 - label_loss: 0.2540 - domain_loss: 1.3968 - val_loss: 0.1867 - lambda: 0.995
#       Iter 3 - DANN | Epoch 31/50 - label_loss: 0.1122 - domain_loss: 1.4981 - val_loss: 0.1942 - lambda: 0.996
#       Iter 3 - DANN | Epoch 32/50 - label_loss: 0.3598 - domain_loss: 1.3406 - val_loss: 0.1923 - lambda: 0.996
#       Iter 3 - DANN | Epoch 33/50 - label_loss: 0.2966 - domain_loss: 1.3428 - val_loss: 0.2028 - lambda: 0.997
#       Iter 3 - DANN | Epoch 34/50 - label_loss: 0.1993 - domain_loss: 1.3049 - val_loss: 0.2125 - lambda: 0.998
#       Iter 3 - DANN | Epoch 35/50 - label_loss: 0.2790 - domain_loss: 1.3959 - val_loss: 0.1856 - lambda: 0.998
#       Iter 3 - DANN | Epoch 36/50 - label_loss: 0.1771 - domain_loss: 1.3555 - val_loss: 0.1673 - lambda: 0.998
#       Iter 3 - DANN | Epoch 37/50 - label_loss: 0.0746 - domain_loss: 1.3883 - val_loss: 0.1706 - lambda: 0.999
#       Iter 3 - DANN | Epoch 38/50 - label_loss: 0.3392 - domain_loss: 1.3309 - val_loss: 0.1769 - lambda: 0.999
#       Iter 3 - DANN | Epoch 39/50 - label_loss: 0.1574 - domain_loss: 1.3128 - val_loss: 0.2170 - lambda: 0.999
#       Iter 3 - DANN | Epoch 40/50 - label_loss: 0.4025 - domain_loss: 1.2533 - val_loss: 0.1656 - lambda: 0.999
#       Iter 3 - DANN | Epoch 41/50 - label_loss: 0.1118 - domain_loss: 1.3038 - val_loss: 0.1621 - lambda: 0.999
#       Iter 3 - DANN | Epoch 42/50 - label_loss: 0.0966 - domain_loss: 1.3311 - val_loss: 0.1496 - lambda: 1.000
#       Iter 3 - DANN | Epoch 43/50 - label_loss: 0.2881 - domain_loss: 1.2808 - val_loss: 0.1528 - lambda: 1.000
#       Iter 3 - DANN | Epoch 44/50 - label_loss: 0.2645 - domain_loss: 1.3328 - val_loss: 0.1592 - lambda: 1.000
#       Iter 3 - DANN | Epoch 45/50 - label_loss: 0.3218 - domain_loss: 1.3094 - val_loss: 0.1494 - lambda: 1.000
#       Iter 3 - DANN | Epoch 46/50 - label_loss: 0.1492 - domain_loss: 1.2728 - val_loss: 0.1400 - lambda: 1.000
#       Iter 3 - DANN | Epoch 47/50 - label_loss: 0.2074 - domain_loss: 1.3548 - val_loss: 0.1484 - lambda: 1.000
#       Iter 3 - DANN | Epoch 48/50 - label_loss: 0.1115 - domain_loss: 1.4268 - val_loss: 0.1556 - lambda: 1.000
#       Iter 3 - DANN | Epoch 49/50 - label_loss: 0.2646 - domain_loss: 1.4039 - val_loss: 0.1468 - lambda: 1.000
#       Iter 3 - DANN | Epoch 50/50 - label_loss: 0.4095 - domain_loss: 1.6043 - val_loss: 0.1437 - lambda: 1.000
#       [Iteration 3/3] Training XGBoost on DANN features...
#       [Iteration 3/3] Done
#
# [Metrics] Computing evaluation metrics...
#
# === Evaluation Results (CWE-787 Test Set) - SMOTE + DANN ===
# Accuracy  : 0.892
# Precision : 0.050
# Recall    : 0.476
# F1-score  : 0.091
# AUC       : 0.803
# G-mean    : 0.653
# PF value  : 0.103
#
# Confusion Matrix:
#   TN: 39185  FP: 4521
#   FN: 264  TP: 240
#
# Results saved to results/smote_with_classweight_dann/CWE-787/smote_with_classweight_dann_CWE-787.json
# Confusion matrix saved as results/smote_with_classweight_dann/CWE-787/confusion_matrix_smote_with_classweight_dann_CWE-787.png
