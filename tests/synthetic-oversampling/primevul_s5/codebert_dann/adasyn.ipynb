# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
ADASYN Oversampling, With Class Weighting, WITH Domain-Adversarial Neural Network (DANN)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl"
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/adasyn_with_classweight_dann/{HELD_OUT_CWE}"

# DANN-specific
LAMBDA_MAX   = 1.0   # max weight for domain loss (GRL strength ceiling)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup
# =========================================================
def load_cwe_lookup(raw_path):
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading 
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.lambda_ * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self, lambda_=1.0):
        super().__init__()
        self.lambda_ = lambda_

    def forward(self, x):
        return GradientReversalFunction.apply(x, self.lambda_)

    def set_lambda(self, lambda_):
        self.lambda_ = lambda_


# =========================================================
# DANN Architecture: FeatureExtractor + ClassifierHead + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # shared embedding, dim=64


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.grl = GradientReversalLayer(lambda_=1.0)
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        reversed_features = self.grl(features)
        return self.network(reversed_features)


# =========================================================
# DANN Training Loop
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val,
                class_weights, epochs, desc):
    """
    x_source/y_source : ADASYN-oversampled labeled training pool (source domain)
    x_target          : UNLABELED held-out CWE test set (used only for domain adaptation)
    """
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    label_criterion  = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    source_dataset = TensorDataset(
        torch.tensor(x_source, dtype=torch.float32),
        torch.tensor(y_source, dtype=torch.float32)
    )
    target_dataset = TensorDataset(
        torch.tensor(x_target, dtype=torch.float32)
    )

    batch_size = 64
    source_loader = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=batch_size, shuffle=True)

    n_batches = max(len(source_loader), len(target_loader))

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        p = epoch / max(epochs - 1, 1)
        lambda_ = (2.0 / (1.0 + np.exp(-10 * p)) - 1.0) * LAMBDA_MAX
        domain_discriminator.grl.set_lambda(lambda_)

        source_iter = iter(source_loader)
        target_iter = iter(target_loader)

        for _ in range(n_batches):
            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(source_loader)
                x_s, y_s = next(source_iter)
            try:
                (x_t,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (x_t,) = next(target_iter)

            x_s, y_s = x_s.to(DEVICE), y_s.to(DEVICE)
            x_t = x_t.to(DEVICE)

            optimizer.zero_grad()

            # --- Label prediction loss (source only) ---
            features_s = feature_extractor(x_s)
            label_pred = classifier_head(features_s).squeeze()
            weights    = torch.where(y_s == 1, pos_weight, neg_weight)
            label_loss = (label_criterion(label_pred, y_s) * weights).mean()

            # --- Domain discrimination loss (source + target) ---
            features_t = feature_extractor(x_t)
            domain_pred_s = domain_discriminator(features_s).squeeze()
            domain_pred_t = domain_discriminator(features_t).squeeze()

            domain_labels_s = torch.zeros(domain_pred_s.shape[0]).to(DEVICE)  # source = 0
            domain_labels_t = torch.ones(domain_pred_t.shape[0]).to(DEVICE)   # target = 1

            domain_loss = (domain_criterion(domain_pred_s, domain_labels_s) +
                            domain_criterion(domain_pred_t, domain_labels_t))

            total_loss = label_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (label_criterion(val_preds, y_val) * weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"label_loss: {label_loss.item():.4f} - domain_loss: {domain_loss.item():.4f} - "
              f"val_loss: {val_loss:.4f} - lambda: {lambda_:.3f}")

    return feature_extractor, classifier_head, domain_discriminator


# =========================================================
# XGBoost (trained on domain-invariant FEATURES, not raw embeddings)
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])
    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set) - ADASYN + DANN")
    plt.colorbar(img, ax=ax)
    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | LOCO + ADASYN + DANN: Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/7] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/7] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    print(f"\n[3/7] Splitting by CWE (held-out: {HELD_OUT_CWE})...")
    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)  # only used for FINAL evaluation, never during training

    print(f"      Training pool (source, pre-ADASYN) : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set / target ({HELD_OUT_CWE})         : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio           : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[4/7] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    print("\n[5/7] Applying ADASYN to source training pool...")
    adasyn = ADASYN(random_state=SEED)
    train_emb, train_lbl = adasyn.fit_resample(train_emb, train_lbl)
    train_emb = train_emb.astype(np.float32)
    train_lbl = train_lbl.astype(np.int32)
    print(f"      Training pool (post-ADASYN)        : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")

    print("\n[6/7] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(class_weight='balanced', classes=classes, y=train_lbl)
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[7/7] Running DANN + ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN...")

        x_tr, x_val, y_tr, y_val = train_test_split(
            train_emb, train_lbl, test_size=0.2, random_state=SEED
        )
        x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
        y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

        feature_extractor     = FeatureExtractor(train_emb.shape[1]).to(DEVICE)
        classifier_head       = ClassifierHead(feature_dim=64).to(DEVICE)
        domain_discriminator  = DomainDiscriminator(feature_dim=64).to(DEVICE)

        feature_extractor, classifier_head, domain_discriminator = train_dann(
            feature_extractor, classifier_head, domain_discriminator,
            x_source=x_tr, y_source=y_tr,
            x_target=test_emb,          # unlabeled target domain, used only for domain loss
            x_val=x_val_t, y_val=y_val_t,
            class_weights=class_weight_dict,
            epochs=50,
            desc=f"Iter {i+1} - DANN"
        )

        feature_extractor.eval()
        with torch.no_grad():
            train_features = feature_extractor(
                torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()
            test_features = feature_extractor(
                torch.tensor(test_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()

            y_train_pred = classifier_head(
                torch.tensor(train_features, dtype=torch.float32).to(DEVICE)
            ).squeeze().cpu().numpy()

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost on DANN features...")
        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(
            train_features, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_features)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[Metrics] Computing evaluation metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) - ADASYN + DANN ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "adasyn_with_classweight_dann",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"adasyn_with_classweight_dann_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_adasyn_with_classweight_dann_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | LOCO + ADASYN + DANN: Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/7] Building CWE lookup from raw file...
#
# [2/7] Loading combined embeddings with CWE join...
#
# [3/7] Splitting by CWE (held-out: CWE-787)...
#       Training pool (source, pre-ADASYN) : (180323, 768)  vuln=5500  benign=174823
#       Test set / target (CWE-787)         : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio           : 0.0305
#
# [4/7] Normalizing embeddings...
#
# [5/7] Applying ADASYN to source training pool...
#       Training pool (post-ADASYN)        : (348873, 768)  vuln=174050  benign=174823
#
# [6/7] Computing class weights...
#       Class weights: {0: 0.9977891924975547, 1: 1.0022206262568227}
#
# [7/7] Running DANN + ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN...
# Iter 1 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - DANN | Epoch 1/50 - label_loss: 0.5611 - domain_loss: 1.3513 - val_loss: 0.5454 - lambda: 0.000
#       Iter 1 - DANN | Epoch 2/50 - label_loss: 0.4353 - domain_loss: 1.2981 - val_loss: 0.4891 - lambda: 0.102
#       Iter 1 - DANN | Epoch 3/50 - label_loss: 0.4534 - domain_loss: 1.3317 - val_loss: 0.4530 - lambda: 0.201
#       Iter 1 - DANN | Epoch 4/50 - label_loss: 0.3234 - domain_loss: 1.2852 - val_loss: 0.4279 - lambda: 0.297
#       Iter 1 - DANN | Epoch 5/50 - label_loss: 0.3954 - domain_loss: 1.3324 - val_loss: 0.3998 - lambda: 0.387
#       Iter 1 - DANN | Epoch 6/50 - label_loss: 0.3043 - domain_loss: 1.3578 - val_loss: 0.3790 - lambda: 0.470
#       Iter 1 - DANN | Epoch 7/50 - label_loss: 0.4242 - domain_loss: 1.3214 - val_loss: 0.3597 - lambda: 0.546
#       Iter 1 - DANN | Epoch 8/50 - label_loss: 0.4756 - domain_loss: 1.3223 - val_loss: 0.3473 - lambda: 0.613
#       Iter 1 - DANN | Epoch 9/50 - label_loss: 0.3719 - domain_loss: 1.3540 - val_loss: 0.3412 - lambda: 0.673
#       Iter 1 - DANN | Epoch 10/50 - label_loss: 0.3772 - domain_loss: 1.2421 - val_loss: 0.3225 - lambda: 0.725
#       Iter 1 - DANN | Epoch 11/50 - label_loss: 0.2329 - domain_loss: 1.2774 - val_loss: 0.3070 - lambda: 0.770
#       Iter 1 - DANN | Epoch 12/50 - label_loss: 0.2517 - domain_loss: 1.2844 - val_loss: 0.2970 - lambda: 0.808
#       Iter 1 - DANN | Epoch 13/50 - label_loss: 0.2482 - domain_loss: 1.3254 - val_loss: 0.2855 - lambda: 0.841
#       Iter 1 - DANN | Epoch 14/50 - label_loss: 0.2959 - domain_loss: 1.1926 - val_loss: 0.2752 - lambda: 0.868
#       Iter 1 - DANN | Epoch 15/50 - label_loss: 0.2673 - domain_loss: 1.2839 - val_loss: 0.2674 - lambda: 0.891
#       Iter 1 - DANN | Epoch 16/50 - label_loss: 0.2369 - domain_loss: 1.3133 - val_loss: 0.2613 - lambda: 0.911
#       Iter 1 - DANN | Epoch 17/50 - label_loss: 0.2621 - domain_loss: 1.2435 - val_loss: 0.2500 - lambda: 0.926
#       Iter 1 - DANN | Epoch 18/50 - label_loss: 0.2949 - domain_loss: 1.2693 - val_loss: 0.2406 - lambda: 0.940
#       Iter 1 - DANN | Epoch 19/50 - label_loss: 0.3329 - domain_loss: 1.3767 - val_loss: 0.2320 - lambda: 0.950
#       Iter 1 - DANN | Epoch 20/50 - label_loss: 0.3668 - domain_loss: 1.2895 - val_loss: 0.2348 - lambda: 0.959
#       Iter 1 - DANN | Epoch 21/50 - label_loss: 0.2367 - domain_loss: 1.2959 - val_loss: 0.2366 - lambda: 0.967
#       Iter 1 - DANN | Epoch 22/50 - label_loss: 0.3041 - domain_loss: 1.3980 - val_loss: 0.2253 - lambda: 0.973
#       Iter 1 - DANN | Epoch 23/50 - label_loss: 0.4568 - domain_loss: 1.5256 - val_loss: 0.2142 - lambda: 0.978
#       Iter 1 - DANN | Epoch 24/50 - label_loss: 0.3014 - domain_loss: 1.3439 - val_loss: 0.2203 - lambda: 0.982
#       Iter 1 - DANN | Epoch 25/50 - label_loss: 0.2898 - domain_loss: 1.2981 - val_loss: 0.2091 - lambda: 0.985
#       Iter 1 - DANN | Epoch 26/50 - label_loss: 0.2109 - domain_loss: 1.4352 - val_loss: 0.2127 - lambda: 0.988
#       Iter 1 - DANN | Epoch 27/50 - label_loss: 0.4334 - domain_loss: 1.2733 - val_loss: 0.2095 - lambda: 0.990
#       Iter 1 - DANN | Epoch 28/50 - label_loss: 0.2402 - domain_loss: 1.3874 - val_loss: 0.2172 - lambda: 0.992
#       Iter 1 - DANN | Epoch 29/50 - label_loss: 0.3768 - domain_loss: 1.3931 - val_loss: 0.2396 - lambda: 0.993
#       Iter 1 - DANN | Epoch 30/50 - label_loss: 0.2596 - domain_loss: 1.4062 - val_loss: 0.2210 - lambda: 0.995
#       Iter 1 - DANN | Epoch 31/50 - label_loss: 0.2268 - domain_loss: 1.4181 - val_loss: 0.1973 - lambda: 0.996
#       Iter 1 - DANN | Epoch 32/50 - label_loss: 0.4553 - domain_loss: 1.4087 - val_loss: 0.1962 - lambda: 0.996
#       Iter 1 - DANN | Epoch 33/50 - label_loss: 0.1532 - domain_loss: 1.3431 - val_loss: 0.2020 - lambda: 0.997
#       Iter 1 - DANN | Epoch 34/50 - label_loss: 0.2660 - domain_loss: 1.4220 - val_loss: 0.2051 - lambda: 0.998
#       Iter 1 - DANN | Epoch 35/50 - label_loss: 0.2448 - domain_loss: 1.3133 - val_loss: 0.1980 - lambda: 0.998
#       Iter 1 - DANN | Epoch 36/50 - label_loss: 0.1365 - domain_loss: 1.5882 - val_loss: 0.1721 - lambda: 0.998
#       Iter 1 - DANN | Epoch 37/50 - label_loss: 0.2217 - domain_loss: 1.3505 - val_loss: 0.1876 - lambda: 0.999
#       Iter 1 - DANN | Epoch 38/50 - label_loss: 0.1693 - domain_loss: 1.2646 - val_loss: 0.1876 - lambda: 0.999
#       Iter 1 - DANN | Epoch 39/50 - label_loss: 0.4798 - domain_loss: 1.5622 - val_loss: 0.1830 - lambda: 0.999
#       Iter 1 - DANN | Epoch 40/50 - label_loss: 0.2156 - domain_loss: 1.3897 - val_loss: 0.1954 - lambda: 0.999
#       Iter 1 - DANN | Epoch 41/50 - label_loss: 0.1921 - domain_loss: 1.2572 - val_loss: 0.1814 - lambda: 0.999
#       Iter 1 - DANN | Epoch 42/50 - label_loss: 0.2573 - domain_loss: 1.2722 - val_loss: 0.1661 - lambda: 1.000
#       Iter 1 - DANN | Epoch 43/50 - label_loss: 0.1066 - domain_loss: 1.2359 - val_loss: 0.1780 - lambda: 1.000
#       Iter 1 - DANN | Epoch 44/50 - label_loss: 0.2383 - domain_loss: 1.3751 - val_loss: 0.1717 - lambda: 1.000
#       Iter 1 - DANN | Epoch 45/50 - label_loss: 0.2107 - domain_loss: 1.2536 - val_loss: 0.1706 - lambda: 1.000
#       Iter 1 - DANN | Epoch 46/50 - label_loss: 0.1820 - domain_loss: 1.4181 - val_loss: 0.1695 - lambda: 1.000
#       Iter 1 - DANN | Epoch 47/50 - label_loss: 0.1384 - domain_loss: 1.5202 - val_loss: 0.1899 - lambda: 1.000
#       Iter 1 - DANN | Epoch 48/50 - label_loss: 0.1389 - domain_loss: 1.3529 - val_loss: 0.1763 - lambda: 1.000
#       Iter 1 - DANN | Epoch 49/50 - label_loss: 0.2694 - domain_loss: 1.2111 - val_loss: 0.1705 - lambda: 1.000
#       Iter 1 - DANN | Epoch 50/50 - label_loss: 0.0685 - domain_loss: 1.1882 - val_loss: 0.1714 - lambda: 1.000
#       [Iteration 1/3] Training XGBoost on DANN features...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN...
# Iter 2 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - DANN | Epoch 1/50 - label_loss: 0.5671 - domain_loss: 1.2795 - val_loss: 0.5433 - lambda: 0.000
#       Iter 2 - DANN | Epoch 2/50 - label_loss: 0.4800 - domain_loss: 1.2997 - val_loss: 0.4915 - lambda: 0.102
#       Iter 2 - DANN | Epoch 3/50 - label_loss: 0.5425 - domain_loss: 1.2728 - val_loss: 0.4566 - lambda: 0.201
#       Iter 2 - DANN | Epoch 4/50 - label_loss: 0.5377 - domain_loss: 1.2869 - val_loss: 0.4291 - lambda: 0.297
#       Iter 2 - DANN | Epoch 5/50 - label_loss: 0.3758 - domain_loss: 1.2654 - val_loss: 0.4068 - lambda: 0.387
#       Iter 2 - DANN | Epoch 6/50 - label_loss: 0.4170 - domain_loss: 1.3107 - val_loss: 0.3881 - lambda: 0.470
#       Iter 2 - DANN | Epoch 7/50 - label_loss: 0.4019 - domain_loss: 1.2893 - val_loss: 0.3695 - lambda: 0.546
#       Iter 2 - DANN | Epoch 8/50 - label_loss: 0.3544 - domain_loss: 1.3046 - val_loss: 0.3576 - lambda: 0.613
#       Iter 2 - DANN | Epoch 9/50 - label_loss: 0.3802 - domain_loss: 1.3305 - val_loss: 0.3590 - lambda: 0.673
#       Iter 2 - DANN | Epoch 10/50 - label_loss: 0.2786 - domain_loss: 1.3054 - val_loss: 0.3437 - lambda: 0.725
#       Iter 2 - DANN | Epoch 11/50 - label_loss: 0.3725 - domain_loss: 1.2758 - val_loss: 0.3248 - lambda: 0.770
#       Iter 2 - DANN | Epoch 12/50 - label_loss: 0.4380 - domain_loss: 1.3676 - val_loss: 0.3088 - lambda: 0.808
#       Iter 2 - DANN | Epoch 13/50 - label_loss: 0.3397 - domain_loss: 1.3084 - val_loss: 0.2960 - lambda: 0.841
#       Iter 2 - DANN | Epoch 14/50 - label_loss: 0.2435 - domain_loss: 1.3039 - val_loss: 0.2849 - lambda: 0.868
#       Iter 2 - DANN | Epoch 15/50 - label_loss: 0.2119 - domain_loss: 1.3487 - val_loss: 0.2733 - lambda: 0.891
#       Iter 2 - DANN | Epoch 16/50 - label_loss: 0.3683 - domain_loss: 1.2136 - val_loss: 0.2633 - lambda: 0.911
#       Iter 2 - DANN | Epoch 17/50 - label_loss: 0.2114 - domain_loss: 1.3388 - val_loss: 0.2539 - lambda: 0.926
#       Iter 2 - DANN | Epoch 18/50 - label_loss: 0.2558 - domain_loss: 1.2553 - val_loss: 0.2448 - lambda: 0.940
#       Iter 2 - DANN | Epoch 19/50 - label_loss: 0.3251 - domain_loss: 1.2621 - val_loss: 0.2376 - lambda: 0.950
#       Iter 2 - DANN | Epoch 20/50 - label_loss: 0.3124 - domain_loss: 1.2674 - val_loss: 0.2333 - lambda: 0.959
#       Iter 2 - DANN | Epoch 21/50 - label_loss: 0.1430 - domain_loss: 1.4087 - val_loss: 0.2219 - lambda: 0.967
#       Iter 2 - DANN | Epoch 22/50 - label_loss: 0.2084 - domain_loss: 1.4071 - val_loss: 0.2264 - lambda: 0.973
#       Iter 2 - DANN | Epoch 23/50 - label_loss: 0.1970 - domain_loss: 1.4005 - val_loss: 0.2183 - lambda: 0.978
#       Iter 2 - DANN | Epoch 24/50 - label_loss: 0.1781 - domain_loss: 1.4300 - val_loss: 0.2083 - lambda: 0.982
#       Iter 2 - DANN | Epoch 25/50 - label_loss: 0.2186 - domain_loss: 1.3278 - val_loss: 0.2063 - lambda: 0.985
#       Iter 2 - DANN | Epoch 26/50 - label_loss: 0.3316 - domain_loss: 1.2975 - val_loss: 0.1948 - lambda: 0.988
#       Iter 2 - DANN | Epoch 27/50 - label_loss: 0.1647 - domain_loss: 1.3630 - val_loss: 0.1910 - lambda: 0.990
#       Iter 2 - DANN | Epoch 28/50 - label_loss: 0.1941 - domain_loss: 1.2852 - val_loss: 0.1924 - lambda: 0.992
#       Iter 2 - DANN | Epoch 29/50 - label_loss: 0.1719 - domain_loss: 1.3472 - val_loss: 0.2054 - lambda: 0.993
#       Iter 2 - DANN | Epoch 30/50 - label_loss: 0.2023 - domain_loss: 1.3286 - val_loss: 0.1962 - lambda: 0.995
#       Iter 2 - DANN | Epoch 31/50 - label_loss: 0.2847 - domain_loss: 1.2965 - val_loss: 0.1754 - lambda: 0.996
#       Iter 2 - DANN | Epoch 32/50 - label_loss: 0.3396 - domain_loss: 1.3167 - val_loss: 0.1771 - lambda: 0.996
#       Iter 2 - DANN | Epoch 33/50 - label_loss: 0.2992 - domain_loss: 1.2983 - val_loss: 0.1750 - lambda: 0.997
#       Iter 2 - DANN | Epoch 34/50 - label_loss: 0.2526 - domain_loss: 1.2799 - val_loss: 0.1663 - lambda: 0.998
#       Iter 2 - DANN | Epoch 35/50 - label_loss: 0.1296 - domain_loss: 1.3439 - val_loss: 0.1670 - lambda: 0.998
#       Iter 2 - DANN | Epoch 36/50 - label_loss: 0.2663 - domain_loss: 1.2696 - val_loss: 0.1698 - lambda: 0.998
#       Iter 2 - DANN | Epoch 37/50 - label_loss: 0.1240 - domain_loss: 1.3110 - val_loss: 0.1608 - lambda: 0.999
#       Iter 2 - DANN | Epoch 38/50 - label_loss: 0.2135 - domain_loss: 1.2975 - val_loss: 0.1573 - lambda: 0.999
#       Iter 2 - DANN | Epoch 39/50 - label_loss: 0.1383 - domain_loss: 1.2330 - val_loss: 0.1560 - lambda: 0.999
#       Iter 2 - DANN | Epoch 40/50 - label_loss: 0.2783 - domain_loss: 1.2852 - val_loss: 0.1586 - lambda: 0.999
#       Iter 2 - DANN | Epoch 41/50 - label_loss: 0.1302 - domain_loss: 1.3421 - val_loss: 0.1585 - lambda: 0.999
#       Iter 2 - DANN | Epoch 42/50 - label_loss: 0.1014 - domain_loss: 1.2462 - val_loss: 0.1550 - lambda: 1.000
#       Iter 2 - DANN | Epoch 43/50 - label_loss: 0.2399 - domain_loss: 1.2466 - val_loss: 0.1633 - lambda: 1.000
#       Iter 2 - DANN | Epoch 44/50 - label_loss: 0.1119 - domain_loss: 1.2483 - val_loss: 0.1468 - lambda: 1.000
#       Iter 2 - DANN | Epoch 45/50 - label_loss: 0.1757 - domain_loss: 1.2186 - val_loss: 0.1632 - lambda: 1.000
#       Iter 2 - DANN | Epoch 46/50 - label_loss: 0.0670 - domain_loss: 1.2296 - val_loss: 0.1613 - lambda: 1.000
#       Iter 2 - DANN | Epoch 47/50 - label_loss: 0.1115 - domain_loss: 1.2440 - val_loss: 0.1560 - lambda: 1.000
#       Iter 2 - DANN | Epoch 48/50 - label_loss: 0.1622 - domain_loss: 1.1066 - val_loss: 0.1663 - lambda: 1.000
#       Iter 2 - DANN | Epoch 49/50 - label_loss: 0.3735 - domain_loss: 1.2192 - val_loss: 0.1456 - lambda: 1.000
#       Iter 2 - DANN | Epoch 50/50 - label_loss: 0.0989 - domain_loss: 2.8460 - val_loss: 0.1483 - lambda: 1.000
#       [Iteration 2/3] Training XGBoost on DANN features...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN...
# Iter 3 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - DANN | Epoch 1/50 - label_loss: 0.5449 - domain_loss: 1.3529 - val_loss: 0.5452 - lambda: 0.000
#       Iter 3 - DANN | Epoch 2/50 - label_loss: 0.4483 - domain_loss: 1.2892 - val_loss: 0.4947 - lambda: 0.102
#       Iter 3 - DANN | Epoch 3/50 - label_loss: 0.3586 - domain_loss: 1.3230 - val_loss: 0.4597 - lambda: 0.201
#       Iter 3 - DANN | Epoch 4/50 - label_loss: 0.4303 - domain_loss: 1.4286 - val_loss: 0.4338 - lambda: 0.297
#       Iter 3 - DANN | Epoch 5/50 - label_loss: 0.3941 - domain_loss: 1.3172 - val_loss: 0.4098 - lambda: 0.387
#       Iter 3 - DANN | Epoch 6/50 - label_loss: 0.5612 - domain_loss: 1.2831 - val_loss: 0.3909 - lambda: 0.470
#       Iter 3 - DANN | Epoch 7/50 - label_loss: 0.3627 - domain_loss: 1.2711 - val_loss: 0.3742 - lambda: 0.546
#       Iter 3 - DANN | Epoch 8/50 - label_loss: 0.2388 - domain_loss: 1.2815 - val_loss: 0.3600 - lambda: 0.613
#       Iter 3 - DANN | Epoch 9/50 - label_loss: 0.3921 - domain_loss: 1.2065 - val_loss: 0.3535 - lambda: 0.673
#       Iter 3 - DANN | Epoch 10/50 - label_loss: 0.3854 - domain_loss: 1.3255 - val_loss: 0.3464 - lambda: 0.725
#       Iter 3 - DANN | Epoch 11/50 - label_loss: 0.3999 - domain_loss: 1.2244 - val_loss: 0.3306 - lambda: 0.770
#       Iter 3 - DANN | Epoch 12/50 - label_loss: 0.2677 - domain_loss: 1.2780 - val_loss: 0.3196 - lambda: 0.808
#       Iter 3 - DANN | Epoch 13/50 - label_loss: 0.3168 - domain_loss: 1.2844 - val_loss: 0.3023 - lambda: 0.841
#       Iter 3 - DANN | Epoch 14/50 - label_loss: 0.3661 - domain_loss: 1.2672 - val_loss: 0.2977 - lambda: 0.868
#       Iter 3 - DANN | Epoch 15/50 - label_loss: 0.3882 - domain_loss: 1.2955 - val_loss: 0.2878 - lambda: 0.891
#       Iter 3 - DANN | Epoch 16/50 - label_loss: 0.4310 - domain_loss: 1.3320 - val_loss: 0.2779 - lambda: 0.911
#       Iter 3 - DANN | Epoch 17/50 - label_loss: 0.3139 - domain_loss: 1.2844 - val_loss: 0.2711 - lambda: 0.926
#       Iter 3 - DANN | Epoch 18/50 - label_loss: 0.2810 - domain_loss: 1.3477 - val_loss: 0.2595 - lambda: 0.940
#       Iter 3 - DANN | Epoch 19/50 - label_loss: 0.2758 - domain_loss: 1.4032 - val_loss: 0.2557 - lambda: 0.950
#       Iter 3 - DANN | Epoch 20/50 - label_loss: 0.4388 - domain_loss: 1.4499 - val_loss: 0.2463 - lambda: 0.959
#       Iter 3 - DANN | Epoch 21/50 - label_loss: 0.2726 - domain_loss: 1.4144 - val_loss: 0.2413 - lambda: 0.967
#       Iter 3 - DANN | Epoch 22/50 - label_loss: 0.2572 - domain_loss: 1.3146 - val_loss: 0.2410 - lambda: 0.973
#       Iter 3 - DANN | Epoch 23/50 - label_loss: 0.2785 - domain_loss: 1.3813 - val_loss: 0.2268 - lambda: 0.978
#       Iter 3 - DANN | Epoch 24/50 - label_loss: 0.3053 - domain_loss: 1.2964 - val_loss: 0.2166 - lambda: 0.982
#       Iter 3 - DANN | Epoch 25/50 - label_loss: 0.2823 - domain_loss: 1.3401 - val_loss: 0.2309 - lambda: 0.985
#       Iter 3 - DANN | Epoch 26/50 - label_loss: 0.2427 - domain_loss: 1.2929 - val_loss: 0.2071 - lambda: 0.988
#       Iter 3 - DANN | Epoch 27/50 - label_loss: 0.1937 - domain_loss: 1.2558 - val_loss: 0.2308 - lambda: 0.990
#       Iter 3 - DANN | Epoch 28/50 - label_loss: 0.3626 - domain_loss: 1.2578 - val_loss: 0.1964 - lambda: 0.992
#       Iter 3 - DANN | Epoch 29/50 - label_loss: 0.2072 - domain_loss: 1.3789 - val_loss: 0.1963 - lambda: 0.993
#       Iter 3 - DANN | Epoch 30/50 - label_loss: 0.2228 - domain_loss: 1.3359 - val_loss: 0.1901 - lambda: 0.995
#       Iter 3 - DANN | Epoch 31/50 - label_loss: 0.1290 - domain_loss: 1.2051 - val_loss: 0.1947 - lambda: 0.996
#       Iter 3 - DANN | Epoch 32/50 - label_loss: 0.3065 - domain_loss: 1.3316 - val_loss: 0.1789 - lambda: 0.996
#       Iter 3 - DANN | Epoch 33/50 - label_loss: 0.1525 - domain_loss: 1.3467 - val_loss: 0.1762 - lambda: 0.997
#       Iter 3 - DANN | Epoch 34/50 - label_loss: 0.2083 - domain_loss: 1.3037 - val_loss: 0.1755 - lambda: 0.998
#       Iter 3 - DANN | Epoch 35/50 - label_loss: 0.1478 - domain_loss: 1.4825 - val_loss: 0.1916 - lambda: 0.998
#       Iter 3 - DANN | Epoch 36/50 - label_loss: 0.1516 - domain_loss: 1.4274 - val_loss: 0.1764 - lambda: 0.998
#       Iter 3 - DANN | Epoch 37/50 - label_loss: 0.2959 - domain_loss: 1.7062 - val_loss: 0.2017 - lambda: 0.999
#       Iter 3 - DANN | Epoch 38/50 - label_loss: 0.1221 - domain_loss: 1.3405 - val_loss: 0.1668 - lambda: 0.999
#       Iter 3 - DANN | Epoch 39/50 - label_loss: 0.3666 - domain_loss: 1.5344 - val_loss: 0.1688 - lambda: 0.999
#       Iter 3 - DANN | Epoch 40/50 - label_loss: 0.2599 - domain_loss: 1.3402 - val_loss: 0.1855 - lambda: 0.999
#       Iter 3 - DANN | Epoch 41/50 - label_loss: 0.2792 - domain_loss: 1.3126 - val_loss: 0.1733 - lambda: 0.999
#       Iter 3 - DANN | Epoch 42/50 - label_loss: 0.1961 - domain_loss: 1.4157 - val_loss: 0.1670 - lambda: 1.000
#       Iter 3 - DANN | Epoch 43/50 - label_loss: 1.8392 - domain_loss: 1.3870 - val_loss: 0.1491 - lambda: 1.000
#       Iter 3 - DANN | Epoch 44/50 - label_loss: 0.1120 - domain_loss: 1.3512 - val_loss: 0.1544 - lambda: 1.000
#       Iter 3 - DANN | Epoch 45/50 - label_loss: 0.1924 - domain_loss: 1.2362 - val_loss: 0.1452 - lambda: 1.000
#       Iter 3 - DANN | Epoch 46/50 - label_loss: 0.3079 - domain_loss: 1.2436 - val_loss: 0.1583 - lambda: 1.000
#       Iter 3 - DANN | Epoch 47/50 - label_loss: 0.1096 - domain_loss: 1.3437 - val_loss: 0.1551 - lambda: 1.000
#       Iter 3 - DANN | Epoch 48/50 - label_loss: 0.0866 - domain_loss: 1.2197 - val_loss: 0.1334 - lambda: 1.000
#       Iter 3 - DANN | Epoch 49/50 - label_loss: 0.0792 - domain_loss: 1.2429 - val_loss: 0.1380 - lambda: 1.000
#       Iter 3 - DANN | Epoch 50/50 - label_loss: 0.2128 - domain_loss: 1.0945 - val_loss: 0.1371 - lambda: 1.000
#       [Iteration 3/3] Training XGBoost on DANN features...
#       [Iteration 3/3] Done
#
# [Metrics] Computing evaluation metrics...
#
# === Evaluation Results (CWE-787 Test Set) - ADASYN + DANN ===
# Accuracy  : 0.902
# Precision : 0.053
# Recall    : 0.452
# F1-score  : 0.095
# AUC       : 0.807
# G-mean    : 0.640
# PF value  : 0.093
#
# Confusion Matrix:
#   TN: 39631  FP: 4075
#   FN: 276  TP: 228
#
# Results saved to results/adasyn_with_classweight_dann/CWE-787/adasyn_with_classweight_dann_CWE-787.json
# Confusion matrix saved as results/adasyn_with_classweight_dann/CWE-787/confusion_matrix_adasyn_with_classweight_dann_CWE-787.png
