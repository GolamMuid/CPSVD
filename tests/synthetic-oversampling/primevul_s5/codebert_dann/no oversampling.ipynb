# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Leave-One-CWE-Out (LOCO)
Train on ALL CWEs EXCEPT CWE-787 -> Test on CWE-787 (pooled, cross-project)
No Oversampling, With Class Weighting, WITH Domain-Adversarial Neural Network (DANN)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED         = 42
HELD_OUT_CWE = "CWE-787"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
RAW_FILE      = "../../../../dataset/primevul/primevul_raw_combined.jsonl"
EMB_KEY      = "emb"
OUTPUT_DIR   = f"results/no_oversampling_with_classweight_dann/{HELD_OUT_CWE}"

# DANN-specific
LAMBDA_MAX   = 1.0   # max weight for domain loss (GRL strength ceiling)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# CWE Lookup
# =========================================================
def load_cwe_lookup(raw_path):
    cwe_map = {}
    with open(raw_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            rec = json.loads(line)
            cwe_list = rec.get("cwe", [])
            cwe_val = cwe_list[0] if cwe_list else None
            cwe_map[rec["idx"]] = cwe_val
    return cwe_map


# =========================================================
# Data Loading
# =========================================================
def load_jsonl_with_cwe(path, cwe_map):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))

    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    cwe      = np.array([cwe_map.get(r["idx"], None) for r in records], dtype=object)
    return X, y, projects, cwe


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.lambda_ * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self, lambda_=1.0):
        super().__init__()
        self.lambda_ = lambda_

    def forward(self, x):
        return GradientReversalFunction.apply(x, self.lambda_)

    def set_lambda(self, lambda_):
        self.lambda_ = lambda_


# =========================================================
# DANN Architecture: FeatureExtractor + ClassifierHead + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # shared embedding, e.g. dim=64


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.grl = GradientReversalLayer(lambda_=1.0)
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        reversed_features = self.grl(features)
        return self.network(reversed_features)


# =========================================================
# DANN Training Loop
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val,
                class_weights, epochs, desc):
    """
    x_source/y_source : labeled training pool (all CWEs except held-out)
    x_target          : UNLABELED held-out CWE test set (used only for domain adaptation)
    """
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    label_criterion  = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    source_dataset = TensorDataset(
        torch.tensor(x_source, dtype=torch.float32),
        torch.tensor(y_source, dtype=torch.float32)
    )
    target_dataset = TensorDataset(
        torch.tensor(x_target, dtype=torch.float32)
    )

    batch_size = 64
    source_loader = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=batch_size, shuffle=True)

    n_batches = max(len(source_loader), len(target_loader))

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        # p ramps 0 -> 1 across training; used to schedule GRL lambda_ (standard DANN trick)
        p = epoch / max(epochs - 1, 1)
        lambda_ = (2.0 / (1.0 + np.exp(-10 * p)) - 1.0) * LAMBDA_MAX
        domain_discriminator.grl.set_lambda(lambda_)

        source_iter = iter(source_loader)
        target_iter = iter(target_loader)

        for _ in range(n_batches):
            try:
                x_s, y_s = next(source_iter)
            except StopIteration:
                source_iter = iter(source_loader)
                x_s, y_s = next(source_iter)
            try:
                (x_t,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (x_t,) = next(target_iter)

            x_s, y_s = x_s.to(DEVICE), y_s.to(DEVICE)
            x_t = x_t.to(DEVICE)

            optimizer.zero_grad()

            # --- Label prediction loss (source only) ---
            features_s = feature_extractor(x_s)
            label_pred = classifier_head(features_s).squeeze()
            weights    = torch.where(y_s == 1, pos_weight, neg_weight)
            label_loss = (label_criterion(label_pred, y_s) * weights).mean()

            # --- Domain discrimination loss (source + target) ---
            features_t = feature_extractor(x_t)
            domain_pred_s = domain_discriminator(features_s).squeeze()
            domain_pred_t = domain_discriminator(features_t).squeeze()

            domain_labels_s = torch.zeros(domain_pred_s.shape[0]).to(DEVICE)  # source = 0
            domain_labels_t = torch.ones(domain_pred_t.shape[0]).to(DEVICE)   # target = 1

            domain_loss = (domain_criterion(domain_pred_s, domain_labels_s) +
                            domain_criterion(domain_pred_t, domain_labels_t))

            total_loss = label_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        # --- Validation (label loss only, on source val split) ---
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (label_criterion(val_preds, y_val) * weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"label_loss: {label_loss.item():.4f} - domain_loss: {domain_loss.item():.4f} - "
              f"val_loss: {val_loss:.4f} - lambda: {lambda_:.3f}")

    return feature_extractor, classifier_head, domain_discriminator


# =========================================================
# XGBoost (trained on domain-invariant FEATURES)
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])
    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({HELD_OUT_CWE} Test Set) - DANN")
    plt.colorbar(img, ax=ax)
    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | LOCO + DANN: Train on ALL except {HELD_OUT_CWE} -> Test on {HELD_OUT_CWE} ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/6] Building CWE lookup from raw file...")
    cwe_map = load_cwe_lookup(RAW_FILE)

    print("\n[2/6] Loading combined embeddings with CWE join...")
    X_all, y_all, proj_all, cwe_all = load_jsonl_with_cwe(COMBINED_FILE, cwe_map)

    n_missing = int(np.sum((y_all == 1) & (cwe_all == None)))
    if n_missing > 0:
        print(f"      WARNING: {n_missing} vulnerable rows had no CWE match via idx join.")

    print(f"\n[3/6] Splitting by CWE (held-out: {HELD_OUT_CWE})...")
    vuln_mask       = (y_all == 1)
    test_vuln_mask  = vuln_mask & (cwe_all == HELD_OUT_CWE)
    train_vuln_mask = vuln_mask & (cwe_all != HELD_OUT_CWE) & (cwe_all != None)

    if test_vuln_mask.sum() == 0:
        raise ValueError(f"No vulnerable instances found for {HELD_OUT_CWE}. Check CWE join.")

    benign_idx = np.where(y_all == 0)[0]
    benign_train_idx, benign_test_idx = train_test_split(
        benign_idx, test_size=0.2, random_state=SEED
    )

    train_idx = np.concatenate([np.where(train_vuln_mask)[0], benign_train_idx])
    test_idx  = np.concatenate([np.where(test_vuln_mask)[0],  benign_test_idx])

    train_emb = X_all[train_idx].astype(np.float32)
    train_lbl = y_all[train_idx].astype(np.int32)
    test_emb  = X_all[test_idx].astype(np.float32)
    test_lbl  = y_all[test_idx].astype(np.int32)  # only used for FINAL evaluation, never during training

    print(f"      Training pool (source)     : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test set / target ({HELD_OUT_CWE}) : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio   : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[4/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    print("\n[5/6] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(class_weight='balanced', classes=classes, y=train_lbl)
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[6/6] Running DANN + ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN...")

        x_tr, x_val, y_tr, y_val = train_test_split(
            train_emb, train_lbl, test_size=0.2, random_state=SEED
        )
        x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
        y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

        feature_extractor     = FeatureExtractor(train_emb.shape[1]).to(DEVICE)
        classifier_head       = ClassifierHead(feature_dim=64).to(DEVICE)
        domain_discriminator  = DomainDiscriminator(feature_dim=64).to(DEVICE)

        feature_extractor, classifier_head, domain_discriminator = train_dann(
            feature_extractor, classifier_head, domain_discriminator,
            x_source=x_tr, y_source=y_tr,
            x_target=test_emb,          # unlabeled target domain, used only for domain loss
            x_val=x_val_t, y_val=y_val_t,
            class_weights=class_weight_dict,
            epochs=50,
            desc=f"Iter {i+1} - DANN"
        )

        # --- Extract domain-invariant features for train + test ---
        feature_extractor.eval()
        with torch.no_grad():
            train_features = feature_extractor(
                torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()
            test_features = feature_extractor(
                torch.tensor(test_emb, dtype=torch.float32).to(DEVICE)
            ).cpu().numpy()

            y_train_pred = classifier_head(
                torch.tensor(train_features, dtype=torch.float32).to(DEVICE)
            ).squeeze().cpu().numpy()

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost on DANN features...")
        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(
            train_features, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_features)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[Metrics] Computing evaluation metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({HELD_OUT_CWE} Test Set) - DANN ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "no_oversampling_with_classweight_dann",
        "scenario"         : "LOCO",
        "held_out_cwe"     : HELD_OUT_CWE,
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"no_oversampling_with_classweight_dann_{HELD_OUT_CWE}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_no_oversampling_with_classweight_dann_{HELD_OUT_CWE}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | LOCO + DANN: Train on ALL except CWE-787 -> Test on CWE-787 ===
#     Device: mps
#
# [1/6] Building CWE lookup from raw file...
#
# [2/6] Loading combined embeddings with CWE join...
#
# [3/6] Splitting by CWE (held-out: CWE-787)...
#       Training pool (source)     : (180323, 768)  vuln=5500  benign=174823
#       Test set / target (CWE-787) : (44210, 768)  vuln=504  benign=43706
#       Training imbalance ratio   : 0.0305
#
# [4/6] Normalizing embeddings...
#
# [5/6] Computing class weights...
#       Class weights: {0: 0.5157301956836343, 1: 16.393}
#
# [6/6] Running DANN + ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN...
# Iter 1 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - DANN | Epoch 1/50 - label_loss: 0.2316 - domain_loss: 1.3910 - val_loss: 0.5990 - lambda: 0.000
#       Iter 1 - DANN | Epoch 2/50 - label_loss: 0.3323 - domain_loss: 1.3514 - val_loss: 0.5763 - lambda: 0.102
#       Iter 1 - DANN | Epoch 3/50 - label_loss: 2.7843 - domain_loss: 1.3898 - val_loss: 0.5676 - lambda: 0.201
#       Iter 1 - DANN | Epoch 4/50 - label_loss: 0.0364 - domain_loss: 1.2881 - val_loss: 0.5590 - lambda: 0.297
#       Iter 1 - DANN | Epoch 5/50 - label_loss: 0.2667 - domain_loss: 1.3750 - val_loss: 0.5555 - lambda: 0.387
#       Iter 1 - DANN | Epoch 6/50 - label_loss: 1.9891 - domain_loss: 1.4232 - val_loss: 0.5487 - lambda: 0.470
#       Iter 1 - DANN | Epoch 7/50 - label_loss: 0.4325 - domain_loss: 1.3779 - val_loss: 0.5430 - lambda: 0.546
#       Iter 1 - DANN | Epoch 8/50 - label_loss: 0.2459 - domain_loss: 1.3994 - val_loss: 0.5427 - lambda: 0.613
#       Iter 1 - DANN | Epoch 9/50 - label_loss: 0.2278 - domain_loss: 1.3925 - val_loss: 0.5383 - lambda: 0.673
#       Iter 1 - DANN | Epoch 10/50 - label_loss: 0.1816 - domain_loss: 1.4021 - val_loss: 0.5317 - lambda: 0.725
#       Iter 1 - DANN | Epoch 11/50 - label_loss: 0.5227 - domain_loss: 1.4093 - val_loss: 0.5282 - lambda: 0.770
#       Iter 1 - DANN | Epoch 12/50 - label_loss: 0.5064 - domain_loss: 1.3801 - val_loss: 0.5277 - lambda: 0.808
#       Iter 1 - DANN | Epoch 13/50 - label_loss: 0.4379 - domain_loss: 1.3727 - val_loss: 0.5240 - lambda: 0.841
#       Iter 1 - DANN | Epoch 14/50 - label_loss: 0.1353 - domain_loss: 1.3860 - val_loss: 0.5204 - lambda: 0.868
#       Iter 1 - DANN | Epoch 15/50 - label_loss: 0.1401 - domain_loss: 1.3830 - val_loss: 0.5189 - lambda: 0.891
#       Iter 1 - DANN | Epoch 16/50 - label_loss: 0.4511 - domain_loss: 1.3754 - val_loss: 0.5169 - lambda: 0.911
#       Iter 1 - DANN | Epoch 17/50 - label_loss: 0.3486 - domain_loss: 1.3617 - val_loss: 0.5145 - lambda: 0.926
#       Iter 1 - DANN | Epoch 18/50 - label_loss: 0.2344 - domain_loss: 1.4027 - val_loss: 0.5139 - lambda: 0.940
#       Iter 1 - DANN | Epoch 19/50 - label_loss: 0.5086 - domain_loss: 1.3772 - val_loss: 0.5111 - lambda: 0.950
#       Iter 1 - DANN | Epoch 20/50 - label_loss: 0.2165 - domain_loss: 1.3585 - val_loss: 0.5119 - lambda: 0.959
#       Iter 1 - DANN | Epoch 21/50 - label_loss: 0.1019 - domain_loss: 1.3903 - val_loss: 0.5096 - lambda: 0.967
#       Iter 1 - DANN | Epoch 22/50 - label_loss: 0.2844 - domain_loss: 1.3966 - val_loss: 0.5086 - lambda: 0.973
#       Iter 1 - DANN | Epoch 23/50 - label_loss: 0.5087 - domain_loss: 1.3707 - val_loss: 0.5080 - lambda: 0.978
#       Iter 1 - DANN | Epoch 24/50 - label_loss: 0.2602 - domain_loss: 1.3756 - val_loss: 0.5080 - lambda: 0.982
#       Iter 1 - DANN | Epoch 25/50 - label_loss: 0.0227 - domain_loss: 1.4356 - val_loss: 0.5074 - lambda: 0.985
#       Iter 1 - DANN | Epoch 26/50 - label_loss: 0.0687 - domain_loss: 1.3955 - val_loss: 0.5068 - lambda: 0.988
#       Iter 1 - DANN | Epoch 27/50 - label_loss: 0.3682 - domain_loss: 1.3941 - val_loss: 0.5061 - lambda: 0.990
#       Iter 1 - DANN | Epoch 28/50 - label_loss: 0.0858 - domain_loss: 1.3902 - val_loss: 0.5085 - lambda: 0.992
#       Iter 1 - DANN | Epoch 29/50 - label_loss: 0.3971 - domain_loss: 1.3770 - val_loss: 0.5072 - lambda: 0.993
#       Iter 1 - DANN | Epoch 30/50 - label_loss: 0.3173 - domain_loss: 1.3815 - val_loss: 0.5065 - lambda: 0.995
#       Iter 1 - DANN | Epoch 31/50 - label_loss: 0.0351 - domain_loss: 1.4063 - val_loss: 0.5090 - lambda: 0.996
#       Iter 1 - DANN | Epoch 32/50 - label_loss: 0.1785 - domain_loss: 1.3767 - val_loss: 0.5098 - lambda: 0.996
#       Iter 1 - DANN | Epoch 33/50 - label_loss: 0.0968 - domain_loss: 1.4131 - val_loss: 0.5073 - lambda: 0.997
#       Iter 1 - DANN | Epoch 34/50 - label_loss: 0.1052 - domain_loss: 1.3748 - val_loss: 0.5079 - lambda: 0.998
#       Iter 1 - DANN | Epoch 35/50 - label_loss: 0.0699 - domain_loss: 1.4056 - val_loss: 0.5079 - lambda: 0.998
#       Iter 1 - DANN | Epoch 36/50 - label_loss: 0.3290 - domain_loss: 1.3721 - val_loss: 0.5120 - lambda: 0.998
#       Iter 1 - DANN | Epoch 37/50 - label_loss: 0.0638 - domain_loss: 1.3935 - val_loss: 0.5098 - lambda: 0.999
#       Iter 1 - DANN | Epoch 38/50 - label_loss: 0.6834 - domain_loss: 1.3934 - val_loss: 0.5160 - lambda: 0.999
#       Iter 1 - DANN | Epoch 39/50 - label_loss: 0.3929 - domain_loss: 1.3765 - val_loss: 0.5146 - lambda: 0.999
#       Iter 1 - DANN | Epoch 40/50 - label_loss: 0.0145 - domain_loss: 1.3990 - val_loss: 0.5130 - lambda: 0.999
#       Iter 1 - DANN | Epoch 41/50 - label_loss: 0.3821 - domain_loss: 1.3789 - val_loss: 0.5178 - lambda: 0.999
#       Iter 1 - DANN | Epoch 42/50 - label_loss: 0.1647 - domain_loss: 1.3874 - val_loss: 0.5168 - lambda: 1.000
#       Iter 1 - DANN | Epoch 43/50 - label_loss: 0.3315 - domain_loss: 1.3720 - val_loss: 0.5214 - lambda: 1.000
#       Iter 1 - DANN | Epoch 44/50 - label_loss: 0.2049 - domain_loss: 1.3910 - val_loss: 0.5223 - lambda: 1.000
#       Iter 1 - DANN | Epoch 45/50 - label_loss: 0.4695 - domain_loss: 1.3961 - val_loss: 0.5206 - lambda: 1.000
#       Iter 1 - DANN | Epoch 46/50 - label_loss: 0.6563 - domain_loss: 1.3739 - val_loss: 0.5243 - lambda: 1.000
#       Iter 1 - DANN | Epoch 47/50 - label_loss: 0.2093 - domain_loss: 1.3852 - val_loss: 0.5268 - lambda: 1.000
#       Iter 1 - DANN | Epoch 48/50 - label_loss: 0.2950 - domain_loss: 1.3938 - val_loss: 0.5297 - lambda: 1.000
#       Iter 1 - DANN | Epoch 49/50 - label_loss: 0.2163 - domain_loss: 1.3732 - val_loss: 0.5258 - lambda: 1.000
#       Iter 1 - DANN | Epoch 50/50 - label_loss: 0.0788 - domain_loss: 1.3934 - val_loss: 0.5310 - lambda: 1.000
#       [Iteration 1/3] Training XGBoost on DANN features...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN...
# Iter 2 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - DANN | Epoch 1/50 - label_loss: 0.2821 - domain_loss: 1.3587 - val_loss: 0.5902 - lambda: 0.000
#       Iter 2 - DANN | Epoch 2/50 - label_loss: 0.4771 - domain_loss: 1.3712 - val_loss: 0.5755 - lambda: 0.102
#       Iter 2 - DANN | Epoch 3/50 - label_loss: 0.4911 - domain_loss: 1.3438 - val_loss: 0.5637 - lambda: 0.201
#       Iter 2 - DANN | Epoch 4/50 - label_loss: 0.4372 - domain_loss: 1.3669 - val_loss: 0.5553 - lambda: 0.297
#       Iter 2 - DANN | Epoch 5/50 - label_loss: 0.1870 - domain_loss: 1.4033 - val_loss: 0.5503 - lambda: 0.387
#       Iter 2 - DANN | Epoch 6/50 - label_loss: 0.5637 - domain_loss: 1.3866 - val_loss: 0.5446 - lambda: 0.470
#       Iter 2 - DANN | Epoch 7/50 - label_loss: 0.0702 - domain_loss: 1.4714 - val_loss: 0.5403 - lambda: 0.546
#       Iter 2 - DANN | Epoch 8/50 - label_loss: 0.1178 - domain_loss: 1.3523 - val_loss: 0.5365 - lambda: 0.613
#       Iter 2 - DANN | Epoch 9/50 - label_loss: 0.3759 - domain_loss: 1.3729 - val_loss: 0.5329 - lambda: 0.673
#       Iter 2 - DANN | Epoch 10/50 - label_loss: 0.6887 - domain_loss: 1.4422 - val_loss: 0.5306 - lambda: 0.725
#       Iter 2 - DANN | Epoch 11/50 - label_loss: 0.4119 - domain_loss: 1.3884 - val_loss: 0.5265 - lambda: 0.770
#       Iter 2 - DANN | Epoch 12/50 - label_loss: 0.2597 - domain_loss: 1.3893 - val_loss: 0.5284 - lambda: 0.808
#       Iter 2 - DANN | Epoch 13/50 - label_loss: 0.1513 - domain_loss: 1.3540 - val_loss: 0.5204 - lambda: 0.841
#       Iter 2 - DANN | Epoch 14/50 - label_loss: 0.2229 - domain_loss: 1.3529 - val_loss: 0.5191 - lambda: 0.868
#       Iter 2 - DANN | Epoch 15/50 - label_loss: 0.5929 - domain_loss: 1.4046 - val_loss: 0.5184 - lambda: 0.891
#       Iter 2 - DANN | Epoch 16/50 - label_loss: 0.6010 - domain_loss: 1.3596 - val_loss: 0.5135 - lambda: 0.911
#       Iter 2 - DANN | Epoch 17/50 - label_loss: 0.4674 - domain_loss: 1.3707 - val_loss: 0.5162 - lambda: 0.926
#       Iter 2 - DANN | Epoch 18/50 - label_loss: 0.1594 - domain_loss: 1.4100 - val_loss: 0.5112 - lambda: 0.940
#       Iter 2 - DANN | Epoch 19/50 - label_loss: 0.0626 - domain_loss: 1.3757 - val_loss: 0.5092 - lambda: 0.950
#       Iter 2 - DANN | Epoch 20/50 - label_loss: 0.2099 - domain_loss: 1.3755 - val_loss: 0.5090 - lambda: 0.959
#       Iter 2 - DANN | Epoch 21/50 - label_loss: 0.0861 - domain_loss: 1.4331 - val_loss: 0.5087 - lambda: 0.967
#       Iter 2 - DANN | Epoch 22/50 - label_loss: 0.6924 - domain_loss: 1.3777 - val_loss: 0.5092 - lambda: 0.973
#       Iter 2 - DANN | Epoch 23/50 - label_loss: 0.3613 - domain_loss: 1.3805 - val_loss: 0.5051 - lambda: 0.978
#       Iter 2 - DANN | Epoch 24/50 - label_loss: 0.0636 - domain_loss: 1.4110 - val_loss: 0.5040 - lambda: 0.982
#       Iter 2 - DANN | Epoch 25/50 - label_loss: 0.5908 - domain_loss: 1.3604 - val_loss: 0.5043 - lambda: 0.985
#       Iter 2 - DANN | Epoch 26/50 - label_loss: 0.2108 - domain_loss: 1.3813 - val_loss: 0.5034 - lambda: 0.988
#       Iter 2 - DANN | Epoch 27/50 - label_loss: 0.2045 - domain_loss: 1.4011 - val_loss: 0.5020 - lambda: 0.990
#       Iter 2 - DANN | Epoch 28/50 - label_loss: 0.0550 - domain_loss: 1.3741 - val_loss: 0.5036 - lambda: 0.992
#       Iter 2 - DANN | Epoch 29/50 - label_loss: 0.0601 - domain_loss: 1.4522 - val_loss: 0.5052 - lambda: 0.993
#       Iter 2 - DANN | Epoch 30/50 - label_loss: 0.1984 - domain_loss: 1.3800 - val_loss: 0.5083 - lambda: 0.995
#       Iter 2 - DANN | Epoch 31/50 - label_loss: 0.2263 - domain_loss: 1.3855 - val_loss: 0.5028 - lambda: 0.996
#       Iter 2 - DANN | Epoch 32/50 - label_loss: 0.4600 - domain_loss: 1.3800 - val_loss: 0.5096 - lambda: 0.996
#       Iter 2 - DANN | Epoch 33/50 - label_loss: 0.2781 - domain_loss: 1.3794 - val_loss: 0.5059 - lambda: 0.997
#       Iter 2 - DANN | Epoch 34/50 - label_loss: 0.8375 - domain_loss: 1.3367 - val_loss: 0.5061 - lambda: 0.998
#       Iter 2 - DANN | Epoch 35/50 - label_loss: 1.2617 - domain_loss: 1.3737 - val_loss: 0.5057 - lambda: 0.998
#       Iter 2 - DANN | Epoch 36/50 - label_loss: 0.1924 - domain_loss: 1.3830 - val_loss: 0.5077 - lambda: 0.998
#       Iter 2 - DANN | Epoch 37/50 - label_loss: 0.0035 - domain_loss: 1.4108 - val_loss: 0.5063 - lambda: 0.999
#       Iter 2 - DANN | Epoch 38/50 - label_loss: 0.5873 - domain_loss: 1.3560 - val_loss: 0.5085 - lambda: 0.999
#       Iter 2 - DANN | Epoch 39/50 - label_loss: 0.0782 - domain_loss: 1.3908 - val_loss: 0.5119 - lambda: 0.999
#       Iter 2 - DANN | Epoch 40/50 - label_loss: 0.6014 - domain_loss: 1.3566 - val_loss: 0.5114 - lambda: 0.999
#       Iter 2 - DANN | Epoch 41/50 - label_loss: 0.2744 - domain_loss: 1.3969 - val_loss: 0.5108 - lambda: 0.999
#       Iter 2 - DANN | Epoch 42/50 - label_loss: 0.4579 - domain_loss: 1.3803 - val_loss: 0.5153 - lambda: 1.000
#       Iter 2 - DANN | Epoch 43/50 - label_loss: 0.0347 - domain_loss: 1.4011 - val_loss: 0.5124 - lambda: 1.000
#       Iter 2 - DANN | Epoch 44/50 - label_loss: 0.0183 - domain_loss: 1.3892 - val_loss: 0.5255 - lambda: 1.000
#       Iter 2 - DANN | Epoch 45/50 - label_loss: 0.3946 - domain_loss: 1.3729 - val_loss: 0.5167 - lambda: 1.000
#       Iter 2 - DANN | Epoch 46/50 - label_loss: 0.0095 - domain_loss: 1.4512 - val_loss: 0.5230 - lambda: 1.000
#       Iter 2 - DANN | Epoch 47/50 - label_loss: 0.1154 - domain_loss: 1.3892 - val_loss: 0.5201 - lambda: 1.000
#       Iter 2 - DANN | Epoch 48/50 - label_loss: 0.5164 - domain_loss: 1.3841 - val_loss: 0.5256 - lambda: 1.000
#       Iter 2 - DANN | Epoch 49/50 - label_loss: 0.2389 - domain_loss: 1.4003 - val_loss: 0.5251 - lambda: 1.000
#       Iter 2 - DANN | Epoch 50/50 - label_loss: 0.2911 - domain_loss: 1.3911 - val_loss: 0.5251 - lambda: 1.000
#       [Iteration 2/3] Training XGBoost on DANN features...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN...
# Iter 3 - DANN:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - DANN | Epoch 1/50 - label_loss: 0.5770 - domain_loss: 1.3700 - val_loss: 0.5814 - lambda: 0.000
#       Iter 3 - DANN | Epoch 2/50 - label_loss: 0.4233 - domain_loss: 1.4020 - val_loss: 0.5723 - lambda: 0.102
#       Iter 3 - DANN | Epoch 3/50 - label_loss: 0.4266 - domain_loss: 1.3725 - val_loss: 0.5652 - lambda: 0.201
#       Iter 3 - DANN | Epoch 4/50 - label_loss: 0.2341 - domain_loss: 1.4115 - val_loss: 0.5575 - lambda: 0.297
#       Iter 3 - DANN | Epoch 5/50 - label_loss: 0.2700 - domain_loss: 1.4262 - val_loss: 0.5540 - lambda: 0.387
#       Iter 3 - DANN | Epoch 6/50 - label_loss: 0.0749 - domain_loss: 1.4042 - val_loss: 0.5491 - lambda: 0.470
#       Iter 3 - DANN | Epoch 7/50 - label_loss: 0.1351 - domain_loss: 1.3522 - val_loss: 0.5453 - lambda: 0.546
#       Iter 3 - DANN | Epoch 8/50 - label_loss: 0.1906 - domain_loss: 1.4041 - val_loss: 0.5410 - lambda: 0.613
#       Iter 3 - DANN | Epoch 9/50 - label_loss: 0.2791 - domain_loss: 1.3778 - val_loss: 0.5366 - lambda: 0.673
#       Iter 3 - DANN | Epoch 10/50 - label_loss: 0.0542 - domain_loss: 1.3739 - val_loss: 0.5333 - lambda: 0.725
#       Iter 3 - DANN | Epoch 11/50 - label_loss: 0.1772 - domain_loss: 1.3951 - val_loss: 0.5318 - lambda: 0.770
#       Iter 3 - DANN | Epoch 12/50 - label_loss: 0.0904 - domain_loss: 1.3472 - val_loss: 0.5292 - lambda: 0.808
#       Iter 3 - DANN | Epoch 13/50 - label_loss: 0.0854 - domain_loss: 1.3616 - val_loss: 0.5263 - lambda: 0.841
#       Iter 3 - DANN | Epoch 14/50 - label_loss: 0.3299 - domain_loss: 1.3819 - val_loss: 0.5217 - lambda: 0.868
#       Iter 3 - DANN | Epoch 15/50 - label_loss: 0.0483 - domain_loss: 1.3867 - val_loss: 0.5195 - lambda: 0.891
#       Iter 3 - DANN | Epoch 16/50 - label_loss: 0.5271 - domain_loss: 1.3892 - val_loss: 0.5177 - lambda: 0.911
#       Iter 3 - DANN | Epoch 17/50 - label_loss: 0.1032 - domain_loss: 1.4130 - val_loss: 0.5157 - lambda: 0.926
#       Iter 3 - DANN | Epoch 18/50 - label_loss: 0.4398 - domain_loss: 1.3884 - val_loss: 0.5138 - lambda: 0.940
#       Iter 3 - DANN | Epoch 19/50 - label_loss: 0.0088 - domain_loss: 1.3686 - val_loss: 0.5123 - lambda: 0.950
#       Iter 3 - DANN | Epoch 20/50 - label_loss: 0.3753 - domain_loss: 1.3671 - val_loss: 0.5105 - lambda: 0.959
#       Iter 3 - DANN | Epoch 21/50 - label_loss: 0.1648 - domain_loss: 1.3867 - val_loss: 0.5090 - lambda: 0.967
#       Iter 3 - DANN | Epoch 22/50 - label_loss: 0.0617 - domain_loss: 1.3891 - val_loss: 0.5081 - lambda: 0.973
#       Iter 3 - DANN | Epoch 23/50 - label_loss: 0.1537 - domain_loss: 1.3930 - val_loss: 0.5083 - lambda: 0.978
#       Iter 3 - DANN | Epoch 24/50 - label_loss: 0.2320 - domain_loss: 1.4055 - val_loss: 0.5073 - lambda: 0.982
#       Iter 3 - DANN | Epoch 25/50 - label_loss: 7.1653 - domain_loss: 1.3781 - val_loss: 0.5074 - lambda: 0.985
#       Iter 3 - DANN | Epoch 26/50 - label_loss: 0.0370 - domain_loss: 1.3914 - val_loss: 0.5083 - lambda: 0.988
#       Iter 3 - DANN | Epoch 27/50 - label_loss: 0.8495 - domain_loss: 1.3796 - val_loss: 0.5059 - lambda: 0.990
#       Iter 3 - DANN | Epoch 28/50 - label_loss: 0.0268 - domain_loss: 1.3532 - val_loss: 0.5065 - lambda: 0.992
#       Iter 3 - DANN | Epoch 29/50 - label_loss: 0.0364 - domain_loss: 1.4000 - val_loss: 0.5044 - lambda: 0.993
#       Iter 3 - DANN | Epoch 30/50 - label_loss: 0.1906 - domain_loss: 1.3855 - val_loss: 0.5078 - lambda: 0.995
#       Iter 3 - DANN | Epoch 31/50 - label_loss: 0.7008 - domain_loss: 1.3692 - val_loss: 0.5079 - lambda: 0.996
#       Iter 3 - DANN | Epoch 32/50 - label_loss: 0.2627 - domain_loss: 1.3892 - val_loss: 0.5067 - lambda: 0.996
#       Iter 3 - DANN | Epoch 33/50 - label_loss: 0.3794 - domain_loss: 1.4161 - val_loss: 0.5080 - lambda: 0.997
#       Iter 3 - DANN | Epoch 34/50 - label_loss: 0.0097 - domain_loss: 1.3963 - val_loss: 0.5075 - lambda: 0.998
#       Iter 3 - DANN | Epoch 35/50 - label_loss: 0.0188 - domain_loss: 1.3901 - val_loss: 0.5109 - lambda: 0.998
#       Iter 3 - DANN | Epoch 36/50 - label_loss: 2.1026 - domain_loss: 1.3598 - val_loss: 0.5093 - lambda: 0.998
#       Iter 3 - DANN | Epoch 37/50 - label_loss: 0.0950 - domain_loss: 1.4079 - val_loss: 0.5113 - lambda: 0.999
#       Iter 3 - DANN | Epoch 38/50 - label_loss: 0.1409 - domain_loss: 1.3913 - val_loss: 0.5104 - lambda: 0.999
#       Iter 3 - DANN | Epoch 39/50 - label_loss: 0.0210 - domain_loss: 1.3826 - val_loss: 0.5100 - lambda: 0.999
#       Iter 3 - DANN | Epoch 40/50 - label_loss: 2.0102 - domain_loss: 1.3850 - val_loss: 0.5123 - lambda: 0.999
#       Iter 3 - DANN | Epoch 41/50 - label_loss: 0.3440 - domain_loss: 1.3887 - val_loss: 0.5151 - lambda: 0.999
#       Iter 3 - DANN | Epoch 42/50 - label_loss: 0.0347 - domain_loss: 1.3974 - val_loss: 0.5153 - lambda: 1.000
#       Iter 3 - DANN | Epoch 43/50 - label_loss: 0.0272 - domain_loss: 1.3997 - val_loss: 0.5198 - lambda: 1.000
#       Iter 3 - DANN | Epoch 44/50 - label_loss: 0.0232 - domain_loss: 1.4002 - val_loss: 0.5205 - lambda: 1.000
#       Iter 3 - DANN | Epoch 45/50 - label_loss: 0.2290 - domain_loss: 1.4027 - val_loss: 0.5149 - lambda: 1.000
#       Iter 3 - DANN | Epoch 46/50 - label_loss: 0.6053 - domain_loss: 1.3705 - val_loss: 0.5167 - lambda: 1.000
#       Iter 3 - DANN | Epoch 47/50 - label_loss: 0.3428 - domain_loss: 1.3768 - val_loss: 0.5229 - lambda: 1.000
#       Iter 3 - DANN | Epoch 48/50 - label_loss: 0.2704 - domain_loss: 1.3917 - val_loss: 0.5229 - lambda: 1.000
#       Iter 3 - DANN | Epoch 49/50 - label_loss: 0.2366 - domain_loss: 1.3912 - val_loss: 0.5288 - lambda: 1.000
#       Iter 3 - DANN | Epoch 50/50 - label_loss: 0.0547 - domain_loss: 1.3935 - val_loss: 0.5241 - lambda: 1.000
#       [Iteration 3/3] Training XGBoost on DANN features...
#       [Iteration 3/3] Done
#
# [Metrics] Computing evaluation metrics...
#
# === Evaluation Results (CWE-787 Test Set) - DANN ===
# Accuracy  : 0.766
# Precision : 0.036
# Recall    : 0.760
# F1-score  : 0.069
# AUC       : 0.839
# G-mean    : 0.763
# PF value  : 0.234
#
# Confusion Matrix:
#   TN: 33499  FP: 10207
#   FN: 121  TP: 383
#
# Results saved to results/no_oversampling_with_classweight_dann/CWE-787/no_oversampling_with_classweight_dann_CWE-787.json
# Confusion matrix saved as results/no_oversampling_with_classweight_dann/CWE-787/confusion_matrix_no_oversampling_with_classweight_dann_CWE-787.png
