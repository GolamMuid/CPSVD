# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
No Oversampling Baseline
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation and Class Weights
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze()
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (criterion(val_preds, y_val) * weights).mean().item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss(reduction='none')

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codet5/debian_codet5p_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codet5/debian_codet5p_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Computing class weights...")
    classes           = np.unique(deb_lbl)
    class_weights     = compute_class_weight(class_weight='balanced', classes=classes, y=deb_lbl)
    class_weight_dict = {int(cls): float(w) for cls, w in zip(classes, class_weights)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb, deb_lbl,
            chr_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb, deb_lbl, class_weight_dict, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "no_oversampling",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "no_oversampling.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_no_oversampling.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 256) | Chrome: (4436, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing class weights...
#       Class weights: {0: 0.5419060593496416, 1: 6.465724381625441}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6803
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6789
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6773
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6753
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6730
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6697
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6644
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6559
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6436
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6276
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.6136
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.6021
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.5934
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.5865
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.5802
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.5744
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.5692
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.5639
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.5589
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.5548
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.5510
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.5480
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.5452
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.5427
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.5404
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.5384
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.5366
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.5350
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.5332
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.5319
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.5304
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.5291
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.5279
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.5270
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.5260
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.5249
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.5235
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.5227
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.5218
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.5215
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.5207
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.5205
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.5193
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.5186
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.5187
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.5182
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.5172
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.5171
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.5166
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.5163
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5251
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5258
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5251
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.5215
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.5171
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.5118
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.5083
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.5054
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.5016
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.4975
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.4933
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.4901
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.4873
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.4830
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.4793
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.4734
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.4699
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.4659
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.4627
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.4597
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.4562
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.4510
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.4484
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.4446
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.4406
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.4358
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.4350
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.4295
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.4269
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.4229
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6743
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6737
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6727
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6714
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6691
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6656
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6608
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6544
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6470
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.6378
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.6269
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.6142
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.6004
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.5876
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.5756
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.5659
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.5587
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.5535
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.5498
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.5466
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.5440
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.5418
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.5397
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.5377
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.5358
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.5341
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.5328
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.5313
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.5297
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.5284
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.5267
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.5257
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.5244
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.5233
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.5222
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.5211
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.5198
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.5193
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.5181
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.5174
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.5165
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.5156
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.5149
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.5143
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.5131
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.5125
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.5120
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.5122
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.5116
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.5103
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.5240
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.5261
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5242
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.5221
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.5205
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.5141
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.5091
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.5042
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.5015
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.4951
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.4929
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.4888
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.4861
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.4818
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.4775
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.4726
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.4709
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.4676
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.4645
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.4598
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.4563
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.4513
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.4503
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.4467
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.4430
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.4366
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.4330
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.4332
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.4281
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.4273
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6753
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6748
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6740
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6727
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6706
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6674
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6632
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.6578
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.6492
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.6354
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.6192
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.6028
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.5877
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.5750
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.5655
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.5586
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.5532
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.5493
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.5462
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.5436
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.5414
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.5397
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.5379
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.5358
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.5341
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.5320
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.5305
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.5292
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.5278
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.5262
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.5248
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.5237
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.5222
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.5208
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.5195
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.5190
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.5177
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.5164
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.5152
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.5143
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.5134
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.5126
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.5117
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.5113
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.5107
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.5105
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.5094
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.5089
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.5080
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.5084
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5195
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.5202
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.5149
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.5122
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.5066
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.5020
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.4988
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.4945
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.4910
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.4884
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.4849
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.4811
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.4769
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.4730
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.4698
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.4645
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.4615
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.4565
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.4536
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.4507
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.4467
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.4425
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.4397
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.4372
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.4330
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.4329
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.4300
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.4260
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.4238
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.4207
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.707
# Precision:  0.254
# Recall:     0.298
# F1-score:   0.275
# AUC:        0.597
# G-mean:     0.489
# PF value:   0.200
#
# Confusion Matrix:
# TN: 2890  FP: 721
# FN: 579  TP: 246
#
# Results saved to results/no_oversampling.json
# Confusion matrix saved as results/confusion_matrix_no_oversampling.png
