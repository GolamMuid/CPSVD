# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
SVMSMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SVMSMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (SVMSMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codet5/debian_codet5p_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codet5/debian_codet5p_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying SVMSMOTE...")
    svmsmote                              = SVMSMOTE(random_state=SEED)
    deb_emb_svmsmote, deb_lbl_svmsmote   = svmsmote.fit_resample(deb_emb, deb_lbl)
    print(f"      Before SVMSMOTE: {deb_emb.shape} | After SVMSMOTE: {deb_emb_svmsmote.shape}")
    unique, counts = np.unique(deb_lbl_svmsmote, return_counts=True)
    print(f"      Class distribution after SVMSMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_svmsmote, deb_lbl_svmsmote,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_svmsmote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_svmsmote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_svmsmote, deb_lbl_svmsmote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "svmsmote",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "svmsmote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_svmsmote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (SVMSMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 256) | Chrome: (4436, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SVMSMOTE...
#       Before SVMSMOTE: (18298, 256) | After SVMSMOTE: (33766, 256)
#       Class distribution after SVMSMOTE: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16883)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6895
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6730
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6179
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.5024
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.4397
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.4175
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.4033
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3919
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.3830
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.3743
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.3671
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.3598
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.3527
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.3461
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.3397
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.3340
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.3268
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3200
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.3139
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.3078
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.3013
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.2954
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.2901
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.2850
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.2807
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.2767
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.2717
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.2679
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.2642
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.2602
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.2565
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2536
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2501
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2477
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2443
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2414
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2391
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2368
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2340
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2320
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2299
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2279
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2261
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2240
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2230
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2212
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2192
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2177
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2166
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2160
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2100
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2053
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.2024
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1982
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1960
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1935
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1918
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1882
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1859
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1843
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1829
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1816
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1781
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1768
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1733
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1715
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1707
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1688
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1686
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1676
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1653
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1625
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1614
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1598
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1615
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1582
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1561
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1568
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1561
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1540
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6871
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6625
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.5927
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.4886
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.4394
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.4177
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.4042
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.3927
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.3829
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.3743
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.3669
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.3587
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.3515
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.3445
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.3373
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.3305
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.3235
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.3174
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.3110
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.3050
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.3000
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.2933
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.2890
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.2838
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.2786
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.2740
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.2702
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.2666
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.2635
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.2596
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.2565
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.2537
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.2501
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.2465
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2442
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2422
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2394
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2368
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2342
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2325
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2312
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2287
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2270
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2251
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2237
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2223
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2206
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2201
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2174
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2165
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2114
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.2069
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.2033
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.2008
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1969
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1942
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1908
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1887
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1852
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1845
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1825
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1794
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1771
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1764
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1737
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1716
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1717
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1702
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1673
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1673
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1669
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1639
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1619
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1626
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1594
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1591
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1574
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1574
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1546
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1542
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6882
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6651
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.5785
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4834
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.4373
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.4165
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.4029
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3923
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.3821
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.3735
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.3650
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.3578
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.3508
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.3425
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.3353
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.3281
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3213
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3148
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3085
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.3025
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.2970
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.2919
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.2864
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.2818
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.2777
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.2742
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.2695
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.2652
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.2619
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.2583
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2561
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2521
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2492
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2476
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2439
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2411
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2396
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2359
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2336
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2326
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2294
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2271
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2255
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2232
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2229
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2208
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2199
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2168
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2166
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2139
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2087
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2039
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.2006
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1970
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1955
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1916
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1888
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1886
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1831
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1829
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1789
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1780
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1760
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1748
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1736
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1721
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1699
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1687
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1680
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1671
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1651
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1629
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1616
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1617
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1615
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1570
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1575
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1554
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1550
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1557
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.775
# Precision:  0.204
# Recall:     0.073
# F1-score:   0.107
# AUC:        0.577
# G-mean:     0.261
# PF value:   0.065
#
# Confusion Matrix:
# TN: 3377  FP: 234
# FN: 765  TP: 60
#
# Results saved to results/svmsmote.json
# Confusion matrix saved as results/confusion_matrix_svmsmote.png
