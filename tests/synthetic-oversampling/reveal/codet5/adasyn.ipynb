# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
ADASYN Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codet5/debian_codet5p_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codet5/debian_codet5p_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    deb_emb_adasyn, deb_lbl_adasyn = adasyn.fit_resample(deb_emb, deb_lbl)
    print(f"      Before ADASYN: {deb_emb.shape} | After ADASYN: {deb_emb_adasyn.shape}")
    unique, counts = np.unique(deb_lbl_adasyn, return_counts=True)
    print(f"      Class distribution after ADASYN: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_adasyn, deb_lbl_adasyn,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_adasyn, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_adasyn == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_adasyn, deb_lbl_adasyn, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "adasyn",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (ADASYN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 256) | Chrome: (4436, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN: (18298, 256) | After ADASYN: (33519, 256)
#       Class distribution after ADASYN: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16636)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6942
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6865
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6636
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6147
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.5738
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.5419
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.5171
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.4989
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.4845
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.4721
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.4607
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.4498
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.4397
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.4298
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.4201
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.4109
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.4018
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3928
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.3842
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.3752
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.3667
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.3590
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.3523
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.3441
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.3389
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.3306
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.3257
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.3183
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.3133
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.3084
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.3032
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2990
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2944
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2893
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2851
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2799
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2773
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2729
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2720
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2685
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2628
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2611
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2576
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2530
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2499
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2475
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2472
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2418
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2415
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2385
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2310
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2226
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.2208
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.2165
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.2103
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.2067
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.2050
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1998
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1981
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1918
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1889
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1897
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1824
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1818
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1807
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1794
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1769
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1742
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1727
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1723
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1678
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1664
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1679
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1653
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1618
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1610
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1623
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1583
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1590
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1577
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6901
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6800
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6591
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6203
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.5691
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.5321
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.5111
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.4948
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.4809
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.4693
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.4590
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.4493
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.4399
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.4310
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.4222
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.4131
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.4049
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.3962
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.3890
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.3812
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.3733
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.3671
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.3610
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.3549
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.3485
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.3424
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.3359
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.3296
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.3243
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.3190
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.3141
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.3101
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.3063
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.3009
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2958
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2932
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2888
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2850
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2817
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2769
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2733
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2705
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2658
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2625
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2613
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2591
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2553
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2540
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2503
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2449
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2383
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.2291
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.2236
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.2196
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.2170
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.2081
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.2072
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.2053
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.2016
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1972
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1926
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1909
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1890
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1828
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1854
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1822
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1793
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1786
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1741
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1726
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1696
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1697
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1695
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1681
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1654
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1661
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1634
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1588
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1591
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1600
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6913
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6838
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6645
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6149
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.5620
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.5256
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.5031
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.4871
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.4737
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.4617
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.4504
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.4406
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.4311
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.4214
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.4122
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.4025
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3934
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3848
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3766
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.3680
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.3605
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.3524
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.3459
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.3371
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.3323
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.3260
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.3199
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.3146
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.3090
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.3048
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2977
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2939
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2898
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2869
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2827
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2783
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2736
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2725
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2673
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2634
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2622
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2582
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2552
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2526
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2511
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2470
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2441
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2435
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2394
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2393
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2306
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2243
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.2172
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.2131
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.2090
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.2069
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.2013
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.2005
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1935
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1897
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1885
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1865
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1846
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1801
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1806
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1766
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1767
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1757
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1717
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1652
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1693
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1660
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1658
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1645
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1604
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1579
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1586
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1584
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1573
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1552
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.768
# Precision:  0.275
# Recall:     0.152
# F1-score:   0.195
# AUC:        0.592
# G-mean:     0.371
# PF value:   0.091
#
# Confusion Matrix:
# TN: 3282  FP: 329
# FN: 700  TP: 125
#
# Results saved to results/adasyn.json
# Confusion matrix saved as results/confusion_matrix_adasyn.png
