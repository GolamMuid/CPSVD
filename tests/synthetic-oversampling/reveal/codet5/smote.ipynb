# %%
""""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
SMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (SMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codet5/debian_codet5p_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codet5/debian_codet5p_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying SMOTE...")
    smote                       = SMOTE(random_state=SEED)
    deb_emb_smote, deb_lbl_smote = smote.fit_resample(deb_emb, deb_lbl)
    print(f"      Before SMOTE: {deb_emb.shape} | After SMOTE: {deb_emb_smote.shape}")
    unique, counts = np.unique(deb_lbl_smote, return_counts=True)
    print(f"      Class distribution after SMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_smote, deb_lbl_smote,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_smote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_smote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_smote, deb_lbl_smote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "smote",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "smote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_smote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (SMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 256) | Chrome: (4436, 256)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SMOTE...
#       Before SMOTE: (18298, 256) | After SMOTE: (33766, 256)
#       Class distribution after SMOTE: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16883)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6924
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6836
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6571
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6013
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.5516
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.5181
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.4977
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.4822
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.4686
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.4565
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.4449
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.4348
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.4247
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.4148
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.4056
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.3967
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.3867
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3777
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.3697
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.3621
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.3539
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.3468
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.3393
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.3333
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.3284
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.3219
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.3161
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.3130
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.3071
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.3025
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.2970
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2942
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2889
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2859
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2814
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2767
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2741
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2714
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2678
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2640
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2629
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2601
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2569
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2538
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2531
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2502
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2474
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2452
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2439
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2413
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2340
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2287
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.2223
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.2165
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.2123
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.2094
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.2060
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.2015
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1980
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1947
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1944
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1886
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1868
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1842
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1815
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1754
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1770
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1755
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1719
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1699
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1664
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1638
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1642
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1613
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1613
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1593
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1569
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1550
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1556
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1527
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6898
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6779
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6514
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6006
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.5429
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.5121
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.4944
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.4795
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.4663
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.4539
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.4436
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.4332
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.4241
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.4157
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.4070
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.3989
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.3902
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.3826
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.3743
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.3666
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.3602
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.3525
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.3472
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.3407
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.3348
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.3286
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.3244
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.3197
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.3150
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.3092
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.3045
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.3005
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.2960
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.2911
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2869
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2832
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2801
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2775
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2710
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2680
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2662
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2638
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2605
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2570
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2541
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2516
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2484
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2485
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2440
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2436
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2363
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.2273
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.2233
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.2195
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.2163
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.2124
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.2072
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.2039
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.2000
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1986
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1970
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1900
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1879
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1887
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1824
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1796
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1784
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1748
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1722
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1751
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1733
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1696
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1667
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1671
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1630
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1632
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1616
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1593
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1567
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1569
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6907
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6821
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6564
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.5923
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.5345
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.5059
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.4880
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.4740
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.4611
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.4496
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.4381
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.4278
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.4180
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.4076
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.3983
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.3891
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3801
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3715
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3631
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.3562
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.3479
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.3414
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.3346
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.3287
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.3229
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.3175
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.3118
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.3060
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.3017
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.2974
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2944
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2890
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2852
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2824
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2782
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2742
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2733
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2699
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2656
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2637
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2601
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2572
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2542
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2519
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2515
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2492
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2454
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2428
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2425
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2398
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2319
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2252
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.2195
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.2145
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.2105
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.2054
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.2010
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.2032
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1946
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1944
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1873
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1874
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1833
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1821
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1814
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1774
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1778
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1728
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1700
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1720
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1680
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1671
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1629
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1636
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1624
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1590
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1585
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1564
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1567
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1564
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.773
# Precision:  0.288
# Recall:     0.150
# F1-score:   0.197
# AUC:        0.586
# G-mean:     0.371
# PF value:   0.085
#
# Confusion Matrix:
# TN: 3304  FP: 307
# FN: 701  TP: 124
#
# Results saved to results/smote.json
# Confusion matrix saved as results/confusion_matrix_smote.png
