# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
No Oversampling Baseline
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation and Class Weights
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze()
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (criterion(val_preds, y_val) * weights).mean().item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss(reduction='none')

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codebert/debian_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codebert/debian_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codebert/chrome_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codebert/chrome_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Computing class weights...")
    classes           = np.unique(deb_lbl)
    class_weights     = compute_class_weight(class_weight='balanced', classes=classes, y=deb_lbl)
    class_weight_dict = {int(cls): float(w) for cls, w in zip(classes, class_weights)}
    print(f"      Class weights: {class_weight_dict}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb, deb_lbl,
            chr_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb, deb_lbl, class_weight_dict, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "no_oversampling",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "no_oversampling.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_no_oversampling.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 768) | Chrome: (4436, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing class weights...
#       Class weights: {0: 0.5419060593496416, 1: 6.465724381625441}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6728
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6701
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6649
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.6562
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.6457
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.6356
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.6265
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.6178
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.6102
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.6021
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.5939
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.5866
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.5808
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.5767
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.5730
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.5698
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.5664
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.5633
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.5603
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.5576
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.5544
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.5513
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.5483
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.5459
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.5433
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.5407
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.5381
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.5357
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.5334
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.5307
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.5292
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.5268
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.5251
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.5224
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.5202
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.5210
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.5177
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.5173
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.5164
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.5125
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.5119
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.5107
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.5111
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.5102
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.5100
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.5086
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.5111
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.5085
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.5088
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.5088
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5207
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5158
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5195
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.5173
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.5132
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.5058
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.5007
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.4914
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.4888
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.4854
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.4795
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.4753
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.4724
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.4689
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.4651
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.4622
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.4572
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.4529
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.4517
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.4432
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.4455
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.4432
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.4323
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.4328
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.4327
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.4257
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.4213
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.4250
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.4202
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.4223
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6721
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6685
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.6632
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.6548
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.6438
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.6337
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.6241
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.6152
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.6044
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.5943
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.5855
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.5797
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.5750
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.5719
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.5683
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.5645
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.5608
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.5570
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.5541
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.5506
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.5469
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.5438
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.5405
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.5374
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.5347
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.5316
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.5288
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.5267
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.5222
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.5209
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.5190
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.5179
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.5154
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.5130
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.5126
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.5115
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.5105
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.5082
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.5078
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.5074
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.5070
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.5050
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.5071
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.5054
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.5061
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.5032
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.5041
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.5034
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.5041
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.5031
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.5138
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.5073
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5030
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.5034
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.4987
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.4933
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.4832
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.4845
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.4784
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.4761
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.4674
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.4640
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.4543
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.4527
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.4496
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.4440
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.4399
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.4399
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.4328
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.4251
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.4202
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.4186
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.4108
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.4141
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.4004
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.4002
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.3931
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.3871
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.3878
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.3822
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6794
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6776
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.6725
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.6595
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.6389
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.6210
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.6071
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.5967
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.5895
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.5845
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.5800
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.5762
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.5726
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.5688
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.5648
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.5612
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.5579
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.5539
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.5504
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.5472
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.5446
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.5406
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.5379
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.5338
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.5307
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.5285
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.5261
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.5234
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.5229
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.5186
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.5180
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.5147
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.5142
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.5128
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.5113
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.5099
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.5084
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.5089
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.5080
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.5069
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.5050
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.5051
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.5046
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.5038
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.5038
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.5038
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.5036
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.5038
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.5024
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.5044
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5147
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.5113
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.5064
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.4994
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.4951
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.4904
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.4887
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.4862
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.4815
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.4755
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.4749
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.4692
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.4666
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.4616
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.4580
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.4585
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.4464
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.4419
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.4410
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.4334
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.4328
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.4285
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.4226
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.4202
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.4160
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.4143
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.4124
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.4038
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.4048
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.3995
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.725
# Precision:  0.299
# Recall:     0.356
# F1-score:   0.325
# AUC:        0.614
# G-mean:     0.537
# PF value:   0.191
#
# Confusion Matrix:
# TN: 2922  FP: 689
# FN: 531  TP: 294
#
# Results saved to results/no_oversampling.json
# Confusion matrix saved as results/confusion_matrix_no_oversampling.png
