# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
ADASYN Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codebert/debian_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codebert/debian_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codebert/chrome_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codebert/chrome_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    deb_emb_adasyn, deb_lbl_adasyn = adasyn.fit_resample(deb_emb, deb_lbl)
    print(f"      Before ADASYN: {deb_emb.shape} | After ADASYN: {deb_emb_adasyn.shape}")
    unique, counts = np.unique(deb_lbl_adasyn, return_counts=True)
    print(f"      Class distribution after ADASYN: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_adasyn, deb_lbl_adasyn,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_adasyn, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_adasyn == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_adasyn, deb_lbl_adasyn, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "adasyn",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (ADASYN) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 768) | Chrome: (4436, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN: (18298, 768) | After ADASYN: (33521, 768)
#       Class distribution after ADASYN: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16638)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6826
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6460
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.6019
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.5625
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.5366
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.5169
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.4998
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.4783
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.4616
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.4497
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.4358
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.4244
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.4145
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.4046
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.3938
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.3863
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.3758
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3676
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.3624
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.3530
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.3488
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.3424
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.3372
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.3294
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.3255
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.3190
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.3125
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.3065
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.3020
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.2992
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.2934
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2914
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2858
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2789
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2760
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2711
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2694
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2635
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2604
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2569
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2557
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2534
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2492
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2443
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2423
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2398
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2354
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2311
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2324
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2277
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2167
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2118
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.2033
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1986
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1962
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1904
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1864
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1881
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1828
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1756
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1731
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1804
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1722
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1682
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1662
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1604
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1613
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1605
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1591
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1559
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1567
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1534
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1477
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1485
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1489
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1450
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1468
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1433
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1446
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1449
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6791
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6393
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.5826
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.5474
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.5244
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.5025
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.4824
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.4640
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.4519
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.4372
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.4245
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.4137
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.4032
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.3943
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.3827
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.3737
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.3659
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.3576
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.3482
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.3420
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.3362
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.3280
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.3233
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.3175
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.3129
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.3043
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.3012
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.2960
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.2917
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.2878
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.2854
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.2802
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.2746
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.2692
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2642
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2622
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2574
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2576
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2515
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2464
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2427
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2397
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2403
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2356
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2325
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2291
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2278
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2245
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2234
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2194
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2091
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.2036
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1979
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1909
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1898
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1897
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1845
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1798
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1743
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1731
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1693
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1665
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1655
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1617
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1617
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1569
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1547
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1500
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1530
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1475
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1452
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1489
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1454
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1412
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1392
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1376
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1380
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1332
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1329
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1334
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6915
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6428
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.5818
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.5539
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.5325
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.5101
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.4926
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.4742
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.4589
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.4460
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.4352
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.4246
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.4154
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.4073
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.3967
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.3889
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3822
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3728
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3644
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.3567
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.3506
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.3445
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.3375
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.3315
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.3256
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.3190
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.3143
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.3089
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.3046
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.2983
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2935
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2905
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2856
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2797
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2796
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2715
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2696
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2646
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2602
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2576
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2540
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2508
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2515
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2451
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2414
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2410
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2376
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2340
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2312
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2294
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2212
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2115
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.2046
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.2023
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1980
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1881
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1883
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1817
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1770
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1724
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1692
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1661
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1644
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1626
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1574
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1542
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1544
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1507
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1534
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1481
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1467
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1494
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1427
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1398
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1427
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1379
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1386
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1328
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1292
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1279
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.772
# Precision:  0.323
# Recall:     0.205
# F1-score:   0.251
# AUC:        0.613
# G-mean:     0.430
# PF value:   0.098
#
# Confusion Matrix:
# TN: 3256  FP: 355
# FN: 656  TP: 169
#
# Results saved to results/adasyn.json
# Confusion matrix saved as results/confusion_matrix_adasyn.png
