# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
SVM-SMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SVMSMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (SVM-SMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codebert/debian_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codebert/debian_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codebert/chrome_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codebert/chrome_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying SVM-SMOTE...")
    svmsmote                              = SVMSMOTE(random_state=SEED)
    deb_emb_svmsmote, deb_lbl_svmsmote   = svmsmote.fit_resample(deb_emb, deb_lbl)
    print(f"      Before SVM-SMOTE: {deb_emb.shape} | After SVM-SMOTE: {deb_emb_svmsmote.shape}")
    unique, counts = np.unique(deb_lbl_svmsmote, return_counts=True)
    print(f"      Class distribution after SVM-SMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_svmsmote, deb_lbl_svmsmote,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_svmsmote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_svmsmote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_svmsmote, deb_lbl_svmsmote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "svmsmote",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "svmsmote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_svmsmote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (SVM-SMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 768) | Chrome: (4436, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SVM-SMOTE...
#       Before SVM-SMOTE: (18298, 768) | After SVM-SMOTE: (33766, 768)
#       Class distribution after SVM-SMOTE: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16883)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6713
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.5963
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.5107
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4705
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.4444
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.4229
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.4046
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3883
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.3716
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.3599
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.3482
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.3405
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.3305
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.3249
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.3203
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.3161
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.3105
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3042
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.2989
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.2953
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.2907
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.2870
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.2840
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.2792
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.2759
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.2719
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.2680
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.2653
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.2620
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.2591
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.2563
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2547
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2509
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2489
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2462
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2420
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2421
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2373
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2349
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2334
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2306
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2293
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2274
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2260
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2243
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2231
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2199
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2179
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2166
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2152
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2091
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2019
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1991
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1951
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1914
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1885
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1845
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1817
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1778
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1744
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1714
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1698
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1671
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1650
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1633
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1624
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1599
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1582
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1558
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1521
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1517
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1515
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1487
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1482
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1451
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1444
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1418
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1415
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1395
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1374
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6679
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.5847
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4963
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.4552
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.4259
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.4050
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3853
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.3708
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.3601
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.3481
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.3394
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.3319
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.3249
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.3182
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.3124
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.3077
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.3032
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.2987
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.2938
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.2903
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.2851
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.2822
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.2787
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.2757
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.2707
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.2665
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.2648
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.2600
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.2553
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.2533
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.2498
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.2464
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.2452
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.2411
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2400
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2366
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2359
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2309
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2291
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2273
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2250
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2249
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2213
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2215
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2186
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2163
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2143
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2114
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2106
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2092
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2022
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1954
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1923
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1889
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1853
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1810
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1806
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1750
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1720
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1698
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1685
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1645
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1620
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1617
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1575
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1564
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1548
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1518
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1520
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1478
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1474
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1455
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1495
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1436
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1438
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1395
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1369
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1361
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1350
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1327
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6739
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.5847
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.5032
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4590
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.4280
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.4061
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3898
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3785
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.3668
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.3564
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.3486
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.3395
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.3323
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.3255
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.3213
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.3160
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3107
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3060
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3024
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.2993
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.2960
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.2899
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.2875
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.2829
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.2795
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.2765
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.2735
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.2703
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.2676
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.2633
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2608
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2576
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2554
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2523
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2497
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2481
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2437
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2419
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2392
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2366
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2346
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2318
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2307
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2279
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2263
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2257
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2215
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2226
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2177
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2162
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2102
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2044
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1978
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1945
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1907
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1877
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1838
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1800
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1773
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1752
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1714
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1683
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1663
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1639
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1607
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1585
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1571
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1556
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1536
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1514
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1481
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1500
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1486
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1442
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1454
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1420
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1407
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1371
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1367
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1357
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.781
# Precision:  0.327
# Recall:     0.166
# F1-score:   0.220
# AUC:        0.628
# G-mean:     0.391
# PF value:   0.078
#
# Confusion Matrix:
# TN: 3329  FP: 282
# FN: 688  TP: 137
#
# Results saved to results/svmsmote.json
# Confusion matrix saved as results/confusion_matrix_svmsmote.png
