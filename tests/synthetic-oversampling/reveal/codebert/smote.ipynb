# %%
"""
Cross-Project Vulnerability Detection
-------------------------------------
Train on Debian -> Test on Chrome
SMOTE Oversampling
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss'
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== Training on Debian -> Testing on Chrome (SMOTE) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codebert/debian_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codebert/debian_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codebert/chrome_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codebert/chrome_labels.npy')
    print(f"      Debian: {deb_emb.shape} | Chrome: {chr_emb.shape}")

    print("\n[2/5] Normalizing embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Applying SMOTE...")
    smote                       = SMOTE(random_state=SEED)
    deb_emb_smote, deb_lbl_smote = smote.fit_resample(deb_emb, deb_lbl)
    print(f"      Before SMOTE: {deb_emb.shape} | After SMOTE: {deb_emb_smote.shape}")
    unique, counts = np.unique(deb_lbl_smote, return_counts=True)
    print(f"      Class distribution after SMOTE: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_smote, deb_lbl_smote,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb_smote, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze().cpu().numpy()

        sample_weights = np.where(deb_lbl_smote == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(deb_emb_smote, deb_lbl_smote, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment" : "smote",
        "train"      : "debian",
        "test"       : "chrome",
        "accuracy"   : round(accuracy,  3),
        "precision"  : round(precision, 3),
        "recall"     : round(recall,    3),
        "f1"         : round(f1,        3),
        "auc"        : round(auc,       3),
        "g_mean"     : round(g_mean,    3),
        "pf"         : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "smote.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_smote.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Training on Debian -> Testing on Chrome (SMOTE) ===
#     Device: mps
#
# [1/5] Loading embeddings...
#       Debian: (18298, 768) | Chrome: (4436, 768)
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying SMOTE...
#       Before SMOTE: (18298, 768) | After SMOTE: (33766, 768)
#       Class distribution after SMOTE: {np.int64(0): np.int64(16883), np.int64(1): np.int64(16883)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.6819
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.6431
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.5915
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.5461
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.5199
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.4974
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.4782
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.4590
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.4424
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.4294
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.4162
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.4056
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.3949
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.3860
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.3784
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.3710
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.3626
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.3557
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.3487
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.3421
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.3357
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.3296
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.3256
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.3193
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.3152
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.3099
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.3059
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.2997
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.2966
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.2913
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.2881
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.2829
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.2777
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.2738
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.2703
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.2652
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.2627
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.2577
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.2535
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.2518
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.2477
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.2448
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.2431
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.2410
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.2362
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.2330
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.2324
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.2281
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.2261
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.2227
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.2131
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.2049
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.2019
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1943
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1893
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1878
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1832
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1789
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1775
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1715
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1707
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1697
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1666
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1617
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1606
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1592
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1560
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1521
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1515
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1491
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1480
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1486
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1438
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1414
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1427
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1415
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1395
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1370
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1326
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1359
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.6783
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.6350
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.5686
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.5302
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.5031
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.4794
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.4574
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.4415
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.4290
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.4153
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.4042
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.3947
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.3851
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.3766
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.3688
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.3610
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.3542
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.3457
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.3392
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.3340
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.3270
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.3219
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.3167
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.3117
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.3056
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.3008
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.2957
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.2907
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.2861
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.2817
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.2775
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.2735
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.2698
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.2658
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.2617
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.2581
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.2557
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.2511
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.2468
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.2443
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.2414
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.2385
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.2348
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.2325
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.2309
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.2261
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.2247
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.2212
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.2191
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.2170
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.2118
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1999
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1959
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1900
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1860
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1797
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1771
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1703
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1700
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1652
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1632
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1601
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1551
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1555
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1514
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1493
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1482
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1454
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1430
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1413
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1412
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1400
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1398
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1353
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1363
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1309
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1306
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1272
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1258
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1237
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.6891
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.6349
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.5682
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.5348
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.5089
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.4874
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.4685
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.4515
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.4367
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.4246
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.4141
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.4032
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.3948
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.3857
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.3795
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.3722
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.3649
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.3586
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.3522
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.3458
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.3395
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.3334
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.3282
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.3232
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.3178
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.3137
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.3084
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.3039
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.2990
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.2943
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.2898
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.2861
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.2806
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.2782
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.2735
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.2701
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.2647
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.2618
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.2575
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.2540
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.2501
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.2451
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.2438
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.2396
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.2376
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.2344
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.2321
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.2294
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.2266
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.2240
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.2155
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.2054
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1977
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1929
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1875
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1826
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1781
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1737
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1692
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1662
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1622
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1596
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1553
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1544
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1514
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1472
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1468
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1444
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1414
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1389
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1356
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1358
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1334
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1315
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1314
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1282
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1269
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1248
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1217
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1220
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.772
# Precision:  0.312
# Recall:     0.188
# F1-score:   0.235
# AUC:        0.609
# G-mean:     0.412
# PF value:   0.094
#
# Confusion Matrix:
# TN: 3270  FP: 341
# FN: 670  TP: 155
#
# Results saved to results/smote.json
# Confusion matrix saved as results/confusion_matrix_smote.png
