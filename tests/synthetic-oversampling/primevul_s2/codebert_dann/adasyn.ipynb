# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
DANN Domain Adaptation + ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "poppler"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_adasyn/poppler"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on ADASYN-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (poppler)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (ADASYN) + pseudo-labelled poppler
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (poppler Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except poppler -> Test on poppler (DANN + ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (poppler)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on ADASYN-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_ada)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_ada
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_ada, train_lbl_ada,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_ada, train_lbl_ada, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (poppler Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_adasyn",
        "train"            : "all_except_poppler",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_adasyn_poppler.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_adasyn_poppler.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except poppler -> Test on poppler (DANN + ADASYN) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (222735, 768)  vuln=5971  benign=216764
#       Projects in training pool : 753
#       Test set (poppler)          : (1798, 768)  vuln=33  benign=1765
#       Training imbalance ratio  : 0.0268
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying ADASYN oversampling...
#       Before ADASYN : (222735, 768)  vuln=5971  benign=216764
#       After ADASYN  : (434040, 768)  vuln=217276  benign=216764
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0011810079164436, 1: 0.9988217750694969}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4686  domain_loss: 1.3201  alpha: 0.100  val_loss: 0.5318
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5166  domain_loss: 1.3982  alpha: 0.197  val_loss: 0.4785
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3908  domain_loss: 1.3582  alpha: 0.291  val_loss: 0.4420
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5058  domain_loss: 1.4100  alpha: 0.380  val_loss: 0.4115
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.2616  domain_loss: 1.3792  alpha: 0.462  val_loss: 0.3828
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.2044  domain_loss: 1.4000  alpha: 0.537  val_loss: 0.3567
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4160  domain_loss: 1.3712  alpha: 0.604  val_loss: 0.3319
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2208  domain_loss: 1.3905  alpha: 0.664  val_loss: 0.3122
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2997  domain_loss: 1.4106  alpha: 0.716  val_loss: 0.2948
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2910  domain_loss: 1.3766  alpha: 0.762  val_loss: 0.2708
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2366  domain_loss: 1.3885  alpha: 0.800  val_loss: 0.2541
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.4425  domain_loss: 1.3826  alpha: 0.834  val_loss: 0.2403
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.4253  domain_loss: 1.3880  alpha: 0.862  val_loss: 0.2344
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.4763  domain_loss: 1.3974  alpha: 0.885  val_loss: 0.2144
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2618  domain_loss: 1.3916  alpha: 0.905  val_loss: 0.2056
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3487  domain_loss: 1.3865  alpha: 0.922  val_loss: 0.1980
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1932  domain_loss: 1.3864  alpha: 0.935  val_loss: 0.1854
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2225  domain_loss: 1.3779  alpha: 0.947  val_loss: 0.1783
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1898  domain_loss: 1.4010  alpha: 0.956  val_loss: 0.1727
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1521  domain_loss: 1.3839  alpha: 0.964  val_loss: 0.1658
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2422  domain_loss: 1.3875  alpha: 0.970  val_loss: 0.1636
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2628  domain_loss: 1.3938  alpha: 0.976  val_loss: 0.1520
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1438  domain_loss: 1.3918  alpha: 0.980  val_loss: 0.1444
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1507  domain_loss: 1.3861  alpha: 0.984  val_loss: 0.1392
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1557  domain_loss: 1.3898  alpha: 0.987  val_loss: 0.1406
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1977  domain_loss: 1.3867  alpha: 0.989  val_loss: 0.1299
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0762  domain_loss: 1.3852  alpha: 0.991  val_loss: 0.1291
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.1536  domain_loss: 1.3718  alpha: 0.993  val_loss: 0.1229
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.2524  domain_loss: 1.3919  alpha: 0.994  val_loss: 0.1223
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1626  domain_loss: 1.3899  alpha: 0.995  val_loss: 0.1214
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1588  domain_loss: 1.3844  alpha: 0.996  val_loss: 0.1140
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1860  domain_loss: 1.3886  alpha: 0.997  val_loss: 0.1111
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.2914  domain_loss: 1.3869  alpha: 0.997  val_loss: 0.1078
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0530  domain_loss: 1.3851  alpha: 0.998  val_loss: 0.1061
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0734  domain_loss: 1.3876  alpha: 0.998  val_loss: 0.1023
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1466  domain_loss: 1.3888  alpha: 0.999  val_loss: 0.1012
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.2732  domain_loss: 1.3918  alpha: 0.999  val_loss: 0.1015
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.2180  domain_loss: 1.3881  alpha: 0.999  val_loss: 0.0969
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.3491  domain_loss: 1.3831  alpha: 0.999  val_loss: 0.0949
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1538  domain_loss: 1.3835  alpha: 0.999  val_loss: 0.0942
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0827  domain_loss: 1.3817  alpha: 0.999  val_loss: 0.0904
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1456  domain_loss: 1.3884  alpha: 1.000  val_loss: 0.0891
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1709  domain_loss: 1.3907  alpha: 1.000  val_loss: 0.0871
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.1374  domain_loss: 1.3915  alpha: 1.000  val_loss: 0.0864
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1959  domain_loss: 1.3922  alpha: 1.000  val_loss: 0.0861
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0732  domain_loss: 1.3855  alpha: 1.000  val_loss: 0.0859
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0189  domain_loss: 1.3867  alpha: 1.000  val_loss: 0.0818
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.2233  domain_loss: 1.3887  alpha: 1.000  val_loss: 0.0815
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0682  domain_loss: 1.3884  alpha: 1.000  val_loss: 0.0807
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0365  domain_loss: 1.3839  alpha: 1.000  val_loss: 0.0809
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0799
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0784
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0724
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0751
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0685
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0632
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0639
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0630
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0592
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0620
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0571
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0537
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0568
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0534
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0534
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0535
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0504
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0478
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0466
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0516
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0449
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0435
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0464
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0466
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0458
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0438
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0447
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0439
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5073  domain_loss: 1.3188  alpha: 0.100  val_loss: 0.5269
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5502  domain_loss: 1.3814  alpha: 0.197  val_loss: 0.4768
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4161  domain_loss: 1.4022  alpha: 0.291  val_loss: 0.4394
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5393  domain_loss: 1.3903  alpha: 0.380  val_loss: 0.4061
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.4827  domain_loss: 1.3777  alpha: 0.462  val_loss: 0.3789
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.2877  domain_loss: 1.3679  alpha: 0.537  val_loss: 0.3551
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3171  domain_loss: 1.3942  alpha: 0.604  val_loss: 0.3276
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3041  domain_loss: 1.4053  alpha: 0.664  val_loss: 0.3046
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3031  domain_loss: 1.3700  alpha: 0.716  val_loss: 0.2836
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3194  domain_loss: 1.3859  alpha: 0.762  val_loss: 0.2646
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3600  domain_loss: 1.3898  alpha: 0.800  val_loss: 0.2484
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1786  domain_loss: 1.3903  alpha: 0.834  val_loss: 0.2364
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2305  domain_loss: 1.3864  alpha: 0.862  val_loss: 0.2195
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1860  domain_loss: 1.3890  alpha: 0.885  val_loss: 0.2123
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1904  domain_loss: 1.3880  alpha: 0.905  val_loss: 0.2002
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1856  domain_loss: 1.3910  alpha: 0.922  val_loss: 0.1908
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2473  domain_loss: 1.3772  alpha: 0.935  val_loss: 0.1808
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2024  domain_loss: 1.3868  alpha: 0.947  val_loss: 0.1744
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1489  domain_loss: 1.3725  alpha: 0.956  val_loss: 0.1647
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1859  domain_loss: 1.3884  alpha: 0.964  val_loss: 0.1630
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1003  domain_loss: 1.3784  alpha: 0.970  val_loss: 0.1556
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.3289  domain_loss: 1.3830  alpha: 0.976  val_loss: 0.1504
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1688  domain_loss: 1.3899  alpha: 0.980  val_loss: 0.1462
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2712  domain_loss: 1.3887  alpha: 0.984  val_loss: 0.1397
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1033  domain_loss: 1.3865  alpha: 0.987  val_loss: 0.1346
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.3042  domain_loss: 1.3905  alpha: 0.989  val_loss: 0.1273
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1693  domain_loss: 1.3882  alpha: 0.991  val_loss: 0.1249
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.1391  domain_loss: 1.3916  alpha: 0.993  val_loss: 0.1241
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1463  domain_loss: 1.3801  alpha: 0.994  val_loss: 0.1178
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1618  domain_loss: 1.3860  alpha: 0.995  val_loss: 0.1167
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0776  domain_loss: 1.3896  alpha: 0.996  val_loss: 0.1102
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.2472  domain_loss: 1.3891  alpha: 0.997  val_loss: 0.1083
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0243  domain_loss: 1.3772  alpha: 0.997  val_loss: 0.1071
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.2049  domain_loss: 1.3857  alpha: 0.998  val_loss: 0.1032
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.2176  domain_loss: 1.3942  alpha: 0.998  val_loss: 0.1103
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0261  domain_loss: 1.3861  alpha: 0.999  val_loss: 0.1009
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0761  domain_loss: 1.3883  alpha: 0.999  val_loss: 0.1070
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1624  domain_loss: 1.3939  alpha: 0.999  val_loss: 0.0954
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1841  domain_loss: 1.3850  alpha: 0.999  val_loss: 0.0928
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1494  domain_loss: 1.3855  alpha: 0.999  val_loss: 0.0938
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0327  domain_loss: 1.3801  alpha: 0.999  val_loss: 0.0897
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0371  domain_loss: 1.3813  alpha: 1.000  val_loss: 0.0888
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1687  domain_loss: 1.3890  alpha: 1.000  val_loss: 0.0859
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0827  domain_loss: 1.3885  alpha: 1.000  val_loss: 0.0847
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1780  domain_loss: 1.3872  alpha: 1.000  val_loss: 0.0864
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0674  domain_loss: 1.3853  alpha: 1.000  val_loss: 0.0865
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0474  domain_loss: 1.3863  alpha: 1.000  val_loss: 0.0837
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.2374  domain_loss: 1.3862  alpha: 1.000  val_loss: 0.0818
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.1061  domain_loss: 1.3880  alpha: 1.000  val_loss: 0.0805
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.2471  domain_loss: 1.3785  alpha: 1.000  val_loss: 0.0794
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0790
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0750
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0771
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0680
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0681
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0643
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0692
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0613
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0640
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0647
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0573
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0569
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0618
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0574
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0549
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0532
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0504
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0545
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0482
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0486
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0451
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0477
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0517
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0474
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0447
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0465
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0448
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0452
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0457
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0410
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.6186  domain_loss: 1.4462  alpha: 0.100  val_loss: 0.5264
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3582  domain_loss: 1.4366  alpha: 0.197  val_loss: 0.4712
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3602  domain_loss: 1.3488  alpha: 0.291  val_loss: 0.4358
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4733  domain_loss: 1.4008  alpha: 0.380  val_loss: 0.4060
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.2757  domain_loss: 1.3571  alpha: 0.462  val_loss: 0.3796
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.4123  domain_loss: 1.4076  alpha: 0.537  val_loss: 0.3539
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2980  domain_loss: 1.3695  alpha: 0.604  val_loss: 0.3288
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2762  domain_loss: 1.4300  alpha: 0.664  val_loss: 0.3071
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3045  domain_loss: 1.4042  alpha: 0.716  val_loss: 0.2884
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3820  domain_loss: 1.4070  alpha: 0.762  val_loss: 0.2670
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1928  domain_loss: 1.3837  alpha: 0.800  val_loss: 0.2529
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3073  domain_loss: 1.3825  alpha: 0.834  val_loss: 0.2359
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2036  domain_loss: 1.4023  alpha: 0.862  val_loss: 0.2233
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1087  domain_loss: 1.3766  alpha: 0.885  val_loss: 0.2110
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1726  domain_loss: 1.4083  alpha: 0.905  val_loss: 0.1996
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.0898  domain_loss: 1.3856  alpha: 0.922  val_loss: 0.1912
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1386  domain_loss: 1.3950  alpha: 0.935  val_loss: 0.1810
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2731  domain_loss: 1.3821  alpha: 0.947  val_loss: 0.1753
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.0719  domain_loss: 1.3887  alpha: 0.956  val_loss: 0.1673
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1107  domain_loss: 1.3786  alpha: 0.964  val_loss: 0.1706
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2369  domain_loss: 1.3906  alpha: 0.970  val_loss: 0.1541
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1416  domain_loss: 1.3864  alpha: 0.976  val_loss: 0.1525
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.3407  domain_loss: 1.3816  alpha: 0.980  val_loss: 0.1468
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.3661  domain_loss: 1.3896  alpha: 0.984  val_loss: 0.1406
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1298  domain_loss: 1.3798  alpha: 0.987  val_loss: 0.1362
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1456  domain_loss: 1.3954  alpha: 0.989  val_loss: 0.1306
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1129  domain_loss: 1.3858  alpha: 0.991  val_loss: 0.1271
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.1153  domain_loss: 1.3903  alpha: 0.993  val_loss: 0.1251
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1468  domain_loss: 1.3910  alpha: 0.994  val_loss: 0.1190
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0930  domain_loss: 1.3880  alpha: 0.995  val_loss: 0.1173
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0367  domain_loss: 1.3891  alpha: 0.996  val_loss: 0.1127
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0979  domain_loss: 1.3861  alpha: 0.997  val_loss: 0.1170
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1911  domain_loss: 1.3829  alpha: 0.997  val_loss: 0.1086
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0772  domain_loss: 1.3834  alpha: 0.998  val_loss: 0.1056
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0824  domain_loss: 1.3856  alpha: 0.998  val_loss: 0.1064
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1030  domain_loss: 1.3840  alpha: 0.999  val_loss: 0.1010
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0859  domain_loss: 1.3876  alpha: 0.999  val_loss: 0.1014
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.2085  domain_loss: 1.3839  alpha: 0.999  val_loss: 0.0996
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0824  domain_loss: 1.3890  alpha: 0.999  val_loss: 0.0942
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0726  domain_loss: 1.3863  alpha: 0.999  val_loss: 0.0959
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.3283  domain_loss: 1.3876  alpha: 0.999  val_loss: 0.0912
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0798  domain_loss: 1.3843  alpha: 1.000  val_loss: 0.0922
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1621  domain_loss: 1.3853  alpha: 1.000  val_loss: 0.0962
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2938  domain_loss: 1.3897  alpha: 1.000  val_loss: 0.0895
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1437  domain_loss: 1.3881  alpha: 1.000  val_loss: 0.0858
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1048  domain_loss: 1.3859  alpha: 1.000  val_loss: 0.0898
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0604  domain_loss: 1.3832  alpha: 1.000  val_loss: 0.0874
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0831  domain_loss: 1.3819  alpha: 1.000  val_loss: 0.0861
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0313  domain_loss: 1.3871  alpha: 1.000  val_loss: 0.0809
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0718  domain_loss: 1.3889  alpha: 1.000  val_loss: 0.0857
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0829
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0764
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0748
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0693
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0654
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0637
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0672
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0605
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0710
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0585
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0586
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0547
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0640
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0557
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0539
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0474
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0494
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0483
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0457
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0434
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0447
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0456
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0451
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0449
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0428
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (poppler Test Set) ===
# Accuracy  : 0.778
# Precision : 0.066
# Recall    : 0.848
# F1-score  : 0.123
# AUC       : 0.880
# G-mean    : 0.812
# PF value  : 0.223
#
# Confusion Matrix:
#   TN: 1371  FP: 394
#   FN: 5  TP: 28
#
# Results saved to results/dann_adasyn/poppler/dann_adasyn_poppler.json
# Confusion matrix saved as results/dann_adasyn/poppler/confusion_matrix_dann_adasyn_poppler.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
DANN Domain Adaptation + ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_adasyn/radare2"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on ADASYN-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (radare2)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (ADASYN) + pseudo-labelled radare2
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (DANN + ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on ADASYN-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_ada)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_ada
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_ada, train_lbl_ada,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_ada, train_lbl_ada, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_adasyn",
        "train"            : "all_except_radare2",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_adasyn_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_adasyn_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except radare2 -> Test on radare2 (DANN + ADASYN) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221730, 768)  vuln=5930  benign=215800
#       Projects in training pool : 753
#       Test set (radare2)          : (2803, 768)  vuln=74  benign=2729
#       Training imbalance ratio  : 0.0267
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying ADASYN oversampling...
#       Before ADASYN : (221730, 768)  vuln=5930  benign=215800
#       After ADASYN  : (431662, 768)  vuln=215862  benign=215800
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0001436515291937, 1: 0.999856389730476}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5565  domain_loss: 1.3370  alpha: 0.100  val_loss: 0.5364
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4257  domain_loss: 1.3748  alpha: 0.197  val_loss: 0.4814
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3673  domain_loss: 1.3488  alpha: 0.291  val_loss: 0.4438
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4211  domain_loss: 1.3895  alpha: 0.380  val_loss: 0.4142
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3964  domain_loss: 1.3593  alpha: 0.462  val_loss: 0.3871
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3645  domain_loss: 1.3820  alpha: 0.537  val_loss: 0.3662
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4819  domain_loss: 1.3649  alpha: 0.604  val_loss: 0.3400
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3985  domain_loss: 1.3950  alpha: 0.664  val_loss: 0.3146
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.1766  domain_loss: 1.4028  alpha: 0.716  val_loss: 0.2950
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3075  domain_loss: 1.3971  alpha: 0.762  val_loss: 0.2745
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3506  domain_loss: 1.3865  alpha: 0.800  val_loss: 0.2581
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1568  domain_loss: 1.3991  alpha: 0.834  val_loss: 0.2436
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2193  domain_loss: 1.3823  alpha: 0.862  val_loss: 0.2328
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2689  domain_loss: 1.3894  alpha: 0.885  val_loss: 0.2190
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2118  domain_loss: 1.4007  alpha: 0.905  val_loss: 0.2154
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3404  domain_loss: 1.3771  alpha: 0.922  val_loss: 0.1994
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1737  domain_loss: 1.3856  alpha: 0.935  val_loss: 0.1886
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2039  domain_loss: 1.3890  alpha: 0.947  val_loss: 0.1795
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2655  domain_loss: 1.3966  alpha: 0.956  val_loss: 0.1777
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1822  domain_loss: 1.3851  alpha: 0.964  val_loss: 0.1650
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1097  domain_loss: 1.3796  alpha: 0.970  val_loss: 0.1617
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2047  domain_loss: 1.3875  alpha: 0.976  val_loss: 0.1589
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1706  domain_loss: 1.3919  alpha: 0.980  val_loss: 0.1507
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1365  domain_loss: 1.3909  alpha: 0.984  val_loss: 0.1434
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0967  domain_loss: 1.3926  alpha: 0.987  val_loss: 0.1381
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1245  domain_loss: 1.3803  alpha: 0.989  val_loss: 0.1333
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1549  domain_loss: 1.3866  alpha: 0.991  val_loss: 0.1329
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.1004  domain_loss: 1.3878  alpha: 0.993  val_loss: 0.1247
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0947  domain_loss: 1.3860  alpha: 0.994  val_loss: 0.1228
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1773  domain_loss: 1.3927  alpha: 0.995  val_loss: 0.1214
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1779  domain_loss: 1.3902  alpha: 0.996  val_loss: 0.1222
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0459  domain_loss: 1.3805  alpha: 0.997  val_loss: 0.1126
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1862  domain_loss: 1.3926  alpha: 0.997  val_loss: 0.1129
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1143  domain_loss: 1.3810  alpha: 0.998  val_loss: 0.1088
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0845  domain_loss: 1.3805  alpha: 0.998  val_loss: 0.1067
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1720  domain_loss: 1.3860  alpha: 0.999  val_loss: 0.1038
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0969  domain_loss: 1.3849  alpha: 0.999  val_loss: 0.1026
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0398  domain_loss: 1.3865  alpha: 0.999  val_loss: 0.1001
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0202  domain_loss: 1.3829  alpha: 0.999  val_loss: 0.0985
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1453  domain_loss: 1.3889  alpha: 0.999  val_loss: 0.0957
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.2622  domain_loss: 1.3864  alpha: 0.999  val_loss: 0.0943
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0440  domain_loss: 1.3848  alpha: 1.000  val_loss: 0.0923
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1984  domain_loss: 1.3854  alpha: 1.000  val_loss: 0.0905
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0183  domain_loss: 1.3862  alpha: 1.000  val_loss: 0.0882
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0955  domain_loss: 1.3846  alpha: 1.000  val_loss: 0.0889
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.3013  domain_loss: 1.3842  alpha: 1.000  val_loss: 0.0860
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1655  domain_loss: 1.3899  alpha: 1.000  val_loss: 0.0836
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1499  domain_loss: 1.3847  alpha: 1.000  val_loss: 0.0861
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.1349  domain_loss: 1.3846  alpha: 1.000  val_loss: 0.0856
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0378  domain_loss: 1.3914  alpha: 1.000  val_loss: 0.0814
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 576
#     572     plot_confusion_matrix(tn, fp, fn, tp, cm_path)
#     575 if __name__ == "__main__":
# --> 576     main()
#
# Cell In[2], line 488, in main()
#     486 for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
#     487     print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
# --> 488     (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
#     489         train_emb_ada, train_lbl_ada,
#     490         test_emb,
#     491         class_weight_dict,
#     492         iteration=i+1
#     493     )
#     495     print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
#     496     feature_extractor.eval()
#
# Cell In[2], line 346, in semi_supervised_transfer_learning_dann(x_train, y_train, x_test, class_weights, iteration)
#     340 optimizer = torch.optim.Adam(
#     341     list(feature_extractor.parameters()) + list(classifier_head.parameters()),
#     342     lr=1e-5
#     343 )
#     344 criterion = nn.BCELoss(reduction='none')
# --> 346 feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
#     347     feature_extractor, classifier_head,
#     348     dataloader_aug, x_aug_val_t, y_aug_val_t,
#     349     optimizer, criterion,
#     350     epochs=30,
#     351     desc=f"Iter {iteration} - Phase 2",
#     352     class_weights=class_weights
#     353 )
#     355 feature_extractor.eval()
#     356 classifier_head.eval()
#
# Cell In[2], line 276, in fine_tune_on_pseudo_labels(feature_extractor, classifier_head, dataloader, x_val, y_val, optimizer, criterion, epochs, desc, class_weights)
#     274 predictions = classifier_head(features).squeeze()
#     275 weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
# --> 276 loss        = (criterion(predictions, y_batch) * weights).mean()
#     277 loss.backward()
#     278 optimizer.step()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/loss.py:710, in BCELoss.forward(self, input, target)
#     706 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     707     """
#     708     Runs the forward pass.
#     709     """
# --> 710     return F.binary_cross_entropy(
#     711         input, target, weight=self.weight, reduction=self.reduction
#     712     )
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:3564, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3562     reduction_enum = _Reduction.get_enum(reduction)
#    3563 if target.size() != input.size():
# -> 3564     raise ValueError(
#    3565         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3566         "Please ensure they have the same size."
#    3567     )
#    3569 if weight is not None:
#    3570     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
DANN Domain Adaptation + ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux-2.6"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_adasyn/linux-2.6"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on ADASYN-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (linux-2.6)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (ADASYN) + pseudo-labelled linux-2.6
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux-2.6 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (DANN + ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux-2.6)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on ADASYN-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_ada)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_ada
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_ada, train_lbl_ada,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_ada, train_lbl_ada, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux-2.6 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_adasyn",
        "train"            : "all_except_linux-2.6",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_adasyn_linux-2.6.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_adasyn_linux-2.6.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (DANN + ADASYN) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221163, 768)  vuln=5904  benign=215259
#       Projects in training pool : 753
#       Test set (linux-2.6)          : (3370, 768)  vuln=100  benign=3270
#       Training imbalance ratio  : 0.0267
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying ADASYN oversampling...
#       Before ADASYN : (221163, 768)  vuln=5904  benign=215259
#       After ADASYN  : (429492, 768)  vuln=214233  benign=215259
#
# [4/6] Computing class weights...
#       Class weights: {0: 0.9976168243836495, 1: 1.002394589068911}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5147  domain_loss: 1.3972  alpha: 0.100  val_loss: 0.5350
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4700  domain_loss: 1.3222  alpha: 0.197  val_loss: 0.4756
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3810  domain_loss: 1.3319  alpha: 0.291  val_loss: 0.4431
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5227  domain_loss: 1.4071  alpha: 0.380  val_loss: 0.4168
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3922  domain_loss: 1.3611  alpha: 0.462  val_loss: 0.3927
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.5060  domain_loss: 1.3511  alpha: 0.537  val_loss: 0.3712
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.5028  domain_loss: 1.4109  alpha: 0.604  val_loss: 0.3521
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.4219  domain_loss: 1.3517  alpha: 0.664  val_loss: 0.3296
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3340  domain_loss: 1.3824  alpha: 0.716  val_loss: 0.3139
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2776  domain_loss: 1.4191  alpha: 0.762  val_loss: 0.2948
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.4088  domain_loss: 1.3798  alpha: 0.800  val_loss: 0.2801
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1709  domain_loss: 1.3420  alpha: 0.834  val_loss: 0.2699
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2817  domain_loss: 1.3872  alpha: 0.862  val_loss: 0.2597
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1950  domain_loss: 1.3690  alpha: 0.885  val_loss: 0.2431
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.4179  domain_loss: 1.3927  alpha: 0.905  val_loss: 0.2356
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3399  domain_loss: 1.4114  alpha: 0.922  val_loss: 0.2263
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2847  domain_loss: 1.4003  alpha: 0.935  val_loss: 0.2157
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2911  domain_loss: 1.3827  alpha: 0.947  val_loss: 0.2090
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.3075  domain_loss: 1.4079  alpha: 0.956  val_loss: 0.1983
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1644  domain_loss: 1.3820  alpha: 0.964  val_loss: 0.1943
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1685  domain_loss: 1.3845  alpha: 0.970  val_loss: 0.1862
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1725  domain_loss: 1.3840  alpha: 0.976  val_loss: 0.1800
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2623  domain_loss: 1.3860  alpha: 0.980  val_loss: 0.1742
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1409  domain_loss: 1.3653  alpha: 0.984  val_loss: 0.1672
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.4051  domain_loss: 1.3754  alpha: 0.987  val_loss: 0.1643
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.2427  domain_loss: 1.3976  alpha: 0.989  val_loss: 0.1598
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1478  domain_loss: 1.3734  alpha: 0.991  val_loss: 0.1520
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.1292  domain_loss: 1.4062  alpha: 0.993  val_loss: 0.1495
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1973  domain_loss: 1.3836  alpha: 0.994  val_loss: 0.1484
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1461  domain_loss: 1.3645  alpha: 0.995  val_loss: 0.1422
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1096  domain_loss: 1.3777  alpha: 0.996  val_loss: 0.1402
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0301  domain_loss: 1.3843  alpha: 0.997  val_loss: 0.1344
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.2439  domain_loss: 1.3730  alpha: 0.997  val_loss: 0.1292
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0390  domain_loss: 1.3846  alpha: 0.998  val_loss: 0.1331
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1068  domain_loss: 1.3847  alpha: 0.998  val_loss: 0.1260
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.3014  domain_loss: 1.3720  alpha: 0.999  val_loss: 0.1212
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.2427  domain_loss: 1.3776  alpha: 0.999  val_loss: 0.1200
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1452  domain_loss: 1.3870  alpha: 0.999  val_loss: 0.1187
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1288  domain_loss: 1.3717  alpha: 0.999  val_loss: 0.1151
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0944  domain_loss: 1.3779  alpha: 0.999  val_loss: 0.1138
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.2640  domain_loss: 1.3854  alpha: 0.999  val_loss: 0.1104
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2094  domain_loss: 1.3924  alpha: 1.000  val_loss: 0.1155
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0392  domain_loss: 1.3913  alpha: 1.000  val_loss: 0.1111
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0818  domain_loss: 1.3892  alpha: 1.000  val_loss: 0.1069
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0752  domain_loss: 1.3812  alpha: 1.000  val_loss: 0.1034
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0402  domain_loss: 1.3797  alpha: 1.000  val_loss: 0.1055
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0664  domain_loss: 1.3830  alpha: 1.000  val_loss: 0.1020
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0665  domain_loss: 1.3975  alpha: 1.000  val_loss: 0.1014
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0690  domain_loss: 1.3895  alpha: 1.000  val_loss: 0.1010
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.1213  domain_loss: 1.3808  alpha: 1.000  val_loss: 0.0973
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0913
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0890
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0856
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0809
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0817
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0732
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0724
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0732
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0658
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0649
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0654
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0620
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0646
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0579
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0598
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0533
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0628
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0529
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0518
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0514
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0485
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0503
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0465
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0458
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0560
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0476
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0516
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0452
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4466  domain_loss: 1.3915  alpha: 0.100  val_loss: 0.5346
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4167  domain_loss: 1.3708  alpha: 0.197  val_loss: 0.4747
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.5009  domain_loss: 1.4070  alpha: 0.291  val_loss: 0.4435
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3736  domain_loss: 1.4060  alpha: 0.380  val_loss: 0.4180
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3811  domain_loss: 1.4305  alpha: 0.462  val_loss: 0.3989
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3703  domain_loss: 1.3392  alpha: 0.537  val_loss: 0.3732
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2162  domain_loss: 1.3649  alpha: 0.604  val_loss: 0.3532
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.4743  domain_loss: 1.3745  alpha: 0.664  val_loss: 0.3328
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.4614  domain_loss: 1.3989  alpha: 0.716  val_loss: 0.3136
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2547  domain_loss: 1.3634  alpha: 0.762  val_loss: 0.2999
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2014  domain_loss: 1.3969  alpha: 0.800  val_loss: 0.2890
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2564  domain_loss: 1.4205  alpha: 0.834  val_loss: 0.2731
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2705  domain_loss: 1.3736  alpha: 0.862  val_loss: 0.2576
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1722  domain_loss: 1.3821  alpha: 0.885  val_loss: 0.2497
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1177  domain_loss: 1.3722  alpha: 0.905  val_loss: 0.2377
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2120  domain_loss: 1.3730  alpha: 0.922  val_loss: 0.2251
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2185  domain_loss: 1.4689  alpha: 0.935  val_loss: 0.2211
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1738  domain_loss: 1.3889  alpha: 0.947  val_loss: 0.2112
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1347  domain_loss: 1.4263  alpha: 0.956  val_loss: 0.2044
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.0772  domain_loss: 1.4025  alpha: 0.964  val_loss: 0.1978
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0936  domain_loss: 1.4003  alpha: 0.970  val_loss: 0.1949
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.4030  domain_loss: 1.3761  alpha: 0.976  val_loss: 0.1941
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1068  domain_loss: 1.3766  alpha: 0.980  val_loss: 0.1776
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1588  domain_loss: 1.4057  alpha: 0.984  val_loss: 0.1745
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1288  domain_loss: 1.3852  alpha: 0.987  val_loss: 0.1662
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1200  domain_loss: 1.4053  alpha: 0.989  val_loss: 0.1594
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1382  domain_loss: 1.3929  alpha: 0.991  val_loss: 0.1581
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.3325  domain_loss: 1.4038  alpha: 0.993  val_loss: 0.1556
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0495  domain_loss: 1.3920  alpha: 0.994  val_loss: 0.1481
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1547  domain_loss: 1.3929  alpha: 0.995  val_loss: 0.1458
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.2505  domain_loss: 1.3799  alpha: 0.996  val_loss: 0.1415
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1720  domain_loss: 1.3908  alpha: 0.997  val_loss: 0.1361
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1878  domain_loss: 1.3701  alpha: 0.997  val_loss: 0.1400
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1038  domain_loss: 1.3835  alpha: 0.998  val_loss: 0.1299
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0230  domain_loss: 1.3661  alpha: 0.998  val_loss: 0.1314
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1698  domain_loss: 1.3483  alpha: 0.999  val_loss: 0.1300
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1014  domain_loss: 1.3967  alpha: 0.999  val_loss: 0.1246
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1717  domain_loss: 1.3603  alpha: 0.999  val_loss: 0.1340
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1314  domain_loss: 1.4028  alpha: 0.999  val_loss: 0.1165
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1158  domain_loss: 1.3611  alpha: 0.999  val_loss: 0.1251
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0962  domain_loss: 1.3878  alpha: 0.999  val_loss: 0.1156
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0757  domain_loss: 1.3883  alpha: 1.000  val_loss: 0.1181
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.2243  domain_loss: 1.3716  alpha: 1.000  val_loss: 0.1095
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0411  domain_loss: 1.4110  alpha: 1.000  val_loss: 0.1156
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1525  domain_loss: 1.3843  alpha: 1.000  val_loss: 0.1035
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1030  domain_loss: 1.3751  alpha: 1.000  val_loss: 0.1116
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1757  domain_loss: 1.3988  alpha: 1.000  val_loss: 0.1040
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0808  domain_loss: 1.3833  alpha: 1.000  val_loss: 0.1048
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0747  domain_loss: 1.3724  alpha: 1.000  val_loss: 0.1021
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0626  domain_loss: 1.3751  alpha: 1.000  val_loss: 0.0997
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0934
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0848
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0828
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0802
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0852
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0728
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0719
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0707
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0648
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0706
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0629
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0606
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0610
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0557
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0614
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0548
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0706
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0590
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0584
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0549
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0522
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0491
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0579
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0498
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0554
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0507
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0472
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0483
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0459
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0438
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4707  domain_loss: 1.4152  alpha: 0.100  val_loss: 0.5352
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5096  domain_loss: 1.3932  alpha: 0.197  val_loss: 0.4897
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4806  domain_loss: 1.4037  alpha: 0.291  val_loss: 0.4582
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4440  domain_loss: 1.3716  alpha: 0.380  val_loss: 0.4349
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.5238  domain_loss: 1.3386  alpha: 0.462  val_loss: 0.4138
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.5452  domain_loss: 1.3882  alpha: 0.537  val_loss: 0.3927
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3215  domain_loss: 1.3651  alpha: 0.604  val_loss: 0.3749
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.4538  domain_loss: 1.4036  alpha: 0.664  val_loss: 0.3605
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.4267  domain_loss: 1.3276  alpha: 0.716  val_loss: 0.3349
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3867  domain_loss: 1.3943  alpha: 0.762  val_loss: 0.3159
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3907  domain_loss: 1.3916  alpha: 0.800  val_loss: 0.2981
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3014  domain_loss: 1.3566  alpha: 0.834  val_loss: 0.2837
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.4913  domain_loss: 1.3776  alpha: 0.862  val_loss: 0.2688
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1204  domain_loss: 1.3811  alpha: 0.885  val_loss: 0.2595
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2064  domain_loss: 1.3678  alpha: 0.905  val_loss: 0.2469
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2307  domain_loss: 1.4263  alpha: 0.922  val_loss: 0.2334
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1882  domain_loss: 1.4068  alpha: 0.935  val_loss: 0.2241
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2626  domain_loss: 1.3551  alpha: 0.947  val_loss: 0.2160
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1512  domain_loss: 1.3845  alpha: 0.956  val_loss: 0.2052
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1681  domain_loss: 1.4293  alpha: 0.964  val_loss: 0.1975
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1999  domain_loss: 1.4211  alpha: 0.970  val_loss: 0.1942
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1269  domain_loss: 1.3818  alpha: 0.976  val_loss: 0.1844
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2154  domain_loss: 1.3984  alpha: 0.980  val_loss: 0.1798
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2866  domain_loss: 1.3800  alpha: 0.984  val_loss: 0.1729
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0916  domain_loss: 1.3925  alpha: 0.987  val_loss: 0.1688
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0898  domain_loss: 1.3850  alpha: 0.989  val_loss: 0.1652
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1549  domain_loss: 1.3838  alpha: 0.991  val_loss: 0.1567
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.2192  domain_loss: 1.3803  alpha: 0.993  val_loss: 0.1552
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1232  domain_loss: 1.3971  alpha: 0.994  val_loss: 0.1476
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0780  domain_loss: 1.3762  alpha: 0.995  val_loss: 0.1539
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0652  domain_loss: 1.3817  alpha: 0.996  val_loss: 0.1466
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1177  domain_loss: 1.3807  alpha: 0.997  val_loss: 0.1349
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1570  domain_loss: 1.3896  alpha: 0.997  val_loss: 0.1315
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1184  domain_loss: 1.3745  alpha: 0.998  val_loss: 0.1407
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1521  domain_loss: 1.3934  alpha: 0.998  val_loss: 0.1281
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0958  domain_loss: 1.3918  alpha: 0.999  val_loss: 0.1221
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1887  domain_loss: 1.3750  alpha: 0.999  val_loss: 0.1224
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1300  domain_loss: 1.4051  alpha: 0.999  val_loss: 0.1168
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0900  domain_loss: 1.3870  alpha: 0.999  val_loss: 0.1205
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1683  domain_loss: 1.3838  alpha: 0.999  val_loss: 0.1134
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0730  domain_loss: 1.3948  alpha: 0.999  val_loss: 0.1130
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0368  domain_loss: 1.3795  alpha: 1.000  val_loss: 0.1097
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1907  domain_loss: 1.3944  alpha: 1.000  val_loss: 0.1119
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.1244  domain_loss: 1.3792  alpha: 1.000  val_loss: 0.1067
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0476  domain_loss: 1.3831  alpha: 1.000  val_loss: 0.1045
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1101  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.1057
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1175  domain_loss: 1.3905  alpha: 1.000  val_loss: 0.1043
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1934  domain_loss: 1.3793  alpha: 1.000  val_loss: 0.0988
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0975  domain_loss: 1.4046  alpha: 1.000  val_loss: 0.1024
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.2339  domain_loss: 1.3948  alpha: 1.000  val_loss: 0.0958
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0925
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0904
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0816
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0776
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0846
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0719
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0716
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0692
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0677
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0680
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0625
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0603
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0611
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0559
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0589
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0581
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0546
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0573
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0583
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0527
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0521
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0490
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0534
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0551
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0554
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0469
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0450
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0532
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0477
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (linux-2.6 Test Set) ===
# Accuracy  : 0.733
# Precision : 0.064
# Recall    : 0.590
# F1-score  : 0.116
# AUC       : 0.733
# G-mean    : 0.660
# PF value  : 0.263
#
# Confusion Matrix:
#   TN: 2411  FP: 859
#   FN: 41  TP: 59
#
# Results saved to results/dann_adasyn/linux-2.6/dann_adasyn_linux-2.6.json
# Confusion matrix saved as results/dann_adasyn/linux-2.6/confusion_matrix_dann_adasyn_linux-2.6.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
DANN Domain Adaptation + ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "vim"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_adasyn/vim"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on ADASYN-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (vim)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (ADASYN) + pseudo-labelled vim
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (DANN + ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on ADASYN-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_ada)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_ada
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_ada, train_lbl_ada,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_ada, train_lbl_ada, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_adasyn",
        "train"            : "all_except_vim",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_adasyn_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_adasyn_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (DANN + ADASYN) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221466, 768)  vuln=5898  benign=215568
#       Projects in training pool : 753
#       Test set (vim)          : (3067, 768)  vuln=106  benign=2961
#       Training imbalance ratio  : 0.0266
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying ADASYN oversampling...
#       Before ADASYN : (221466, 768)  vuln=5898  benign=215568
#       After ADASYN  : (431618, 768)  vuln=216050  benign=215568
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.001117976694129, 1: 0.9988845174728073}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5584  domain_loss: 1.4324  alpha: 0.100  val_loss: 0.5344
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5550  domain_loss: 1.4072  alpha: 0.197  val_loss: 0.4750
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4610  domain_loss: 1.3803  alpha: 0.291  val_loss: 0.4363
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4436  domain_loss: 1.3657  alpha: 0.380  val_loss: 0.4050
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3762  domain_loss: 1.3937  alpha: 0.462  val_loss: 0.3776
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.8051  domain_loss: 1.3894  alpha: 0.537  val_loss: 0.3494
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.6948  domain_loss: 1.4017  alpha: 0.604  val_loss: 0.3298
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2176  domain_loss: 1.3667  alpha: 0.664  val_loss: 0.3030
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3219  domain_loss: 1.3962  alpha: 0.716  val_loss: 0.2833
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.1913  domain_loss: 1.4040  alpha: 0.762  val_loss: 0.2662
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2152  domain_loss: 1.3998  alpha: 0.800  val_loss: 0.2492
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1680  domain_loss: 1.3800  alpha: 0.834  val_loss: 0.2362
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.3122  domain_loss: 1.3854  alpha: 0.862  val_loss: 0.2216
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2746  domain_loss: 1.3937  alpha: 0.885  val_loss: 0.2127
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.3201  domain_loss: 1.3979  alpha: 0.905  val_loss: 0.2046
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1007  domain_loss: 1.3857  alpha: 0.922  val_loss: 0.1903
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.0520  domain_loss: 1.3934  alpha: 0.935  val_loss: 0.1850
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1787  domain_loss: 1.3879  alpha: 0.947  val_loss: 0.1769
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.0981  domain_loss: 1.3871  alpha: 0.956  val_loss: 0.1696
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1980  domain_loss: 1.3893  alpha: 0.964  val_loss: 0.1608
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2293  domain_loss: 1.3866  alpha: 0.970  val_loss: 0.1541
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1170  domain_loss: 1.3831  alpha: 0.976  val_loss: 0.1565
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.0306  domain_loss: 1.3883  alpha: 0.980  val_loss: 0.1438
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2385  domain_loss: 1.3851  alpha: 0.984  val_loss: 0.1434
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0138  domain_loss: 1.3920  alpha: 0.987  val_loss: 0.1357
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0481  domain_loss: 1.3858  alpha: 0.989  val_loss: 0.1349
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0651  domain_loss: 1.3888  alpha: 0.991  val_loss: 0.1262
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0907  domain_loss: 1.3848  alpha: 0.993  val_loss: 0.1228
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0838  domain_loss: 1.3870  alpha: 0.994  val_loss: 0.1195
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1628  domain_loss: 1.3874  alpha: 0.995  val_loss: 0.1160
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1010  domain_loss: 1.3815  alpha: 0.996  val_loss: 0.1129
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0313  domain_loss: 1.3881  alpha: 0.997  val_loss: 0.1089
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0248  domain_loss: 1.3929  alpha: 0.997  val_loss: 0.1074
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0206  domain_loss: 1.3801  alpha: 0.998  val_loss: 0.1048
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0069  domain_loss: 1.3906  alpha: 0.998  val_loss: 0.1010
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0223  domain_loss: 1.3830  alpha: 0.999  val_loss: 0.1013
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1315  domain_loss: 1.3920  alpha: 0.999  val_loss: 0.0972
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0135  domain_loss: 1.3822  alpha: 0.999  val_loss: 0.0968
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0646  domain_loss: 1.3806  alpha: 0.999  val_loss: 0.0930
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0389  domain_loss: 1.3895  alpha: 0.999  val_loss: 0.0928
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0816  domain_loss: 1.3901  alpha: 0.999  val_loss: 0.0928
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1052  domain_loss: 1.3819  alpha: 1.000  val_loss: 0.0955
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.2078  domain_loss: 1.3889  alpha: 1.000  val_loss: 0.0889
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2308  domain_loss: 1.3802  alpha: 1.000  val_loss: 0.0876
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0097  domain_loss: 1.3864  alpha: 1.000  val_loss: 0.0863
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0250  domain_loss: 1.3856  alpha: 1.000  val_loss: 0.0825
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1234  domain_loss: 1.3887  alpha: 1.000  val_loss: 0.0825
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0625  domain_loss: 1.3858  alpha: 1.000  val_loss: 0.0833
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.1813  domain_loss: 1.3914  alpha: 1.000  val_loss: 0.0832
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0457  domain_loss: 1.3846  alpha: 1.000  val_loss: 0.0878
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0780
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0746
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0717
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0711
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0638
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0666
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0629
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0652
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0667
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0616
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0573
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0569
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0544
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0631
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0499
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0494
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0592
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0521
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0543
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0503
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0448
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0467
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0449
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0451
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0439
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0430
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0454
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0471
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0417
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0441
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.6379  domain_loss: 1.3477  alpha: 0.100  val_loss: 0.5332
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3330  domain_loss: 1.3773  alpha: 0.197  val_loss: 0.4796
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3121  domain_loss: 1.3818  alpha: 0.291  val_loss: 0.4448
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4778  domain_loss: 1.3477  alpha: 0.380  val_loss: 0.4173
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.5661  domain_loss: 1.3689  alpha: 0.462  val_loss: 0.3882
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.2503  domain_loss: 1.4061  alpha: 0.537  val_loss: 0.3599
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3174  domain_loss: 1.3770  alpha: 0.604  val_loss: 0.3320
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3344  domain_loss: 1.3805  alpha: 0.664  val_loss: 0.3088
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.1753  domain_loss: 1.4056  alpha: 0.716  val_loss: 0.2851
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3035  domain_loss: 1.3879  alpha: 0.762  val_loss: 0.2647
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3445  domain_loss: 1.3776  alpha: 0.800  val_loss: 0.2471
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2653  domain_loss: 1.3992  alpha: 0.834  val_loss: 0.2301
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.1129  domain_loss: 1.3886  alpha: 0.862  val_loss: 0.2182
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2209  domain_loss: 1.3777  alpha: 0.885  val_loss: 0.2058
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.4285  domain_loss: 1.3857  alpha: 0.905  val_loss: 0.1935
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1505  domain_loss: 1.3727  alpha: 0.922  val_loss: 0.1882
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1191  domain_loss: 1.3926  alpha: 0.935  val_loss: 0.1785
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2936  domain_loss: 1.4091  alpha: 0.947  val_loss: 0.1694
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.0848  domain_loss: 1.4098  alpha: 0.956  val_loss: 0.1618
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1105  domain_loss: 1.3815  alpha: 0.964  val_loss: 0.1552
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.5658  domain_loss: 1.3843  alpha: 0.970  val_loss: 0.1587
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.0374  domain_loss: 1.3635  alpha: 0.976  val_loss: 0.1511
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1079  domain_loss: 1.3842  alpha: 0.980  val_loss: 0.1402
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.0586  domain_loss: 1.3822  alpha: 0.984  val_loss: 0.1345
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0428  domain_loss: 1.3996  alpha: 0.987  val_loss: 0.1387
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0744  domain_loss: 1.3872  alpha: 0.989  val_loss: 0.1324
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0340  domain_loss: 1.3819  alpha: 0.991  val_loss: 0.1352
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0280  domain_loss: 1.3919  alpha: 0.993  val_loss: 0.1185
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.2805  domain_loss: 1.3958  alpha: 0.994  val_loss: 0.1177
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0292  domain_loss: 1.3903  alpha: 0.995  val_loss: 0.1122
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1973  domain_loss: 1.3864  alpha: 0.996  val_loss: 0.1100
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0797  domain_loss: 1.3937  alpha: 0.997  val_loss: 0.1078
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.2604  domain_loss: 1.3765  alpha: 0.997  val_loss: 0.1069
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1023  domain_loss: 1.3847  alpha: 0.998  val_loss: 0.1015
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1540  domain_loss: 1.3936  alpha: 0.998  val_loss: 0.1016
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0406  domain_loss: 1.3897  alpha: 0.999  val_loss: 0.0976
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0575  domain_loss: 1.3910  alpha: 0.999  val_loss: 0.0986
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0287  domain_loss: 1.3826  alpha: 0.999  val_loss: 0.0962
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0180  domain_loss: 1.3872  alpha: 0.999  val_loss: 0.0925
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.3781  domain_loss: 1.3899  alpha: 0.999  val_loss: 0.1034
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.1444  domain_loss: 1.3890  alpha: 0.999  val_loss: 0.0916
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0059  domain_loss: 1.3818  alpha: 1.000  val_loss: 0.0971
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1093  domain_loss: 1.3902  alpha: 1.000  val_loss: 0.0872
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0156  domain_loss: 1.3866  alpha: 1.000  val_loss: 0.0908
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1355  domain_loss: 1.3851  alpha: 1.000  val_loss: 0.0864
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.3158  domain_loss: 1.3882  alpha: 1.000  val_loss: 0.0830
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0393  domain_loss: 1.3928  alpha: 1.000  val_loss: 0.0814
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0279  domain_loss: 1.3855  alpha: 1.000  val_loss: 0.0942
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0447  domain_loss: 1.3895  alpha: 1.000  val_loss: 0.0814
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0841  domain_loss: 1.3875  alpha: 1.000  val_loss: 0.0817
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0787
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0768
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0731
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0703
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0669
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0616
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0624
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0642
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0730
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0558
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0575
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0578
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0531
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0543
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0490
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0558
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0519
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0505
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0490
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0493
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0471
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0476
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0539
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0458
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0448
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0438
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0422
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0447
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4655  domain_loss: 1.3813  alpha: 0.100  val_loss: 0.5306
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4056  domain_loss: 1.3735  alpha: 0.197  val_loss: 0.4713
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4601  domain_loss: 1.3785  alpha: 0.291  val_loss: 0.4374
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.2716  domain_loss: 1.3802  alpha: 0.380  val_loss: 0.4060
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3594  domain_loss: 1.3798  alpha: 0.462  val_loss: 0.3774
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3964  domain_loss: 1.4040  alpha: 0.537  val_loss: 0.3514
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.5428  domain_loss: 1.3633  alpha: 0.604  val_loss: 0.3283
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.1320  domain_loss: 1.4048  alpha: 0.664  val_loss: 0.3024
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3150  domain_loss: 1.3829  alpha: 0.716  val_loss: 0.2864
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2068  domain_loss: 1.3809  alpha: 0.762  val_loss: 0.2651
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2207  domain_loss: 1.3750  alpha: 0.800  val_loss: 0.2487
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3168  domain_loss: 1.3762  alpha: 0.834  val_loss: 0.2311
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.3638  domain_loss: 1.3839  alpha: 0.862  val_loss: 0.2193
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2413  domain_loss: 1.3861  alpha: 0.885  val_loss: 0.2082
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1806  domain_loss: 1.3952  alpha: 0.905  val_loss: 0.1948
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1028  domain_loss: 1.3808  alpha: 0.922  val_loss: 0.1878
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.4710  domain_loss: 1.3878  alpha: 0.935  val_loss: 0.1771
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.3145  domain_loss: 1.3804  alpha: 0.947  val_loss: 0.1705
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.0670  domain_loss: 1.3762  alpha: 0.956  val_loss: 0.1622
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.2723  domain_loss: 1.3850  alpha: 0.964  val_loss: 0.1564
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.3067  domain_loss: 1.3880  alpha: 0.970  val_loss: 0.1507
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.7164  domain_loss: 1.3866  alpha: 0.976  val_loss: 0.1441
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.3812  domain_loss: 1.3944  alpha: 0.980  val_loss: 0.1426
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1455  domain_loss: 1.3781  alpha: 0.984  val_loss: 0.1406
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0521  domain_loss: 1.3861  alpha: 0.987  val_loss: 0.1309
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0976  domain_loss: 1.3897  alpha: 0.989  val_loss: 0.1315
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1980  domain_loss: 1.3931  alpha: 0.991  val_loss: 0.1268
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0635  domain_loss: 1.3815  alpha: 0.993  val_loss: 0.1303
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1324  domain_loss: 1.3845  alpha: 0.994  val_loss: 0.1188
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1025  domain_loss: 1.3869  alpha: 0.995  val_loss: 0.1131
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1103  domain_loss: 1.3842  alpha: 0.996  val_loss: 0.1117
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0604  domain_loss: 1.3913  alpha: 0.997  val_loss: 0.1087
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.3168  domain_loss: 1.3899  alpha: 0.997  val_loss: 0.1058
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0521  domain_loss: 1.3878  alpha: 0.998  val_loss: 0.1042
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0251  domain_loss: 1.3880  alpha: 0.998  val_loss: 0.1027
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.2761  domain_loss: 1.3808  alpha: 0.999  val_loss: 0.0998
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.3415  domain_loss: 1.3852  alpha: 0.999  val_loss: 0.0998
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0734  domain_loss: 1.3892  alpha: 0.999  val_loss: 0.0974
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0448  domain_loss: 1.3855  alpha: 0.999  val_loss: 0.0942
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0427  domain_loss: 1.3901  alpha: 0.999  val_loss: 0.0935
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.1397  domain_loss: 1.3892  alpha: 0.999  val_loss: 0.0892
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2591  domain_loss: 1.3916  alpha: 1.000  val_loss: 0.0912
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0842  domain_loss: 1.3898  alpha: 1.000  val_loss: 0.0868
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0146  domain_loss: 1.3857  alpha: 1.000  val_loss: 0.0840
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0845  domain_loss: 1.3949  alpha: 1.000  val_loss: 0.0896
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0426  domain_loss: 1.3894  alpha: 1.000  val_loss: 0.0823
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0231  domain_loss: 1.3839  alpha: 1.000  val_loss: 0.0838
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1493  domain_loss: 1.3868  alpha: 1.000  val_loss: 0.0794
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0434  domain_loss: 1.3847  alpha: 1.000  val_loss: 0.0990
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0327  domain_loss: 1.3925  alpha: 1.000  val_loss: 0.0790
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0782
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0711
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0716
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0759
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0673
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0679
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0620
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0600
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0592
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0584
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0559
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0598
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0566
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0519
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0542
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0471
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0548
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0479
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0469
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0456
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0648
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0447
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0450
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0435
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0428
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0428
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (vim Test Set) ===
# Accuracy  : 0.588
# Precision : 0.068
# Recall    : 0.858
# F1-score  : 0.126
# AUC       : 0.796
# G-mean    : 0.705
# PF value  : 0.422
#
# Confusion Matrix:
#   TN: 1712  FP: 1249
#   FN: 15  TP: 91
#
# Results saved to results/dann_adasyn/vim/dann_adasyn_vim.json
# Confusion matrix saved as results/dann_adasyn/vim/confusion_matrix_dann_adasyn_vim.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
DANN Domain Adaptation + ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FFmpeg"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_adasyn/FFmpeg"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on ADASYN-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (FFmpeg)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (ADASYN) + pseudo-labelled FFmpeg
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (DANN + ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FFmpeg)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] ADASYN Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying ADASYN oversampling...")
    adasyn = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada = train_emb_ada.astype(np.float32)
    train_lbl_ada = train_lbl_ada.astype(np.int32)

    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on ADASYN-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_ada)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_ada
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_ada, train_lbl_ada,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_ada, train_lbl_ada, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_adasyn",
        "train"            : "all_except_FFmpeg",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_adasyn"   : int(len(train_lbl_ada)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_adasyn_FFmpeg.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_adasyn_FFmpeg.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (DANN + ADASYN) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (222072, 768)  vuln=5915  benign=216157
#       Projects in training pool : 753
#       Test set (FFmpeg)          : (2461, 768)  vuln=89  benign=2372
#       Training imbalance ratio  : 0.0266
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying ADASYN oversampling...
#       Before ADASYN : (222072, 768)  vuln=5915  benign=216157
#       After ADASYN  : (432378, 768)  vuln=216221  benign=216157
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0001480405446042, 1: 0.9998520032744276}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4828  domain_loss: 1.3866  alpha: 0.100  val_loss: 0.5323
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5552  domain_loss: 1.3927  alpha: 0.197  val_loss: 0.4731
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.5081  domain_loss: 1.3804  alpha: 0.291  val_loss: 0.4358
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5225  domain_loss: 1.3862  alpha: 0.380  val_loss: 0.4062
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.4009  domain_loss: 1.3947  alpha: 0.462  val_loss: 0.3773
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3845  domain_loss: 1.3863  alpha: 0.537  val_loss: 0.3465
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.5148  domain_loss: 1.3965  alpha: 0.604  val_loss: 0.3242
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3886  domain_loss: 1.3847  alpha: 0.664  val_loss: 0.3007
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.4314  domain_loss: 1.3952  alpha: 0.716  val_loss: 0.2839
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2694  domain_loss: 1.3913  alpha: 0.762  val_loss: 0.2663
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2728  domain_loss: 1.3724  alpha: 0.800  val_loss: 0.2501
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3307  domain_loss: 1.3881  alpha: 0.834  val_loss: 0.2338
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2731  domain_loss: 1.3888  alpha: 0.862  val_loss: 0.2226
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2459  domain_loss: 1.3789  alpha: 0.885  val_loss: 0.2110
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2325  domain_loss: 1.3834  alpha: 0.905  val_loss: 0.1986
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1800  domain_loss: 1.3900  alpha: 0.922  val_loss: 0.1904
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2231  domain_loss: 1.3873  alpha: 0.935  val_loss: 0.1842
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1594  domain_loss: 1.3868  alpha: 0.947  val_loss: 0.1735
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1413  domain_loss: 1.3913  alpha: 0.956  val_loss: 0.1667
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1183  domain_loss: 1.3810  alpha: 0.964  val_loss: 0.1587
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1629  domain_loss: 1.3836  alpha: 0.970  val_loss: 0.1558
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1554  domain_loss: 1.3784  alpha: 0.976  val_loss: 0.1529
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2651  domain_loss: 1.3864  alpha: 0.980  val_loss: 0.1445
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2289  domain_loss: 1.3915  alpha: 0.984  val_loss: 0.1435
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2559  domain_loss: 1.3883  alpha: 0.987  val_loss: 0.1357
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0995  domain_loss: 1.3786  alpha: 0.989  val_loss: 0.1293
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0846  domain_loss: 1.3858  alpha: 0.991  val_loss: 0.1261
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0669  domain_loss: 1.3799  alpha: 0.993  val_loss: 0.1238
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1853  domain_loss: 1.3837  alpha: 0.994  val_loss: 0.1213
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1850  domain_loss: 1.3875  alpha: 0.995  val_loss: 0.1166
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1381  domain_loss: 1.3812  alpha: 0.996  val_loss: 0.1133
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1295  domain_loss: 1.3814  alpha: 0.997  val_loss: 0.1100
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1528  domain_loss: 1.3902  alpha: 0.997  val_loss: 0.1152
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.2874  domain_loss: 1.3866  alpha: 0.998  val_loss: 0.1062
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1598  domain_loss: 1.3892  alpha: 0.998  val_loss: 0.1019
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1472  domain_loss: 1.3901  alpha: 0.999  val_loss: 0.1043
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1266  domain_loss: 1.3869  alpha: 0.999  val_loss: 0.1007
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.2673  domain_loss: 1.3892  alpha: 0.999  val_loss: 0.0998
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0620  domain_loss: 1.3864  alpha: 0.999  val_loss: 0.0953
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0757  domain_loss: 1.3793  alpha: 0.999  val_loss: 0.0935
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.2004  domain_loss: 1.3845  alpha: 0.999  val_loss: 0.0890
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2171  domain_loss: 1.3873  alpha: 1.000  val_loss: 0.0885
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1453  domain_loss: 1.3857  alpha: 1.000  val_loss: 0.0875
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0916  domain_loss: 1.3845  alpha: 1.000  val_loss: 0.0898
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0874  domain_loss: 1.3872  alpha: 1.000  val_loss: 0.0839
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0342  domain_loss: 1.3882  alpha: 1.000  val_loss: 0.0847
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.2010  domain_loss: 1.3831  alpha: 1.000  val_loss: 0.0810
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0170  domain_loss: 1.3873  alpha: 1.000  val_loss: 0.0837
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0889  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.0795
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0290  domain_loss: 1.3872  alpha: 1.000  val_loss: 0.0777
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0797
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0863
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0706
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0719
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0649
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0638
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0699
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0588
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0596
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0567
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0565
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0556
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0525
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0532
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0528
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0545
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0527
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0602
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0491
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0489
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0478
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0452
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0463
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0468
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0440
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0416
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0448
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0416
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0406
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5226  domain_loss: 1.3967  alpha: 0.100  val_loss: 0.5289
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4057  domain_loss: 1.4051  alpha: 0.197  val_loss: 0.4747
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3520  domain_loss: 1.3864  alpha: 0.291  val_loss: 0.4396
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3897  domain_loss: 1.4148  alpha: 0.380  val_loss: 0.4106
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3134  domain_loss: 1.4084  alpha: 0.462  val_loss: 0.3826
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.2781  domain_loss: 1.4016  alpha: 0.537  val_loss: 0.3574
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2961  domain_loss: 1.3742  alpha: 0.604  val_loss: 0.3297
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3793  domain_loss: 1.3873  alpha: 0.664  val_loss: 0.3086
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3321  domain_loss: 1.3772  alpha: 0.716  val_loss: 0.2865
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3785  domain_loss: 1.3865  alpha: 0.762  val_loss: 0.2670
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2250  domain_loss: 1.3896  alpha: 0.800  val_loss: 0.2516
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2694  domain_loss: 1.3926  alpha: 0.834  val_loss: 0.2384
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2609  domain_loss: 1.3939  alpha: 0.862  val_loss: 0.2242
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2742  domain_loss: 1.3957  alpha: 0.885  val_loss: 0.2126
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1588  domain_loss: 1.3909  alpha: 0.905  val_loss: 0.2065
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3501  domain_loss: 1.3933  alpha: 0.922  val_loss: 0.1928
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2114  domain_loss: 1.3903  alpha: 0.935  val_loss: 0.1885
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1796  domain_loss: 1.4006  alpha: 0.947  val_loss: 0.1777
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2899  domain_loss: 1.3958  alpha: 0.956  val_loss: 0.1692
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.2345  domain_loss: 1.3856  alpha: 0.964  val_loss: 0.1658
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1524  domain_loss: 1.3930  alpha: 0.970  val_loss: 0.1588
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2713  domain_loss: 1.3982  alpha: 0.976  val_loss: 0.1517
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1806  domain_loss: 1.3801  alpha: 0.980  val_loss: 0.1480
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2167  domain_loss: 1.3778  alpha: 0.984  val_loss: 0.1413
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0585  domain_loss: 1.3914  alpha: 0.987  val_loss: 0.1337
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1194  domain_loss: 1.3967  alpha: 0.989  val_loss: 0.1356
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0917  domain_loss: 1.3812  alpha: 0.991  val_loss: 0.1294
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0542  domain_loss: 1.3816  alpha: 0.993  val_loss: 0.1238
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1517  domain_loss: 1.3864  alpha: 0.994  val_loss: 0.1202
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0874  domain_loss: 1.3893  alpha: 0.995  val_loss: 0.1164
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0726  domain_loss: 1.3901  alpha: 0.996  val_loss: 0.1147
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0918  domain_loss: 1.3827  alpha: 0.997  val_loss: 0.1126
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1976  domain_loss: 1.3921  alpha: 0.997  val_loss: 0.1070
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.3278  domain_loss: 1.3912  alpha: 0.998  val_loss: 0.1087
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1037  domain_loss: 1.3843  alpha: 0.998  val_loss: 0.1041
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0578  domain_loss: 1.3874  alpha: 0.999  val_loss: 0.1031
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0803  domain_loss: 1.3858  alpha: 0.999  val_loss: 0.0993
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0788  domain_loss: 1.3842  alpha: 0.999  val_loss: 0.0973
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.2243  domain_loss: 1.3858  alpha: 0.999  val_loss: 0.0947
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1277  domain_loss: 1.3903  alpha: 0.999  val_loss: 0.1115
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0645  domain_loss: 1.3870  alpha: 0.999  val_loss: 0.0914
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0188  domain_loss: 1.3874  alpha: 1.000  val_loss: 0.0921
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0807  domain_loss: 1.3905  alpha: 1.000  val_loss: 0.0889
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2049  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.0904
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1804  domain_loss: 1.3875  alpha: 1.000  val_loss: 0.0859
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1404  domain_loss: 1.3887  alpha: 1.000  val_loss: 0.0837
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1908  domain_loss: 1.3883  alpha: 1.000  val_loss: 0.0888
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0457  domain_loss: 1.3890  alpha: 1.000  val_loss: 0.0791
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0339  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.0796
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.1843  domain_loss: 1.3847  alpha: 1.000  val_loss: 0.0797
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0794
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0747
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0781
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0701
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0702
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0628
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0625
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0625
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0573
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0573
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0617
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0622
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0565
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0573
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0521
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0504
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0511
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0490
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0479
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0463
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0485
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0472
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0453
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0422
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0481
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0444
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0445
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0413
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0419
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4473  domain_loss: 1.4012  alpha: 0.100  val_loss: 0.5245
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4718  domain_loss: 1.4088  alpha: 0.197  val_loss: 0.4705
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4293  domain_loss: 1.3793  alpha: 0.291  val_loss: 0.4278
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5792  domain_loss: 1.3843  alpha: 0.380  val_loss: 0.3957
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3275  domain_loss: 1.3888  alpha: 0.462  val_loss: 0.3643
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.2315  domain_loss: 1.4244  alpha: 0.537  val_loss: 0.3386
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3116  domain_loss: 1.3945  alpha: 0.604  val_loss: 0.3118
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2708  domain_loss: 1.3913  alpha: 0.664  val_loss: 0.2874
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.1675  domain_loss: 1.3792  alpha: 0.716  val_loss: 0.2710
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2558  domain_loss: 1.3774  alpha: 0.762  val_loss: 0.2487
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1378  domain_loss: 1.3868  alpha: 0.800  val_loss: 0.2452
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2623  domain_loss: 1.3810  alpha: 0.834  val_loss: 0.2211
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2014  domain_loss: 1.3857  alpha: 0.862  val_loss: 0.2145
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3401  domain_loss: 1.3869  alpha: 0.885  val_loss: 0.2004
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2432  domain_loss: 1.3906  alpha: 0.905  val_loss: 0.1871
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1872  domain_loss: 1.3806  alpha: 0.922  val_loss: 0.1790
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1554  domain_loss: 1.3941  alpha: 0.935  val_loss: 0.1710
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2487  domain_loss: 1.3881  alpha: 0.947  val_loss: 0.1615
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1873  domain_loss: 1.3893  alpha: 0.956  val_loss: 0.1581
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.3942  domain_loss: 1.3947  alpha: 0.964  val_loss: 0.1512
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2802  domain_loss: 1.3792  alpha: 0.970  val_loss: 0.1453
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.3566  domain_loss: 1.3779  alpha: 0.976  val_loss: 0.1408
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1642  domain_loss: 1.3830  alpha: 0.980  val_loss: 0.1333
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1884  domain_loss: 1.3838  alpha: 0.984  val_loss: 0.1298
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0618  domain_loss: 1.3901  alpha: 0.987  val_loss: 0.1254
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0492  domain_loss: 1.3899  alpha: 0.989  val_loss: 0.1216
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0841  domain_loss: 1.3873  alpha: 0.991  val_loss: 0.1199
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0724  domain_loss: 1.3851  alpha: 0.993  val_loss: 0.1186
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0532  domain_loss: 1.3868  alpha: 0.994  val_loss: 0.1121
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0626  domain_loss: 1.3905  alpha: 0.995  val_loss: 0.1083
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0717  domain_loss: 1.3912  alpha: 0.996  val_loss: 0.1082
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1926  domain_loss: 1.3847  alpha: 0.997  val_loss: 0.1039
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0408  domain_loss: 1.3862  alpha: 0.997  val_loss: 0.1050
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0787  domain_loss: 1.3866  alpha: 0.998  val_loss: 0.1013
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0308  domain_loss: 1.3899  alpha: 0.998  val_loss: 0.0986
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.2554  domain_loss: 1.3853  alpha: 0.999  val_loss: 0.0934
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0607  domain_loss: 1.3879  alpha: 0.999  val_loss: 0.0935
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0563  domain_loss: 1.3861  alpha: 0.999  val_loss: 0.0969
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1654  domain_loss: 1.3876  alpha: 0.999  val_loss: 0.0964
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.2320  domain_loss: 1.3911  alpha: 0.999  val_loss: 0.0872
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0412  domain_loss: 1.3843  alpha: 0.999  val_loss: 0.0948
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0590  domain_loss: 1.3871  alpha: 1.000  val_loss: 0.0854
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1261  domain_loss: 1.3848  alpha: 1.000  val_loss: 0.0856
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.1779  domain_loss: 1.3884  alpha: 1.000  val_loss: 0.0851
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1363  domain_loss: 1.3886  alpha: 1.000  val_loss: 0.0824
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0541  domain_loss: 1.3893  alpha: 1.000  val_loss: 0.0888
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.2755  domain_loss: 1.3815  alpha: 1.000  val_loss: 0.0797
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0279  domain_loss: 1.3875  alpha: 1.000  val_loss: 0.0782
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0859  domain_loss: 1.3890  alpha: 1.000  val_loss: 0.0784
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0989  domain_loss: 1.3826  alpha: 1.000  val_loss: 0.0763
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0786
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0712
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0694
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0668
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0662
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0611
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0607
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0578
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0602
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0578
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0611
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0560
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0519
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0503
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0482
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0504
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0501
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0445
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0454
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0496
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0453
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0449
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0449
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0463
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0426
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0422
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0421
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0399
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy  : 0.570
# Precision : 0.066
# Recall    : 0.820
# F1-score  : 0.121
# AUC       : 0.734
# G-mean    : 0.678
# PF value  : 0.439
#
# Confusion Matrix:
#   TN: 1331  FP: 1041
#   FN: 16  TP: 73
#
# Results saved to results/dann_adasyn/FFmpeg/dann_adasyn_FFmpeg.json
# Confusion matrix saved as results/dann_adasyn/FFmpeg/confusion_matrix_dann_adasyn_FFmpeg.png
