# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
DANN Domain Adaptation + SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "poppler"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_smote/poppler"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on SMOTE-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (poppler)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (SMOTE) + pseudo-labelled poppler
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (poppler Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except poppler -> Test on poppler (DANN + SMOTE) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (poppler)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on SMOTE-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_sm)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_sm
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_sm, train_lbl_sm,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_sm, train_lbl_sm, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (poppler Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_smote",
        "train"            : "all_except_poppler",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_smote_poppler.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_smote_poppler.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except poppler -> Test on poppler (DANN + SMOTE) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (222735, 768)  vuln=5971  benign=216764
#       Projects in training pool : 753
#       Test set (poppler)          : (1798, 768)  vuln=33  benign=1765
#       Training imbalance ratio  : 0.0268
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying SMOTE oversampling...
#       Before SMOTE : (222735, 768)  vuln=5971  benign=216764
#       After SMOTE  : (433528, 768)  vuln=216764  benign=216764
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.4542  domain_loss: 1.1675  alpha: 0.100  val_loss: 0.5174
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.6080  domain_loss: 1.3959  alpha: 0.197  val_loss: 0.4724
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.9106  domain_loss: 1.4251  alpha: 0.291  val_loss: 0.4373
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.5349  domain_loss: 1.3330  alpha: 0.380  val_loss: 0.4109
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.1547  domain_loss: 1.3717  alpha: 0.462  val_loss: 0.3880
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3657  domain_loss: 1.3649  alpha: 0.537  val_loss: 0.3639
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4830  domain_loss: 1.3887  alpha: 0.604  val_loss: 0.3407
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.0634  domain_loss: 1.3854  alpha: 0.664  val_loss: 0.3170
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3634  domain_loss: 1.3655  alpha: 0.716  val_loss: 0.2990
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3561  domain_loss: 1.3862  alpha: 0.762  val_loss: 0.2793
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.4296  domain_loss: 1.3638  alpha: 0.800  val_loss: 0.2619
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2652  domain_loss: 1.3715  alpha: 0.834  val_loss: 0.2497
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.0817  domain_loss: 1.4082  alpha: 0.862  val_loss: 0.2363
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.0922  domain_loss: 1.3966  alpha: 0.885  val_loss: 0.2229
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.0736  domain_loss: 1.3630  alpha: 0.905  val_loss: 0.2121
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2402  domain_loss: 1.3640  alpha: 0.922  val_loss: 0.2020
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.0774  domain_loss: 1.3911  alpha: 0.935  val_loss: 0.1911
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.7399  domain_loss: 1.3876  alpha: 0.947  val_loss: 0.1846
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2353  domain_loss: 1.3747  alpha: 0.956  val_loss: 0.1768
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.6045  domain_loss: 1.3732  alpha: 0.964  val_loss: 0.1725
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2113  domain_loss: 1.3979  alpha: 0.970  val_loss: 0.1627
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2952  domain_loss: 1.3785  alpha: 0.976  val_loss: 0.1588
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.4570  domain_loss: 1.3969  alpha: 0.980  val_loss: 0.1510
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.0079  domain_loss: 1.3921  alpha: 0.984  val_loss: 0.1453
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1102  domain_loss: 1.3871  alpha: 0.987  val_loss: 0.1420
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0362  domain_loss: 1.3769  alpha: 0.989  val_loss: 0.1371
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0516  domain_loss: 1.3833  alpha: 0.991  val_loss: 0.1334
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0049  domain_loss: 1.4123  alpha: 0.993  val_loss: 0.1322
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0599  domain_loss: 1.3911  alpha: 0.994  val_loss: 0.1256
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0105  domain_loss: 1.3848  alpha: 0.995  val_loss: 0.1249
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0090  domain_loss: 1.4000  alpha: 0.996  val_loss: 0.1176
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0693  domain_loss: 1.3780  alpha: 0.997  val_loss: 0.1176
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1101  domain_loss: 1.4011  alpha: 0.997  val_loss: 0.1132
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1584  domain_loss: 1.3897  alpha: 0.998  val_loss: 0.1113
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0236  domain_loss: 1.3860  alpha: 0.998  val_loss: 0.1107
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0050  domain_loss: 1.3861  alpha: 0.999  val_loss: 0.1076
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0413  domain_loss: 1.3705  alpha: 0.999  val_loss: 0.1050
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0423  domain_loss: 1.3908  alpha: 0.999  val_loss: 0.1038
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0141  domain_loss: 1.3886  alpha: 0.999  val_loss: 0.1004
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0860  domain_loss: 1.3942  alpha: 0.999  val_loss: 0.0985
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0155  domain_loss: 1.3775  alpha: 0.999  val_loss: 0.0953
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2218  domain_loss: 1.3994  alpha: 1.000  val_loss: 0.0982
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1256  domain_loss: 1.3920  alpha: 1.000  val_loss: 0.0982
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0371  domain_loss: 1.3817  alpha: 1.000  val_loss: 0.0949
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0892  domain_loss: 1.3900  alpha: 1.000  val_loss: 0.0949
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.3580  domain_loss: 1.3888  alpha: 1.000  val_loss: 0.0900
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0188  domain_loss: 1.3865  alpha: 1.000  val_loss: 0.0911
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0897  domain_loss: 1.3924  alpha: 1.000  val_loss: 0.0919
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.3660  domain_loss: 1.3837  alpha: 1.000  val_loss: 0.0855
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0546  domain_loss: 1.3900  alpha: 1.000  val_loss: 0.0837
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0824
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0808
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0745
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0746
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0716
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0690
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0672
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0647
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0646
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0589
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0612
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0583
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0617
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0541
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0545
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0516
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0560
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0507
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0526
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0486
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0520
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0568
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0493
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0476
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0497
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0459
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0467
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0461
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0456
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.2716  domain_loss: 1.3988  alpha: 0.100  val_loss: 0.5050
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3617  domain_loss: 1.3475  alpha: 0.197  val_loss: 0.4573
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.7192  domain_loss: 1.3668  alpha: 0.291  val_loss: 0.4258
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.0760  domain_loss: 1.4028  alpha: 0.380  val_loss: 0.3978
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.1581  domain_loss: 1.4528  alpha: 0.462  val_loss: 0.3720
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3185  domain_loss: 1.3519  alpha: 0.537  val_loss: 0.3451
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2161  domain_loss: 1.3748  alpha: 0.604  val_loss: 0.3224
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2317  domain_loss: 1.3907  alpha: 0.664  val_loss: 0.3000
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 1.0217  domain_loss: 1.4537  alpha: 0.716  val_loss: 0.2781
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.6570  domain_loss: 1.3751  alpha: 0.762  val_loss: 0.2615
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1878  domain_loss: 1.3832  alpha: 0.800  val_loss: 0.2433
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1766  domain_loss: 1.3673  alpha: 0.834  val_loss: 0.2380
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.0672  domain_loss: 1.4020  alpha: 0.862  val_loss: 0.2170
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.0448  domain_loss: 1.3896  alpha: 0.885  val_loss: 0.2070
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1089  domain_loss: 1.4314  alpha: 0.905  val_loss: 0.1977
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2304  domain_loss: 1.3517  alpha: 0.922  val_loss: 0.1908
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.0697  domain_loss: 1.3934  alpha: 0.935  val_loss: 0.1788
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.5583  domain_loss: 1.3633  alpha: 0.947  val_loss: 0.1710
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1284  domain_loss: 1.3738  alpha: 0.956  val_loss: 0.1632
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.0267  domain_loss: 1.3786  alpha: 0.964  val_loss: 0.1579
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0269  domain_loss: 1.4015  alpha: 0.970  val_loss: 0.1505
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.0580  domain_loss: 1.3997  alpha: 0.976  val_loss: 0.1480
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.5298  domain_loss: 1.3597  alpha: 0.980  val_loss: 0.1431
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.0579  domain_loss: 1.3902  alpha: 0.984  val_loss: 0.1380
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0245  domain_loss: 1.3981  alpha: 0.987  val_loss: 0.1322
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0159  domain_loss: 1.3933  alpha: 0.989  val_loss: 0.1297
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0780  domain_loss: 1.3683  alpha: 0.991  val_loss: 0.1269
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0870  domain_loss: 1.3741  alpha: 0.993  val_loss: 0.1227
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.2752  domain_loss: 1.3871  alpha: 0.994  val_loss: 0.1205
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0414  domain_loss: 1.3787  alpha: 0.995  val_loss: 0.1159
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0202  domain_loss: 1.3903  alpha: 0.996  val_loss: 0.1106
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1974  domain_loss: 1.3886  alpha: 0.997  val_loss: 0.1086
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.2254  domain_loss: 1.3867  alpha: 0.997  val_loss: 0.1100
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.7222  domain_loss: 1.3779  alpha: 0.998  val_loss: 0.1061
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0126  domain_loss: 1.3829  alpha: 0.998  val_loss: 0.1011
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0289  domain_loss: 1.3768  alpha: 0.999  val_loss: 0.1048
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1183  domain_loss: 1.3873  alpha: 0.999  val_loss: 0.0976
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0262  domain_loss: 1.3927  alpha: 0.999  val_loss: 0.1019
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0116  domain_loss: 1.3857  alpha: 0.999  val_loss: 0.0997
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.4496  domain_loss: 1.3942  alpha: 0.999  val_loss: 0.0965
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0107  domain_loss: 1.3819  alpha: 0.999  val_loss: 0.0920
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1513  domain_loss: 1.3999  alpha: 1.000  val_loss: 0.0908
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0533  domain_loss: 1.3797  alpha: 1.000  val_loss: 0.0894
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.1020  domain_loss: 1.3846  alpha: 1.000  val_loss: 0.0887
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0211  domain_loss: 1.3858  alpha: 1.000  val_loss: 0.0884
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.2749  domain_loss: 1.3838  alpha: 1.000  val_loss: 0.0831
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1177  domain_loss: 1.3932  alpha: 1.000  val_loss: 0.0821
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0841  domain_loss: 1.3918  alpha: 1.000  val_loss: 0.0813
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.3949  domain_loss: 1.3857  alpha: 1.000  val_loss: 0.0802
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0034  domain_loss: 1.3875  alpha: 1.000  val_loss: 0.0843
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0779
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0770
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0721
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0813
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0686
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0692
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0653
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0622
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0609
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0595
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0581
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0563
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0565
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0546
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0524
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0532
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0561
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0496
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0509
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0503
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0497
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0521
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0481
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0496
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0481
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0460
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0449
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0448
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0470
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0456
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.7429  domain_loss: 1.1942  alpha: 0.100  val_loss: 0.5095
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3005  domain_loss: 1.3616  alpha: 0.197  val_loss: 0.4617
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4568  domain_loss: 1.3310  alpha: 0.291  val_loss: 0.4271
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.9698  domain_loss: 1.4438  alpha: 0.380  val_loss: 0.3997
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.2825  domain_loss: 1.3598  alpha: 0.462  val_loss: 0.3735
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.4311  domain_loss: 1.4118  alpha: 0.537  val_loss: 0.3472
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2615  domain_loss: 1.3883  alpha: 0.604  val_loss: 0.3240
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.1336  domain_loss: 1.3667  alpha: 0.664  val_loss: 0.3034
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2067  domain_loss: 1.2864  alpha: 0.716  val_loss: 0.2816
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3967  domain_loss: 1.3296  alpha: 0.762  val_loss: 0.2627
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1505  domain_loss: 1.3810  alpha: 0.800  val_loss: 0.2452
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1456  domain_loss: 1.4066  alpha: 0.834  val_loss: 0.2326
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.1208  domain_loss: 1.3816  alpha: 0.862  val_loss: 0.2169
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.6213  domain_loss: 1.3976  alpha: 0.885  val_loss: 0.2091
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.0644  domain_loss: 1.4078  alpha: 0.905  val_loss: 0.1940
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.6798  domain_loss: 1.3859  alpha: 0.922  val_loss: 0.1919
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.0737  domain_loss: 1.3866  alpha: 0.935  val_loss: 0.1816
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.4851  domain_loss: 1.4010  alpha: 0.947  val_loss: 0.1701
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.0725  domain_loss: 1.3476  alpha: 0.956  val_loss: 0.1659
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.0870  domain_loss: 1.4047  alpha: 0.964  val_loss: 0.1608
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2573  domain_loss: 1.3818  alpha: 0.970  val_loss: 0.1490
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1244  domain_loss: 1.3809  alpha: 0.976  val_loss: 0.1509
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.0349  domain_loss: 1.4007  alpha: 0.980  val_loss: 0.1409
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.4120  domain_loss: 1.4140  alpha: 0.984  val_loss: 0.1434
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.5376  domain_loss: 1.3868  alpha: 0.987  val_loss: 0.1321
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0277  domain_loss: 1.3622  alpha: 0.989  val_loss: 0.1285
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0447  domain_loss: 1.3794  alpha: 0.991  val_loss: 0.1292
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0181  domain_loss: 1.3809  alpha: 0.993  val_loss: 0.1233
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.5211  domain_loss: 1.3756  alpha: 0.994  val_loss: 0.1186
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.4012  domain_loss: 1.3957  alpha: 0.995  val_loss: 0.1170
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.2451  domain_loss: 1.3786  alpha: 0.996  val_loss: 0.1133
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0382  domain_loss: 1.3952  alpha: 0.997  val_loss: 0.1117
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0133  domain_loss: 1.3565  alpha: 0.997  val_loss: 0.1045
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1166  domain_loss: 1.3961  alpha: 0.998  val_loss: 0.1060
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0266  domain_loss: 1.3839  alpha: 0.998  val_loss: 0.1047
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0165  domain_loss: 1.3840  alpha: 0.999  val_loss: 0.1010
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0375  domain_loss: 1.4010  alpha: 0.999  val_loss: 0.1005
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0372  domain_loss: 1.3906  alpha: 0.999  val_loss: 0.0961
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1144  domain_loss: 1.3774  alpha: 0.999  val_loss: 0.0963
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0236  domain_loss: 1.3744  alpha: 0.999  val_loss: 0.0915
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0031  domain_loss: 1.3832  alpha: 0.999  val_loss: 0.0901
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0726  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.0907
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0079  domain_loss: 1.3797  alpha: 1.000  val_loss: 0.0932
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0203  domain_loss: 1.3885  alpha: 1.000  val_loss: 0.0856
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1364  domain_loss: 1.3911  alpha: 1.000  val_loss: 0.0840
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0095  domain_loss: 1.3782  alpha: 1.000  val_loss: 0.0888
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0075  domain_loss: 1.3821  alpha: 1.000  val_loss: 0.0815
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0068  domain_loss: 1.3807  alpha: 1.000  val_loss: 0.0908
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.4872  domain_loss: 1.3851  alpha: 1.000  val_loss: 0.0837
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0014  domain_loss: 1.3880  alpha: 1.000  val_loss: 0.0833
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0796
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0788
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0712
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0788
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0727
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0652
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0636
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0631
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0579
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0648
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0595
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0627
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0573
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0578
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0551
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0640
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0498
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0560
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0480
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0490
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0454
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0483
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0451
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0437
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0484
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0475
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0465
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0425
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (poppler Test Set) ===
# Accuracy  : 0.791
# Precision : 0.064
# Recall    : 0.758
# F1-score  : 0.117
# AUC       : 0.887
# G-mean    : 0.774
# PF value  : 0.208
#
# Confusion Matrix:
#   TN: 1397  FP: 368
#   FN: 8  TP: 25
#
# Results saved to results/dann_smote/poppler/dann_smote_poppler.json
# Confusion matrix saved as results/dann_smote/poppler/confusion_matrix_dann_smote_poppler.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
DANN Domain Adaptation + SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_smote/radare2"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on SMOTE-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (radare2)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (SMOTE) + pseudo-labelled radare2
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (DANN + SMOTE) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on SMOTE-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_sm)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_sm
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_sm, train_lbl_sm,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_sm, train_lbl_sm, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_smote",
        "train"            : "all_except_radare2",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_smote_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_smote_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except radare2 -> Test on radare2 (DANN + SMOTE) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221730, 768)  vuln=5930  benign=215800
#       Projects in training pool : 753
#       Test set (radare2)          : (2803, 768)  vuln=74  benign=2729
#       Training imbalance ratio  : 0.0267
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying SMOTE oversampling...
#       Before SMOTE : (221730, 768)  vuln=5930  benign=215800
#       After SMOTE  : (431600, 768)  vuln=215800  benign=215800
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5474  domain_loss: 1.3374  alpha: 0.100  val_loss: 0.5209
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.5436  domain_loss: 1.4057  alpha: 0.197  val_loss: 0.4725
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4826  domain_loss: 1.4210  alpha: 0.291  val_loss: 0.4378
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4012  domain_loss: 1.3546  alpha: 0.380  val_loss: 0.4113
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3104  domain_loss: 1.3691  alpha: 0.462  val_loss: 0.3879
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3590  domain_loss: 1.3916  alpha: 0.537  val_loss: 0.3617
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4556  domain_loss: 1.3704  alpha: 0.604  val_loss: 0.3413
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2846  domain_loss: 1.3834  alpha: 0.664  val_loss: 0.3169
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2623  domain_loss: 1.4024  alpha: 0.716  val_loss: 0.2977
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2918  domain_loss: 1.3752  alpha: 0.762  val_loss: 0.2859
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2272  domain_loss: 1.3967  alpha: 0.800  val_loss: 0.2625
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2018  domain_loss: 1.4007  alpha: 0.834  val_loss: 0.2474
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.3574  domain_loss: 1.3811  alpha: 0.862  val_loss: 0.2345
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3542  domain_loss: 1.3840  alpha: 0.885  val_loss: 0.2284
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1651  domain_loss: 1.3794  alpha: 0.905  val_loss: 0.2123
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1890  domain_loss: 1.3894  alpha: 0.922  val_loss: 0.2013
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1518  domain_loss: 1.3734  alpha: 0.935  val_loss: 0.1908
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2019  domain_loss: 1.3918  alpha: 0.947  val_loss: 0.1834
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1512  domain_loss: 1.3816  alpha: 0.956  val_loss: 0.1768
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.2919  domain_loss: 1.3873  alpha: 0.964  val_loss: 0.1688
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2307  domain_loss: 1.3849  alpha: 0.970  val_loss: 0.1629
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1971  domain_loss: 1.3834  alpha: 0.976  val_loss: 0.1555
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.3105  domain_loss: 1.3840  alpha: 0.980  val_loss: 0.1538
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1185  domain_loss: 1.3848  alpha: 0.984  val_loss: 0.1465
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2330  domain_loss: 1.3887  alpha: 0.987  val_loss: 0.1395
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.2303  domain_loss: 1.3873  alpha: 0.989  val_loss: 0.1362
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1003  domain_loss: 1.3834  alpha: 0.991  val_loss: 0.1315
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.2204  domain_loss: 1.3837  alpha: 0.993  val_loss: 0.1280
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1435  domain_loss: 1.3913  alpha: 0.994  val_loss: 0.1250
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1325  domain_loss: 1.3917  alpha: 0.995  val_loss: 0.1208
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.2278  domain_loss: 1.3851  alpha: 0.996  val_loss: 0.1175
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.2418  domain_loss: 1.3827  alpha: 0.997  val_loss: 0.1169
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1010  domain_loss: 1.3842  alpha: 0.997  val_loss: 0.1248
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.2908  domain_loss: 1.3878  alpha: 0.998  val_loss: 0.1095
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1812  domain_loss: 1.3853  alpha: 0.998  val_loss: 0.1128
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1008  domain_loss: 1.3902  alpha: 0.999  val_loss: 0.1057
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1927  domain_loss: 1.3913  alpha: 0.999  val_loss: 0.1028
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0845  domain_loss: 1.3904  alpha: 0.999  val_loss: 0.1030
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1435  domain_loss: 1.3840  alpha: 0.999  val_loss: 0.0988
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1275  domain_loss: 1.3852  alpha: 0.999  val_loss: 0.0976
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0539  domain_loss: 1.3870  alpha: 0.999  val_loss: 0.0940
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0882  domain_loss: 1.3884  alpha: 1.000  val_loss: 0.0995
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1873  domain_loss: 1.3863  alpha: 1.000  val_loss: 0.0915
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0413  domain_loss: 1.3822  alpha: 1.000  val_loss: 0.0933
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0363  domain_loss: 1.3840  alpha: 1.000  val_loss: 0.0934
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0314  domain_loss: 1.3906  alpha: 1.000  val_loss: 0.0924
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0358  domain_loss: 1.3853  alpha: 1.000  val_loss: 0.0857
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1284  domain_loss: 1.3843  alpha: 1.000  val_loss: 0.0856
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.1673  domain_loss: 1.3875  alpha: 1.000  val_loss: 0.0848
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0815  domain_loss: 1.3821  alpha: 1.000  val_loss: 0.0839
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0811
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0804
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0787
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0736
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0713
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0648
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0663
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0696
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0679
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0619
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0614
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0589
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0564
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0538
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0516
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0550
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0539
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0513
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0488
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0478
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0508
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0530
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0460
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0447
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0459
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0495
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0424
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0422
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0425
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5279  domain_loss: 1.3264  alpha: 0.100  val_loss: 0.5178
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4726  domain_loss: 1.4238  alpha: 0.197  val_loss: 0.4689
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4844  domain_loss: 1.3515  alpha: 0.291  val_loss: 0.4350
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3140  domain_loss: 1.4081  alpha: 0.380  val_loss: 0.4083
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3066  domain_loss: 1.3929  alpha: 0.462  val_loss: 0.3875
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3612  domain_loss: 1.3868  alpha: 0.537  val_loss: 0.3620
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3001  domain_loss: 1.3974  alpha: 0.604  val_loss: 0.3402
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3520  domain_loss: 1.3964  alpha: 0.664  val_loss: 0.3184
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.4092  domain_loss: 1.3750  alpha: 0.716  val_loss: 0.3000
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3640  domain_loss: 1.4196  alpha: 0.762  val_loss: 0.2847
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1369  domain_loss: 1.3929  alpha: 0.800  val_loss: 0.2690
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3431  domain_loss: 1.3983  alpha: 0.834  val_loss: 0.2596
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2397  domain_loss: 1.9158  alpha: 0.862  val_loss: 0.2803
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3723  domain_loss: 3.5302  alpha: 0.885  val_loss: 0.6211
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2891  domain_loss: 5.6339  alpha: 0.905  val_loss: 1.6274
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 3.3040  domain_loss: 16.0047  alpha: 0.922  val_loss: 3.3594
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 1.7966  domain_loss: 20.3547  alpha: 0.935  val_loss: 4.8460
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 3.8102  domain_loss: 18.1523  alpha: 0.947  val_loss: 5.0227
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 7.9678  domain_loss: 28.8546  alpha: 0.956  val_loss: 5.0552
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 14.2571  domain_loss: 31.5066  alpha: 0.964  val_loss: 5.1488
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 5.6446  domain_loss: 25.7047  alpha: 0.970  val_loss: 5.3926
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2579  domain_loss: 5.3615  alpha: 0.976  val_loss: 5.8121
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 12.7977  domain_loss: 1.3478  alpha: 0.980  val_loss: 5.6040
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 3.4843  domain_loss: 1.3622  alpha: 0.984  val_loss: 5.2719
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 1.7932  domain_loss: 1.3482  alpha: 0.987  val_loss: 5.0383
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 4.3761  domain_loss: 1.3148  alpha: 0.989  val_loss: 4.7901
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 2.6418  domain_loss: 1.3428  alpha: 0.991  val_loss: 4.5366
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 7.9760  domain_loss: 1.3890  alpha: 0.993  val_loss: 4.1029
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 6.3914  domain_loss: 1.3753  alpha: 0.994  val_loss: 3.6716
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 3.9931  domain_loss: 1.3220  alpha: 0.995  val_loss: 3.2030
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 1.9032  domain_loss: 1.3799  alpha: 0.996  val_loss: 2.5614
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.2028  domain_loss: 1.3194  alpha: 0.997  val_loss: 2.0865
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 1.8807  domain_loss: 1.3558  alpha: 0.997  val_loss: 1.7248
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.2095  domain_loss: 1.3695  alpha: 0.998  val_loss: 1.5039
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 1.8748  domain_loss: 1.3523  alpha: 0.998  val_loss: 1.3924
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 1.7484  domain_loss: 1.3813  alpha: 0.999  val_loss: 1.3138
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1410  domain_loss: 1.3760  alpha: 0.999  val_loss: 1.2525
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1471  domain_loss: 1.3969  alpha: 0.999  val_loss: 1.1710
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 1.6867  domain_loss: 1.3542  alpha: 0.999  val_loss: 1.1020
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 1.0740  domain_loss: 1.3731  alpha: 0.999  val_loss: 1.0388
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.1123  domain_loss: 1.3710  alpha: 0.999  val_loss: 0.9798
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1132  domain_loss: 1.3653  alpha: 1.000  val_loss: 0.9430
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1943  domain_loss: 1.3570  alpha: 1.000  val_loss: 0.8937
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.3286  domain_loss: 1.3826  alpha: 1.000  val_loss: 0.8306
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.2357  domain_loss: 1.3678  alpha: 1.000  val_loss: 0.7990
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1906  domain_loss: 1.3720  alpha: 1.000  val_loss: 0.7662
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.2038  domain_loss: 1.3833  alpha: 1.000  val_loss: 0.7477
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1366  domain_loss: 1.3827  alpha: 1.000  val_loss: 0.6811
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.1756  domain_loss: 1.3876  alpha: 1.000  val_loss: 0.6477
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 1.8307  domain_loss: 1.3685  alpha: 1.000  val_loss: 0.6228
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.5583
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.4997
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.4568
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.4046
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.3768
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.3098
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.2744
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.2457
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.2114
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1767
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1606
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1372
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1243
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1119
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1062
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0958
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0872
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0874
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0810
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0826
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0818
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0722
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0684
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0713
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0674
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0669
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0666
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0596
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0639
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0598
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5466  domain_loss: 1.3765  alpha: 0.100  val_loss: 0.5191
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4567  domain_loss: 1.3506  alpha: 0.197  val_loss: 0.4792
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4830  domain_loss: 1.3983  alpha: 0.291  val_loss: 0.4454
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4387  domain_loss: 1.3610  alpha: 0.380  val_loss: 0.4187
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3512  domain_loss: 1.4141  alpha: 0.462  val_loss: 0.3938
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.4102  domain_loss: 1.3796  alpha: 0.537  val_loss: 0.3744
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4219  domain_loss: 1.3985  alpha: 0.604  val_loss: 0.3504
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.4977  domain_loss: 1.4008  alpha: 0.664  val_loss: 0.3297
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3323  domain_loss: 1.3772  alpha: 0.716  val_loss: 0.3083
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3947  domain_loss: 1.3875  alpha: 0.762  val_loss: 0.2888
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.4143  domain_loss: 1.3821  alpha: 0.800  val_loss: 0.2726
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3552  domain_loss: 1.4073  alpha: 0.834  val_loss: 0.2581
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.3873  domain_loss: 1.3819  alpha: 0.862  val_loss: 0.2432
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3672  domain_loss: 1.3703  alpha: 0.885  val_loss: 0.2294
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2740  domain_loss: 1.3785  alpha: 0.905  val_loss: 0.2176
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1961  domain_loss: 1.3845  alpha: 0.922  val_loss: 0.2094
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1549  domain_loss: 1.3966  alpha: 0.935  val_loss: 0.2008
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2812  domain_loss: 1.3773  alpha: 0.947  val_loss: 0.1932
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1435  domain_loss: 1.3784  alpha: 0.956  val_loss: 0.1805
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.3167  domain_loss: 1.3914  alpha: 0.964  val_loss: 0.1719
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.3640  domain_loss: 1.3856  alpha: 0.970  val_loss: 0.1675
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1265  domain_loss: 1.3827  alpha: 0.976  val_loss: 0.1604
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1153  domain_loss: 1.3785  alpha: 0.980  val_loss: 0.1551
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1341  domain_loss: 1.3880  alpha: 0.984  val_loss: 0.1518
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2343  domain_loss: 1.3825  alpha: 0.987  val_loss: 0.1448
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1815  domain_loss: 1.3842  alpha: 0.989  val_loss: 0.1391
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.1647  domain_loss: 1.3930  alpha: 0.991  val_loss: 0.1353
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.2098  domain_loss: 1.3877  alpha: 0.993  val_loss: 0.1302
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1567  domain_loss: 1.3817  alpha: 0.994  val_loss: 0.1269
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.1225  domain_loss: 1.3849  alpha: 0.995  val_loss: 0.1221
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.2145  domain_loss: 1.3805  alpha: 0.996  val_loss: 0.1300
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1229  domain_loss: 1.3864  alpha: 0.997  val_loss: 0.1163
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1655  domain_loss: 1.3919  alpha: 0.997  val_loss: 0.1147
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1983  domain_loss: 1.3858  alpha: 0.998  val_loss: 0.1134
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1698  domain_loss: 1.3902  alpha: 0.998  val_loss: 0.1091
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0785  domain_loss: 1.3839  alpha: 0.999  val_loss: 0.1048
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0257  domain_loss: 1.3869  alpha: 0.999  val_loss: 0.1058
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1250  domain_loss: 1.3832  alpha: 0.999  val_loss: 0.1017
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0974  domain_loss: 1.3882  alpha: 0.999  val_loss: 0.1044
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1992  domain_loss: 1.3923  alpha: 0.999  val_loss: 0.0990
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.1870  domain_loss: 1.3878  alpha: 0.999  val_loss: 0.0961
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1141  domain_loss: 1.3818  alpha: 1.000  val_loss: 0.0935
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1244  domain_loss: 1.3876  alpha: 1.000  val_loss: 0.0919
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0565  domain_loss: 1.3853  alpha: 1.000  val_loss: 0.0917
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1787  domain_loss: 1.3857  alpha: 1.000  val_loss: 0.0937
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.2099  domain_loss: 1.3891  alpha: 1.000  val_loss: 0.0876
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0548  domain_loss: 1.3892  alpha: 1.000  val_loss: 0.0942
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1135  domain_loss: 1.3868  alpha: 1.000  val_loss: 0.0877
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0641  domain_loss: 1.3835  alpha: 1.000  val_loss: 0.0871
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0454  domain_loss: 1.3830  alpha: 1.000  val_loss: 0.0837
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0876
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0828
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0771
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0742
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0717
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0739
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0692
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0665
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0612
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0643
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0587
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0575
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0554
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0560
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0574
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0550
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0500
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0531
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0508
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0476
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0495
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0456
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0514
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0461
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0454
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0446
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0442
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (radare2 Test Set) ===
# Accuracy  : 0.849
# Precision : 0.088
# Recall    : 0.500
# F1-score  : 0.149
# AUC       : 0.798
# G-mean    : 0.655
# PF value  : 0.141
#
# Confusion Matrix:
#   TN: 2344  FP: 385
#   FN: 37  TP: 37
#
# Results saved to results/dann_smote/radare2/dann_smote_radare2.json
# Confusion matrix saved as results/dann_smote/radare2/confusion_matrix_dann_smote_radare2.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
DANN Domain Adaptation + SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux-2.6"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_smote/linux-2.6"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on SMOTE-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (linux-2.6)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (SMOTE) + pseudo-labelled linux-2.6
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux-2.6 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (DANN + SMOTE) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux-2.6)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on SMOTE-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_sm)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_sm
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_sm, train_lbl_sm,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_sm, train_lbl_sm, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux-2.6 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_smote",
        "train"            : "all_except_linux-2.6",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_smote_linux-2.6.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_smote_linux-2.6.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (DANN + SMOTE) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221163, 768)  vuln=5904  benign=215259
#       Projects in training pool : 753
#       Test set (linux-2.6)          : (3370, 768)  vuln=100  benign=3270
#       Training imbalance ratio  : 0.0267
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying SMOTE oversampling...
#       Before SMOTE : (221163, 768)  vuln=5904  benign=215259
#       After SMOTE  : (430518, 768)  vuln=215259  benign=215259
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.6399  domain_loss: 1.3272  alpha: 0.100  val_loss: 0.5198
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4416  domain_loss: 1.3970  alpha: 0.197  val_loss: 0.4677
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.4153  domain_loss: 1.3569  alpha: 0.291  val_loss: 0.4386
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3632  domain_loss: 1.4328  alpha: 0.380  val_loss: 0.4141
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.3979  domain_loss: 1.3476  alpha: 0.462  val_loss: 0.3945
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.4890  domain_loss: 1.3444  alpha: 0.537  val_loss: 0.3765
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3663  domain_loss: 1.3714  alpha: 0.604  val_loss: 0.3563
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2892  domain_loss: 1.3870  alpha: 0.664  val_loss: 0.3371
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.3315  domain_loss: 1.4034  alpha: 0.716  val_loss: 0.3221
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3849  domain_loss: 1.3641  alpha: 0.762  val_loss: 0.3049
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2519  domain_loss: 1.3618  alpha: 0.800  val_loss: 0.2888
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1993  domain_loss: 1.3943  alpha: 0.834  val_loss: 0.2765
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.4143  domain_loss: 1.4136  alpha: 0.862  val_loss: 0.2650
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2529  domain_loss: 1.4014  alpha: 0.885  val_loss: 0.2521
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2705  domain_loss: 1.4138  alpha: 0.905  val_loss: 0.2428
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3016  domain_loss: 1.3847  alpha: 0.922  val_loss: 0.2288
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.3709  domain_loss: 1.3669  alpha: 0.935  val_loss: 0.2215
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1866  domain_loss: 1.4037  alpha: 0.947  val_loss: 0.2153
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2588  domain_loss: 1.3747  alpha: 0.956  val_loss: 0.2071
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.2464  domain_loss: 1.3924  alpha: 0.964  val_loss: 0.1963
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0764  domain_loss: 1.3587  alpha: 0.970  val_loss: 0.1921
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2237  domain_loss: 1.3667  alpha: 0.976  val_loss: 0.1828
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2749  domain_loss: 1.3624  alpha: 0.980  val_loss: 0.1870
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1432  domain_loss: 1.3737  alpha: 0.984  val_loss: 0.1736
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1463  domain_loss: 1.3914  alpha: 0.987  val_loss: 0.1667
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.3047  domain_loss: 1.3988  alpha: 0.989  val_loss: 0.1631
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.3172  domain_loss: 1.4099  alpha: 0.991  val_loss: 0.1589
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0900  domain_loss: 1.3935  alpha: 0.993  val_loss: 0.1564
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1513  domain_loss: 1.3738  alpha: 0.994  val_loss: 0.1498
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0600  domain_loss: 1.3881  alpha: 0.995  val_loss: 0.1475
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.4255  domain_loss: 1.3641  alpha: 0.996  val_loss: 0.1417
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.3172  domain_loss: 1.3579  alpha: 0.997  val_loss: 0.1394
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0447  domain_loss: 1.3709  alpha: 0.997  val_loss: 0.1379
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.2558  domain_loss: 1.3777  alpha: 0.998  val_loss: 0.1311
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0407  domain_loss: 1.3897  alpha: 0.998  val_loss: 0.1339
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1155  domain_loss: 1.3785  alpha: 0.999  val_loss: 0.1271
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0512  domain_loss: 1.4117  alpha: 0.999  val_loss: 0.1257
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1550  domain_loss: 1.3835  alpha: 0.999  val_loss: 0.1197
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0749  domain_loss: 1.3723  alpha: 0.999  val_loss: 0.1209
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0485  domain_loss: 1.3924  alpha: 0.999  val_loss: 0.1175
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.2281  domain_loss: 1.3960  alpha: 0.999  val_loss: 0.1159
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2934  domain_loss: 1.3833  alpha: 1.000  val_loss: 0.1170
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1394  domain_loss: 1.3809  alpha: 1.000  val_loss: 0.1090
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2033  domain_loss: 1.3782  alpha: 1.000  val_loss: 0.1120
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.2542  domain_loss: 1.3831  alpha: 1.000  val_loss: 0.1150
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1342  domain_loss: 1.3918  alpha: 1.000  val_loss: 0.1087
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0244  domain_loss: 1.3764  alpha: 1.000  val_loss: 0.1050
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.2215  domain_loss: 1.3936  alpha: 1.000  val_loss: 0.1043
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0420  domain_loss: 1.3674  alpha: 1.000  val_loss: 0.0990
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.1717  domain_loss: 1.3810  alpha: 1.000  val_loss: 0.0991
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0931
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0857
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0836
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0817
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0867
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0762
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0831
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0669
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0775
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0645
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0615
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0618
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0622
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0642
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0570
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0655
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0539
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0552
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0533
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0536
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0565
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0520
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0527
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0505
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0489
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0486
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0508
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0435
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0465
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5709  domain_loss: 1.3611  alpha: 0.100  val_loss: 0.5180
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4677  domain_loss: 1.4168  alpha: 0.197  val_loss: 0.4679
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.5437  domain_loss: 1.3441  alpha: 0.291  val_loss: 0.4405
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4651  domain_loss: 1.3870  alpha: 0.380  val_loss: 0.4150
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.5095  domain_loss: 1.3807  alpha: 0.462  val_loss: 0.3950
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3687  domain_loss: 1.3377  alpha: 0.537  val_loss: 0.3768
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4501  domain_loss: 1.3682  alpha: 0.604  val_loss: 0.3571
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.4539  domain_loss: 1.3522  alpha: 0.664  val_loss: 0.3403
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.5337  domain_loss: 1.3801  alpha: 0.716  val_loss: 0.3238
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.3548  domain_loss: 1.3377  alpha: 0.762  val_loss: 0.3101
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2857  domain_loss: 1.3779  alpha: 0.800  val_loss: 0.2943
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2260  domain_loss: 1.3926  alpha: 0.834  val_loss: 0.2820
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2344  domain_loss: 1.3906  alpha: 0.862  val_loss: 0.2703
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1916  domain_loss: 1.3644  alpha: 0.885  val_loss: 0.2564
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.4496  domain_loss: 1.3812  alpha: 0.905  val_loss: 0.2460
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2611  domain_loss: 1.3768  alpha: 0.922  val_loss: 0.2360
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.4805  domain_loss: 1.3642  alpha: 0.935  val_loss: 0.2310
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.3512  domain_loss: 1.3933  alpha: 0.947  val_loss: 0.2254
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.3572  domain_loss: 1.3557  alpha: 0.956  val_loss: 0.2139
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.2518  domain_loss: 1.3967  alpha: 0.964  val_loss: 0.2066
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.1601  domain_loss: 1.3951  alpha: 0.970  val_loss: 0.1970
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.1408  domain_loss: 1.3837  alpha: 0.976  val_loss: 0.1916
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.0920  domain_loss: 1.3525  alpha: 0.980  val_loss: 0.1831
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2287  domain_loss: 1.4062  alpha: 0.984  val_loss: 0.1782
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2984  domain_loss: 1.3449  alpha: 0.987  val_loss: 0.1730
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0957  domain_loss: 1.3897  alpha: 0.989  val_loss: 0.1664
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.3600  domain_loss: 1.3578  alpha: 0.991  val_loss: 0.1606
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.5046  domain_loss: 1.3682  alpha: 0.993  val_loss: 0.1612
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0551  domain_loss: 1.3932  alpha: 0.994  val_loss: 0.1508
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.4093  domain_loss: 1.3915  alpha: 0.995  val_loss: 0.1496
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1711  domain_loss: 1.3344  alpha: 0.996  val_loss: 0.1454
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.2167  domain_loss: 1.3691  alpha: 0.997  val_loss: 0.1390
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1520  domain_loss: 1.3748  alpha: 0.997  val_loss: 0.1368
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0822  domain_loss: 1.3875  alpha: 0.998  val_loss: 0.1330
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1904  domain_loss: 1.3627  alpha: 0.998  val_loss: 0.1312
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1307  domain_loss: 1.3669  alpha: 0.999  val_loss: 0.1319
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1396  domain_loss: 1.3849  alpha: 0.999  val_loss: 0.1266
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1174  domain_loss: 1.3724  alpha: 0.999  val_loss: 0.1232
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1464  domain_loss: 1.3966  alpha: 0.999  val_loss: 0.1220
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.2864  domain_loss: 1.3698  alpha: 0.999  val_loss: 0.1197
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0240  domain_loss: 1.3817  alpha: 0.999  val_loss: 0.1190
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0618  domain_loss: 1.3808  alpha: 1.000  val_loss: 0.1208
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.2268  domain_loss: 1.3699  alpha: 1.000  val_loss: 0.1119
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0425  domain_loss: 1.3816  alpha: 1.000  val_loss: 0.1117
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.1557  domain_loss: 1.3811  alpha: 1.000  val_loss: 0.1098
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0557  domain_loss: 1.3796  alpha: 1.000  val_loss: 0.1048
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0848  domain_loss: 1.3860  alpha: 1.000  val_loss: 0.1066
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1036  domain_loss: 1.3883  alpha: 1.000  val_loss: 0.1030
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0887  domain_loss: 1.3692  alpha: 1.000  val_loss: 0.0995
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.2564  domain_loss: 1.3802  alpha: 1.000  val_loss: 0.1122
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0894
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0867
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0850
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0799
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0770
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0726
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0801
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0697
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0666
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0701
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0640
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0610
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0584
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0587
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0574
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0624
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0646
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0548
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0555
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0536
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0527
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0501
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0525
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0497
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0476
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0518
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0543
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0464
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0483
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.5342  domain_loss: 1.3345  alpha: 0.100  val_loss: 0.5185
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.6616  domain_loss: 1.3120  alpha: 0.197  val_loss: 0.4807
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.3822  domain_loss: 1.3556  alpha: 0.291  val_loss: 0.4528
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3510  domain_loss: 1.4175  alpha: 0.380  val_loss: 0.4309
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.4883  domain_loss: 1.3789  alpha: 0.462  val_loss: 0.4125
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3548  domain_loss: 1.3803  alpha: 0.537  val_loss: 0.3926
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.5308  domain_loss: 1.3865  alpha: 0.604  val_loss: 0.3765
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.6129  domain_loss: 1.4049  alpha: 0.664  val_loss: 0.3582
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2368  domain_loss: 1.3814  alpha: 0.716  val_loss: 0.3408
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2330  domain_loss: 1.3556  alpha: 0.762  val_loss: 0.3259
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3842  domain_loss: 1.3589  alpha: 0.800  val_loss: 0.3077
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.4083  domain_loss: 1.3843  alpha: 0.834  val_loss: 0.2915
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.1085  domain_loss: 1.3784  alpha: 0.862  val_loss: 0.2849
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.1323  domain_loss: 1.3582  alpha: 0.885  val_loss: 0.2641
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.3115  domain_loss: 1.3695  alpha: 0.905  val_loss: 0.2540
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3186  domain_loss: 1.4282  alpha: 0.922  val_loss: 0.2434
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.3584  domain_loss: 1.3850  alpha: 0.935  val_loss: 0.2299
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.2311  domain_loss: 1.4094  alpha: 0.947  val_loss: 0.2207
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2535  domain_loss: 1.3832  alpha: 0.956  val_loss: 0.2145
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1984  domain_loss: 1.3684  alpha: 0.964  val_loss: 0.2056
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0778  domain_loss: 1.3830  alpha: 0.970  val_loss: 0.2000
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2711  domain_loss: 1.3879  alpha: 0.976  val_loss: 0.1902
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2646  domain_loss: 1.3734  alpha: 0.980  val_loss: 0.1860
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1939  domain_loss: 1.3751  alpha: 0.984  val_loss: 0.1790
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2198  domain_loss: 1.3669  alpha: 0.987  val_loss: 0.1747
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.2421  domain_loss: 1.3862  alpha: 0.989  val_loss: 0.1662
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0626  domain_loss: 1.3773  alpha: 0.991  val_loss: 0.1622
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.2322  domain_loss: 1.3547  alpha: 0.993  val_loss: 0.1595
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1198  domain_loss: 1.3705  alpha: 0.994  val_loss: 0.1529
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.2761  domain_loss: 1.4028  alpha: 0.995  val_loss: 0.1469
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1190  domain_loss: 1.3839  alpha: 0.996  val_loss: 0.1448
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.1328  domain_loss: 1.4114  alpha: 0.997  val_loss: 0.1394
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1374  domain_loss: 1.4023  alpha: 0.997  val_loss: 0.1361
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.1837  domain_loss: 1.4151  alpha: 0.998  val_loss: 0.1344
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.1621  domain_loss: 1.3533  alpha: 0.998  val_loss: 0.1316
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1054  domain_loss: 1.3780  alpha: 0.999  val_loss: 0.1243
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.0662  domain_loss: 1.3658  alpha: 0.999  val_loss: 0.1258
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1953  domain_loss: 1.3782  alpha: 0.999  val_loss: 0.1260
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1064  domain_loss: 1.3975  alpha: 0.999  val_loss: 0.1315
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.1438  domain_loss: 1.3895  alpha: 0.999  val_loss: 0.1175
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0921  domain_loss: 1.3666  alpha: 0.999  val_loss: 0.1202
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.2450  domain_loss: 1.3847  alpha: 1.000  val_loss: 0.1125
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0426  domain_loss: 1.3724  alpha: 1.000  val_loss: 0.1085
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2162  domain_loss: 1.3812  alpha: 1.000  val_loss: 0.1079
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0188  domain_loss: 1.3967  alpha: 1.000  val_loss: 0.1079
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.1564  domain_loss: 1.3962  alpha: 1.000  val_loss: 0.1027
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0245  domain_loss: 1.3925  alpha: 1.000  val_loss: 0.1123
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0581  domain_loss: 1.3845  alpha: 1.000  val_loss: 0.1276
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0632  domain_loss: 1.3745  alpha: 1.000  val_loss: 0.1064
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.1127  domain_loss: 1.3928  alpha: 1.000  val_loss: 0.1042
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0933
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1060
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0807
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0820
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0749
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0736
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0762
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0681
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0677
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0697
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0667
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0818
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0668
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0641
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0623
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0653
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0563
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0547
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0560
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0584
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0533
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0501
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0529
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0511
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0485
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0537
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0499
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0494
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0483
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (linux-2.6 Test Set) ===
# Accuracy  : 0.755
# Precision : 0.068
# Recall    : 0.570
# F1-score  : 0.121
# AUC       : 0.741
# G-mean    : 0.659
# PF value  : 0.239
#
# Confusion Matrix:
#   TN: 2488  FP: 782
#   FN: 43  TP: 57
#
# Results saved to results/dann_smote/linux-2.6/dann_smote_linux-2.6.json
# Confusion matrix saved as results/dann_smote/linux-2.6/confusion_matrix_dann_smote_linux-2.6.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
DANN Domain Adaptation + SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "vim"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_smote/vim"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on SMOTE-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (vim)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (SMOTE) + pseudo-labelled vim
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (DANN + SMOTE) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on SMOTE-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_sm)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_sm
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_sm, train_lbl_sm,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_sm, train_lbl_sm, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_smote",
        "train"            : "all_except_vim",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_smote_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_smote_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (DANN + SMOTE) ===
#     Device: mps
#
# [1/6] Loading combined embeddings...
#       Training pool             : (221466, 768)  vuln=5898  benign=215568
#       Projects in training pool : 753
#       Test set (vim)          : (3067, 768)  vuln=106  benign=2961
#       Training imbalance ratio  : 0.0266
#
# [2/6] Normalizing embeddings...
#
# [3/6] Applying SMOTE oversampling...
#       Before SMOTE : (221466, 768)  vuln=5898  benign=215568
#       After SMOTE  : (431136, 768)  vuln=215568  benign=215568
#
# [4/6] Computing class weights...
#       Class weights: {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.3377  domain_loss: 1.4446  alpha: 0.100  val_loss: 0.5175
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3691  domain_loss: 1.3845  alpha: 0.197  val_loss: 0.4664
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.2641  domain_loss: 1.3692  alpha: 0.291  val_loss: 0.4313
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.2652  domain_loss: 1.3984  alpha: 0.380  val_loss: 0.4063
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.4479  domain_loss: 1.3514  alpha: 0.462  val_loss: 0.3799
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.7171  domain_loss: 1.4269  alpha: 0.537  val_loss: 0.3571
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.4470  domain_loss: 1.3600  alpha: 0.604  val_loss: 0.3353
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.5014  domain_loss: 1.4059  alpha: 0.664  val_loss: 0.3128
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2402  domain_loss: 1.4066  alpha: 0.716  val_loss: 0.2943
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.4738  domain_loss: 1.3879  alpha: 0.762  val_loss: 0.2798
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3722  domain_loss: 1.4070  alpha: 0.800  val_loss: 0.2597
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1381  domain_loss: 1.3689  alpha: 0.834  val_loss: 0.2469
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.4960  domain_loss: 1.3713  alpha: 0.862  val_loss: 0.2338
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3394  domain_loss: 1.3959  alpha: 0.885  val_loss: 0.2222
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.3249  domain_loss: 1.3733  alpha: 0.905  val_loss: 0.2096
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.4252  domain_loss: 1.3968  alpha: 0.922  val_loss: 0.2035
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.4434  domain_loss: 1.3902  alpha: 0.935  val_loss: 0.1935
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.5206  domain_loss: 1.3777  alpha: 0.947  val_loss: 0.1881
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.2519  domain_loss: 1.3776  alpha: 0.956  val_loss: 0.1768
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.0478  domain_loss: 1.3838  alpha: 0.964  val_loss: 0.1689
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0846  domain_loss: 1.3939  alpha: 0.970  val_loss: 0.1641
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.0641  domain_loss: 1.3997  alpha: 0.976  val_loss: 0.1633
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1847  domain_loss: 1.3834  alpha: 0.980  val_loss: 0.1524
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2190  domain_loss: 1.3797  alpha: 0.984  val_loss: 0.1479
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.0835  domain_loss: 1.3884  alpha: 0.987  val_loss: 0.1430
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1136  domain_loss: 1.3952  alpha: 0.989  val_loss: 0.1384
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0926  domain_loss: 1.3910  alpha: 0.991  val_loss: 0.1349
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0132  domain_loss: 1.3883  alpha: 0.993  val_loss: 0.1292
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.0163  domain_loss: 1.3908  alpha: 0.994  val_loss: 0.1285
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0560  domain_loss: 1.3841  alpha: 0.995  val_loss: 0.1236
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.0150  domain_loss: 1.3837  alpha: 0.996  val_loss: 0.1204
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.0105  domain_loss: 1.3904  alpha: 0.997  val_loss: 0.1155
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1334  domain_loss: 1.3849  alpha: 0.997  val_loss: 0.1150
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.0246  domain_loss: 1.3881  alpha: 0.998  val_loss: 0.1130
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0225  domain_loss: 1.3836  alpha: 0.998  val_loss: 0.1073
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0386  domain_loss: 1.3900  alpha: 0.999  val_loss: 0.1078
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.2184  domain_loss: 1.3830  alpha: 0.999  val_loss: 0.1095
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0043  domain_loss: 1.3891  alpha: 0.999  val_loss: 0.1077
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1610  domain_loss: 1.3868  alpha: 0.999  val_loss: 0.0992
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.0730  domain_loss: 1.3819  alpha: 0.999  val_loss: 0.0984
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0753  domain_loss: 1.3841  alpha: 0.999  val_loss: 0.0952
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.0025  domain_loss: 1.3924  alpha: 1.000  val_loss: 0.0934
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0380  domain_loss: 1.3879  alpha: 1.000  val_loss: 0.0935
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0663  domain_loss: 1.3845  alpha: 1.000  val_loss: 0.0917
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0150  domain_loss: 1.3861  alpha: 1.000  val_loss: 0.0889
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0065  domain_loss: 1.3892  alpha: 1.000  val_loss: 0.0891
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.2223  domain_loss: 1.3914  alpha: 1.000  val_loss: 0.0842
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0249  domain_loss: 1.3821  alpha: 1.000  val_loss: 0.0869
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.0212  domain_loss: 1.3814  alpha: 1.000  val_loss: 0.0868
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0490  domain_loss: 1.3876  alpha: 1.000  val_loss: 0.0892
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0875
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0796
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0736
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0755
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0780
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0661
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0687
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0638
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0619
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0608
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0594
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0646
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0588
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0571
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0554
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0545
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0573
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0574
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0506
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0491
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0510
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0506
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0453
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0461
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0471
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0433
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0474
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.3203  domain_loss: 1.4520  alpha: 0.100  val_loss: 0.5145
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.4742  domain_loss: 1.3712  alpha: 0.197  val_loss: 0.4678
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 0.7007  domain_loss: 1.3930  alpha: 0.291  val_loss: 0.4350
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.4473  domain_loss: 1.3452  alpha: 0.380  val_loss: 0.4095
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.6356  domain_loss: 1.3794  alpha: 0.462  val_loss: 0.3864
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.5871  domain_loss: 1.3745  alpha: 0.537  val_loss: 0.3608
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.2850  domain_loss: 1.3831  alpha: 0.604  val_loss: 0.3411
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2299  domain_loss: 1.3975  alpha: 0.664  val_loss: 0.3129
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2706  domain_loss: 1.3901  alpha: 0.716  val_loss: 0.2920
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2016  domain_loss: 1.4026  alpha: 0.762  val_loss: 0.2739
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.1333  domain_loss: 1.3832  alpha: 0.800  val_loss: 0.2553
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1325  domain_loss: 1.4271  alpha: 0.834  val_loss: 0.2453
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.4384  domain_loss: 1.3853  alpha: 0.862  val_loss: 0.2269
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.2153  domain_loss: 1.3642  alpha: 0.885  val_loss: 0.2153
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.4143  domain_loss: 1.3927  alpha: 0.905  val_loss: 0.2040
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.2637  domain_loss: 1.3891  alpha: 0.922  val_loss: 0.1967
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1775  domain_loss: 1.3886  alpha: 0.935  val_loss: 0.1862
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1206  domain_loss: 1.3834  alpha: 0.947  val_loss: 0.1812
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1680  domain_loss: 1.3836  alpha: 0.956  val_loss: 0.1751
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.5532  domain_loss: 1.3754  alpha: 0.964  val_loss: 0.1629
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.0504  domain_loss: 1.3922  alpha: 0.970  val_loss: 0.1568
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.0347  domain_loss: 1.3867  alpha: 0.976  val_loss: 0.1519
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1283  domain_loss: 1.3882  alpha: 0.980  val_loss: 0.1487
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.1322  domain_loss: 1.3941  alpha: 0.984  val_loss: 0.1389
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1646  domain_loss: 1.3940  alpha: 0.987  val_loss: 0.1369
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.0182  domain_loss: 1.3955  alpha: 0.989  val_loss: 0.1322
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.3828  domain_loss: 1.3851  alpha: 0.991  val_loss: 0.1268
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.0495  domain_loss: 1.3829  alpha: 0.993  val_loss: 0.1238
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.1001  domain_loss: 1.3905  alpha: 0.994  val_loss: 0.1196
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.0849  domain_loss: 1.3910  alpha: 0.995  val_loss: 0.1182
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.4585  domain_loss: 1.3823  alpha: 0.996  val_loss: 0.1213
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.3707  domain_loss: 1.3771  alpha: 0.997  val_loss: 0.1134
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.0374  domain_loss: 1.3868  alpha: 0.997  val_loss: 0.1071
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.4229  domain_loss: 1.3837  alpha: 0.998  val_loss: 0.1044
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.0726  domain_loss: 1.3844  alpha: 0.998  val_loss: 0.1049
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.0412  domain_loss: 1.3866  alpha: 0.999  val_loss: 0.1019
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1396  domain_loss: 1.3877  alpha: 0.999  val_loss: 0.0998
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.0594  domain_loss: 1.3881  alpha: 0.999  val_loss: 0.1003
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.0853  domain_loss: 1.3894  alpha: 0.999  val_loss: 0.0965
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.3256  domain_loss: 1.3894  alpha: 0.999  val_loss: 0.0964
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.0113  domain_loss: 1.3802  alpha: 0.999  val_loss: 0.0942
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1797  domain_loss: 1.3842  alpha: 1.000  val_loss: 0.0901
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.2468  domain_loss: 1.3885  alpha: 1.000  val_loss: 0.0878
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.0210  domain_loss: 1.3836  alpha: 1.000  val_loss: 0.0912
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.0815  domain_loss: 1.3868  alpha: 1.000  val_loss: 0.0859
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.0555  domain_loss: 1.3908  alpha: 1.000  val_loss: 0.0843
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.0118  domain_loss: 1.3896  alpha: 1.000  val_loss: 0.0865
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.0193  domain_loss: 1.3807  alpha: 1.000  val_loss: 0.0833
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.2593  domain_loss: 1.3835  alpha: 1.000  val_loss: 0.0828
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.0137  domain_loss: 1.3903  alpha: 1.000  val_loss: 0.0805
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
DANN Domain Adaptation + SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FFmpeg"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann_smote/FFmpeg"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training on SMOTE-oversampled source + target domain alignment
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (FFmpeg)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source (SMOTE) + pseudo-labelled FFmpeg
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (DANN + SMOTE) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/6] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FFmpeg)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalize
    # ----------------------------------------------------------
    print("\n[2/6] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] SMOTE Oversampling (training pool only)
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE oversampling...")
    smote = SMOTE(random_state=SEED)
    train_emb_sm, train_lbl_sm = smote.fit_resample(train_emb, train_lbl)
    train_emb_sm = train_emb_sm.astype(np.float32)
    train_lbl_sm = train_lbl_sm.astype(np.int32)

    print(f"      Before SMOTE : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After SMOTE  : {train_emb_sm.shape}  "
          f"vuln={train_lbl_sm.sum()}  benign={int((train_lbl_sm == 0).sum())}")

    # ----------------------------------------------------------
    # [4/6] Class weights (computed on SMOTE-balanced pool)
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_sm)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl_sm
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb_sm, train_lbl_sm,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t         = torch.tensor(train_emb_sm, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_sm == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb_sm, train_lbl_sm, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann_smote",
        "train"            : "all_except_FFmpeg",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_train_smote"    : int(len(train_lbl_sm)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_train_smote": int(train_lbl_sm.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_smote_FFmpeg.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_smote_FFmpeg.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
