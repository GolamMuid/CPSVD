# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
DANN Domain Adaptation, SMOTE oversampling
"""

import json
import math
import random
import traceback
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, average_precision_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from xgboost import XGBClassifier

# =========================================================
# Config
# =========================================================
SEED            = 42
TEST_PROJS      = "poppler"
COMBINED_FILE   = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY         = "emb"
OUTPUT_ROOT     = "results/smote_oversampling"

DANN_EPOCHS            = 50
DANN_BATCH_SIZE        = 64
LEARNING_RATE          = 1e-5
DOMAIN_LOSS_WEIGHT_MAX = 1.0
VALIDATION_SIZE        = 0.2
NUM_RUNS               = 3
THRESHOLD              = 0.5
METHOD_VERSION         = "dann_xgboost_smote_v1"
SMOTE_K_NEIGHBORS      = 5

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
else:
    DEVICE = "cpu"


def now_utc():
    return datetime.now(timezone.utc).isoformat()


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)


def atomic_json_dump(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, allow_nan=False)
        f.flush()
    tmp.replace(path)


def load_jsonl(path):
    embeddings, labels, projects, sample_ids = [], [], [], []
    with open(path, "r", encoding="utf-8") as f:
        for row_number, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            embeddings.append(record[EMB_KEY])
            labels.append(record["target"])
            projects.append(record["project"])
            sample_ids.append(str(record.get("idx", row_number)))
    return (np.asarray(embeddings, dtype=np.float32),
            np.asarray(labels, dtype=np.int32),
            np.asarray(projects, dtype=object),
            np.asarray(sample_ids, dtype=str))


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Architecture: 64-dim bottleneck FeatureExtractor + linear ClassifierHead
# + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # 64-dim domain-invariant features


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Linear(feature_dim, 1)

    def forward(self, features):
        return self.network(features).squeeze(-1)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
        )

    def forward(self, features):
        return self.network(features).squeeze(-1)


# =========================================================
# SMOTE oversampling on the source pool
# =========================================================
def apply_smote(X_source, y_source, seed):
    smote = SMOTE(random_state=seed, k_neighbors=SMOTE_K_NEIGHBORS)
    X_res, y_res = smote.fit_resample(X_source, y_source)
    return X_res.astype(np.float32), y_res.astype(np.int32)


# =========================================================
# DANN training
# =========================================================
def train_dann(x_source, y_source, x_target, seed):
    set_seed(seed)
    stratify = y_source if len(np.unique(y_source)) > 1 else None
    x_train, x_val, y_train, y_val = train_test_split(
        x_source, y_source,
        test_size=VALIDATION_SIZE,
        random_state=seed,
        stratify=stratify,
    )

    feature_extractor = FeatureExtractor(x_source.shape[1]).to(DEVICE)
    classifier         = ClassifierHead(feature_dim=64).to(DEVICE)
    discriminator      = DomainDiscriminator(feature_dim=64).to(DEVICE)
    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier.parameters()) +
              list(discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=LEARNING_RATE)

    classification_loss_fn = nn.BCEWithLogitsLoss()
    domain_loss_fn = nn.BCEWithLogitsLoss()

    source_dataset = TensorDataset(
        torch.tensor(x_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    target_dataset = TensorDataset(torch.tensor(x_target, dtype=torch.float32))
    source_loader = DataLoader(source_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)

    x_val_t = torch.tensor(x_val, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32, device=DEVICE)

    total_steps = max(1, DANN_EPOCHS * len(source_loader) - 1)
    global_step = 0
    history = []

    for epoch in tqdm(range(DANN_EPOCHS), desc=f"DANN seed={seed}", leave=False):
        feature_extractor.train()
        classifier.train()
        discriminator.train()

        target_iter = iter(target_loader)
        classification_losses, domain_losses = [], []

        for xs_batch, ys_batch in source_loader:
            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            progress = global_step / total_steps
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + math.exp(-10.0 * progress)) - 1.0)

            optimizer.zero_grad(set_to_none=True)

            source_features = feature_extractor(xs_batch)
            target_features = feature_extractor(xt_batch)

            vulnerability_logits = classifier(source_features)
            classification_loss = classification_loss_fn(vulnerability_logits, ys_batch)

            source_domain_logits = discriminator(grl(source_features, alpha))
            target_domain_logits = discriminator(grl(target_features, alpha))
            source_domain_labels = torch.zeros(source_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)
            target_domain_labels = torch.ones(target_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)

            source_domain_loss = domain_loss_fn(source_domain_logits, source_domain_labels)
            target_domain_loss = domain_loss_fn(target_domain_logits, target_domain_labels)
            domain_loss = 0.5 * (source_domain_loss + target_domain_loss)

            loss = classification_loss + domain_loss
            loss.backward()
            optimizer.step()

            classification_losses.append(classification_loss.item())
            domain_losses.append(domain_loss.item())
            global_step += 1

        feature_extractor.eval()
        classifier.eval()
        discriminator.eval()
        with torch.no_grad():
            val_logits = classifier(feature_extractor(x_val_t))
            val_loss = classification_loss_fn(val_logits, y_val_t).item()
            val_prob = torch.sigmoid(val_logits)
            val_pred = (val_prob >= THRESHOLD).long().cpu().numpy()
            val_f1 = f1_score(y_val, val_pred, zero_division=0)

        epoch_result = {
            "epoch": epoch + 1,
            "classification_loss": float(np.mean(classification_losses)),
            "domain_loss": float(np.mean(domain_losses)),
            "source_validation_loss": float(val_loss),
            "source_validation_f1": float(val_f1),
            "grl_alpha": float(alpha),
        }
        history.append(epoch_result)
        print(f"      epoch={epoch + 1}/{DANN_EPOCHS} "
              f"cls={epoch_result['classification_loss']:.4f} "
              f"domain={epoch_result['domain_loss']:.4f} "
              f"val={val_loss:.4f} val_f1={val_f1:.4f} alpha={alpha:.4f}")

    return feature_extractor, classifier, discriminator, history


# =========================================================
# XGBoost trained on DANN's extracted (domain-invariant) features
# =========================================================
def extract_features(feature_extractor, X, batch_size=256):
    feature_extractor.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            outputs.append(feature_extractor(x_batch).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty((0, 64), dtype=np.float32)


def classifier_probabilities(feature_extractor, classifier, X, batch_size=256):
    feature_extractor.eval()
    classifier.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            logits = classifier(feature_extractor(x_batch))
            outputs.append(torch.sigmoid(logits).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty(0, dtype=np.float32)


def train_xgboost(x_train_feat, y_train, sample_weights, seed):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric="logloss",
        random_state=seed,
    )
    model.fit(x_train_feat, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Evaluation
# =========================================================
def evaluate(y_true, probabilities):
    predictions = (probabilities >= THRESHOLD).astype(np.int32)
    tn, fp, fn, tp = confusion_matrix(y_true, predictions, labels=[0, 1]).ravel()
    accuracy = accuracy_score(y_true, predictions)
    precision = precision_score(y_true, predictions, zero_division=0)
    recall = recall_score(y_true, predictions, zero_division=0)
    f1 = f1_score(y_true, predictions, zero_division=0)
    roc_auc = roc_auc_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    pr_auc = average_precision_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    tpr = tp / (tp + fn) if tp + fn else 0.0
    tnr = tn / (tn + fp) if tn + fp else 0.0
    g_mean = math.sqrt(tpr * tnr)
    pf = fp / (fp + tn) if fp + tn else 0.0
    metrics = {
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall),
        "f1": float(f1),
        "roc_auc": None if roc_auc is None else float(roc_auc),
        "pr_auc": None if pr_auc is None else float(pr_auc),
        "g_mean": float(g_mean),
        "pf": float(pf),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }
    return metrics, predictions


def save_confusion_matrix(metrics, path, title="Confusion Matrix (poppler Test Set) - DANN + XGBoost (SMOTE)", show=False):
    cm_values = metrics["confusion_matrix"]
    cm = np.asarray([[cm_values["tn"], cm_values["fp"]], [cm_values["fn"], cm_values["tp"]]])
    fig, ax = plt.subplots(figsize=(6, 5))
    image = ax.imshow(cm, interpolation="nearest")
    ax.set_title(title)
    plt.colorbar(image, ax=ax)
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2 if cm.max() else 0
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label"); ax.set_xlabel("Predicted Label")
    fig.tight_layout()
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300)
    if show:
        plt.show()
    plt.close(fig)
    print(f"Confusion matrix saved as {path}")


def cpu_state_dict(module):
    return {key: value.detach().cpu() for key, value in module.state_dict().items()}


# =========================================================
# Single run: one DANN training + one XGBoost fit
# =========================================================
def run_single(run_number, X_source_smote, y_source_smote, X_target, y_target, scaler, output_dir):
    seed = SEED + run_number - 1
    run_dir = Path(output_dir) / f"run_{run_number:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)
    started_at = now_utc()

    feature_extractor, classifier, discriminator, history = train_dann(
        X_source_smote, y_source_smote, X_target, seed
    )

    # Extract domain-invariant features for the (SMOTE-balanced) train set + target
    train_features = extract_features(feature_extractor, X_source_smote)
    target_features = extract_features(feature_extractor, X_target)

    # Confidence-based sample weights from the DANN's own classifier head
    train_probs = classifier_probabilities(feature_extractor, classifier, X_source_smote)
    sample_weights = np.where(y_source_smote == 1, train_probs, 1 - train_probs)

    model_xgb = train_xgboost(train_features, y_source_smote, sample_weights, seed)
    probabilities = model_xgb.predict_proba(target_features)[:, 1]

    metrics, predictions = evaluate(y_target, probabilities)
    finished_at = now_utc()

    result = {
        "method_version": METHOD_VERSION,
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "run": run_number,
        "seed": seed,
        "final_classifier": "XGBoost on DANN-extracted features",
        "n_source_samples_smote": int(len(y_source_smote)),
        "n_source_vulnerable_smote": int(y_source_smote.sum()),
        "n_target_samples": int(len(y_target)),
        "n_target_vulnerable": int(y_target.sum()),
        "threshold": THRESHOLD,
        "metrics": metrics,
        "training_history": history,
        "started_at": started_at,
        "finished_at": finished_at,
    }
    atomic_json_dump(result, run_dir / "result.json")
    np.savez_compressed(
        run_dir / "predictions.npz",
        target=y_target, probability=probabilities, prediction=predictions
    )
    torch.save(
        {
            "method_version": METHOD_VERSION,
            "project": TEST_PROJS,
            "run": run_number,
            "seed": seed,
            "feature_extractor": cpu_state_dict(feature_extractor),
            "classifier": cpu_state_dict(classifier),
            "domain_discriminator": cpu_state_dict(discriminator),
            "scaler_mean": scaler.mean_,
            "scaler_scale": scaler.scale_,
            "threshold": THRESHOLD,
        },
        run_dir / "model.pt",
    )
    save_confusion_matrix(metrics, run_dir / "confusion_matrix.png")
    print(f"      Saved run {run_number} to {run_dir}")

    del feature_extractor, classifier, discriminator, model_xgb
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE == "mps":
        torch.mps.empty_cache()

    return result


# =========================================================
# Ensemble aggregation
# =========================================================
def aggregate_ensemble(run_results, output_dir, y_target):
    prob_arrays = []
    for r in run_results:
        npz_path = Path(output_dir) / f"run_{r['run']:02d}" / "predictions.npz"
        data = np.load(npz_path)
        prob_arrays.append(data["probability"])

    ensemble_probability = np.mean(np.stack(prob_arrays, axis=0), axis=0)
    ensemble_metrics, ensemble_predictions = evaluate(y_target, ensemble_probability)

    per_run_metric_names = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", "g_mean", "pf"]
    per_run_summary = {}
    for metric in per_run_metric_names:
        values = [r["metrics"][metric] for r in run_results if r["metrics"][metric] is not None]
        per_run_summary[metric] = {
            "mean": float(np.mean(values)) if values else None,
            "std": float(np.std(values, ddof=1)) if len(values) > 1 else (0.0 if values else None),
        }

    return {
        "method_version": METHOD_VERSION,
        "method": "DANN + XGBoost",
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "train": f"all_except_{TEST_PROJS}",
        "num_completed_runs": len(run_results),
        "ensemble_metrics": ensemble_metrics,
        "per_run_metric_summary": per_run_summary,
        "runs": run_results,
        "updated_at": now_utc(),
    }, ensemble_predictions


# =========================================================
# Main
# =========================================================
def main():
    output_dir = Path(OUTPUT_ROOT) / TEST_PROJS
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Device: {DEVICE}")
    print(f"Method: {METHOD_VERSION}")
    print(f"LOPO target project: {TEST_PROJS}")
    print(f"Dataset: {COMBINED_FILE}")

    print("\n[1/4] Loading embeddings...")
    X_all, y_all, projects_all, ids_all = load_jsonl(COMBINED_FILE)
    print(f"      Loaded {len(y_all)} samples from {len(set(projects_all.tolist()))} projects")

    source_mask = projects_all != TEST_PROJS
    target_mask = projects_all == TEST_PROJS
    if not target_mask.any():
        raise ValueError(f"No samples found for target project '{TEST_PROJS}'.")

    X_source = X_all[source_mask].astype(np.float32)
    y_source = y_all[source_mask].astype(np.int32)
    X_target = X_all[target_mask].astype(np.float32)
    y_target = y_all[target_mask].astype(np.int32)

    if len(np.unique(y_source)) < 2:
        raise ValueError(f"Source pool for {TEST_PROJS} does not contain both classes.")

    source_projects = len(set(projects_all[source_mask].tolist()))
    print(f"      Source projects: {source_projects}")
    print(f"      Source (pre-SMOTE): {X_source.shape} vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    print(f"      Target ({TEST_PROJS}): {X_target.shape} vulnerable={int(y_target.sum())} benign={int((y_target == 0).sum())}")

    print("\n[2/4] Normalizing embeddings...")
    scaler = StandardScaler()
    X_source = scaler.fit_transform(X_source).astype(np.float32)
    X_target = scaler.transform(X_target).astype(np.float32)

    print("\n[3/4] Applying SMOTE oversampling to the source pool...")
    print(f"      Before SMOTE: vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    X_source_smote, y_source_smote = apply_smote(X_source, y_source, SEED)
    print(f"      After  SMOTE: vulnerable={int(y_source_smote.sum())} benign={int((y_source_smote == 0).sum())}")

    print("\n[4/4] Running DANN + XGBoost ensemble runs...")
    run_results = []
    for run_number in range(1, NUM_RUNS + 1):
        print(f"\n      Run {run_number}/{NUM_RUNS}")
        try:
            result = run_single(run_number, X_source_smote, y_source_smote, X_target, y_target,
                                 scaler, output_dir)
            run_results.append(result)
        except Exception as exc:
            print(f"      [RUN FAILED] run {run_number}: {exc}")
            traceback.print_exc()
            continue

    if not run_results:
        raise RuntimeError(f"All {NUM_RUNS} runs failed.")

    print("\nAggregating ensemble results...")
    ensemble_summary, ensemble_predictions = aggregate_ensemble(run_results, output_dir, y_target)
    atomic_json_dump(ensemble_summary, output_dir / f"dann_xgboost_{TEST_PROJS}_smote.json")
    save_confusion_matrix(ensemble_summary["ensemble_metrics"],
                          output_dir / f"confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png",
                          show=True)

    m = ensemble_summary["ensemble_metrics"]
    print(f"\n=== Ensemble Evaluation Results ({TEST_PROJS} Test Set, SMOTE) ===")
    print(f"Accuracy:   {m['accuracy']:.3f}")
    print(f"Precision:  {m['precision']:.3f}")
    print(f"Recall:     {m['recall']:.3f}")
    print(f"F1-score:   {m['f1']:.3f}")
    print(f"ROC-AUC:    {m['roc_auc']:.3f}" if m['roc_auc'] is not None else "ROC-AUC:    N/A")
    print(f"PR-AUC:     {m['pr_auc']:.3f}" if m['pr_auc'] is not None else "PR-AUC:     N/A")
    print(f"G-mean:     {m['g_mean']:.3f}")
    print(f"PF value:   {m['pf']:.3f}")
    print(f"\nResults saved to {output_dir / f'dann_xgboost_{TEST_PROJS}_smote.json'}")
    print(f"Confusion matrix saved to {output_dir / f'confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png'}")


if __name__ == "__main__":
    main()
# Out:
# Device: mps
# Method: dann_xgboost_smote_v1
# LOPO target project: poppler
# Dataset: ../../../../embedding/primevul/codebert/primevul_embedded.jsonl
#
# [1/4] Loading embeddings...
#       Loaded 224533 samples from 754 projects
#       Source projects: 753
#       Source (pre-SMOTE): (222735, 768) vulnerable=5971 benign=216764
#       Target (poppler): (1798, 768) vulnerable=33 benign=1765
#
# [2/4] Normalizing embeddings...
#
# [3/4] Applying SMOTE oversampling to the source pool...
#       Before SMOTE: vulnerable=5971 benign=216764
#       After  SMOTE: vulnerable=216764 benign=216764
#
# [4/4] Running DANN + XGBoost ensemble runs...
#
#       Run 1/3
# DANN seed=42:   2%|█▍                                                                    | 1/50 [00:27<22:46, 27.88s/it]
#       epoch=1/50 cls=0.5379 domain=0.6577 val=0.4783 val_f1=0.7803 alpha=0.0997
# DANN seed=42:   4%|██▊                                                                   | 2/50 [00:52<20:48, 26.01s/it]
#       epoch=2/50 cls=0.4586 domain=0.6687 val=0.4206 val_f1=0.8199 alpha=0.1974
# DANN seed=42:   6%|████▏                                                                 | 3/50 [01:17<19:53, 25.39s/it]
#       epoch=3/50 cls=0.4171 domain=0.6774 val=0.3828 val_f1=0.8397 alpha=0.2913
# DANN seed=42:   8%|█████▌                                                                | 4/50 [01:42<19:20, 25.22s/it]
#       epoch=4/50 cls=0.3870 domain=0.6833 val=0.3511 val_f1=0.8560 alpha=0.3799
# DANN seed=42:  10%|███████                                                               | 5/50 [02:06<18:42, 24.94s/it]
#       epoch=5/50 cls=0.3601 domain=0.6880 val=0.3230 val_f1=0.8698 alpha=0.4621
# DANN seed=42:  12%|████████▍                                                             | 6/50 [02:31<18:13, 24.86s/it]
#       epoch=6/50 cls=0.3366 domain=0.6884 val=0.2979 val_f1=0.8822 alpha=0.5370
# DANN seed=42:  14%|█████████▊                                                            | 7/50 [02:56<17:49, 24.87s/it]
#       epoch=7/50 cls=0.3158 domain=0.6895 val=0.2756 val_f1=0.8924 alpha=0.6044
# DANN seed=42:  16%|███████████▏                                                          | 8/50 [03:21<17:25, 24.90s/it]
#       epoch=8/50 cls=0.2979 domain=0.6897 val=0.2575 val_f1=0.9010 alpha=0.6640
# DANN seed=42:  18%|████████████▌                                                         | 9/50 [03:46<17:05, 25.01s/it]
#       epoch=9/50 cls=0.2817 domain=0.6901 val=0.2438 val_f1=0.9057 alpha=0.7163
# DANN seed=42:  20%|█████████████▊                                                       | 10/50 [04:11<16:40, 25.02s/it]
#       epoch=10/50 cls=0.2660 domain=0.6903 val=0.2299 val_f1=0.9106 alpha=0.7616
# DANN seed=42:  22%|███████████████▏                                                     | 11/50 [04:36<16:17, 25.06s/it]
#       epoch=11/50 cls=0.2538 domain=0.6907 val=0.2351 val_f1=0.9090 alpha=0.8005
# DANN seed=42:  24%|████████████████▌                                                    | 12/50 [05:01<15:51, 25.04s/it]
#       epoch=12/50 cls=0.2422 domain=0.6910 val=0.2052 val_f1=0.9224 alpha=0.8337
# DANN seed=42:  26%|█████████████████▉                                                   | 13/50 [05:27<15:32, 25.20s/it]
#       epoch=13/50 cls=0.2325 domain=0.6916 val=0.1969 val_f1=0.9259 alpha=0.8617
# DANN seed=42:  28%|███████████████████▎                                                 | 14/50 [05:52<15:11, 25.32s/it]
#       epoch=14/50 cls=0.2215 domain=0.6919 val=0.1849 val_f1=0.9305 alpha=0.8853
# DANN seed=42:  30%|████████████████████▋                                                | 15/50 [06:18<14:48, 25.39s/it]
#       epoch=15/50 cls=0.2130 domain=0.6920 val=0.1826 val_f1=0.9319 alpha=0.9051
# DANN seed=42:  32%|██████████████████████                                               | 16/50 [06:44<14:30, 25.61s/it]
#       epoch=16/50 cls=0.2053 domain=0.6923 val=0.1713 val_f1=0.9363 alpha=0.9217
# DANN seed=42:  34%|███████████████████████▍                                             | 17/50 [07:10<14:10, 25.78s/it]
#       epoch=17/50 cls=0.1968 domain=0.6926 val=0.1635 val_f1=0.9397 alpha=0.9354
# DANN seed=42:  36%|████████████████████████▊                                            | 18/50 [07:38<14:00, 26.27s/it]
#       epoch=18/50 cls=0.1908 domain=0.6927 val=0.1558 val_f1=0.9423 alpha=0.9468
# DANN seed=42:  38%|██████████████████████████▏                                          | 19/50 [08:05<13:43, 26.55s/it]
#       epoch=19/50 cls=0.1838 domain=0.6926 val=0.1514 val_f1=0.9445 alpha=0.9562
# DANN seed=42:  40%|███████████████████████████▌                                         | 20/50 [08:44<15:11, 30.39s/it]
#       epoch=20/50 cls=0.1778 domain=0.6926 val=0.1479 val_f1=0.9456 alpha=0.9640
# DANN seed=42:  42%|████████████████████████████▉                                        | 21/50 [09:14<14:40, 30.35s/it]
#       epoch=21/50 cls=0.1715 domain=0.6928 val=0.1462 val_f1=0.9459 alpha=0.9705
# DANN seed=42:  44%|██████████████████████████████▎                                      | 22/50 [09:44<14:01, 30.07s/it]
#       epoch=22/50 cls=0.1671 domain=0.6927 val=0.1404 val_f1=0.9490 alpha=0.9757
# DANN seed=42:  46%|███████████████████████████████▋                                     | 23/50 [10:13<13:28, 29.95s/it]
#       epoch=23/50 cls=0.1626 domain=0.6927 val=0.1335 val_f1=0.9514 alpha=0.9801
# DANN seed=42:  48%|█████████████████████████████████                                    | 24/50 [10:42<12:50, 29.65s/it]
#       epoch=24/50 cls=0.1569 domain=0.6928 val=0.1304 val_f1=0.9525 alpha=0.9837
# DANN seed=42:  50%|██████████████████████████████████▌                                  | 25/50 [11:12<12:18, 29.52s/it]
#       epoch=25/50 cls=0.1533 domain=0.6928 val=0.1276 val_f1=0.9533 alpha=0.9866
# DANN seed=42:  52%|███████████████████████████████████▉                                 | 26/50 [11:40<11:40, 29.18s/it]
#       epoch=26/50 cls=0.1484 domain=0.6927 val=0.1206 val_f1=0.9571 alpha=0.9890
# DANN seed=42:  54%|█████████████████████████████████████▎                               | 27/50 [12:08<11:03, 28.86s/it]
#       epoch=27/50 cls=0.1450 domain=0.6927 val=0.1202 val_f1=0.9563 alpha=0.9910
# DANN seed=42:  56%|██████████████████████████████████████▋                              | 28/50 [12:36<10:31, 28.69s/it]
#       epoch=28/50 cls=0.1409 domain=0.6926 val=0.1186 val_f1=0.9568 alpha=0.9926
# DANN seed=42:  58%|████████████████████████████████████████                             | 29/50 [13:05<09:59, 28.56s/it]
#       epoch=29/50 cls=0.1377 domain=0.6927 val=0.1235 val_f1=0.9554 alpha=0.9940
# DANN seed=42:  60%|█████████████████████████████████████████▍                           | 30/50 [13:33<09:28, 28.44s/it]
#       epoch=30/50 cls=0.1336 domain=0.6928 val=0.1135 val_f1=0.9588 alpha=0.9951
# DANN seed=42:  62%|██████████████████████████████████████████▊                          | 31/50 [14:01<09:01, 28.49s/it]
#       epoch=31/50 cls=0.1303 domain=0.6927 val=0.1093 val_f1=0.9605 alpha=0.9959
# DANN seed=42:  64%|████████████████████████████████████████████▏                        | 32/50 [14:30<08:30, 28.36s/it]
#       epoch=32/50 cls=0.1281 domain=0.6927 val=0.1060 val_f1=0.9621 alpha=0.9967
# DANN seed=42:  66%|█████████████████████████████████████████████▌                       | 33/50 [14:58<08:03, 28.47s/it]
#       epoch=33/50 cls=0.1250 domain=0.6928 val=0.1037 val_f1=0.9636 alpha=0.9973
# DANN seed=42:  68%|██████████████████████████████████████████████▉                      | 34/50 [15:26<07:34, 28.40s/it]
#       epoch=34/50 cls=0.1221 domain=0.6928 val=0.1015 val_f1=0.9642 alpha=0.9978
# DANN seed=42:  70%|████████████████████████████████████████████████▎                    | 35/50 [15:55<07:04, 28.31s/it]
#       epoch=35/50 cls=0.1200 domain=0.6928 val=0.1004 val_f1=0.9642 alpha=0.9982
# DANN seed=42:  72%|█████████████████████████████████████████████████▋                   | 36/50 [16:23<06:35, 28.23s/it]
#       epoch=36/50 cls=0.1172 domain=0.6928 val=0.0970 val_f1=0.9660 alpha=0.9985
# DANN seed=42:  74%|███████████████████████████████████████████████████                  | 37/50 [16:51<06:05, 28.13s/it]
#       epoch=37/50 cls=0.1146 domain=0.6928 val=0.0962 val_f1=0.9661 alpha=0.9988
# DANN seed=42:  76%|████████████████████████████████████████████████████▍                | 38/50 [17:18<05:36, 28.08s/it]
#       epoch=38/50 cls=0.1119 domain=0.6928 val=0.0919 val_f1=0.9678 alpha=0.9990
# DANN seed=42:  78%|█████████████████████████████████████████████████████▊               | 39/50 [17:47<05:08, 28.08s/it]
#       epoch=39/50 cls=0.1102 domain=0.6929 val=0.0960 val_f1=0.9655 alpha=0.9992
# DANN seed=42:  80%|███████████████████████████████████████████████████████▏             | 40/50 [18:15<04:41, 28.11s/it]
#       epoch=40/50 cls=0.1087 domain=0.6928 val=0.0899 val_f1=0.9688 alpha=0.9993
# DANN seed=42:  82%|████████████████████████████████████████████████████████▌            | 41/50 [18:43<04:12, 28.07s/it]
#       epoch=41/50 cls=0.1061 domain=0.6929 val=0.0975 val_f1=0.9662 alpha=0.9995
# DANN seed=42:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [19:11<03:44, 28.02s/it]
#       epoch=42/50 cls=0.1047 domain=0.6929 val=0.0867 val_f1=0.9704 alpha=0.9996
# DANN seed=42:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [19:39<03:16, 28.11s/it]
#       epoch=43/50 cls=0.1024 domain=0.6929 val=0.0891 val_f1=0.9696 alpha=0.9996
# DANN seed=42:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [20:07<02:49, 28.20s/it]
#       epoch=44/50 cls=0.1017 domain=0.6929 val=0.0857 val_f1=0.9711 alpha=0.9997
# DANN seed=42:  90%|██████████████████████████████████████████████████████████████       | 45/50 [20:36<02:21, 28.21s/it]
#       epoch=45/50 cls=0.0998 domain=0.6929 val=0.0856 val_f1=0.9705 alpha=0.9998
# DANN seed=42:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [21:04<01:52, 28.22s/it]
#       epoch=46/50 cls=0.0974 domain=0.6929 val=0.0877 val_f1=0.9701 alpha=0.9998
# DANN seed=42:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [21:32<01:24, 28.22s/it]
#       epoch=47/50 cls=0.0960 domain=0.6929 val=0.0826 val_f1=0.9716 alpha=0.9998
# DANN seed=42:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [22:00<00:56, 28.20s/it]
#       epoch=48/50 cls=0.0947 domain=0.6929 val=0.0796 val_f1=0.9733 alpha=0.9999
# DANN seed=42:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [22:28<00:28, 28.17s/it]
#       epoch=49/50 cls=0.0935 domain=0.6929 val=0.0791 val_f1=0.9730 alpha=0.9999
#       epoch=50/50 cls=0.0923 domain=0.6930 val=0.0779 val_f1=0.9731 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/poppler/run_01/confusion_matrix.png
#       Saved run 1 to results/smote_oversampling/poppler/run_01
#
#       Run 2/3
# DANN seed=43:   2%|█▍                                                                    | 1/50 [00:28<23:27, 28.72s/it]
#       epoch=1/50 cls=0.5363 domain=0.6570 val=0.4795 val_f1=0.7830 alpha=0.0997
# DANN seed=43:   4%|██▊                                                                   | 2/50 [00:57<22:52, 28.59s/it]
#       epoch=2/50 cls=0.4570 domain=0.6661 val=0.4223 val_f1=0.8192 alpha=0.1974
# DANN seed=43:   6%|████▏                                                                 | 3/50 [01:25<22:22, 28.57s/it]
#       epoch=3/50 cls=0.4153 domain=0.6790 val=0.3837 val_f1=0.8388 alpha=0.2913
# DANN seed=43:   8%|█████▌                                                                | 4/50 [01:53<21:45, 28.38s/it]
#       epoch=4/50 cls=0.3843 domain=0.6845 val=0.3538 val_f1=0.8548 alpha=0.3799
# DANN seed=43:  10%|███████                                                               | 5/50 [02:24<21:49, 29.11s/it]
#       epoch=5/50 cls=0.3589 domain=0.6882 val=0.3250 val_f1=0.8684 alpha=0.4621
# DANN seed=43:  12%|████████▍                                                             | 6/50 [02:56<22:11, 30.27s/it]
#       epoch=6/50 cls=0.3353 domain=0.6885 val=0.3002 val_f1=0.8808 alpha=0.5370
# DANN seed=43:  14%|█████████▊                                                            | 7/50 [03:26<21:33, 30.09s/it]
#       epoch=7/50 cls=0.3148 domain=0.6894 val=0.2816 val_f1=0.8885 alpha=0.6044
# DANN seed=43:  16%|███████████▏                                                          | 8/50 [03:56<20:57, 29.95s/it]
#       epoch=8/50 cls=0.2965 domain=0.6895 val=0.2597 val_f1=0.8991 alpha=0.6640
# DANN seed=43:  18%|████████████▌                                                         | 9/50 [04:25<20:19, 29.74s/it]
#       epoch=9/50 cls=0.2798 domain=0.6902 val=0.2542 val_f1=0.8991 alpha=0.7163
# DANN seed=43:  20%|█████████████▊                                                       | 10/50 [04:54<19:42, 29.55s/it]
#       epoch=10/50 cls=0.2655 domain=0.6904 val=0.2284 val_f1=0.9133 alpha=0.7616
# DANN seed=43:  22%|███████████████▏                                                     | 11/50 [05:23<19:05, 29.38s/it]
#       epoch=11/50 cls=0.2532 domain=0.6909 val=0.2195 val_f1=0.9163 alpha=0.8005
# DANN seed=43:  24%|████████████████▌                                                    | 12/50 [05:51<18:20, 28.97s/it]
#       epoch=12/50 cls=0.2418 domain=0.6915 val=0.2052 val_f1=0.9234 alpha=0.8337
# DANN seed=43:  26%|█████████████████▉                                                   | 13/50 [06:20<17:51, 28.96s/it]
#       epoch=13/50 cls=0.2308 domain=0.6918 val=0.1974 val_f1=0.9257 alpha=0.8617
# DANN seed=43:  28%|███████████████████▎                                                 | 14/50 [06:48<17:17, 28.81s/it]
#       epoch=14/50 cls=0.2207 domain=0.6921 val=0.1869 val_f1=0.9306 alpha=0.8853
# DANN seed=43:  30%|████████████████████▋                                                | 15/50 [07:17<16:43, 28.69s/it]
#       epoch=15/50 cls=0.2127 domain=0.6923 val=0.1787 val_f1=0.9339 alpha=0.9051
# DANN seed=43:  32%|██████████████████████                                               | 16/50 [07:45<16:14, 28.66s/it]
#       epoch=16/50 cls=0.2045 domain=0.6925 val=0.1741 val_f1=0.9352 alpha=0.9217
# DANN seed=43:  34%|███████████████████████▍                                             | 17/50 [08:14<15:41, 28.54s/it]
#       epoch=17/50 cls=0.1964 domain=0.6926 val=0.1732 val_f1=0.9342 alpha=0.9354
# DANN seed=43:  36%|████████████████████████▊                                            | 18/50 [08:42<15:09, 28.41s/it]
#       epoch=18/50 cls=0.1888 domain=0.6927 val=0.1609 val_f1=0.9412 alpha=0.9468
# DANN seed=43:  38%|██████████████████████████▏                                          | 19/50 [09:11<14:47, 28.63s/it]
#       epoch=19/50 cls=0.1820 domain=0.6926 val=0.1584 val_f1=0.9413 alpha=0.9562
# DANN seed=43:  40%|███████████████████████████▌                                         | 20/50 [09:40<14:21, 28.70s/it]
#       epoch=20/50 cls=0.1764 domain=0.6927 val=0.1453 val_f1=0.9477 alpha=0.9640
# DANN seed=43:  42%|████████████████████████████▉                                        | 21/50 [10:09<13:53, 28.73s/it]
#       epoch=21/50 cls=0.1708 domain=0.6927 val=0.1415 val_f1=0.9488 alpha=0.9705
# DANN seed=43:  44%|██████████████████████████████▎                                      | 22/50 [10:37<13:24, 28.73s/it]
#       epoch=22/50 cls=0.1648 domain=0.6927 val=0.1406 val_f1=0.9496 alpha=0.9757
# DANN seed=43:  46%|███████████████████████████████▋                                     | 23/50 [11:07<13:02, 28.97s/it]
#       epoch=23/50 cls=0.1599 domain=0.6926 val=0.1308 val_f1=0.9531 alpha=0.9801
# DANN seed=43:  48%|█████████████████████████████████                                    | 24/50 [11:37<12:45, 29.43s/it]
#       epoch=24/50 cls=0.1548 domain=0.6927 val=0.1304 val_f1=0.9534 alpha=0.9837
# DANN seed=43:  50%|██████████████████████████████████▌                                  | 25/50 [12:07<12:13, 29.36s/it]
#       epoch=25/50 cls=0.1502 domain=0.6927 val=0.1277 val_f1=0.9548 alpha=0.9866
# DANN seed=43:  52%|███████████████████████████████████▉                                 | 26/50 [12:35<11:39, 29.13s/it]
#       epoch=26/50 cls=0.1466 domain=0.6927 val=0.1253 val_f1=0.9549 alpha=0.9890
# DANN seed=43:  54%|█████████████████████████████████████▎                               | 27/50 [13:05<11:14, 29.32s/it]
#       epoch=27/50 cls=0.1437 domain=0.6927 val=0.1205 val_f1=0.9580 alpha=0.9910
# DANN seed=43:  56%|██████████████████████████████████████▋                              | 28/50 [13:34<10:41, 29.15s/it]
#       epoch=28/50 cls=0.1397 domain=0.6927 val=0.1179 val_f1=0.9577 alpha=0.9926
# DANN seed=43:  58%|████████████████████████████████████████                             | 29/50 [14:04<10:22, 29.63s/it]
#       epoch=29/50 cls=0.1357 domain=0.6927 val=0.1153 val_f1=0.9590 alpha=0.9940
# DANN seed=43:  60%|█████████████████████████████████████████▍                           | 30/50 [14:33<09:48, 29.42s/it]
#       epoch=30/50 cls=0.1323 domain=0.6928 val=0.1110 val_f1=0.9608 alpha=0.9951
# DANN seed=43:  62%|██████████████████████████████████████████▊                          | 31/50 [15:03<09:18, 29.39s/it]
#       epoch=31/50 cls=0.1292 domain=0.6927 val=0.1081 val_f1=0.9620 alpha=0.9959
# DANN seed=43:  64%|████████████████████████████████████████████▏                        | 32/50 [15:33<08:53, 29.62s/it]
#       epoch=32/50 cls=0.1258 domain=0.6928 val=0.1068 val_f1=0.9627 alpha=0.9967
# DANN seed=43:  66%|█████████████████████████████████████████████▌                       | 33/50 [16:03<08:26, 29.78s/it]
#       epoch=33/50 cls=0.1218 domain=0.6928 val=0.1160 val_f1=0.9584 alpha=0.9973
# DANN seed=43:  68%|██████████████████████████████████████████████▉                      | 34/50 [16:32<07:50, 29.42s/it]
#       epoch=34/50 cls=0.1197 domain=0.6928 val=0.1026 val_f1=0.9643 alpha=0.9978
# DANN seed=43:  70%|████████████████████████████████████████████████▎                    | 35/50 [17:00<07:17, 29.18s/it]
#       epoch=35/50 cls=0.1177 domain=0.6928 val=0.0983 val_f1=0.9659 alpha=0.9982
# DANN seed=43:  72%|█████████████████████████████████████████████████▋                   | 36/50 [17:29<06:46, 29.06s/it]
#       epoch=36/50 cls=0.1158 domain=0.6928 val=0.0998 val_f1=0.9655 alpha=0.9985
# DANN seed=43:  74%|███████████████████████████████████████████████████                  | 37/50 [17:56<06:09, 28.45s/it]
#       epoch=37/50 cls=0.1129 domain=0.6928 val=0.0946 val_f1=0.9679 alpha=0.9988
# DANN seed=43:  76%|████████████████████████████████████████████████████▍                | 38/50 [18:24<05:40, 28.34s/it]
#       epoch=38/50 cls=0.1105 domain=0.6928 val=0.0976 val_f1=0.9663 alpha=0.9990
# DANN seed=43:  78%|█████████████████████████████████████████████████████▊               | 39/50 [18:51<05:07, 27.99s/it]
#       epoch=39/50 cls=0.1087 domain=0.6929 val=0.1008 val_f1=0.9649 alpha=0.9992
# DANN seed=43:  80%|███████████████████████████████████████████████████████▏             | 40/50 [19:19<04:39, 27.95s/it]
#       epoch=40/50 cls=0.1061 domain=0.6929 val=0.0915 val_f1=0.9687 alpha=0.9993
# DANN seed=43:  82%|████████████████████████████████████████████████████████▌            | 41/50 [19:47<04:10, 27.88s/it]
#       epoch=41/50 cls=0.1042 domain=0.6929 val=0.0913 val_f1=0.9692 alpha=0.9995
# DANN seed=43:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [20:17<03:47, 28.45s/it]
#       epoch=42/50 cls=0.1024 domain=0.6929 val=0.0872 val_f1=0.9703 alpha=0.9996
# DANN seed=43:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [20:53<03:35, 30.72s/it]
#       epoch=43/50 cls=0.1005 domain=0.6928 val=0.0865 val_f1=0.9703 alpha=0.9996
# DANN seed=43:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [21:26<03:08, 31.40s/it]
#       epoch=44/50 cls=0.0991 domain=0.6929 val=0.0854 val_f1=0.9709 alpha=0.9997
# DANN seed=43:  90%|██████████████████████████████████████████████████████████████       | 45/50 [21:56<02:35, 31.00s/it]
#       epoch=45/50 cls=0.0974 domain=0.6929 val=0.0827 val_f1=0.9722 alpha=0.9998
# DANN seed=43:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [22:23<01:59, 29.91s/it]
#       epoch=46/50 cls=0.0954 domain=0.6929 val=0.0855 val_f1=0.9710 alpha=0.9998
# DANN seed=43:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [22:50<01:27, 29.06s/it]
#       epoch=47/50 cls=0.0942 domain=0.6929 val=0.0863 val_f1=0.9710 alpha=0.9998
# DANN seed=43:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [23:18<00:57, 28.80s/it]
#       epoch=48/50 cls=0.0927 domain=0.6929 val=0.0807 val_f1=0.9725 alpha=0.9999
# DANN seed=43:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [23:46<00:28, 28.50s/it]
#       epoch=49/50 cls=0.0908 domain=0.6929 val=0.0979 val_f1=0.9671 alpha=0.9999
#       epoch=50/50 cls=0.0898 domain=0.6930 val=0.0803 val_f1=0.9734 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/poppler/run_02/confusion_matrix.png
#       Saved run 2 to results/smote_oversampling/poppler/run_02
#
#       Run 3/3
# DANN seed=44:   2%|█▍                                                                    | 1/50 [00:29<23:54, 29.27s/it]
#       epoch=1/50 cls=0.5371 domain=0.6626 val=0.4757 val_f1=0.7852 alpha=0.0997
# DANN seed=44:   4%|██▊                                                                   | 2/50 [00:58<23:20, 29.18s/it]
#       epoch=2/50 cls=0.4562 domain=0.6665 val=0.4185 val_f1=0.8208 alpha=0.1974
# DANN seed=44:   6%|████▏                                                                 | 3/50 [01:25<22:16, 28.44s/it]
#       epoch=3/50 cls=0.4160 domain=0.6798 val=0.3808 val_f1=0.8401 alpha=0.2913
# DANN seed=44:   8%|█████▌                                                                | 4/50 [01:53<21:23, 27.91s/it]
#       epoch=4/50 cls=0.3865 domain=0.6847 val=0.3534 val_f1=0.8555 alpha=0.3799
# DANN seed=44:  10%|███████                                                               | 5/50 [02:20<20:48, 27.74s/it]
#       epoch=5/50 cls=0.3601 domain=0.6878 val=0.3249 val_f1=0.8701 alpha=0.4621
# DANN seed=44:  12%|████████▍                                                             | 6/50 [02:47<20:13, 27.58s/it]
#       epoch=6/50 cls=0.3362 domain=0.6889 val=0.2964 val_f1=0.8813 alpha=0.5370
# DANN seed=44:  14%|█████████▊                                                            | 7/50 [03:15<19:44, 27.54s/it]
#       epoch=7/50 cls=0.3155 domain=0.6899 val=0.2769 val_f1=0.8908 alpha=0.6044
# DANN seed=44:  16%|███████████▏                                                          | 8/50 [03:42<19:13, 27.47s/it]
#       epoch=8/50 cls=0.2971 domain=0.6899 val=0.2562 val_f1=0.9007 alpha=0.6640
# DANN seed=44:  18%|████████████▌                                                         | 9/50 [04:09<18:45, 27.46s/it]
#       epoch=9/50 cls=0.2809 domain=0.6905 val=0.2385 val_f1=0.9079 alpha=0.7163
# DANN seed=44:  20%|█████████████▊                                                       | 10/50 [04:37<18:19, 27.48s/it]
#       epoch=10/50 cls=0.2664 domain=0.6907 val=0.2302 val_f1=0.9113 alpha=0.7616
# DANN seed=44:  22%|███████████████▏                                                     | 11/50 [05:04<17:49, 27.42s/it]
#       epoch=11/50 cls=0.2531 domain=0.6912 val=0.2117 val_f1=0.9189 alpha=0.8005
# DANN seed=44:  24%|████████████████▌                                                    | 12/50 [05:31<17:16, 27.27s/it]
#       epoch=12/50 cls=0.2408 domain=0.6916 val=0.2084 val_f1=0.9198 alpha=0.8337
# DANN seed=44:  26%|█████████████████▉                                                   | 13/50 [05:58<16:47, 27.23s/it]
#       epoch=13/50 cls=0.2299 domain=0.6919 val=0.1913 val_f1=0.9275 alpha=0.8617
# DANN seed=44:  28%|███████████████████▎                                                 | 14/50 [06:25<16:19, 27.20s/it]
#       epoch=14/50 cls=0.2212 domain=0.6922 val=0.1815 val_f1=0.9322 alpha=0.8853
# DANN seed=44:  30%|████████████████████▋                                                | 15/50 [06:53<15:51, 27.18s/it]
#       epoch=15/50 cls=0.2121 domain=0.6925 val=0.1728 val_f1=0.9352 alpha=0.9051
# DANN seed=44:  32%|██████████████████████                                               | 16/50 [07:20<15:24, 27.18s/it]
#       epoch=16/50 cls=0.2029 domain=0.6927 val=0.1666 val_f1=0.9371 alpha=0.9217
# DANN seed=44:  34%|███████████████████████▍                                             | 17/50 [07:47<14:59, 27.26s/it]
#       epoch=17/50 cls=0.1960 domain=0.6927 val=0.1631 val_f1=0.9386 alpha=0.9354
# DANN seed=44:  36%|████████████████████████▊                                            | 18/50 [08:15<14:34, 27.33s/it]
#       epoch=18/50 cls=0.1888 domain=0.6927 val=0.1538 val_f1=0.9437 alpha=0.9468
# DANN seed=44:  38%|██████████████████████████▏                                          | 19/50 [08:43<14:12, 27.51s/it]
#       epoch=19/50 cls=0.1820 domain=0.6927 val=0.1565 val_f1=0.9413 alpha=0.9562
# DANN seed=44:  40%|███████████████████████████▌                                         | 20/50 [09:10<13:42, 27.43s/it]
#       epoch=20/50 cls=0.1758 domain=0.6928 val=0.1446 val_f1=0.9467 alpha=0.9640
# DANN seed=44:  42%|████████████████████████████▉                                        | 21/50 [09:37<13:12, 27.33s/it]
#       epoch=21/50 cls=0.1704 domain=0.6928 val=0.1376 val_f1=0.9503 alpha=0.9705
# DANN seed=44:  44%|██████████████████████████████▎                                      | 22/50 [10:04<12:42, 27.25s/it]
#       epoch=22/50 cls=0.1646 domain=0.6928 val=0.1435 val_f1=0.9468 alpha=0.9757
# DANN seed=44:  46%|███████████████████████████████▋                                     | 23/50 [10:31<12:13, 27.18s/it]
#       epoch=23/50 cls=0.1603 domain=0.6927 val=0.1320 val_f1=0.9517 alpha=0.9801
# DANN seed=44:  48%|█████████████████████████████████                                    | 24/50 [10:58<11:47, 27.20s/it]
#       epoch=24/50 cls=0.1549 domain=0.6927 val=0.1263 val_f1=0.9548 alpha=0.9837
# DANN seed=44:  50%|██████████████████████████████████▌                                  | 25/50 [11:26<11:20, 27.23s/it]
#       epoch=25/50 cls=0.1513 domain=0.6926 val=0.1232 val_f1=0.9556 alpha=0.9866
# DANN seed=44:  52%|███████████████████████████████████▉                                 | 26/50 [11:52<10:50, 27.11s/it]
#       epoch=26/50 cls=0.1468 domain=0.6927 val=0.1186 val_f1=0.9577 alpha=0.9890
# DANN seed=44:  54%|█████████████████████████████████████▎                               | 27/50 [12:20<10:25, 27.19s/it]
#       epoch=27/50 cls=0.1437 domain=0.6926 val=0.1160 val_f1=0.9582 alpha=0.9910
# DANN seed=44:  56%|██████████████████████████████████████▋                              | 28/50 [12:47<09:58, 27.20s/it]
#       epoch=28/50 cls=0.1399 domain=0.6927 val=0.1119 val_f1=0.9599 alpha=0.9926
# DANN seed=44:  58%|████████████████████████████████████████                             | 29/50 [13:14<09:28, 27.08s/it]
#       epoch=29/50 cls=0.1355 domain=0.6927 val=0.1101 val_f1=0.9606 alpha=0.9940
# DANN seed=44:  60%|█████████████████████████████████████████▍                           | 30/50 [13:41<09:01, 27.07s/it]
#       epoch=30/50 cls=0.1327 domain=0.6927 val=0.1100 val_f1=0.9607 alpha=0.9951
# DANN seed=44:  62%|██████████████████████████████████████████▊                          | 31/50 [14:08<08:36, 27.16s/it]
#       epoch=31/50 cls=0.1302 domain=0.6928 val=0.1096 val_f1=0.9602 alpha=0.9959
# DANN seed=44:  64%|████████████████████████████████████████████▏                        | 32/50 [14:35<08:09, 27.17s/it]
#       epoch=32/50 cls=0.1263 domain=0.6926 val=0.1051 val_f1=0.9629 alpha=0.9967
# DANN seed=44:  66%|█████████████████████████████████████████████▌                       | 33/50 [15:02<07:40, 27.07s/it]
#       epoch=33/50 cls=0.1233 domain=0.6928 val=0.1001 val_f1=0.9646 alpha=0.9973
# DANN seed=44:  68%|██████████████████████████████████████████████▉                      | 34/50 [15:29<07:13, 27.10s/it]
#       epoch=34/50 cls=0.1213 domain=0.6927 val=0.1039 val_f1=0.9633 alpha=0.9978
# DANN seed=44:  70%|████████████████████████████████████████████████▎                    | 35/50 [15:57<06:46, 27.10s/it]
#       epoch=35/50 cls=0.1181 domain=0.6927 val=0.0995 val_f1=0.9647 alpha=0.9982
# DANN seed=44:  72%|█████████████████████████████████████████████████▋                   | 36/50 [16:24<06:19, 27.11s/it]
#       epoch=36/50 cls=0.1155 domain=0.6928 val=0.0937 val_f1=0.9670 alpha=0.9985
# DANN seed=44:  74%|███████████████████████████████████████████████████                  | 37/50 [16:51<05:52, 27.12s/it]
#       epoch=37/50 cls=0.1140 domain=0.6928 val=0.0938 val_f1=0.9673 alpha=0.9988
# DANN seed=44:  76%|████████████████████████████████████████████████████▍                | 38/50 [17:18<05:25, 27.11s/it]
#       epoch=38/50 cls=0.1116 domain=0.6928 val=0.0912 val_f1=0.9679 alpha=0.9990
# DANN seed=44:  78%|█████████████████████████████████████████████████████▊               | 39/50 [17:45<04:58, 27.12s/it]
#       epoch=39/50 cls=0.1084 domain=0.6929 val=0.0940 val_f1=0.9669 alpha=0.9992
# DANN seed=44:  80%|███████████████████████████████████████████████████████▏             | 40/50 [18:12<04:30, 27.06s/it]
#       epoch=40/50 cls=0.1072 domain=0.6928 val=0.0887 val_f1=0.9696 alpha=0.9993
# DANN seed=44:  82%|████████████████████████████████████████████████████████▌            | 41/50 [18:39<04:03, 27.02s/it]
#       epoch=41/50 cls=0.1051 domain=0.6929 val=0.0883 val_f1=0.9684 alpha=0.9995
# DANN seed=44:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [19:06<03:35, 26.98s/it]
#       epoch=42/50 cls=0.1025 domain=0.6928 val=0.0892 val_f1=0.9682 alpha=0.9996
# DANN seed=44:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [19:33<03:08, 26.95s/it]
#       epoch=43/50 cls=0.1011 domain=0.6928 val=0.0854 val_f1=0.9700 alpha=0.9996
# DANN seed=44:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [20:00<02:42, 27.03s/it]
#       epoch=44/50 cls=0.1000 domain=0.6929 val=0.0822 val_f1=0.9710 alpha=0.9997
# DANN seed=44:  90%|██████████████████████████████████████████████████████████████       | 45/50 [20:27<02:15, 27.07s/it]
#       epoch=45/50 cls=0.0979 domain=0.6928 val=0.0863 val_f1=0.9698 alpha=0.9998
# DANN seed=44:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [20:54<01:48, 27.10s/it]
#       epoch=46/50 cls=0.0959 domain=0.6929 val=0.0846 val_f1=0.9704 alpha=0.9998
# DANN seed=44:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [21:21<01:21, 27.05s/it]
#       epoch=47/50 cls=0.0949 domain=0.6929 val=0.0891 val_f1=0.9695 alpha=0.9998
# DANN seed=44:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [21:48<00:54, 27.03s/it]
#       epoch=48/50 cls=0.0933 domain=0.6930 val=0.0801 val_f1=0.9727 alpha=0.9999
# DANN seed=44:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [22:16<00:27, 27.14s/it]
#       epoch=49/50 cls=0.0921 domain=0.6930 val=0.0768 val_f1=0.9733 alpha=0.9999
#       epoch=50/50 cls=0.0914 domain=0.6929 val=0.0764 val_f1=0.9740 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/poppler/run_03/confusion_matrix.png
#       Saved run 3 to results/smote_oversampling/poppler/run_03
#
# Aggregating ensemble results...
# Confusion matrix saved as results/smote_oversampling/poppler/confusion_matrix_dann_xgboost_poppler_smote.png
#
# === Ensemble Evaluation Results (poppler Test Set, SMOTE) ===
# Accuracy:   0.509
# Precision:  0.033
# Recall:     0.909
# F1-score:   0.064
# ROC-AUC:    0.756
# PR-AUC:     0.038
# G-mean:     0.676
# PF value:   0.498
#
# Results saved to results/smote_oversampling/poppler/dann_xgboost_poppler_smote.json
# Confusion matrix saved to results/smote_oversampling/poppler/confusion_matrix_dann_xgboost_poppler_smote.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
DANN Domain Adaptation, SMOTE oversampling
"""

import json
import math
import random
import traceback
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, average_precision_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from xgboost import XGBClassifier

# =========================================================
# Config
# =========================================================
SEED            = 42
TEST_PROJS      = "radare2"
COMBINED_FILE   = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY         = "emb"
OUTPUT_ROOT     = "results/smote_oversampling"

DANN_EPOCHS            = 50
DANN_BATCH_SIZE        = 64
LEARNING_RATE          = 1e-5
DOMAIN_LOSS_WEIGHT_MAX = 1.0
VALIDATION_SIZE        = 0.2
NUM_RUNS               = 3
THRESHOLD              = 0.5
METHOD_VERSION         = "dann_xgboost_smote_v1"
SMOTE_K_NEIGHBORS      = 5

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
else:
    DEVICE = "cpu"


def now_utc():
    return datetime.now(timezone.utc).isoformat()


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)


def atomic_json_dump(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, allow_nan=False)
        f.flush()
    tmp.replace(path)


def load_jsonl(path):
    embeddings, labels, projects, sample_ids = [], [], [], []
    with open(path, "r", encoding="utf-8") as f:
        for row_number, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            embeddings.append(record[EMB_KEY])
            labels.append(record["target"])
            projects.append(record["project"])
            sample_ids.append(str(record.get("idx", row_number)))
    return (np.asarray(embeddings, dtype=np.float32),
            np.asarray(labels, dtype=np.int32),
            np.asarray(projects, dtype=object),
            np.asarray(sample_ids, dtype=str))


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Architecture: 64-dim bottleneck FeatureExtractor + linear ClassifierHead
# + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # 64-dim domain-invariant features


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Linear(feature_dim, 1)

    def forward(self, features):
        return self.network(features).squeeze(-1)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
        )

    def forward(self, features):
        return self.network(features).squeeze(-1)


# =========================================================
# SMOTE oversampling on the source pool
# =========================================================
def apply_smote(X_source, y_source, seed):
    smote = SMOTE(random_state=seed, k_neighbors=SMOTE_K_NEIGHBORS)
    X_res, y_res = smote.fit_resample(X_source, y_source)
    return X_res.astype(np.float32), y_res.astype(np.int32)


# =========================================================
# DANN training
# =========================================================
def train_dann(x_source, y_source, x_target, seed):
    set_seed(seed)
    stratify = y_source if len(np.unique(y_source)) > 1 else None
    x_train, x_val, y_train, y_val = train_test_split(
        x_source, y_source,
        test_size=VALIDATION_SIZE,
        random_state=seed,
        stratify=stratify,
    )

    feature_extractor = FeatureExtractor(x_source.shape[1]).to(DEVICE)
    classifier         = ClassifierHead(feature_dim=64).to(DEVICE)
    discriminator      = DomainDiscriminator(feature_dim=64).to(DEVICE)
    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier.parameters()) +
              list(discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=LEARNING_RATE)

    classification_loss_fn = nn.BCEWithLogitsLoss()
    domain_loss_fn = nn.BCEWithLogitsLoss()

    source_dataset = TensorDataset(
        torch.tensor(x_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    target_dataset = TensorDataset(torch.tensor(x_target, dtype=torch.float32))
    source_loader = DataLoader(source_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)

    x_val_t = torch.tensor(x_val, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32, device=DEVICE)

    total_steps = max(1, DANN_EPOCHS * len(source_loader) - 1)
    global_step = 0
    history = []

    for epoch in tqdm(range(DANN_EPOCHS), desc=f"DANN seed={seed}", leave=False):
        feature_extractor.train()
        classifier.train()
        discriminator.train()

        target_iter = iter(target_loader)
        classification_losses, domain_losses = [], []

        for xs_batch, ys_batch in source_loader:
            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            progress = global_step / total_steps
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + math.exp(-10.0 * progress)) - 1.0)

            optimizer.zero_grad(set_to_none=True)

            source_features = feature_extractor(xs_batch)
            target_features = feature_extractor(xt_batch)

            vulnerability_logits = classifier(source_features)
            classification_loss = classification_loss_fn(vulnerability_logits, ys_batch)

            source_domain_logits = discriminator(grl(source_features, alpha))
            target_domain_logits = discriminator(grl(target_features, alpha))
            source_domain_labels = torch.zeros(source_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)
            target_domain_labels = torch.ones(target_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)

            source_domain_loss = domain_loss_fn(source_domain_logits, source_domain_labels)
            target_domain_loss = domain_loss_fn(target_domain_logits, target_domain_labels)
            domain_loss = 0.5 * (source_domain_loss + target_domain_loss)

            loss = classification_loss + domain_loss
            loss.backward()
            optimizer.step()

            classification_losses.append(classification_loss.item())
            domain_losses.append(domain_loss.item())
            global_step += 1

        feature_extractor.eval()
        classifier.eval()
        discriminator.eval()
        with torch.no_grad():
            val_logits = classifier(feature_extractor(x_val_t))
            val_loss = classification_loss_fn(val_logits, y_val_t).item()
            val_prob = torch.sigmoid(val_logits)
            val_pred = (val_prob >= THRESHOLD).long().cpu().numpy()
            val_f1 = f1_score(y_val, val_pred, zero_division=0)

        epoch_result = {
            "epoch": epoch + 1,
            "classification_loss": float(np.mean(classification_losses)),
            "domain_loss": float(np.mean(domain_losses)),
            "source_validation_loss": float(val_loss),
            "source_validation_f1": float(val_f1),
            "grl_alpha": float(alpha),
        }
        history.append(epoch_result)
        print(f"      epoch={epoch + 1}/{DANN_EPOCHS} "
              f"cls={epoch_result['classification_loss']:.4f} "
              f"domain={epoch_result['domain_loss']:.4f} "
              f"val={val_loss:.4f} val_f1={val_f1:.4f} alpha={alpha:.4f}")

    return feature_extractor, classifier, discriminator, history


# =========================================================
# XGBoost trained on DANN's extracted (domain-invariant) features
# =========================================================
def extract_features(feature_extractor, X, batch_size=256):
    feature_extractor.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            outputs.append(feature_extractor(x_batch).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty((0, 64), dtype=np.float32)


def classifier_probabilities(feature_extractor, classifier, X, batch_size=256):
    feature_extractor.eval()
    classifier.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            logits = classifier(feature_extractor(x_batch))
            outputs.append(torch.sigmoid(logits).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty(0, dtype=np.float32)


def train_xgboost(x_train_feat, y_train, sample_weights, seed):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric="logloss",
        random_state=seed,
    )
    model.fit(x_train_feat, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Evaluation
# =========================================================
def evaluate(y_true, probabilities):
    predictions = (probabilities >= THRESHOLD).astype(np.int32)
    tn, fp, fn, tp = confusion_matrix(y_true, predictions, labels=[0, 1]).ravel()
    accuracy = accuracy_score(y_true, predictions)
    precision = precision_score(y_true, predictions, zero_division=0)
    recall = recall_score(y_true, predictions, zero_division=0)
    f1 = f1_score(y_true, predictions, zero_division=0)
    roc_auc = roc_auc_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    pr_auc = average_precision_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    tpr = tp / (tp + fn) if tp + fn else 0.0
    tnr = tn / (tn + fp) if tn + fp else 0.0
    g_mean = math.sqrt(tpr * tnr)
    pf = fp / (fp + tn) if fp + tn else 0.0
    metrics = {
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall),
        "f1": float(f1),
        "roc_auc": None if roc_auc is None else float(roc_auc),
        "pr_auc": None if pr_auc is None else float(pr_auc),
        "g_mean": float(g_mean),
        "pf": float(pf),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }
    return metrics, predictions


def save_confusion_matrix(metrics, path, title="Confusion Matrix (radare2 Test Set) - DANN + XGBoost (SMOTE)", show=False):
    cm_values = metrics["confusion_matrix"]
    cm = np.asarray([[cm_values["tn"], cm_values["fp"]], [cm_values["fn"], cm_values["tp"]]])
    fig, ax = plt.subplots(figsize=(6, 5))
    image = ax.imshow(cm, interpolation="nearest")
    ax.set_title(title)
    plt.colorbar(image, ax=ax)
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2 if cm.max() else 0
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label"); ax.set_xlabel("Predicted Label")
    fig.tight_layout()
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300)
    if show:
        plt.show()
    plt.close(fig)
    print(f"Confusion matrix saved as {path}")


def cpu_state_dict(module):
    return {key: value.detach().cpu() for key, value in module.state_dict().items()}


# =========================================================
# Single run: one DANN training + one XGBoost fit
# =========================================================
def run_single(run_number, X_source_smote, y_source_smote, X_target, y_target, scaler, output_dir):
    seed = SEED + run_number - 1
    run_dir = Path(output_dir) / f"run_{run_number:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)
    started_at = now_utc()

    feature_extractor, classifier, discriminator, history = train_dann(
        X_source_smote, y_source_smote, X_target, seed
    )

    # Extract domain-invariant features for the (SMOTE-balanced) train set + target
    train_features = extract_features(feature_extractor, X_source_smote)
    target_features = extract_features(feature_extractor, X_target)

    # Confidence-based sample weights from the DANN's own classifier head
    train_probs = classifier_probabilities(feature_extractor, classifier, X_source_smote)
    sample_weights = np.where(y_source_smote == 1, train_probs, 1 - train_probs)

    model_xgb = train_xgboost(train_features, y_source_smote, sample_weights, seed)
    probabilities = model_xgb.predict_proba(target_features)[:, 1]

    metrics, predictions = evaluate(y_target, probabilities)
    finished_at = now_utc()

    result = {
        "method_version": METHOD_VERSION,
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "run": run_number,
        "seed": seed,
        "final_classifier": "XGBoost on DANN-extracted features",
        "n_source_samples_smote": int(len(y_source_smote)),
        "n_source_vulnerable_smote": int(y_source_smote.sum()),
        "n_target_samples": int(len(y_target)),
        "n_target_vulnerable": int(y_target.sum()),
        "threshold": THRESHOLD,
        "metrics": metrics,
        "training_history": history,
        "started_at": started_at,
        "finished_at": finished_at,
    }
    atomic_json_dump(result, run_dir / "result.json")
    np.savez_compressed(
        run_dir / "predictions.npz",
        target=y_target, probability=probabilities, prediction=predictions
    )
    torch.save(
        {
            "method_version": METHOD_VERSION,
            "project": TEST_PROJS,
            "run": run_number,
            "seed": seed,
            "feature_extractor": cpu_state_dict(feature_extractor),
            "classifier": cpu_state_dict(classifier),
            "domain_discriminator": cpu_state_dict(discriminator),
            "scaler_mean": scaler.mean_,
            "scaler_scale": scaler.scale_,
            "threshold": THRESHOLD,
        },
        run_dir / "model.pt",
    )
    save_confusion_matrix(metrics, run_dir / "confusion_matrix.png")
    print(f"      Saved run {run_number} to {run_dir}")

    del feature_extractor, classifier, discriminator, model_xgb
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE == "mps":
        torch.mps.empty_cache()

    return result


# =========================================================
# Ensemble aggregation
# =========================================================
def aggregate_ensemble(run_results, output_dir, y_target):
    prob_arrays = []
    for r in run_results:
        npz_path = Path(output_dir) / f"run_{r['run']:02d}" / "predictions.npz"
        data = np.load(npz_path)
        prob_arrays.append(data["probability"])

    ensemble_probability = np.mean(np.stack(prob_arrays, axis=0), axis=0)
    ensemble_metrics, ensemble_predictions = evaluate(y_target, ensemble_probability)

    per_run_metric_names = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", "g_mean", "pf"]
    per_run_summary = {}
    for metric in per_run_metric_names:
        values = [r["metrics"][metric] for r in run_results if r["metrics"][metric] is not None]
        per_run_summary[metric] = {
            "mean": float(np.mean(values)) if values else None,
            "std": float(np.std(values, ddof=1)) if len(values) > 1 else (0.0 if values else None),
        }

    return {
        "method_version": METHOD_VERSION,
        "method": "DANN + XGBoost",
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "train": f"all_except_{TEST_PROJS}",
        "num_completed_runs": len(run_results),
        "ensemble_metrics": ensemble_metrics,
        "per_run_metric_summary": per_run_summary,
        "runs": run_results,
        "updated_at": now_utc(),
    }, ensemble_predictions


# =========================================================
# Main
# =========================================================
def main():
    output_dir = Path(OUTPUT_ROOT) / TEST_PROJS
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Device: {DEVICE}")
    print(f"Method: {METHOD_VERSION}")
    print(f"LOPO target project: {TEST_PROJS}")
    print(f"Dataset: {COMBINED_FILE}")

    print("\n[1/4] Loading embeddings...")
    X_all, y_all, projects_all, ids_all = load_jsonl(COMBINED_FILE)
    print(f"      Loaded {len(y_all)} samples from {len(set(projects_all.tolist()))} projects")

    source_mask = projects_all != TEST_PROJS
    target_mask = projects_all == TEST_PROJS
    if not target_mask.any():
        raise ValueError(f"No samples found for target project '{TEST_PROJS}'.")

    X_source = X_all[source_mask].astype(np.float32)
    y_source = y_all[source_mask].astype(np.int32)
    X_target = X_all[target_mask].astype(np.float32)
    y_target = y_all[target_mask].astype(np.int32)

    if len(np.unique(y_source)) < 2:
        raise ValueError(f"Source pool for {TEST_PROJS} does not contain both classes.")

    source_projects = len(set(projects_all[source_mask].tolist()))
    print(f"      Source projects: {source_projects}")
    print(f"      Source (pre-SMOTE): {X_source.shape} vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    print(f"      Target ({TEST_PROJS}): {X_target.shape} vulnerable={int(y_target.sum())} benign={int((y_target == 0).sum())}")

    print("\n[2/4] Normalizing embeddings...")
    scaler = StandardScaler()
    X_source = scaler.fit_transform(X_source).astype(np.float32)
    X_target = scaler.transform(X_target).astype(np.float32)

    print("\n[3/4] Applying SMOTE oversampling to the source pool...")
    print(f"      Before SMOTE: vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    X_source_smote, y_source_smote = apply_smote(X_source, y_source, SEED)
    print(f"      After  SMOTE: vulnerable={int(y_source_smote.sum())} benign={int((y_source_smote == 0).sum())}")

    print("\n[4/4] Running DANN + XGBoost ensemble runs...")
    run_results = []
    for run_number in range(1, NUM_RUNS + 1):
        print(f"\n      Run {run_number}/{NUM_RUNS}")
        try:
            result = run_single(run_number, X_source_smote, y_source_smote, X_target, y_target,
                                 scaler, output_dir)
            run_results.append(result)
        except Exception as exc:
            print(f"      [RUN FAILED] run {run_number}: {exc}")
            traceback.print_exc()
            continue

    if not run_results:
        raise RuntimeError(f"All {NUM_RUNS} runs failed.")

    print("\nAggregating ensemble results...")
    ensemble_summary, ensemble_predictions = aggregate_ensemble(run_results, output_dir, y_target)
    atomic_json_dump(ensemble_summary, output_dir / f"dann_xgboost_{TEST_PROJS}_smote.json")
    save_confusion_matrix(ensemble_summary["ensemble_metrics"],
                          output_dir / f"confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png",
                          show=True)

    m = ensemble_summary["ensemble_metrics"]
    print(f"\n=== Ensemble Evaluation Results ({TEST_PROJS} Test Set, SMOTE) ===")
    print(f"Accuracy:   {m['accuracy']:.3f}")
    print(f"Precision:  {m['precision']:.3f}")
    print(f"Recall:     {m['recall']:.3f}")
    print(f"F1-score:   {m['f1']:.3f}")
    print(f"ROC-AUC:    {m['roc_auc']:.3f}" if m['roc_auc'] is not None else "ROC-AUC:    N/A")
    print(f"PR-AUC:     {m['pr_auc']:.3f}" if m['pr_auc'] is not None else "PR-AUC:     N/A")
    print(f"G-mean:     {m['g_mean']:.3f}")
    print(f"PF value:   {m['pf']:.3f}")
    print(f"\nResults saved to {output_dir / f'dann_xgboost_{TEST_PROJS}_smote.json'}")
    print(f"Confusion matrix saved to {output_dir / f'confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png'}")


if __name__ == "__main__":
    main()
# Out:
# Device: mps
# Method: dann_xgboost_smote_v1
# LOPO target project: radare2
# Dataset: ../../../../embedding/primevul/codebert/primevul_embedded.jsonl
#
# [1/4] Loading embeddings...
#       Loaded 224533 samples from 754 projects
#       Source projects: 753
#       Source (pre-SMOTE): (221730, 768) vulnerable=5930 benign=215800
#       Target (radare2): (2803, 768) vulnerable=74 benign=2729
#
# [2/4] Normalizing embeddings...
#
# [3/4] Applying SMOTE oversampling to the source pool...
#       Before SMOTE: vulnerable=5930 benign=215800
#       After  SMOTE: vulnerable=215800 benign=215800
#
# [4/4] Running DANN + XGBoost ensemble runs...
#
#       Run 1/3
# DANN seed=42:   2%|█▍                                                                    | 1/50 [00:28<23:06, 28.29s/it]
#       epoch=1/50 cls=0.5380 domain=0.6658 val=0.4776 val_f1=0.7848 alpha=0.0997
# DANN seed=42:   4%|██▊                                                                   | 2/50 [00:55<21:57, 27.44s/it]
#       epoch=2/50 cls=0.4596 domain=0.6664 val=0.4215 val_f1=0.8158 alpha=0.1974
# DANN seed=42:   6%|████▏                                                                 | 3/50 [01:21<21:13, 27.10s/it]
#       epoch=3/50 cls=0.4184 domain=0.6771 val=0.3842 val_f1=0.8370 alpha=0.2913
# DANN seed=42:   8%|█████▌                                                                | 4/50 [01:48<20:41, 26.98s/it]
#       epoch=4/50 cls=0.3872 domain=0.6842 val=0.3525 val_f1=0.8568 alpha=0.3799
# DANN seed=42:  10%|███████                                                               | 5/50 [02:15<20:18, 27.09s/it]
#       epoch=5/50 cls=0.3618 domain=0.6876 val=0.3223 val_f1=0.8698 alpha=0.4621
# DANN seed=42:  12%|████████▍                                                             | 6/50 [02:42<19:48, 27.00s/it]
#       epoch=6/50 cls=0.3371 domain=0.6887 val=0.2987 val_f1=0.8817 alpha=0.5370
# DANN seed=42:  14%|█████████▊                                                            | 7/50 [03:10<19:25, 27.10s/it]
#       epoch=7/50 cls=0.3171 domain=0.6888 val=0.2769 val_f1=0.8914 alpha=0.6044
# DANN seed=42:  16%|███████████▏                                                          | 8/50 [03:36<18:55, 27.03s/it]
#       epoch=8/50 cls=0.2995 domain=0.6892 val=0.2585 val_f1=0.8995 alpha=0.6640
# DANN seed=42:  18%|████████████▌                                                         | 9/50 [04:03<18:26, 27.00s/it]
#       epoch=9/50 cls=0.2822 domain=0.6898 val=0.2428 val_f1=0.9060 alpha=0.7163
# DANN seed=42:  20%|█████████████▊                                                       | 10/50 [04:30<18:00, 27.01s/it]
#       epoch=10/50 cls=0.2698 domain=0.6906 val=0.2281 val_f1=0.9133 alpha=0.7616
# DANN seed=42:  22%|███████████████▏                                                     | 11/50 
alpha=0.9978
# DANN seed=42:  70%|████████████████████████████████████████████████▎                    | 35/50 [17:20<09:00, 36.06s/it]
#       epoch=35/50 cls=0.1202 domain=0.6927 val=0.0955 val_f1=0.9664 alpha=0.9982
# DANN seed=42:  72%|█████████████████████████████████████████████████▋                   | 36/50 [17:56<08:26, 36.20s/it]
#       epoch=36/50 cls=0.1182 domain=0.6927 val=0.0942 val_f1=0.9673 alpha=0.9985
# DANN seed=42:  74%|███████████████████████████████████████████████████                  | 37/50 [18:32<07:50, 36.18s/it]
#       epoch=37/50 cls=0.1157 domain=0.6928 val=0.0946 val_f1=0.9667 alpha=0.9988
# DANN seed=42:  76%|████████████████████████████████████████████████████▍                | 38/50 [19:09<07:13, 36.14s/it]
#       epoch=38/50 cls=0.1139 domain=0.6927 val=0.0972 val_f1=0.9662 alpha=0.9990
# DANN seed=42:  78%|█████████████████████████████████████████████████████▊               | 39/50 [19:45<06:37, 36.14s/it]
#       epoch=39/50 cls=0.1112 domain=0.6928 val=0.0931 val_f1=0.9676 alpha=0.9992
# DANN seed=42:  80%|███████████████████████████████████████████████████████▏             | 40/50 [20:21<06:01, 36.18s/it]
#       epoch=40/50 cls=0.1086 domain=0.6928 val=0.0909 val_f1=0.9681 alpha=0.9993
# DANN seed=42:  82%|████████████████████████████████████████████████████████▌            | 41/50 [20:57<05:25, 36.16s/it]
#       epoch=41/50 cls=0.1070 domain=0.6928 val=0.0841 val_f1=0.9713 alpha=0.9995
# DANN seed=42:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [21:33<04:49, 36.16s/it]
#       epoch=42/50 cls=0.1050 domain=0.6928 val=0.0948 val_f1=0.9653 alpha=0.9996
# DANN seed=42:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [22:10<04:13, 36.28s/it]
#       epoch=43/50 cls=0.1035 domain=0.6928 val=0.0845 val_f1=0.9713 alpha=0.9996
# DANN seed=42:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [22:47<03:39, 36.60s/it]
#       epoch=44/50 cls=0.1018 domain=0.6927 val=0.0858 val_f1=0.9709 alpha=0.9997
# DANN seed=42:  90%|██████████████████████████████████████████████████████████████       | 45/50 [23:32<03:15, 39.07s/it]
#       epoch=45/50 cls=0.1002 domain=0.6928 val=0.0813 val_f1=0.9723 alpha=0.9998
# DANN seed=42:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [24:17<02:42, 40.75s/it]
#       epoch=46/50 cls=0.0984 domain=0.6928 val=0.0793 val_f1=0.9730 alpha=0.9998
# DANN seed=42:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [25:01<02:05, 41.92s/it]
#       epoch=47/50 cls=0.0969 domain=0.6928 val=0.0825 val_f1=0.9722 alpha=0.9998
# DANN seed=42:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [25:46<01:25, 42.83s/it]
#       epoch=48/50 cls=0.0959 domain=0.6928 val=0.0787 val_f1=0.9732 alpha=0.9999
# DANN seed=42:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [26:31<00:43, 43.47s/it]
#       epoch=49/50 cls=0.0935 domain=0.6927 val=0.0778 val_f1=0.9740 alpha=0.9999
#       epoch=50/50 cls=0.0928 domain=0.6928 val=0.0761 val_f1=0.9747 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/radare2/run_01/confusion_matrix.png
#       Saved run 1 to results/smote_oversampling/radare2/run_01
#
#       Run 2/3
# DANN seed=43:   2%|█▍                                                                    | 1/50 [00:36<29:31, 36.15s/it]
#       epoch=1/50 cls=0.5365 domain=0.6645 val=0.4792 val_f1=0.7824 alpha=0.0997
# DANN seed=43:   4%|██▊                                                                   | 2/50 [01:04<25:14, 31.54s/it]
#       epoch=2/50 cls=0.4582 domain=0.6682 val=0.4231 val_f1=0.8152 alpha=0.1974
# DANN seed=43:   6%|████▏                                                                 | 3/50 [01:33<23:40, 30.22s/it]
#       epoch=3/50 cls=0.4175 domain=0.6785 val=0.3851 val_f1=0.8377 alpha=0.2913
# DANN seed=43:   8%|█████▌                                                                | 4/50 [02:01<22:37, 29.51s/it]
#       epoch=4/50 cls=0.3868 domain=0.6850 val=0.3543 val_f1=0.8527 alpha=0.3799
# DANN seed=43:  10%|███████                                                               | 5/50 [02:31<22:10, 29.57s/it]
#       epoch=5/50 cls=0.3609 domain=0.6868 val=0.3253 val_f1=0.8684 alpha=0.4621
# DANN seed=43:  12%|████████▍                                                             | 6/50 [03:01<21:57, 29.95s/it]
#       epoch=6/50 cls=0.3377 domain=0.6879 val=0.3056 val_f1=0.8778 alpha=0.5370
# DANN seed=43:  14%|█████████▊                                                            | 7/50 [03:30<21:06, 29.45s/it]
#       epoch=7/50 cls=0.3176 domain=0.6881 val=0.2833 val_f1=0.8886 alpha=0.6044
# DANN seed=43:  16%|███████████▏                                                          | 8/50 
alpha=0.9959
# DANN seed=43:  64%|████████████████████████████████████████████▏                        | 32/50 [15:18<08:28, 28.24s/it]
#       epoch=32/50 cls=0.1259 domain=0.6926 val=0.1118 val_f1=0.9612 alpha=0.9967
# DANN seed=43:  66%|█████████████████████████████████████████████▌                       | 33/50 [15:46<07:58, 28.16s/it]
#       epoch=33/50 cls=0.1241 domain=0.6925 val=0.1039 val_f1=0.9638 alpha=0.9973
# DANN seed=43:  68%|██████████████████████████████████████████████▉                      | 34/50 [16:14<07:32, 28.29s/it]
#       epoch=34/50 cls=0.1212 domain=0.6927 val=0.1001 val_f1=0.9653 alpha=0.9978
# DANN seed=43:  70%|████████████████████████████████████████████████▎                    | 35/50 [16:43<07:06, 28.40s/it]
#       epoch=35/50 cls=0.1181 domain=0.6926 val=0.0992 val_f1=0.9659 alpha=0.9982
# DANN seed=43:  72%|█████████████████████████████████████████████████▋                   | 36/50 [17:11<06:38, 28.45s/it]
#       epoch=36/50 cls=0.1155 domain=0.6927 val=0.1002 val_f1=0.9658 alpha=0.9985
# DANN seed=43:  74%|███████████████████████████████████████████████████                  | 37/50 [17:40<06:09, 28.45s/it]
#       epoch=37/50 cls=0.1138 domain=0.6928 val=0.0998 val_f1=0.9661 alpha=0.9988
# DANN seed=43:  76%|████████████████████████████████████████████████████▍                | 38/50 [18:08<05:41, 28.47s/it]
#       epoch=38/50 cls=0.1111 domain=0.6927 val=0.0936 val_f1=0.9676 alpha=0.9990
# DANN seed=43:  78%|█████████████████████████████████████████████████████▊               | 39/50 [18:37<05:13, 28.53s/it]
#       epoch=39/50 cls=0.1098 domain=0.6928 val=0.0947 val_f1=0.9671 alpha=0.9992
# DANN seed=43:  80%|███████████████████████████████████████████████████████▏             | 40/50 [19:06<04:45, 28.53s/it]
#       epoch=40/50 cls=0.1069 domain=0.6927 val=0.0915 val_f1=0.9683 alpha=0.9993
# DANN seed=43:  82%|████████████████████████████████████████████████████████▌            | 41/50 [19:34<04:17, 28.56s/it]
#       epoch=41/50 cls=0.1048 domain=0.6928 val=0.0926 val_f1=0.9686 alpha=0.9995
# DANN seed=43:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [20:03<03:48, 28.54s/it]
#       epoch=42/50 cls=0.1032 domain=0.6928 val=0.0962 val_f1=0.9676 alpha=0.9996
# DANN seed=43:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [20:31<03:20, 28.58s/it]
#       epoch=43/50 cls=0.1016 domain=0.6927 val=0.0912 val_f1=0.9688 alpha=0.9996
# DANN seed=43:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [21:00<02:51, 28.57s/it]
#       epoch=44/50 cls=0.1000 domain=0.6928 val=0.0867 val_f1=0.9707 alpha=0.9997
# DANN seed=43:  90%|██████████████████████████████████████████████████████████████       | 45/50 [21:28<02:22, 28.56s/it]
#       epoch=45/50 cls=0.0984 domain=0.6928 val=0.0883 val_f1=0.9693 alpha=0.9998
# DANN seed=43:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [21:57<01:54, 28.63s/it]
#       epoch=46/50 cls=0.0959 domain=0.6928 val=0.0817 val_f1=0.9723 alpha=0.9998
# DANN seed=43:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [22:26<01:25, 28.66s/it]
#       epoch=47/50 cls=0.0948 domain=0.6928 val=0.0850 val_f1=0.9707 alpha=0.9998
# DANN seed=43:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [22:54<00:57, 28.60s/it]
#       epoch=48/50 cls=0.0933 domain=0.6928 val=0.0819 val_f1=0.9723 alpha=0.9999
# DANN seed=43:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [23:23<00:28, 28.59s/it]
#       epoch=49/50 cls=0.0929 domain=0.6928 val=0.0823 val_f1=0.9721 alpha=0.9999
#       epoch=50/50 cls=0.0897 domain=0.6928 val=0.0877 val_f1=0.9705 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/radare2/run_02/confusion_matrix.png
#       Saved run 2 to results/smote_oversampling/radare2/run_02
#
#       Run 3/3
# DANN seed=44:   2%|█▍                                                                    | 1/50 [00:30<24:37, 30.16s/it]
#       epoch=1/50 cls=0.5365 domain=0.6682 val=0.4737 val_f1=0.7847 alpha=0.0997
# DANN seed=44:   4%|██▊                                                                   | 2/50 [01:02<25:01, 31.28s/it]
#       epoch=2/50 cls=0.4551 domain=0.6649 val=0.4189 val_f1=0.8191 alpha=0.1974
# DANN seed=44:   6%|████▏                                                                 | 3/50 [01:32<23:58, 30.61s/it]
#       epoch=3/50 cls=0.4146 domain=0.6768 val=0.3801 val_f1=0.8397 alpha=0.2913
# DANN seed=44:   8%|█████▌                                                                | 4/50 [02:01<23:02, 30.05s/it]
#       epoch=4/50 cls=0.3846 domain=0.6838 val=0.3544 val_f1=0.8559 alpha=0.3799
# DANN seed=44:  10%|███████                                                               | 5/50 
run_03
#
# Aggregating ensemble results...
# Confusion matrix saved as results/smote_oversampling/radare2/confusion_matrix_dann_xgboost_radare2_smote.png
#
# === Ensemble Evaluation Results (radare2 Test Set, SMOTE) ===
# Accuracy:   0.518
# Precision:  0.048
# Recall:     0.919
# F1-score:   0.092
# ROC-AUC:    0.759
# PR-AUC:     0.056
# G-mean:     0.683
# PF value:   0.492
#
# Results saved to results/smote_oversampling/radare2/dann_xgboost_radare2_smote.json
# Confusion matrix saved to results/smote_oversampling/radare2/confusion_matrix_dann_xgboost_radare2_smote.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
DANN Domain Adaptation, SMOTE oversampling
"""

import json
import math
import random
import traceback
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, average_precision_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from xgboost import XGBClassifier

# =========================================================
# Config
# =========================================================
SEED            = 42
TEST_PROJS      = "linux-2.6"
COMBINED_FILE   = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY         = "emb"
OUTPUT_ROOT     = "results/smote_oversampling"

DANN_EPOCHS            = 50
DANN_BATCH_SIZE        = 64
LEARNING_RATE          = 1e-5
DOMAIN_LOSS_WEIGHT_MAX = 1.0
VALIDATION_SIZE        = 0.2
NUM_RUNS               = 3
THRESHOLD              = 0.5
METHOD_VERSION         = "dann_xgboost_smote_v1"
SMOTE_K_NEIGHBORS      = 5

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
else:
    DEVICE = "cpu"


def now_utc():
    return datetime.now(timezone.utc).isoformat()


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)


def atomic_json_dump(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, allow_nan=False)
        f.flush()
    tmp.replace(path)


def load_jsonl(path):
    embeddings, labels, projects, sample_ids = [], [], [], []
    with open(path, "r", encoding="utf-8") as f:
        for row_number, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            embeddings.append(record[EMB_KEY])
            labels.append(record["target"])
            projects.append(record["project"])
            sample_ids.append(str(record.get("idx", row_number)))
    return (np.asarray(embeddings, dtype=np.float32),
            np.asarray(labels, dtype=np.int32),
            np.asarray(projects, dtype=object),
            np.asarray(sample_ids, dtype=str))


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Architecture: 64-dim bottleneck FeatureExtractor + linear ClassifierHead
# + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # 64-dim domain-invariant features


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Linear(feature_dim, 1)

    def forward(self, features):
        return self.network(features).squeeze(-1)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
        )

    def forward(self, features):
        return self.network(features).squeeze(-1)


# =========================================================
# SMOTE oversampling on the source pool
# =========================================================
def apply_smote(X_source, y_source, seed):
    smote = SMOTE(random_state=seed, k_neighbors=SMOTE_K_NEIGHBORS)
    X_res, y_res = smote.fit_resample(X_source, y_source)
    return X_res.astype(np.float32), y_res.astype(np.int32)


# =========================================================
# DANN training
# =========================================================
def train_dann(x_source, y_source, x_target, seed):
    set_seed(seed)
    stratify = y_source if len(np.unique(y_source)) > 1 else None
    x_train, x_val, y_train, y_val = train_test_split(
        x_source, y_source,
        test_size=VALIDATION_SIZE,
        random_state=seed,
        stratify=stratify,
    )

    feature_extractor = FeatureExtractor(x_source.shape[1]).to(DEVICE)
    classifier         = ClassifierHead(feature_dim=64).to(DEVICE)
    discriminator      = DomainDiscriminator(feature_dim=64).to(DEVICE)
    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier.parameters()) +
              list(discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=LEARNING_RATE)

    classification_loss_fn = nn.BCEWithLogitsLoss()
    domain_loss_fn = nn.BCEWithLogitsLoss()

    source_dataset = TensorDataset(
        torch.tensor(x_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    target_dataset = TensorDataset(torch.tensor(x_target, dtype=torch.float32))
    source_loader = DataLoader(source_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)

    x_val_t = torch.tensor(x_val, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32, device=DEVICE)

    total_steps = max(1, DANN_EPOCHS * len(source_loader) - 1)
    global_step = 0
    history = []

    for epoch in tqdm(range(DANN_EPOCHS), desc=f"DANN seed={seed}", leave=False):
        feature_extractor.train()
        classifier.train()
        discriminator.train()

        target_iter = iter(target_loader)
        classification_losses, domain_losses = [], []

        for xs_batch, ys_batch in source_loader:
            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            progress = global_step / total_steps
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + math.exp(-10.0 * progress)) - 1.0)

            optimizer.zero_grad(set_to_none=True)

            source_features = feature_extractor(xs_batch)
            target_features = feature_extractor(xt_batch)

            vulnerability_logits = classifier(source_features)
            classification_loss = classification_loss_fn(vulnerability_logits, ys_batch)

            source_domain_logits = discriminator(grl(source_features, alpha))
            target_domain_logits = discriminator(grl(target_features, alpha))
            source_domain_labels = torch.zeros(source_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)
            target_domain_labels = torch.ones(target_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)

            source_domain_loss = domain_loss_fn(source_domain_logits, source_domain_labels)
            target_domain_loss = domain_loss_fn(target_domain_logits, target_domain_labels)
            domain_loss = 0.5 * (source_domain_loss + target_domain_loss)

            loss = classification_loss + domain_loss
            loss.backward()
            optimizer.step()

            classification_losses.append(classification_loss.item())
            domain_losses.append(domain_loss.item())
            global_step += 1

        feature_extractor.eval()
        classifier.eval()
        discriminator.eval()
        with torch.no_grad():
            val_logits = classifier(feature_extractor(x_val_t))
            val_loss = classification_loss_fn(val_logits, y_val_t).item()
            val_prob = torch.sigmoid(val_logits)
            val_pred = (val_prob >= THRESHOLD).long().cpu().numpy()
            val_f1 = f1_score(y_val, val_pred, zero_division=0)

        epoch_result = {
            "epoch": epoch + 1,
            "classification_loss": float(np.mean(classification_losses)),
            "domain_loss": float(np.mean(domain_losses)),
            "source_validation_loss": float(val_loss),
            "source_validation_f1": float(val_f1),
            "grl_alpha": float(alpha),
        }
        history.append(epoch_result)
        print(f"      epoch={epoch + 1}/{DANN_EPOCHS} "
              f"cls={epoch_result['classification_loss']:.4f} "
              f"domain={epoch_result['domain_loss']:.4f} "
              f"val={val_loss:.4f} val_f1={val_f1:.4f} alpha={alpha:.4f}")

    return feature_extractor, classifier, discriminator, history


# =========================================================
# XGBoost trained on DANN's extracted (domain-invariant) features
# =========================================================
def extract_features(feature_extractor, X, batch_size=256):
    feature_extractor.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            outputs.append(feature_extractor(x_batch).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty((0, 64), dtype=np.float32)


def classifier_probabilities(feature_extractor, classifier, X, batch_size=256):
    feature_extractor.eval()
    classifier.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            logits = classifier(feature_extractor(x_batch))
            outputs.append(torch.sigmoid(logits).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty(0, dtype=np.float32)


def train_xgboost(x_train_feat, y_train, sample_weights, seed):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric="logloss",
        random_state=seed,
    )
    model.fit(x_train_feat, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Evaluation
# =========================================================
def evaluate(y_true, probabilities):
    predictions = (probabilities >= THRESHOLD).astype(np.int32)
    tn, fp, fn, tp = confusion_matrix(y_true, predictions, labels=[0, 1]).ravel()
    accuracy = accuracy_score(y_true, predictions)
    precision = precision_score(y_true, predictions, zero_division=0)
    recall = recall_score(y_true, predictions, zero_division=0)
    f1 = f1_score(y_true, predictions, zero_division=0)
    roc_auc = roc_auc_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    pr_auc = average_precision_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    tpr = tp / (tp + fn) if tp + fn else 0.0
    tnr = tn / (tn + fp) if tn + fp else 0.0
    g_mean = math.sqrt(tpr * tnr)
    pf = fp / (fp + tn) if fp + tn else 0.0
    metrics = {
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall),
        "f1": float(f1),
        "roc_auc": None if roc_auc is None else float(roc_auc),
        "pr_auc": None if pr_auc is None else float(pr_auc),
        "g_mean": float(g_mean),
        "pf": float(pf),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }
    return metrics, predictions


def save_confusion_matrix(metrics, path, title="Confusion Matrix (linux-2.6 Test Set) - DANN + XGBoost (SMOTE)", show=False):
    cm_values = metrics["confusion_matrix"]
    cm = np.asarray([[cm_values["tn"], cm_values["fp"]], [cm_values["fn"], cm_values["tp"]]])
    fig, ax = plt.subplots(figsize=(6, 5))
    image = ax.imshow(cm, interpolation="nearest")
    ax.set_title(title)
    plt.colorbar(image, ax=ax)
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2 if cm.max() else 0
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label"); ax.set_xlabel("Predicted Label")
    fig.tight_layout()
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300)
    if show:
        plt.show()
    plt.close(fig)
    print(f"Confusion matrix saved as {path}")


def cpu_state_dict(module):
    return {key: value.detach().cpu() for key, value in module.state_dict().items()}


# =========================================================
# Single run: one DANN training + one XGBoost fit
# =========================================================
def run_single(run_number, X_source_smote, y_source_smote, X_target, y_target, scaler, output_dir):
    seed = SEED + run_number - 1
    run_dir = Path(output_dir) / f"run_{run_number:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)
    started_at = now_utc()

    feature_extractor, classifier, discriminator, history = train_dann(
        X_source_smote, y_source_smote, X_target, seed
    )

    # Extract domain-invariant features for the (SMOTE-balanced) train set + target
    train_features = extract_features(feature_extractor, X_source_smote)
    target_features = extract_features(feature_extractor, X_target)

    # Confidence-based sample weights from the DANN's own classifier head
    train_probs = classifier_probabilities(feature_extractor, classifier, X_source_smote)
    sample_weights = np.where(y_source_smote == 1, train_probs, 1 - train_probs)

    model_xgb = train_xgboost(train_features, y_source_smote, sample_weights, seed)
    probabilities = model_xgb.predict_proba(target_features)[:, 1]

    metrics, predictions = evaluate(y_target, probabilities)
    finished_at = now_utc()

    result = {
        "method_version": METHOD_VERSION,
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "run": run_number,
        "seed": seed,
        "final_classifier": "XGBoost on DANN-extracted features",
        "n_source_samples_smote": int(len(y_source_smote)),
        "n_source_vulnerable_smote": int(y_source_smote.sum()),
        "n_target_samples": int(len(y_target)),
        "n_target_vulnerable": int(y_target.sum()),
        "threshold": THRESHOLD,
        "metrics": metrics,
        "training_history": history,
        "started_at": started_at,
        "finished_at": finished_at,
    }
    atomic_json_dump(result, run_dir / "result.json")
    np.savez_compressed(
        run_dir / "predictions.npz",
        target=y_target, probability=probabilities, prediction=predictions
    )
    torch.save(
        {
            "method_version": METHOD_VERSION,
            "project": TEST_PROJS,
            "run": run_number,
            "seed": seed,
            "feature_extractor": cpu_state_dict(feature_extractor),
            "classifier": cpu_state_dict(classifier),
            "domain_discriminator": cpu_state_dict(discriminator),
            "scaler_mean": scaler.mean_,
            "scaler_scale": scaler.scale_,
            "threshold": THRESHOLD,
        },
        run_dir / "model.pt",
    )
    save_confusion_matrix(metrics, run_dir / "confusion_matrix.png")
    print(f"      Saved run {run_number} to {run_dir}")

    del feature_extractor, classifier, discriminator, model_xgb
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE == "mps":
        torch.mps.empty_cache()

    return result


# =========================================================
# Ensemble aggregation
# =========================================================
def aggregate_ensemble(run_results, output_dir, y_target):
    prob_arrays = []
    for r in run_results:
        npz_path = Path(output_dir) / f"run_{r['run']:02d}" / "predictions.npz"
        data = np.load(npz_path)
        prob_arrays.append(data["probability"])

    ensemble_probability = np.mean(np.stack(prob_arrays, axis=0), axis=0)
    ensemble_metrics, ensemble_predictions = evaluate(y_target, ensemble_probability)

    per_run_metric_names = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", "g_mean", "pf"]
    per_run_summary = {}
    for metric in per_run_metric_names:
        values = [r["metrics"][metric] for r in run_results if r["metrics"][metric] is not None]
        per_run_summary[metric] = {
            "mean": float(np.mean(values)) if values else None,
            "std": float(np.std(values, ddof=1)) if len(values) > 1 else (0.0 if values else None),
        }

    return {
        "method_version": METHOD_VERSION,
        "method": "DANN + XGBoost",
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "train": f"all_except_{TEST_PROJS}",
        "num_completed_runs": len(run_results),
        "ensemble_metrics": ensemble_metrics,
        "per_run_metric_summary": per_run_summary,
        "runs": run_results,
        "updated_at": now_utc(),
    }, ensemble_predictions


# =========================================================
# Main
# =========================================================
def main():
    output_dir = Path(OUTPUT_ROOT) / TEST_PROJS
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Device: {DEVICE}")
    print(f"Method: {METHOD_VERSION}")
    print(f"LOPO target project: {TEST_PROJS}")
    print(f"Dataset: {COMBINED_FILE}")

    print("\n[1/4] Loading embeddings...")
    X_all, y_all, projects_all, ids_all = load_jsonl(COMBINED_FILE)
    print(f"      Loaded {len(y_all)} samples from {len(set(projects_all.tolist()))} projects")

    source_mask = projects_all != TEST_PROJS
    target_mask = projects_all == TEST_PROJS
    if not target_mask.any():
        raise ValueError(f"No samples found for target project '{TEST_PROJS}'.")

    X_source = X_all[source_mask].astype(np.float32)
    y_source = y_all[source_mask].astype(np.int32)
    X_target = X_all[target_mask].astype(np.float32)
    y_target = y_all[target_mask].astype(np.int32)

    if len(np.unique(y_source)) < 2:
        raise ValueError(f"Source pool for {TEST_PROJS} does not contain both classes.")

    source_projects = len(set(projects_all[source_mask].tolist()))
    print(f"      Source projects: {source_projects}")
    print(f"      Source (pre-SMOTE): {X_source.shape} vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    print(f"      Target ({TEST_PROJS}): {X_target.shape} vulnerable={int(y_target.sum())} benign={int((y_target == 0).sum())}")

    print("\n[2/4] Normalizing embeddings...")
    scaler = StandardScaler()
    X_source = scaler.fit_transform(X_source).astype(np.float32)
    X_target = scaler.transform(X_target).astype(np.float32)

    print("\n[3/4] Applying SMOTE oversampling to the source pool...")
    print(f"      Before SMOTE: vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    X_source_smote, y_source_smote = apply_smote(X_source, y_source, SEED)
    print(f"      After  SMOTE: vulnerable={int(y_source_smote.sum())} benign={int((y_source_smote == 0).sum())}")

    print("\n[4/4] Running DANN + XGBoost ensemble runs...")
    run_results = []
    for run_number in range(1, NUM_RUNS + 1):
        print(f"\n      Run {run_number}/{NUM_RUNS}")
        try:
            result = run_single(run_number, X_source_smote, y_source_smote, X_target, y_target,
                                 scaler, output_dir)
            run_results.append(result)
        except Exception as exc:
            print(f"      [RUN FAILED] run {run_number}: {exc}")
            traceback.print_exc()
            continue

    if not run_results:
        raise RuntimeError(f"All {NUM_RUNS} runs failed.")

    print("\nAggregating ensemble results...")
    ensemble_summary, ensemble_predictions = aggregate_ensemble(run_results, output_dir, y_target)
    atomic_json_dump(ensemble_summary, output_dir / f"dann_xgboost_{TEST_PROJS}_smote.json")
    save_confusion_matrix(ensemble_summary["ensemble_metrics"],
                          output_dir / f"confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png",
                          show=True)

    m = ensemble_summary["ensemble_metrics"]
    print(f"\n=== Ensemble Evaluation Results ({TEST_PROJS} Test Set, SMOTE) ===")
    print(f"Accuracy:   {m['accuracy']:.3f}")
    print(f"Precision:  {m['precision']:.3f}")
    print(f"Recall:     {m['recall']:.3f}")
    print(f"F1-score:   {m['f1']:.3f}")
    print(f"ROC-AUC:    {m['roc_auc']:.3f}" if m['roc_auc'] is not None else "ROC-AUC:    N/A")
    print(f"PR-AUC:     {m['pr_auc']:.3f}" if m['pr_auc'] is not None else "PR-AUC:     N/A")
    print(f"G-mean:     {m['g_mean']:.3f}")
    print(f"PF value:   {m['pf']:.3f}")
    print(f"\nResults saved to {output_dir / f'dann_xgboost_{TEST_PROJS}_smote.json'}")
    print(f"Confusion matrix saved to {output_dir / f'confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png'}")


if __name__ == "__main__":
    main()
# Out:
# Device: mps
# Method: dann_xgboost_smote_v1
# LOPO target project: linux-2.6
# Dataset: ../../../../embedding/primevul/codebert/primevul_embedded.jsonl
#
# [1/4] Loading embeddings...
#       Loaded 224533 samples from 754 projects
#       Source projects: 753
#       Source (pre-SMOTE): (221163, 768) vulnerable=5904 benign=215259
#       Target (linux-2.6): (3370, 768) vulnerable=100 benign=3270
#
# [2/4] Normalizing embeddings...
#
# [3/4] Applying SMOTE oversampling to the source pool...
#       Before SMOTE: vulnerable=5904 benign=215259
#       After  SMOTE: vulnerable=215259 benign=215259
#
# [4/4] Running DANN + XGBoost ensemble runs...
#
#       Run 1/3
# DANN seed=42:   2%|█▍                                                                    | 1/50 [00:27<22:49, 27.95s/it]
#       epoch=1/50 cls=0.5353 domain=0.6717 val=0.4763 val_f1=0.7829 alpha=0.0996
# DANN seed=42:   4%|██▊                                                                   | 2/50 [00:55<22:03, 27.57s/it]
#       epoch=2/50 cls=0.4538 domain=0.6679 val=0.4258 val_f1=0.8186 alpha=0.1974
# DANN seed=42:   6%|████▏                                                                 | 3/50 [01:22<21:23, 27.30s/it]
#       epoch=3/50 cls=0.4131 domain=0.6647 val=0.3858 val_f1=0.8387 alpha=0.2913
# DANN seed=42:   8%|█████▌                                                                | 4/50 [01:49<20:57, 27.34s/it]
#       epoch=4/50 cls=0.3852 domain=0.6667 val=0.3577 val_f1=0.8534 alpha=0.3799
# DANN seed=42:  10%|███████                                                               | 5/50 [02:17<20:32, 27.38s/it]
#       epoch=5/50 cls=0.3611 domain=0.6688 val=0.3326 val_f1=0.8663 alpha=0.4621
# DANN seed=42:  12%|████████▍                                                             | 6/50 [02:44<20:03, 27.35s/it]
#       epoch=6/50 cls=0.3406 domain=0.6718 val=0.3075 val_f1=0.8782 alpha=0.5370
# DANN seed=42:  14%|█████████▊                                                            | 7/50 [03:12<19:46, 27.59s/it]
#       epoch=7/50 cls=0.3222 domain=0.6735 val=0.2925 val_f1=0.8856 alpha=0.6044
# DANN seed=42:  16%|███████████▏                                                          | 8/50 [03:39<19:12, 27.44s/it]
#       epoch=8/50 cls=0.3065 domain=0.6751 val=0.2742 val_f1=0.8941 alpha=0.6640
# DANN seed=42:  18%|████████████▌                                                         | 9/50 
run_03
#
# Aggregating ensemble results...
# Confusion matrix saved as results/smote_oversampling/linux-2.6/confusion_matrix_dann_xgboost_linux-2.6_smote.png
#
# === Ensemble Evaluation Results (linux-2.6 Test Set, SMOTE) ===
# Accuracy:   0.582
# Precision:  0.056
# Recall:     0.820
# F1-score:   0.104
# ROC-AUC:    0.756
# PR-AUC:     0.075
# G-mean:     0.687
# PF value:   0.425
#
# Results saved to results/smote_oversampling/linux-2.6/dann_xgboost_linux-2.6_smote.json
# Confusion matrix saved to results/smote_oversampling/linux-2.6/confusion_matrix_dann_xgboost_linux-2.6_smote.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
DANN Domain Adaptation, SMOTE oversampling
"""

import json
import math
import random
import traceback
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, average_precision_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from xgboost import XGBClassifier

# =========================================================
# Config
# =========================================================
SEED            = 42
TEST_PROJS      = "vim"
COMBINED_FILE   = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY         = "emb"
OUTPUT_ROOT     = "results/smote_oversampling"

DANN_EPOCHS            = 50
DANN_BATCH_SIZE        = 64
LEARNING_RATE          = 1e-5
DOMAIN_LOSS_WEIGHT_MAX = 1.0
VALIDATION_SIZE        = 0.2
NUM_RUNS               = 3
THRESHOLD              = 0.5
METHOD_VERSION         = "dann_xgboost_smote_v1"
SMOTE_K_NEIGHBORS      = 5

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
else:
    DEVICE = "cpu"


def now_utc():
    return datetime.now(timezone.utc).isoformat()


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)


def atomic_json_dump(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, allow_nan=False)
        f.flush()
    tmp.replace(path)


def load_jsonl(path):
    embeddings, labels, projects, sample_ids = [], [], [], []
    with open(path, "r", encoding="utf-8") as f:
        for row_number, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            embeddings.append(record[EMB_KEY])
            labels.append(record["target"])
            projects.append(record["project"])
            sample_ids.append(str(record.get("idx", row_number)))
    return (np.asarray(embeddings, dtype=np.float32),
            np.asarray(labels, dtype=np.int32),
            np.asarray(projects, dtype=object),
            np.asarray(sample_ids, dtype=str))


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Architecture: 64-dim bottleneck FeatureExtractor + linear ClassifierHead
# + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # 64-dim domain-invariant features


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Linear(feature_dim, 1)

    def forward(self, features):
        return self.network(features).squeeze(-1)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
        )

    def forward(self, features):
        return self.network(features).squeeze(-1)


# =========================================================
# SMOTE oversampling on the source pool
# =========================================================
def apply_smote(X_source, y_source, seed):
    smote = SMOTE(random_state=seed, k_neighbors=SMOTE_K_NEIGHBORS)
    X_res, y_res = smote.fit_resample(X_source, y_source)
    return X_res.astype(np.float32), y_res.astype(np.int32)


# =========================================================
# DANN training
# =========================================================
def train_dann(x_source, y_source, x_target, seed):
    set_seed(seed)
    stratify = y_source if len(np.unique(y_source)) > 1 else None
    x_train, x_val, y_train, y_val = train_test_split(
        x_source, y_source,
        test_size=VALIDATION_SIZE,
        random_state=seed,
        stratify=stratify,
    )

    feature_extractor = FeatureExtractor(x_source.shape[1]).to(DEVICE)
    classifier         = ClassifierHead(feature_dim=64).to(DEVICE)
    discriminator      = DomainDiscriminator(feature_dim=64).to(DEVICE)
    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier.parameters()) +
              list(discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=LEARNING_RATE)

    classification_loss_fn = nn.BCEWithLogitsLoss()
    domain_loss_fn = nn.BCEWithLogitsLoss()

    source_dataset = TensorDataset(
        torch.tensor(x_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    target_dataset = TensorDataset(torch.tensor(x_target, dtype=torch.float32))
    source_loader = DataLoader(source_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)

    x_val_t = torch.tensor(x_val, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32, device=DEVICE)

    total_steps = max(1, DANN_EPOCHS * len(source_loader) - 1)
    global_step = 0
    history = []

    for epoch in tqdm(range(DANN_EPOCHS), desc=f"DANN seed={seed}", leave=False):
        feature_extractor.train()
        classifier.train()
        discriminator.train()

        target_iter = iter(target_loader)
        classification_losses, domain_losses = [], []

        for xs_batch, ys_batch in source_loader:
            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            progress = global_step / total_steps
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + math.exp(-10.0 * progress)) - 1.0)

            optimizer.zero_grad(set_to_none=True)

            source_features = feature_extractor(xs_batch)
            target_features = feature_extractor(xt_batch)

            vulnerability_logits = classifier(source_features)
            classification_loss = classification_loss_fn(vulnerability_logits, ys_batch)

            source_domain_logits = discriminator(grl(source_features, alpha))
            target_domain_logits = discriminator(grl(target_features, alpha))
            source_domain_labels = torch.zeros(source_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)
            target_domain_labels = torch.ones(target_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)

            source_domain_loss = domain_loss_fn(source_domain_logits, source_domain_labels)
            target_domain_loss = domain_loss_fn(target_domain_logits, target_domain_labels)
            domain_loss = 0.5 * (source_domain_loss + target_domain_loss)

            loss = classification_loss + domain_loss
            loss.backward()
            optimizer.step()

            classification_losses.append(classification_loss.item())
            domain_losses.append(domain_loss.item())
            global_step += 1

        feature_extractor.eval()
        classifier.eval()
        discriminator.eval()
        with torch.no_grad():
            val_logits = classifier(feature_extractor(x_val_t))
            val_loss = classification_loss_fn(val_logits, y_val_t).item()
            val_prob = torch.sigmoid(val_logits)
            val_pred = (val_prob >= THRESHOLD).long().cpu().numpy()
            val_f1 = f1_score(y_val, val_pred, zero_division=0)

        epoch_result = {
            "epoch": epoch + 1,
            "classification_loss": float(np.mean(classification_losses)),
            "domain_loss": float(np.mean(domain_losses)),
            "source_validation_loss": float(val_loss),
            "source_validation_f1": float(val_f1),
            "grl_alpha": float(alpha),
        }
        history.append(epoch_result)
        print(f"      epoch={epoch + 1}/{DANN_EPOCHS} "
              f"cls={epoch_result['classification_loss']:.4f} "
              f"domain={epoch_result['domain_loss']:.4f} "
              f"val={val_loss:.4f} val_f1={val_f1:.4f} alpha={alpha:.4f}")

    return feature_extractor, classifier, discriminator, history


# =========================================================
# XGBoost trained on DANN's extracted (domain-invariant) features
# =========================================================
def extract_features(feature_extractor, X, batch_size=256):
    feature_extractor.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            outputs.append(feature_extractor(x_batch).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty((0, 64), dtype=np.float32)


def classifier_probabilities(feature_extractor, classifier, X, batch_size=256):
    feature_extractor.eval()
    classifier.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            logits = classifier(feature_extractor(x_batch))
            outputs.append(torch.sigmoid(logits).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty(0, dtype=np.float32)


def train_xgboost(x_train_feat, y_train, sample_weights, seed):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric="logloss",
        random_state=seed,
    )
    model.fit(x_train_feat, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Evaluation
# =========================================================
def evaluate(y_true, probabilities):
    predictions = (probabilities >= THRESHOLD).astype(np.int32)
    tn, fp, fn, tp = confusion_matrix(y_true, predictions, labels=[0, 1]).ravel()
    accuracy = accuracy_score(y_true, predictions)
    precision = precision_score(y_true, predictions, zero_division=0)
    recall = recall_score(y_true, predictions, zero_division=0)
    f1 = f1_score(y_true, predictions, zero_division=0)
    roc_auc = roc_auc_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    pr_auc = average_precision_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    tpr = tp / (tp + fn) if tp + fn else 0.0
    tnr = tn / (tn + fp) if tn + fp else 0.0
    g_mean = math.sqrt(tpr * tnr)
    pf = fp / (fp + tn) if fp + tn else 0.0
    metrics = {
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall),
        "f1": float(f1),
        "roc_auc": None if roc_auc is None else float(roc_auc),
        "pr_auc": None if pr_auc is None else float(pr_auc),
        "g_mean": float(g_mean),
        "pf": float(pf),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }
    return metrics, predictions


def save_confusion_matrix(metrics, path, title="Confusion Matrix (vim Test Set) - DANN + XGBoost (SMOTE)", show=False):
    cm_values = metrics["confusion_matrix"]
    cm = np.asarray([[cm_values["tn"], cm_values["fp"]], [cm_values["fn"], cm_values["tp"]]])
    fig, ax = plt.subplots(figsize=(6, 5))
    image = ax.imshow(cm, interpolation="nearest")
    ax.set_title(title)
    plt.colorbar(image, ax=ax)
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2 if cm.max() else 0
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label"); ax.set_xlabel("Predicted Label")
    fig.tight_layout()
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300)
    if show:
        plt.show()
    plt.close(fig)
    print(f"Confusion matrix saved as {path}")


def cpu_state_dict(module):
    return {key: value.detach().cpu() for key, value in module.state_dict().items()}


# =========================================================
# Single run: one DANN training + one XGBoost fit
# =========================================================
def run_single(run_number, X_source_smote, y_source_smote, X_target, y_target, scaler, output_dir):
    seed = SEED + run_number - 1
    run_dir = Path(output_dir) / f"run_{run_number:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)
    started_at = now_utc()

    feature_extractor, classifier, discriminator, history = train_dann(
        X_source_smote, y_source_smote, X_target, seed
    )

    # Extract domain-invariant features for the (SMOTE-balanced) train set + target
    train_features = extract_features(feature_extractor, X_source_smote)
    target_features = extract_features(feature_extractor, X_target)

    # Confidence-based sample weights from the DANN's own classifier head
    train_probs = classifier_probabilities(feature_extractor, classifier, X_source_smote)
    sample_weights = np.where(y_source_smote == 1, train_probs, 1 - train_probs)

    model_xgb = train_xgboost(train_features, y_source_smote, sample_weights, seed)
    probabilities = model_xgb.predict_proba(target_features)[:, 1]

    metrics, predictions = evaluate(y_target, probabilities)
    finished_at = now_utc()

    result = {
        "method_version": METHOD_VERSION,
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "run": run_number,
        "seed": seed,
        "final_classifier": "XGBoost on DANN-extracted features",
        "n_source_samples_smote": int(len(y_source_smote)),
        "n_source_vulnerable_smote": int(y_source_smote.sum()),
        "n_target_samples": int(len(y_target)),
        "n_target_vulnerable": int(y_target.sum()),
        "threshold": THRESHOLD,
        "metrics": metrics,
        "training_history": history,
        "started_at": started_at,
        "finished_at": finished_at,
    }
    atomic_json_dump(result, run_dir / "result.json")
    np.savez_compressed(
        run_dir / "predictions.npz",
        target=y_target, probability=probabilities, prediction=predictions
    )
    torch.save(
        {
            "method_version": METHOD_VERSION,
            "project": TEST_PROJS,
            "run": run_number,
            "seed": seed,
            "feature_extractor": cpu_state_dict(feature_extractor),
            "classifier": cpu_state_dict(classifier),
            "domain_discriminator": cpu_state_dict(discriminator),
            "scaler_mean": scaler.mean_,
            "scaler_scale": scaler.scale_,
            "threshold": THRESHOLD,
        },
        run_dir / "model.pt",
    )
    save_confusion_matrix(metrics, run_dir / "confusion_matrix.png")
    print(f"      Saved run {run_number} to {run_dir}")

    del feature_extractor, classifier, discriminator, model_xgb
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE == "mps":
        torch.mps.empty_cache()

    return result


# =========================================================
# Ensemble aggregation
# =========================================================
def aggregate_ensemble(run_results, output_dir, y_target):
    prob_arrays = []
    for r in run_results:
        npz_path = Path(output_dir) / f"run_{r['run']:02d}" / "predictions.npz"
        data = np.load(npz_path)
        prob_arrays.append(data["probability"])

    ensemble_probability = np.mean(np.stack(prob_arrays, axis=0), axis=0)
    ensemble_metrics, ensemble_predictions = evaluate(y_target, ensemble_probability)

    per_run_metric_names = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", "g_mean", "pf"]
    per_run_summary = {}
    for metric in per_run_metric_names:
        values = [r["metrics"][metric] for r in run_results if r["metrics"][metric] is not None]
        per_run_summary[metric] = {
            "mean": float(np.mean(values)) if values else None,
            "std": float(np.std(values, ddof=1)) if len(values) > 1 else (0.0 if values else None),
        }

    return {
        "method_version": METHOD_VERSION,
        "method": "DANN + XGBoost",
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "train": f"all_except_{TEST_PROJS}",
        "num_completed_runs": len(run_results),
        "ensemble_metrics": ensemble_metrics,
        "per_run_metric_summary": per_run_summary,
        "runs": run_results,
        "updated_at": now_utc(),
    }, ensemble_predictions


# =========================================================
# Main
# =========================================================
def main():
    output_dir = Path(OUTPUT_ROOT) / TEST_PROJS
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Device: {DEVICE}")
    print(f"Method: {METHOD_VERSION}")
    print(f"LOPO target project: {TEST_PROJS}")
    print(f"Dataset: {COMBINED_FILE}")

    print("\n[1/4] Loading embeddings...")
    X_all, y_all, projects_all, ids_all = load_jsonl(COMBINED_FILE)
    print(f"      Loaded {len(y_all)} samples from {len(set(projects_all.tolist()))} projects")

    source_mask = projects_all != TEST_PROJS
    target_mask = projects_all == TEST_PROJS
    if not target_mask.any():
        raise ValueError(f"No samples found for target project '{TEST_PROJS}'.")

    X_source = X_all[source_mask].astype(np.float32)
    y_source = y_all[source_mask].astype(np.int32)
    X_target = X_all[target_mask].astype(np.float32)
    y_target = y_all[target_mask].astype(np.int32)

    if len(np.unique(y_source)) < 2:
        raise ValueError(f"Source pool for {TEST_PROJS} does not contain both classes.")

    source_projects = len(set(projects_all[source_mask].tolist()))
    print(f"      Source projects: {source_projects}")
    print(f"      Source (pre-SMOTE): {X_source.shape} vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    print(f"      Target ({TEST_PROJS}): {X_target.shape} vulnerable={int(y_target.sum())} benign={int((y_target == 0).sum())}")

    print("\n[2/4] Normalizing embeddings...")
    scaler = StandardScaler()
    X_source = scaler.fit_transform(X_source).astype(np.float32)
    X_target = scaler.transform(X_target).astype(np.float32)

    print("\n[3/4] Applying SMOTE oversampling to the source pool...")
    print(f"      Before SMOTE: vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    X_source_smote, y_source_smote = apply_smote(X_source, y_source, SEED)
    print(f"      After  SMOTE: vulnerable={int(y_source_smote.sum())} benign={int((y_source_smote == 0).sum())}")

    print("\n[4/4] Running DANN + XGBoost ensemble runs...")
    run_results = []
    for run_number in range(1, NUM_RUNS + 1):
        print(f"\n      Run {run_number}/{NUM_RUNS}")
        try:
            result = run_single(run_number, X_source_smote, y_source_smote, X_target, y_target,
                                 scaler, output_dir)
            run_results.append(result)
        except Exception as exc:
            print(f"      [RUN FAILED] run {run_number}: {exc}")
            traceback.print_exc()
            continue

    if not run_results:
        raise RuntimeError(f"All {NUM_RUNS} runs failed.")

    print("\nAggregating ensemble results...")
    ensemble_summary, ensemble_predictions = aggregate_ensemble(run_results, output_dir, y_target)
    atomic_json_dump(ensemble_summary, output_dir / f"dann_xgboost_{TEST_PROJS}_smote.json")
    save_confusion_matrix(ensemble_summary["ensemble_metrics"],
                          output_dir / f"confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png",
                          show=True)

    m = ensemble_summary["ensemble_metrics"]
    print(f"\n=== Ensemble Evaluation Results ({TEST_PROJS} Test Set, SMOTE) ===")
    print(f"Accuracy:   {m['accuracy']:.3f}")
    print(f"Precision:  {m['precision']:.3f}")
    print(f"Recall:     {m['recall']:.3f}")
    print(f"F1-score:   {m['f1']:.3f}")
    print(f"ROC-AUC:    {m['roc_auc']:.3f}" if m['roc_auc'] is not None else "ROC-AUC:    N/A")
    print(f"PR-AUC:     {m['pr_auc']:.3f}" if m['pr_auc'] is not None else "PR-AUC:     N/A")
    print(f"G-mean:     {m['g_mean']:.3f}")
    print(f"PF value:   {m['pf']:.3f}")
    print(f"\nResults saved to {output_dir / f'dann_xgboost_{TEST_PROJS}_smote.json'}")
    print(f"Confusion matrix saved to {output_dir / f'confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png'}")


if __name__ == "__main__":
    main()
# Out:
# Device: mps
# Method: dann_xgboost_smote_v1
# LOPO target project: vim
# Dataset: ../../../../embedding/primevul/codebert/primevul_embedded.jsonl
#
# [1/4] Loading embeddings...
#       Loaded 224533 samples from 754 projects
#       Source projects: 753
#       Source (pre-SMOTE): (221466, 768) vulnerable=5898 benign=215568
#       Target (vim): (3067, 768) vulnerable=106 benign=2961
#
# [2/4] Normalizing embeddings...
#
# [3/4] Applying SMOTE oversampling to the source pool...
#       Before SMOTE: vulnerable=5898 benign=215568
#       After  SMOTE: vulnerable=215568 benign=215568
#
# [4/4] Running DANN + XGBoost ensemble runs...
#
#       Run 1/3
# DANN seed=42:   2%|█▍                                                                    | 1/50 [00:38<31:22, 38.42s/it]
#       epoch=1/50 cls=0.5357 domain=0.6844 val=0.4746 val_f1=0.7871 alpha=0.0996
# DANN seed=42:   4%|██▊                                                                   | 2/50 [01:08<26:36, 33.26s/it]
#       epoch=2/50 cls=0.4544 domain=0.6884 val=0.4156 val_f1=0.8219 alpha=0.1974
# DANN seed=42:   6%|████▏                                                                 | 3/50 [01:37<24:32, 31.32s/it]
#       epoch=3/50 cls=0.4113 domain=0.6910 val=0.3775 val_f1=0.8441 alpha=0.2913
# DANN seed=42:   8%|█████▌                                                                | 4/50 [02:07<23:37, 30.83s/it]
#       epoch=4/50 cls=0.3801 domain=0.6913 val=0.3438 val_f1=0.8599 alpha=0.3799
# DANN seed=42:  10%|███████                                                               | 5/50 [02:40<23:41, 31.58s/it]
#       epoch=5/50 cls=0.3530 domain=0.6919 val=0.3154 val_f1=0.8737 alpha=0.4621
# DANN seed=42:  12%|████████▍                                                             | 6/50 [03:14<23:51, 32.53s/it]
#       epoch=6/50 cls=0.3286 domain=0.6917 val=0.2918 val_f1=0.8855 alpha=0.5370
# DANN seed=42:  14%|█████████▊                                                            | 7/50 
alpha=0.9959
# DANN seed=42:  64%|████████████████████████████████████████████▏                        | 32/50 [16:36<08:51, 29.54s/it]
#       epoch=32/50 cls=0.1239 domain=0.6930 val=0.1017 val_f1=0.9649 alpha=0.9967
# DANN seed=42:  66%|█████████████████████████████████████████████▌                       | 33/50 [17:06<08:21, 29.49s/it]
#       epoch=33/50 cls=0.1214 domain=0.6930 val=0.1022 val_f1=0.9648 alpha=0.9973
# DANN seed=42:  68%|██████████████████████████████████████████████▉                      | 34/50 [17:34<07:46, 29.14s/it]
#       epoch=34/50 cls=0.1180 domain=0.6930 val=0.0981 val_f1=0.9661 alpha=0.9978
# DANN seed=42:  70%|████████████████████████████████████████████████▎                    | 35/50 [18:03<07:17, 29.14s/it]
#       epoch=35/50 cls=0.1162 domain=0.6930 val=0.0948 val_f1=0.9670 alpha=0.9982
# DANN seed=42:  72%|█████████████████████████████████████████████████▋                   | 36/50 [18:32<06:48, 29.16s/it]
#       epoch=36/50 cls=0.1130 domain=0.6930 val=0.0966 val_f1=0.9665 alpha=0.9985
# DANN seed=42:  74%|███████████████████████████████████████████████████                  | 37/50 [19:02<06:19, 29.19s/it]
#       epoch=37/50 cls=0.1119 domain=0.6930 val=0.0929 val_f1=0.9682 alpha=0.9988
# DANN seed=42:  76%|████████████████████████████████████████████████████▍                | 38/50 [19:31<05:49, 29.14s/it]
#       epoch=38/50 cls=0.1088 domain=0.6930 val=0.0914 val_f1=0.9687 alpha=0.9990
# DANN seed=42:  78%|█████████████████████████████████████████████████████▊               | 39/50 [20:00<05:20, 29.13s/it]
#       epoch=39/50 cls=0.1071 domain=0.6930 val=0.0919 val_f1=0.9687 alpha=0.9992
# DANN seed=42:  80%|███████████████████████████████████████████████████████▏             | 40/50 [20:29<04:53, 29.31s/it]
#       epoch=40/50 cls=0.1055 domain=0.6930 val=0.0985 val_f1=0.9663 alpha=0.9993
# DANN seed=42:  82%|████████████████████████████████████████████████████████▌            | 41/50 [20:58<04:23, 29.24s/it]
#       epoch=41/50 cls=0.1027 domain=0.6930 val=0.0887 val_f1=0.9698 alpha=0.9995
# DANN seed=42:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [21:28<03:53, 29.22s/it]
#       epoch=42/50 cls=0.1016 domain=0.6930 val=0.0869 val_f1=0.9699 alpha=0.9996
# DANN seed=42:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [21:56<03:23, 29.05s/it]
#       epoch=43/50 cls=0.0996 domain=0.6930 val=0.0881 val_f1=0.9701 alpha=0.9996
# DANN seed=42:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [22:31<03:03, 30.61s/it]
#       epoch=44/50 cls=0.0973 domain=0.6930 val=0.0847 val_f1=0.9714 alpha=0.9997
# DANN seed=42:  90%|██████████████████████████████████████████████████████████████       | 45/50 [22:58<02:28, 29.74s/it]
#       epoch=45/50 cls=0.0960 domain=0.6930 val=0.0816 val_f1=0.9721 alpha=0.9998
# DANN seed=42:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [23:22<01:51, 27.92s/it]
#       epoch=46/50 cls=0.0949 domain=0.6930 val=0.0809 val_f1=0.9726 alpha=0.9998
# DANN seed=42:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [23:46<01:19, 26.65s/it]
#       epoch=47/50 cls=0.0926 domain=0.6930 val=0.0808 val_f1=0.9720 alpha=0.9998
# DANN seed=42:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [24:08<00:51, 25.51s/it]
#       epoch=48/50 cls=0.0917 domain=0.6930 val=0.0801 val_f1=0.9734 alpha=0.9999
# DANN seed=42:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [24:32<00:24, 24.85s/it]
#       epoch=49/50 cls=0.0903 domain=0.6929 val=0.0806 val_f1=0.9726 alpha=0.9999
#       epoch=50/50 cls=0.0889 domain=0.6930 val=0.0797 val_f1=0.9726 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/vim/run_01/confusion_matrix.png
#       Saved run 1 to results/smote_oversampling/vim/run_01
#
#       Run 2/3
# DANN seed=43:   2%|█▍                                                                    | 1/50 [00:22<18:42, 22.90s/it]
#       epoch=1/50 cls=0.5350 domain=0.6849 val=0.4731 val_f1=0.7834 alpha=0.0996
# DANN seed=43:   4%|██▊                                                                   | 2/50 [00:45<18:17, 22.86s/it]
#       epoch=2/50 cls=0.4553 domain=0.6875 val=0.4176 val_f1=0.8198 alpha=0.1974
# DANN seed=43:   6%|████▏                                                                 | 3/50 [01:08<17:57, 22.92s/it]
#       epoch=3/50 cls=0.4133 domain=0.6899 val=0.3790 val_f1=0.8412 alpha=0.2913
# DANN seed=43:   8%|█████▌                                                                | 4/50 [01:31<17:32, 22.87s/it]
#       epoch=4/50 cls=0.3829 domain=0.6916 val=0.3483 val_f1=0.8590 alpha=0.3799
# DANN seed=43:  10%|███████                                                               | 5/50 
alpha=0.9926
# DANN seed=43:  58%|████████████████████████████████████████                             | 29/50 [11:05<08:03, 23.02s/it]
#       epoch=29/50 cls=0.1350 domain=0.6929 val=0.1160 val_f1=0.9590 alpha=0.9940
# DANN seed=43:  60%|█████████████████████████████████████████▍                           | 30/50 [11:28<07:39, 22.96s/it]
#       epoch=30/50 cls=0.1307 domain=0.6929 val=0.1103 val_f1=0.9610 alpha=0.9951
# DANN seed=43:  62%|██████████████████████████████████████████▊                          | 31/50 [11:51<07:16, 22.96s/it]
#       epoch=31/50 cls=0.1284 domain=0.6929 val=0.1037 val_f1=0.9633 alpha=0.9959
# DANN seed=43:  64%|████████████████████████████████████████████▏                        | 32/50 [12:14<06:53, 22.99s/it]
#       epoch=32/50 cls=0.1258 domain=0.6930 val=0.1014 val_f1=0.9645 alpha=0.9967
# DANN seed=43:  66%|█████████████████████████████████████████████▌                       | 33/50 [12:36<06:29, 22.90s/it]
#       epoch=33/50 cls=0.1220 domain=0.6929 val=0.1000 val_f1=0.9646 alpha=0.9973
# DANN seed=43:  68%|██████████████████████████████████████████████▉                      | 34/50 [12:59<06:06, 22.89s/it]
#       epoch=34/50 cls=0.1194 domain=0.6929 val=0.0960 val_f1=0.9664 alpha=0.9978
# DANN seed=43:  70%|████████████████████████████████████████████████▎                    | 35/50 [13:23<05:44, 22.99s/it]
#       epoch=35/50 cls=0.1172 domain=0.6929 val=0.0948 val_f1=0.9673 alpha=0.9982
# DANN seed=43:  72%|█████████████████████████████████████████████████▋                   | 36/50 [13:46<05:22, 23.02s/it]
#       epoch=36/50 cls=0.1147 domain=0.6929 val=0.0924 val_f1=0.9673 alpha=0.9985
# DANN seed=43:  74%|███████████████████████████████████████████████████                  | 37/50 [14:09<04:59, 23.03s/it]
#       epoch=37/50 cls=0.1117 domain=0.6929 val=0.1004 val_f1=0.9652 alpha=0.9988
# DANN seed=43:  76%|████████████████████████████████████████████████████▍                | 38/50 [14:31<04:35, 22.93s/it]
#       epoch=38/50 cls=0.1097 domain=0.6929 val=0.0961 val_f1=0.9663 alpha=0.9990
# DANN seed=43:  78%|█████████████████████████████████████████████████████▊               | 39/50 [14:54<04:12, 22.93s/it]
#       epoch=39/50 cls=0.1084 domain=0.6929 val=0.0929 val_f1=0.9674 alpha=0.9992
# DANN seed=43:  80%|███████████████████████████████████████████████████████▏             | 40/50 [15:17<03:49, 22.99s/it]
#       epoch=40/50 cls=0.1064 domain=0.6929 val=0.0873 val_f1=0.9699 alpha=0.9993
# DANN seed=43:  82%|████████████████████████████████████████████████████████▌            | 41/50 [15:40<03:26, 22.99s/it]
#       epoch=41/50 cls=0.1040 domain=0.6929 val=0.0846 val_f1=0.9704 alpha=0.9995
# DANN seed=43:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [16:04<03:04, 23.07s/it]
#       epoch=42/50 cls=0.1017 domain=0.6929 val=0.0822 val_f1=0.9715 alpha=0.9996
# DANN seed=43:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [16:27<02:41, 23.03s/it]
#       epoch=43/50 cls=0.0997 domain=0.6929 val=0.0856 val_f1=0.9706 alpha=0.9996
# DANN seed=43:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [16:49<02:17, 22.96s/it]
#       epoch=44/50 cls=0.0982 domain=0.6929 val=0.0830 val_f1=0.9714 alpha=0.9997
# DANN seed=43:  90%|██████████████████████████████████████████████████████████████       | 45/50 [17:14<01:57, 23.47s/it]
#       epoch=45/50 cls=0.0966 domain=0.6930 val=0.0834 val_f1=0.9713 alpha=0.9998
# DANN seed=43:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [17:37<01:33, 23.31s/it]
#       epoch=46/50 cls=0.0942 domain=0.6929 val=0.0792 val_f1=0.9732 alpha=0.9998
# DANN seed=43:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [18:00<01:09, 23.20s/it]
#       epoch=47/50 cls=0.0933 domain=0.6929 val=0.0794 val_f1=0.9720 alpha=0.9998
# DANN seed=43:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [18:23<00:46, 23.14s/it]
#       epoch=48/50 cls=0.0923 domain=0.6929 val=0.0791 val_f1=0.9731 alpha=0.9999
# DANN seed=43:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [18:46<00:23, 23.11s/it]
#       epoch=49/50 cls=0.0910 domain=0.6929 val=0.0774 val_f1=0.9737 alpha=0.9999
#       epoch=50/50 cls=0.0897 domain=0.6929 val=0.0749 val_f1=0.9745 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/vim/run_02/confusion_matrix.png
#       Saved run 2 to results/smote_oversampling/vim/run_02
#
#       Run 3/3
# DANN seed=44:   2%|█▍                                                                    | 1/50 [00:23<19:26, 23.80s/it]
#       epoch=1/50 cls=0.5350 domain=0.6862 val=0.4704 val_f1=0.7883 alpha=0.0996
# DANN seed=44:   4%|██▊                                                                   | 2/50 [00:47<18:49, 23.53s/it]
#       epoch=2/50 cls=0.4511 domain=0.6887 val=0.4126 val_f1=0.8237 alpha=0.1974
# DANN seed=44:   6%|████▏                                                                 | 3/50 [01:09<18:11, 23.22s/it]
#       epoch=3/50 cls=0.4095 domain=0.6903 val=0.3745 val_f1=0.8447 alpha=0.2913
# DANN seed=44:   8%|█████▌                                                                | 4/50 [01:33<17:53, 23.33s/it]
#       epoch=4/50 cls=0.3791 domain=0.6909 val=0.3421 val_f1=0.8600 alpha=0.3799
# DANN seed=44:  10%|███████                                                               | 5/50 [01:56<17:23, 23.18s/it]
#       epoch=5/50 cls=0.3516 domain=0.6924 val=0.3147 val_f1=0.8729 alpha=0.4621
# DANN seed=44:  12%|████████▍                                                             | 6/50 [02:19<16:54, 23.06s/it]
#       epoch=6/50 cls=0.3286 domain=0.6921 val=0.2905 val_f1=0.8850 alpha=0.5370
# DANN seed=44:  14%|█████████▊                                                            | 7/50 [02:41<16:26, 22.95s/it]
#       epoch=7/50 cls=0.3073 domain=0.6917 val=0.2687 val_f1=0.8944 alpha=0.6044
# DANN seed=44:  16%|███████████▏                                                          | 8/50 [03:04<16:00, 22.86s/it]
#       epoch=8/50 cls=0.2893 domain=0.6917 val=0.2502 val_f1=0.9032 alpha=0.6640
# DANN seed=44:  18%|████████████▌                                                         | 9/50 [03:27<15:37, 22.87s/it]
#       epoch=9/50 cls=0.2727 domain=0.6918 val=0.2371 val_f1=0.9086 alpha=0.7163
# DANN seed=44:  20%|█████████████▊                                                       | 10/50 [03:50<15:12, 22.81s/it]
#       epoch=10/50 cls=0.2590 domain=0.6918 val=0.2201 val_f1=0.9164 alpha=0.7616
# DANN seed=44:  22%|███████████████▏                                                     | 11/50 [04:12<14:47, 22.76s/it]
#       epoch=11/50 cls=0.2462 domain=0.6919 val=0.2088 val_f1=0.9206 alpha=0.8005
# DANN seed=44:  24%|████████████████▌                                                    | 12/50 [04:35<14:26, 22.81s/it]
#       epoch=12/50 cls=0.2342 domain=0.6922 val=0.1975 val_f1=0.9257 alpha=0.8337
# DANN seed=44:  26%|█████████████████▉                                                   | 13/50 [04:58<14:04, 22.82s/it]
#       epoch=13/50 cls=0.2237 domain=0.6924 val=0.1883 val_f1=0.9301 alpha=0.8617
# DANN seed=44:  28%|███████████████████▎                                                 | 14/50 [05:21<13:41, 22.82s/it]
#       epoch=14/50 cls=0.2149 domain=0.6926 val=0.1796 val_f1=0.9328 alpha=0.8853
# DANN seed=44:  30%|████████████████████▋                                                | 15/50 [05:43<13:15, 22.73s/it]
#       epoch=15/50 cls=0.2059 domain=0.6927 val=0.1705 val_f1=0.9367 alpha=0.9051
# DANN seed=44:  32%|██████████████████████                                               | 16/50 [06:06<12:53, 22.75s/it]
#       epoch=16/50 cls=0.1978 domain=0.6929 val=0.1689 val_f1=0.9374 alpha=0.9217
# DANN seed=44:  34%|███████████████████████▍                                             | 17/50 [06:30<12:39, 23.03s/it]
#       epoch=17/50 cls=0.1915 domain=0.6930 val=0.1589 val_f1=0.9412 alpha=0.9354
# DANN seed=44:  36%|████████████████████████▊                                            | 18/50 [06:53<12:15, 22.99s/it]
#       epoch=18/50 cls=0.1837 domain=0.6930 val=0.1520 val_f1=0.9448 alpha=0.9468
# DANN seed=44:  38%|██████████████████████████▏                                          | 19/50 [07:16<11:50, 22.90s/it]
#       epoch=19/50 cls=0.1775 domain=0.6930 val=0.1465 val_f1=0.9473 alpha=0.9562
# DANN seed=44:  40%|███████████████████████████▌                                         | 20/50 [07:38<11:26, 22.87s/it]
#       epoch=20/50 cls=0.1699 domain=0.6930 val=0.1469 val_f1=0.9456 alpha=0.9640
# DANN seed=44:  42%|████████████████████████████▉                                        | 21/50 [08:01<11:02, 22.85s/it]
#       epoch=21/50 cls=0.1657 domain=0.6929 val=0.1375 val_f1=0.9497 alpha=0.9705
# DANN seed=44:  44%|██████████████████████████████▎                                      | 22/50 [08:24<10:41, 22.89s/it]
#       epoch=22/50 cls=0.1601 domain=0.6929 val=0.1311 val_f1=0.9530 alpha=0.9757
# DANN seed=44:  46%|███████████████████████████████▋                                     | 23/50 [08:47<10:18, 22.89s/it]
#       epoch=23/50 cls=0.1548 domain=0.6929 val=0.1287 val_f1=0.9538 alpha=0.9801
# DANN seed=44:  48%|█████████████████████████████████                                    | 24/50 [09:10<09:55, 22.91s/it]
#       epoch=24/50 cls=0.1497 domain=0.6929 val=0.1238 val_f1=0.9551 alpha=0.9837
# DANN seed=44:  50%|██████████████████████████████████▌                                  | 25/50 [09:33<09:34, 22.98s/it]
#       epoch=25/50 cls=0.1466 domain=0.6928 val=0.1200 val_f1=0.9580 alpha=0.9866
# DANN seed=44:  52%|███████████████████████████████████▉                                 | 26/50 [09:56<09:12, 23.02s/it]
#       epoch=26/50 cls=0.1416 domain=0.6929 val=0.1160 val_f1=0.9587 alpha=0.9890
# DANN seed=44:  54%|█████████████████████████████████████▎                               | 27/50 [10:19<08:49, 23.01s/it]
#       epoch=27/50 cls=0.1384 domain=0.6929 val=0.1136 val_f1=0.9597 alpha=0.9910
# DANN seed=44:  56%|██████████████████████████████████████▋                              | 28/50 [10:42<08:25, 22.97s/it]
#       epoch=28/50 cls=0.1343 domain=0.6929 val=0.1170 val_f1=0.9584 alpha=0.9926
# DANN seed=44:  58%|████████████████████████████████████████                             | 29/50 [11:05<08:02, 22.96s/it]
#       epoch=29/50 cls=0.1316 domain=0.6929 val=0.1100 val_f1=0.9614 alpha=0.9940
# DANN seed=44:  60%|█████████████████████████████████████████▍                           | 30/50 [11:28<07:37, 22.86s/it]
#       epoch=30/50 cls=0.1272 domain=0.6929 val=0.1070 val_f1=0.9624 alpha=0.9951
# DANN seed=44:  62%|██████████████████████████████████████████▊                          | 31/50 [11:51<07:18, 23.07s/it]
#       epoch=31/50 cls=0.1247 domain=0.6930 val=0.1067 val_f1=0.9620 alpha=0.9959
# DANN seed=44:  64%|████████████████████████████████████████████▏                        | 32/50 [12:14<06:53, 23.00s/it]
#       epoch=32/50 cls=0.1215 domain=0.6929 val=0.1050 val_f1=0.9618 alpha=0.9967
# DANN seed=44:  66%|█████████████████████████████████████████████▌                       | 33/50 [12:37<06:30, 22.96s/it]
#       epoch=33/50 cls=0.1181 domain=0.6929 val=0.1050 val_f1=0.9631 alpha=0.9973
# DANN seed=44:  68%|██████████████████████████████████████████████▉                      | 34/50 [13:00<06:06, 22.92s/it]
#       epoch=34/50 cls=0.1168 domain=0.6930 val=0.0986 val_f1=0.9660 alpha=0.9978
# DANN seed=44:  70%|████████████████████████████████████████████████▎                    | 35/50 [13:23<05:43, 22.88s/it]
#       epoch=35/50 cls=0.1136 domain=0.6929 val=0.0973 val_f1=0.9662 alpha=0.9982
# DANN seed=44:  72%|█████████████████████████████████████████████████▋                   | 36/50 [13:45<05:20, 22.87s/it]
#       epoch=36/50 cls=0.1109 domain=0.6929 val=0.0943 val_f1=0.9672 alpha=0.9985
# DANN seed=44:  74%|███████████████████████████████████████████████████                  | 37/50 [14:08<04:57, 22.89s/it]
#       epoch=37/50 cls=0.1091 domain=0.6930 val=0.0929 val_f1=0.9677 alpha=0.9988
# DANN seed=44:  76%|████████████████████████████████████████████████████▍                | 38/50 [14:31<04:34, 22.90s/it]
#       epoch=38/50 cls=0.1070 domain=0.6930 val=0.0897 val_f1=0.9690 alpha=0.9990
# DANN seed=44:  78%|█████████████████████████████████████████████████████▊               | 39/50 [14:54<04:12, 22.92s/it]
#       epoch=39/50 cls=0.1052 domain=0.6930 val=0.0883 val_f1=0.9697 alpha=0.9992
# DANN seed=44:  80%|███████████████████████████████████████████████████████▏             | 40/50 [15:17<03:48, 22.88s/it]
#       epoch=40/50 cls=0.1025 domain=0.6929 val=0.0862 val_f1=0.9701 alpha=0.9993
# DANN seed=44:  82%|████████████████████████████████████████████████████████▌            | 41/50 [15:40<03:26, 22.93s/it]
#       epoch=41/50 cls=0.1011 domain=0.6930 val=0.0852 val_f1=0.9703 alpha=0.9995
# DANN seed=44:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [16:03<03:03, 22.90s/it]
#       epoch=42/50 cls=0.0988 domain=0.6930 val=0.0852 val_f1=0.9707 alpha=0.9996
# DANN seed=44:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [16:26<02:40, 22.92s/it]
#       epoch=43/50 cls=0.0979 domain=0.6930 val=0.0860 val_f1=0.9709 alpha=0.9996
# DANN seed=44:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [16:49<02:17, 22.99s/it]
#       epoch=44/50 cls=0.0964 domain=0.6930 val=0.0819 val_f1=0.9718 alpha=0.9997
# DANN seed=44:  90%|██████████████████████████████████████████████████████████████       | 45/50 [17:13<01:56, 23.26s/it]
#       epoch=45/50 cls=0.0941 domain=0.6930 val=0.0824 val_f1=0.9718 alpha=0.9998
# DANN seed=44:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [17:36<01:33, 23.38s/it]
#       epoch=46/50 cls=0.0926 domain=0.6930 val=0.0789 val_f1=0.9724 alpha=0.9998
# DANN seed=44:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [17:59<01:09, 23.17s/it]
#       epoch=47/50 cls=0.0917 domain=0.6930 val=0.0785 val_f1=0.9731 alpha=0.9998
# DANN seed=44:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [18:23<00:46, 23.21s/it]
#       epoch=48/50 cls=0.0896 domain=0.6930 val=0.0795 val_f1=0.9730 alpha=0.9999
# DANN seed=44:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [18:46<00:23, 23.22s/it]
#       epoch=49/50 cls=0.0889 domain=0.6930 val=0.0772 val_f1=0.9737 alpha=0.9999
#       epoch=50/50 cls=0.0864 domain=0.6930 val=0.0769 val_f1=0.9737 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/vim/run_03/confusion_matrix.png
#       Saved run 3 to results/smote_oversampling/vim/run_03
#
# Aggregating ensemble results...
# Confusion matrix saved as results/smote_oversampling/vim/confusion_matrix_dann_xgboost_vim_smote.png
#
# === Ensemble Evaluation Results (vim Test Set, SMOTE) ===
# Accuracy:   0.533
# Precision:  0.064
# Recall:     0.925
# F1-score:   0.120
# ROC-AUC:    0.809
# PR-AUC:     0.110
# G-mean:     0.693
# PF value:   0.481
#
# Results saved to results/smote_oversampling/vim/dann_xgboost_vim_smote.json
# Confusion matrix saved to results/smote_oversampling/vim/confusion_matrix_dann_xgboost_vim_smote.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
DANN Domain Adaptation, SMOTE oversampling
"""

import json
import math
import random
import traceback
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, average_precision_score, confusion_matrix,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from xgboost import XGBClassifier

# =========================================================
# Config
# =========================================================
SEED            = 42
TEST_PROJS      = "FFmpeg"
COMBINED_FILE   = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY         = "emb"
OUTPUT_ROOT     = "results/smote_oversampling"

DANN_EPOCHS            = 50
DANN_BATCH_SIZE        = 64
LEARNING_RATE          = 1e-5
DOMAIN_LOSS_WEIGHT_MAX = 1.0
VALIDATION_SIZE        = 0.2
NUM_RUNS               = 3
THRESHOLD              = 0.5
METHOD_VERSION         = "dann_xgboost_smote_v1"
SMOTE_K_NEIGHBORS      = 5

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
elif torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
else:
    DEVICE = "cpu"


def now_utc():
    return datetime.now(timezone.utc).isoformat()


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)


def atomic_json_dump(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, allow_nan=False)
        f.flush()
    tmp.replace(path)


def load_jsonl(path):
    embeddings, labels, projects, sample_ids = [], [], [], []
    with open(path, "r", encoding="utf-8") as f:
        for row_number, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            embeddings.append(record[EMB_KEY])
            labels.append(record["target"])
            projects.append(record["project"])
            sample_ids.append(str(record.get("idx", row_number)))
    return (np.asarray(embeddings, dtype=np.float32),
            np.asarray(labels, dtype=np.int32),
            np.asarray(projects, dtype=object),
            np.asarray(sample_ids, dtype=str))


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Architecture: 64-dim bottleneck FeatureExtractor + linear ClassifierHead
# + DomainDiscriminator
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
        )

    def forward(self, x):
        return self.network(x)  # 64-dim domain-invariant features


class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Linear(feature_dim, 1)

    def forward(self, features):
        return self.network(features).squeeze(-1)


class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=64):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
        )

    def forward(self, features):
        return self.network(features).squeeze(-1)


# =========================================================
# SMOTE oversampling on the source pool
# =========================================================
def apply_smote(X_source, y_source, seed):
    smote = SMOTE(random_state=seed, k_neighbors=SMOTE_K_NEIGHBORS)
    X_res, y_res = smote.fit_resample(X_source, y_source)
    return X_res.astype(np.float32), y_res.astype(np.int32)


# =========================================================
# DANN training
# =========================================================
def train_dann(x_source, y_source, x_target, seed):
    set_seed(seed)
    stratify = y_source if len(np.unique(y_source)) > 1 else None
    x_train, x_val, y_train, y_val = train_test_split(
        x_source, y_source,
        test_size=VALIDATION_SIZE,
        random_state=seed,
        stratify=stratify,
    )

    feature_extractor = FeatureExtractor(x_source.shape[1]).to(DEVICE)
    classifier         = ClassifierHead(feature_dim=64).to(DEVICE)
    discriminator      = DomainDiscriminator(feature_dim=64).to(DEVICE)
    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier.parameters()) +
              list(discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=LEARNING_RATE)

    classification_loss_fn = nn.BCEWithLogitsLoss()
    domain_loss_fn = nn.BCEWithLogitsLoss()

    source_dataset = TensorDataset(
        torch.tensor(x_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    target_dataset = TensorDataset(torch.tensor(x_target, dtype=torch.float32))
    source_loader = DataLoader(source_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)
    target_loader = DataLoader(target_dataset, batch_size=DANN_BATCH_SIZE, shuffle=True)

    x_val_t = torch.tensor(x_val, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32, device=DEVICE)

    total_steps = max(1, DANN_EPOCHS * len(source_loader) - 1)
    global_step = 0
    history = []

    for epoch in tqdm(range(DANN_EPOCHS), desc=f"DANN seed={seed}", leave=False):
        feature_extractor.train()
        classifier.train()
        discriminator.train()

        target_iter = iter(target_loader)
        classification_losses, domain_losses = [], []

        for xs_batch, ys_batch in source_loader:
            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            progress = global_step / total_steps
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + math.exp(-10.0 * progress)) - 1.0)

            optimizer.zero_grad(set_to_none=True)

            source_features = feature_extractor(xs_batch)
            target_features = feature_extractor(xt_batch)

            vulnerability_logits = classifier(source_features)
            classification_loss = classification_loss_fn(vulnerability_logits, ys_batch)

            source_domain_logits = discriminator(grl(source_features, alpha))
            target_domain_logits = discriminator(grl(target_features, alpha))
            source_domain_labels = torch.zeros(source_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)
            target_domain_labels = torch.ones(target_domain_logits.shape[0], dtype=torch.float32, device=DEVICE)

            source_domain_loss = domain_loss_fn(source_domain_logits, source_domain_labels)
            target_domain_loss = domain_loss_fn(target_domain_logits, target_domain_labels)
            domain_loss = 0.5 * (source_domain_loss + target_domain_loss)

            loss = classification_loss + domain_loss
            loss.backward()
            optimizer.step()

            classification_losses.append(classification_loss.item())
            domain_losses.append(domain_loss.item())
            global_step += 1

        feature_extractor.eval()
        classifier.eval()
        discriminator.eval()
        with torch.no_grad():
            val_logits = classifier(feature_extractor(x_val_t))
            val_loss = classification_loss_fn(val_logits, y_val_t).item()
            val_prob = torch.sigmoid(val_logits)
            val_pred = (val_prob >= THRESHOLD).long().cpu().numpy()
            val_f1 = f1_score(y_val, val_pred, zero_division=0)

        epoch_result = {
            "epoch": epoch + 1,
            "classification_loss": float(np.mean(classification_losses)),
            "domain_loss": float(np.mean(domain_losses)),
            "source_validation_loss": float(val_loss),
            "source_validation_f1": float(val_f1),
            "grl_alpha": float(alpha),
        }
        history.append(epoch_result)
        print(f"      epoch={epoch + 1}/{DANN_EPOCHS} "
              f"cls={epoch_result['classification_loss']:.4f} "
              f"domain={epoch_result['domain_loss']:.4f} "
              f"val={val_loss:.4f} val_f1={val_f1:.4f} alpha={alpha:.4f}")

    return feature_extractor, classifier, discriminator, history


# =========================================================
# XGBoost trained on DANN's extracted (domain-invariant) features
# =========================================================
def extract_features(feature_extractor, X, batch_size=256):
    feature_extractor.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            outputs.append(feature_extractor(x_batch).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty((0, 64), dtype=np.float32)


def classifier_probabilities(feature_extractor, classifier, X, batch_size=256):
    feature_extractor.eval()
    classifier.eval()
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    with torch.no_grad():
        for (x_batch,) in loader:
            x_batch = x_batch.to(DEVICE)
            logits = classifier(feature_extractor(x_batch))
            outputs.append(torch.sigmoid(logits).cpu().numpy())
    return np.concatenate(outputs) if outputs else np.empty(0, dtype=np.float32)


def train_xgboost(x_train_feat, y_train, sample_weights, seed):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric="logloss",
        random_state=seed,
    )
    model.fit(x_train_feat, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Evaluation
# =========================================================
def evaluate(y_true, probabilities):
    predictions = (probabilities >= THRESHOLD).astype(np.int32)
    tn, fp, fn, tp = confusion_matrix(y_true, predictions, labels=[0, 1]).ravel()
    accuracy = accuracy_score(y_true, predictions)
    precision = precision_score(y_true, predictions, zero_division=0)
    recall = recall_score(y_true, predictions, zero_division=0)
    f1 = f1_score(y_true, predictions, zero_division=0)
    roc_auc = roc_auc_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    pr_auc = average_precision_score(y_true, probabilities) if len(np.unique(y_true)) > 1 else None
    tpr = tp / (tp + fn) if tp + fn else 0.0
    tnr = tn / (tn + fp) if tn + fp else 0.0
    g_mean = math.sqrt(tpr * tnr)
    pf = fp / (fp + tn) if fp + tn else 0.0
    metrics = {
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall),
        "f1": float(f1),
        "roc_auc": None if roc_auc is None else float(roc_auc),
        "pr_auc": None if pr_auc is None else float(pr_auc),
        "g_mean": float(g_mean),
        "pf": float(pf),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)},
    }
    return metrics, predictions


def save_confusion_matrix(metrics, path, title="Confusion Matrix (FFmpeg Test Set) - DANN + XGBoost (SMOTE)", show=False):
    cm_values = metrics["confusion_matrix"]
    cm = np.asarray([[cm_values["tn"], cm_values["fp"]], [cm_values["fn"], cm_values["tp"]]])
    fig, ax = plt.subplots(figsize=(6, 5))
    image = ax.imshow(cm, interpolation="nearest")
    ax.set_title(title)
    plt.colorbar(image, ax=ax)
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])
    thresh = cm.max() / 2 if cm.max() else 0
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, int(cm[i, j]), ha="center", va="center", color=color)
    ax.set_ylabel("Actual Label"); ax.set_xlabel("Predicted Label")
    fig.tight_layout()
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300)
    if show:
        plt.show()
    plt.close(fig)
    print(f"Confusion matrix saved as {path}")


def cpu_state_dict(module):
    return {key: value.detach().cpu() for key, value in module.state_dict().items()}


# =========================================================
# Single run: one DANN training + one XGBoost fit
# =========================================================
def run_single(run_number, X_source_smote, y_source_smote, X_target, y_target, scaler, output_dir):
    seed = SEED + run_number - 1
    run_dir = Path(output_dir) / f"run_{run_number:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)
    started_at = now_utc()

    feature_extractor, classifier, discriminator, history = train_dann(
        X_source_smote, y_source_smote, X_target, seed
    )

    # Extract domain-invariant features for the (SMOTE-balanced) train set + target
    train_features = extract_features(feature_extractor, X_source_smote)
    target_features = extract_features(feature_extractor, X_target)

    # Confidence-based sample weights from the DANN's own classifier head
    train_probs = classifier_probabilities(feature_extractor, classifier, X_source_smote)
    sample_weights = np.where(y_source_smote == 1, train_probs, 1 - train_probs)

    model_xgb = train_xgboost(train_features, y_source_smote, sample_weights, seed)
    probabilities = model_xgb.predict_proba(target_features)[:, 1]

    metrics, predictions = evaluate(y_target, probabilities)
    finished_at = now_utc()

    result = {
        "method_version": METHOD_VERSION,
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "run": run_number,
        "seed": seed,
        "final_classifier": "XGBoost on DANN-extracted features",
        "n_source_samples_smote": int(len(y_source_smote)),
        "n_source_vulnerable_smote": int(y_source_smote.sum()),
        "n_target_samples": int(len(y_target)),
        "n_target_vulnerable": int(y_target.sum()),
        "threshold": THRESHOLD,
        "metrics": metrics,
        "training_history": history,
        "started_at": started_at,
        "finished_at": finished_at,
    }
    atomic_json_dump(result, run_dir / "result.json")
    np.savez_compressed(
        run_dir / "predictions.npz",
        target=y_target, probability=probabilities, prediction=predictions
    )
    torch.save(
        {
            "method_version": METHOD_VERSION,
            "project": TEST_PROJS,
            "run": run_number,
            "seed": seed,
            "feature_extractor": cpu_state_dict(feature_extractor),
            "classifier": cpu_state_dict(classifier),
            "domain_discriminator": cpu_state_dict(discriminator),
            "scaler_mean": scaler.mean_,
            "scaler_scale": scaler.scale_,
            "threshold": THRESHOLD,
        },
        run_dir / "model.pt",
    )
    save_confusion_matrix(metrics, run_dir / "confusion_matrix.png")
    print(f"      Saved run {run_number} to {run_dir}")

    del feature_extractor, classifier, discriminator, model_xgb
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE == "mps":
        torch.mps.empty_cache()

    return result


# =========================================================
# Ensemble aggregation
# =========================================================
def aggregate_ensemble(run_results, output_dir, y_target):
    prob_arrays = []
    for r in run_results:
        npz_path = Path(output_dir) / f"run_{r['run']:02d}" / "predictions.npz"
        data = np.load(npz_path)
        prob_arrays.append(data["probability"])

    ensemble_probability = np.mean(np.stack(prob_arrays, axis=0), axis=0)
    ensemble_metrics, ensemble_predictions = evaluate(y_target, ensemble_probability)

    per_run_metric_names = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", "g_mean", "pf"]
    per_run_summary = {}
    for metric in per_run_metric_names:
        values = [r["metrics"][metric] for r in run_results if r["metrics"][metric] is not None]
        per_run_summary[metric] = {
            "mean": float(np.mean(values)) if values else None,
            "std": float(np.std(values, ddof=1)) if len(values) > 1 else (0.0 if values else None),
        }

    return {
        "method_version": METHOD_VERSION,
        "method": "DANN + XGBoost",
        "oversampling_method": "SMOTE",
        "project": TEST_PROJS,
        "train": f"all_except_{TEST_PROJS}",
        "num_completed_runs": len(run_results),
        "ensemble_metrics": ensemble_metrics,
        "per_run_metric_summary": per_run_summary,
        "runs": run_results,
        "updated_at": now_utc(),
    }, ensemble_predictions


# =========================================================
# Main
# =========================================================
def main():
    output_dir = Path(OUTPUT_ROOT) / TEST_PROJS
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Device: {DEVICE}")
    print(f"Method: {METHOD_VERSION}")
    print(f"LOPO target project: {TEST_PROJS}")
    print(f"Dataset: {COMBINED_FILE}")

    print("\n[1/4] Loading embeddings...")
    X_all, y_all, projects_all, ids_all = load_jsonl(COMBINED_FILE)
    print(f"      Loaded {len(y_all)} samples from {len(set(projects_all.tolist()))} projects")

    source_mask = projects_all != TEST_PROJS
    target_mask = projects_all == TEST_PROJS
    if not target_mask.any():
        raise ValueError(f"No samples found for target project '{TEST_PROJS}'.")

    X_source = X_all[source_mask].astype(np.float32)
    y_source = y_all[source_mask].astype(np.int32)
    X_target = X_all[target_mask].astype(np.float32)
    y_target = y_all[target_mask].astype(np.int32)

    if len(np.unique(y_source)) < 2:
        raise ValueError(f"Source pool for {TEST_PROJS} does not contain both classes.")

    source_projects = len(set(projects_all[source_mask].tolist()))
    print(f"      Source projects: {source_projects}")
    print(f"      Source (pre-SMOTE): {X_source.shape} vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    print(f"      Target ({TEST_PROJS}): {X_target.shape} vulnerable={int(y_target.sum())} benign={int((y_target == 0).sum())}")

    print("\n[2/4] Normalizing embeddings...")
    scaler = StandardScaler()
    X_source = scaler.fit_transform(X_source).astype(np.float32)
    X_target = scaler.transform(X_target).astype(np.float32)

    print("\n[3/4] Applying SMOTE oversampling to the source pool...")
    print(f"      Before SMOTE: vulnerable={int(y_source.sum())} benign={int((y_source == 0).sum())}")
    X_source_smote, y_source_smote = apply_smote(X_source, y_source, SEED)
    print(f"      After  SMOTE: vulnerable={int(y_source_smote.sum())} benign={int((y_source_smote == 0).sum())}")

    print("\n[4/4] Running DANN + XGBoost ensemble runs...")
    run_results = []
    for run_number in range(1, NUM_RUNS + 1):
        print(f"\n      Run {run_number}/{NUM_RUNS}")
        try:
            result = run_single(run_number, X_source_smote, y_source_smote, X_target, y_target,
                                 scaler, output_dir)
            run_results.append(result)
        except Exception as exc:
            print(f"      [RUN FAILED] run {run_number}: {exc}")
            traceback.print_exc()
            continue

    if not run_results:
        raise RuntimeError(f"All {NUM_RUNS} runs failed.")

    print("\nAggregating ensemble results...")
    ensemble_summary, ensemble_predictions = aggregate_ensemble(run_results, output_dir, y_target)
    atomic_json_dump(ensemble_summary, output_dir / f"dann_xgboost_{TEST_PROJS}_smote.json")
    save_confusion_matrix(ensemble_summary["ensemble_metrics"],
                          output_dir / f"confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png",
                          show=True)

    m = ensemble_summary["ensemble_metrics"]
    print(f"\n=== Ensemble Evaluation Results ({TEST_PROJS} Test Set, SMOTE) ===")
    print(f"Accuracy:   {m['accuracy']:.3f}")
    print(f"Precision:  {m['precision']:.3f}")
    print(f"Recall:     {m['recall']:.3f}")
    print(f"F1-score:   {m['f1']:.3f}")
    print(f"ROC-AUC:    {m['roc_auc']:.3f}" if m['roc_auc'] is not None else "ROC-AUC:    N/A")
    print(f"PR-AUC:     {m['pr_auc']:.3f}" if m['pr_auc'] is not None else "PR-AUC:     N/A")
    print(f"G-mean:     {m['g_mean']:.3f}")
    print(f"PF value:   {m['pf']:.3f}")
    print(f"\nResults saved to {output_dir / f'dann_xgboost_{TEST_PROJS}_smote.json'}")
    print(f"Confusion matrix saved to {output_dir / f'confusion_matrix_dann_xgboost_{TEST_PROJS}_smote.png'}")


if __name__ == "__main__":
    main()
# Out:
# Device: mps
# Method: dann_xgboost_smote_v1
# LOPO target project: FFmpeg
# Dataset: ../../../../embedding/primevul/codebert/primevul_embedded.jsonl
#
# [1/4] Loading embeddings...
#       Loaded 224533 samples from 754 projects
#       Source projects: 753
#       Source (pre-SMOTE): (222072, 768) vulnerable=5915 benign=216157
#       Target (FFmpeg): (2461, 768) vulnerable=89 benign=2372
#
# [2/4] Normalizing embeddings...
#
# [3/4] Applying SMOTE oversampling to the source pool...
#       Before SMOTE: vulnerable=5915 benign=216157
#       After  SMOTE: vulnerable=216157 benign=216157
#
# [4/4] Running DANN + XGBoost ensemble runs...
#
#       Run 1/3
# DANN seed=42:   2%|█▍                                                                    | 1/50 [00:24<19:58, 24.46s/it]
#       epoch=1/50 cls=0.5361 domain=0.6927 val=0.4755 val_f1=0.7837 alpha=0.0997
# DANN seed=42:   4%|██▊                                                                   | 2/50 [00:47<18:46, 23.48s/it]
#       epoch=2/50 cls=0.4548 domain=0.6925 val=0.4153 val_f1=0.8212 alpha=0.1974
# DANN seed=42:   6%|████▏                                                                 | 3/50 [01:10<18:13, 23.26s/it]
#       epoch=3/50 cls=0.4123 domain=0.6932 val=0.3759 val_f1=0.8435 alpha=0.2913
# DANN seed=42:   8%|█████▌                                                                | 4/50 [01:33<17:42, 23.10s/it]
#       epoch=4/50 cls=0.3792 domain=0.6936 val=0.3451 val_f1=0.8558 alpha=0.3799
# DANN seed=42:  10%|███████                                                               | 5/50 [01:56<17:20, 23.11s/it]
#       epoch=5/50 cls=0.3512 domain=0.6927 val=0.3140 val_f1=0.8734 alpha=0.4621
# DANN seed=42:  12%|████████▍                                                             | 6/50 [02:19<16:59, 23.18s/it]
#       epoch=6/50 cls=0.3277 domain=0.6928 val=0.2908 val_f1=0.8856 alpha=0.5370
# DANN seed=42:  14%|█████████▊                                                            | 7/50 [02:42<16:34, 23.13s/it]
#       epoch=7/50 cls=0.3063 domain=0.6927 val=0.2688 val_f1=0.8944 alpha=0.6044
# DANN seed=42:  16%|███████████▏                                                          | 8/50 [03:05<16:07, 23.04s/it]
#       epoch=8/50 cls=0.2879 domain=0.6927 val=0.2500 val_f1=0.9030 alpha=0.6640
# DANN seed=42:  18%|████████████▌                                                         | 9/50 [03:28<15:44, 23.04s/it]
#       epoch=9/50 cls=0.2725 domain=0.6924 val=0.2367 val_f1=0.9089 alpha=0.7163
# DANN seed=42:  20%|█████████████▊                                                       | 10/50 [03:51<15:18, 22.96s/it]
#       epoch=10/50 cls=0.2578 domain=0.6924 val=0.2229 val_f1=0.9144 alpha=0.7616
# DANN seed=42:  22%|███████████████▏                                                     | 11/50 [04:14<14:55, 22.97s/it]
#       epoch=11/50 cls=0.2455 domain=0.6924 val=0.2089 val_f1=0.9213 alpha=0.8005
# DANN seed=42:  24%|████████████████▌                                                    | 12/50 [04:37<14:32, 22.96s/it]
#       epoch=12/50 cls=0.2353 domain=0.6925 val=0.2002 val_f1=0.9245 alpha=0.8337
# DANN seed=42:  26%|█████████████████▉                                                   | 13/50 [05:01<14:23, 23.33s/it]
#       epoch=13/50 cls=0.2243 domain=0.6926 val=0.1888 val_f1=0.9296 alpha=0.8617
# DANN seed=42:  28%|███████████████████▎                                                 | 14/50 [05:26<14:23, 23.98s/it]
#       epoch=14/50 cls=0.2155 domain=0.6926 val=0.1812 val_f1=0.9323 alpha=0.8853
# DANN seed=42:  30%|████████████████████▋                                                | 15/50 [05:49<13:49, 23.71s/it]
#       epoch=15/50 cls=0.2066 domain=0.6927 val=0.1800 val_f1=0.9320 alpha=0.9051
# DANN seed=42:  32%|██████████████████████                                               | 16/50 [06:12<13:17, 23.46s/it]
#       epoch=16/50 cls=0.1990 domain=0.6928 val=0.1672 val_f1=0.9387 alpha=0.9217
# DANN seed=42:  34%|███████████████████████▍                                             | 17/50 [06:35<12:49, 23.30s/it]
#       epoch=17/50 cls=0.1919 domain=0.6930 val=0.1605 val_f1=0.9413 alpha=0.9354
# DANN seed=42:  36%|████████████████████████▊                                            | 18/50 [06:58<12:21, 23.16s/it]
#       epoch=18/50 cls=0.1851 domain=0.6930 val=0.1543 val_f1=0.9435 alpha=0.9468
# DANN seed=42:  38%|██████████████████████████▏                                          | 19/50 [07:21<11:55, 23.08s/it]
#       epoch=19/50 cls=0.1779 domain=0.6930 val=0.1486 val_f1=0.9459 alpha=0.9562
# DANN seed=42:  40%|███████████████████████████▌                                         | 20/50 [07:44<11:30, 23.00s/it]
#       epoch=20/50 cls=0.1726 domain=0.6930 val=0.1432 val_f1=0.9482 alpha=0.9640
# DANN seed=42:  42%|████████████████████████████▉                                        | 21/50 [08:07<11:05, 22.97s/it]
#       epoch=21/50 cls=0.1666 domain=0.6931 val=0.1373 val_f1=0.9508 alpha=0.9705
# DANN seed=42:  44%|██████████████████████████████▎                                      | 22/50 [08:30<10:45, 23.04s/it]
#       epoch=22/50 cls=0.1622 domain=0.6931 val=0.1349 val_f1=0.9516 alpha=0.9757
# DANN seed=42:  46%|███████████████████████████████▋                                     | 23/50 [08:53<10:19, 22.96s/it]
#       epoch=23/50 cls=0.1566 domain=0.6930 val=0.1291 val_f1=0.9538 alpha=0.9801
# DANN seed=42:  48%|█████████████████████████████████                                    | 24/50 [09:16<09:56, 22.94s/it]
#       epoch=24/50 cls=0.1519 domain=0.6930 val=0.1269 val_f1=0.9544 alpha=0.9837
# DANN seed=42:  50%|██████████████████████████████████▌                                  | 25/50 [09:38<09:33, 22.93s/it]
#       epoch=25/50 cls=0.1475 domain=0.6930 val=0.1224 val_f1=0.9565 alpha=0.9866
# DANN seed=42:  52%|███████████████████████████████████▉                                 | 26/50 [10:01<09:08, 22.86s/it]
#       epoch=26/50 cls=0.1434 domain=0.6930 val=0.1190 val_f1=0.9576 alpha=0.9890
# DANN seed=42:  54%|█████████████████████████████████████▎                               | 27/50 [10:24<08:46, 22.87s/it]
#       epoch=27/50 cls=0.1395 domain=0.6929 val=0.1180 val_f1=0.9585 alpha=0.9910
# DANN seed=42:  56%|██████████████████████████████████████▋                              | 28/50 [10:47<08:23, 22.90s/it]
#       epoch=28/50 cls=0.1361 domain=0.6930 val=0.1134 val_f1=0.9602 alpha=0.9926
# DANN seed=42:  58%|████████████████████████████████████████                             | 29/50 [11:10<08:02, 22.98s/it]
#       epoch=29/50 cls=0.1321 domain=0.6930 val=0.1096 val_f1=0.9612 alpha=0.9940
# DANN seed=42:  60%|█████████████████████████████████████████▍                           | 30/50 [11:33<07:40, 23.04s/it]
#       epoch=30/50 cls=0.1288 domain=0.6930 val=0.1058 val_f1=0.9628 alpha=0.9951
# DANN seed=42:  62%|██████████████████████████████████████████▊                          | 31/50 [11:56<07:16, 22.97s/it]
#       epoch=31/50 cls=0.1270 domain=0.6929 val=0.1041 val_f1=0.9634 alpha=0.9959
# DANN seed=42:  64%|████████████████████████████████████████████▏                        | 32/50 [12:19<06:52, 22.94s/it]
#       epoch=32/50 cls=0.1227 domain=0.6929 val=0.1030 val_f1=0.9635 alpha=0.9967
# DANN seed=42:  66%|█████████████████████████████████████████████▌                       | 33/50 [12:42<06:29, 22.93s/it]
#       epoch=33/50 cls=0.1208 domain=0.6930 val=0.1006 val_f1=0.9647 alpha=0.9973
# DANN seed=42:  68%|██████████████████████████████████████████████▉                      | 34/50 [13:05<06:05, 22.86s/it]
#       epoch=34/50 cls=0.1185 domain=0.6929 val=0.1012 val_f1=0.9652 alpha=0.9978
# DANN seed=42:  70%|████████████████████████████████████████████████▎                    | 35/50 [13:28<05:43, 22.89s/it]
#       epoch=35/50 cls=0.1156 domain=0.6930 val=0.0993 val_f1=0.9644 alpha=0.9982
# DANN seed=42:  72%|█████████████████████████████████████████████████▋                   | 36/50 [13:51<05:20, 22.89s/it]
#       epoch=36/50 cls=0.1134 domain=0.6929 val=0.0933 val_f1=0.9676 alpha=0.9985
# DANN seed=42:  74%|███████████████████████████████████████████████████                  | 37/50 [14:13<04:57, 22.89s/it]
#       epoch=37/50 cls=0.1096 domain=0.6929 val=0.0931 val_f1=0.9676 alpha=0.9988
# DANN seed=42:  76%|████████████████████████████████████████████████████▍                | 38/50 [14:36<04:34, 22.88s/it]
#       epoch=38/50 cls=0.1077 domain=0.6930 val=0.0930 val_f1=0.9677 alpha=0.9990
# DANN seed=42:  78%|█████████████████████████████████████████████████████▊               | 39/50 [14:59<04:11, 22.88s/it]
#       epoch=39/50 cls=0.1063 domain=0.6930 val=0.0900 val_f1=0.9689 alpha=0.9992
# DANN seed=42:  80%|███████████████████████████████████████████████████████▏             | 40/50 [15:22<03:48, 22.88s/it]
#       epoch=40/50 cls=0.1045 domain=0.6929 val=0.0885 val_f1=0.9696 alpha=0.9993
# DANN seed=42:  82%|████████████████████████████████████████████████████████▌            | 41/50 [15:45<03:26, 22.92s/it]
#       epoch=41/50 cls=0.1026 domain=0.6929 val=0.0888 val_f1=0.9692 alpha=0.9995
# DANN seed=42:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [16:08<03:03, 22.88s/it]
#       epoch=42/50 cls=0.1002 domain=0.6929 val=0.0884 val_f1=0.9698 alpha=0.9996
# DANN seed=42:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [16:31<02:41, 23.05s/it]
#       epoch=43/50 cls=0.0983 domain=0.6929 val=0.0869 val_f1=0.9705 alpha=0.9996
# DANN seed=42:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [16:57<02:23, 23.99s/it]
#       epoch=44/50 cls=0.0975 domain=0.6929 val=0.0859 val_f1=0.9706 alpha=0.9997
# DANN seed=42:  90%|██████████████████████████████████████████████████████████████       | 45/50 [17:24<02:03, 24.69s/it]
#       epoch=45/50 cls=0.0957 domain=0.6929 val=0.0819 val_f1=0.9722 alpha=0.9998
# DANN seed=42:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [17:50<01:40, 25.05s/it]
#       epoch=46/50 cls=0.0941 domain=0.6930 val=0.0820 val_f1=0.9727 alpha=0.9998
# DANN seed=42:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [18:16<01:16, 25.42s/it]
#       epoch=47/50 cls=0.0926 domain=0.6930 val=0.0815 val_f1=0.9723 alpha=0.9998
# DANN seed=42:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [18:43<00:51, 25.96s/it]
#       epoch=48/50 cls=0.0917 domain=0.6930 val=0.0801 val_f1=0.9728 alpha=0.9999
# DANN seed=42:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [19:12<00:26, 26.70s/it]
#       epoch=49/50 cls=0.0896 domain=0.6929 val=0.0770 val_f1=0.9742 alpha=0.9999
#       epoch=50/50 cls=0.0894 domain=0.6930 val=0.0782 val_f1=0.9737 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/FFmpeg/run_01/confusion_matrix.png
#       Saved run 1 to results/smote_oversampling/FFmpeg/run_01
#
#       Run 2/3
# DANN seed=43:   2%|█▍                                                                    | 1/50 [00:28<23:07, 28.31s/it]
#       epoch=1/50 cls=0.5351 domain=0.6933 val=0.4762 val_f1=0.7834 alpha=0.0997
# DANN seed=43:   4%|██▊                                                                   | 2/50 [00:56<22:37, 28.28s/it]
#       epoch=2/50 cls=0.4561 domain=0.6932 val=0.4221 val_f1=0.8177 alpha=0.1974
# DANN seed=43:   6%|████▏                                                                 | 3/50 [01:24<21:59, 28.08s/it]
#       epoch=3/50 cls=0.4137 domain=0.6925 val=0.3827 val_f1=0.8372 alpha=0.2913
# DANN seed=43:   8%|█████▌                                                                | 4/50 [01:52<21:25, 27.96s/it]
#       epoch=4/50 cls=0.3811 domain=0.6929 val=0.3479 val_f1=0.8567 alpha=0.3799
# DANN seed=43:  10%|███████                                                               | 5/50 [02:20<20:57, 27.94s/it]
#       epoch=5/50 cls=0.3536 domain=0.6930 val=0.3191 val_f1=0.8703 alpha=0.4621
# DANN seed=43:  12%|████████▍                                                             | 6/50 [02:47<20:25, 27.86s/it]
#       epoch=6/50 cls=0.3294 domain=0.6928 val=0.2937 val_f1=0.8833 alpha=0.5370
# DANN seed=43:  14%|█████████▊                                                            | 7/50 [03:15<19:58, 27.86s/it]
#       epoch=7/50 cls=0.3089 domain=0.6926 val=0.2731 val_f1=0.8939 alpha=0.6044
# DANN seed=43:  16%|███████████▏                                                          | 8/50 [03:43<19:24, 27.73s/it]
#       epoch=8/50 cls=0.2900 domain=0.6924 val=0.2540 val_f1=0.9025 alpha=0.6640
# DANN seed=43:  18%|████████████▌                                                         | 9/50 [04:11<18:59, 27.80s/it]
#       epoch=9/50 cls=0.2746 domain=0.6924 val=0.2383 val_f1=0.9102 alpha=0.7163
# DANN seed=43:  20%|█████████████▊                                                       | 10/50 [04:39<18:35, 27.90s/it]
#       epoch=10/50 cls=0.2598 domain=0.6925 val=0.2230 val_f1=0.9157 alpha=0.7616
# DANN seed=43:  22%|███████████████▏                                                     | 11/50 [05:08<18:26, 28.37s/it]
#       epoch=11/50 cls=0.2465 domain=0.6925 val=0.2168 val_f1=0.9182 alpha=0.8005
# DANN seed=43:  24%|████████████████▌                                                    | 12/50 [05:38<18:13, 28.79s/it]
#       epoch=12/50 cls=0.2354 domain=0.6926 val=0.2213 val_f1=0.9151 alpha=0.8337
# DANN seed=43:  26%|█████████████████▉                                                   | 13/50 [06:08<17:55, 29.08s/it]
#       epoch=13/50 cls=0.2252 domain=0.6927 val=0.1905 val_f1=0.9296 alpha=0.8617
# DANN seed=43:  28%|███████████████████▎                                                 | 14/50 [06:38<17:40, 29.46s/it]
#       epoch=14/50 cls=0.2147 domain=0.6928 val=0.1812 val_f1=0.9334 alpha=0.8853
# DANN seed=43:  30%|████████████████████▋                                                | 15/50 [07:08<17:16, 29.62s/it]
#       epoch=15/50 cls=0.2069 domain=0.6928 val=0.1737 val_f1=0.9358 alpha=0.9051
# DANN seed=43:  32%|██████████████████████                                               | 16/50 [07:38<16:52, 29.77s/it]
#       epoch=16/50 cls=0.1985 domain=0.6928 val=0.1692 val_f1=0.9372 alpha=0.9217
# DANN seed=43:  34%|███████████████████████▍                                             | 17/50 [08:08<16:22, 29.77s/it]
#       epoch=17/50 cls=0.1916 domain=0.6929 val=0.1650 val_f1=0.9387 alpha=0.9354
# DANN seed=43:  36%|████████████████████████▊                                            | 18/50 [08:38<15:54, 29.83s/it]
#       epoch=18/50 cls=0.1847 domain=0.6929 val=0.1554 val_f1=0.9438 alpha=0.9468
# DANN seed=43:  38%|██████████████████████████▏                                          | 19/50 [09:07<15:21, 29.72s/it]
#       epoch=19/50 cls=0.1772 domain=0.6929 val=0.1489 val_f1=0.9457 alpha=0.9562
# DANN seed=43:  40%|███████████████████████████▌                                         | 20/50 [09:37<14:49, 29.64s/it]
#       epoch=20/50 cls=0.1715 domain=0.6930 val=0.1432 val_f1=0.9481 alpha=0.9640
# DANN seed=43:  42%|████████████████████████████▉                                        | 21/50 [10:06<14:15, 29.50s/it]
#       epoch=21/50 cls=0.1655 domain=0.6930 val=0.1412 val_f1=0.9484 alpha=0.9705
# DANN seed=43:  44%|██████████████████████████████▎                                      | 22/50 [10:35<13:45, 29.48s/it]
#       epoch=22/50 cls=0.1617 domain=0.6930 val=0.1459 val_f1=0.9461 alpha=0.9757
# DANN seed=43:  46%|███████████████████████████████▋                                     | 23/50 [11:04<13:11, 29.32s/it]
#       epoch=23/50 cls=0.1569 domain=0.6930 val=0.1315 val_f1=0.9528 alpha=0.9801
# DANN seed=43:  48%|█████████████████████████████████                                    | 24/50 [11:33<12:38, 29.18s/it]
#       epoch=24/50 cls=0.1511 domain=0.6930 val=0.1308 val_f1=0.9530 alpha=0.9837
# DANN seed=43:  50%|██████████████████████████████████▌                                  | 25/50 [12:02<12:10, 29.24s/it]
#       epoch=25/50 cls=0.1468 domain=0.6930 val=0.1230 val_f1=0.9555 alpha=0.9866
# DANN seed=43:  52%|███████████████████████████████████▉                                 | 26/50 [12:31<11:38, 29.12s/it]
#       epoch=26/50 cls=0.1426 domain=0.6930 val=0.1204 val_f1=0.9568 alpha=0.9890
# DANN seed=43:  54%|█████████████████████████████████████▎                               | 27/50 [13:00<11:06, 28.99s/it]
#       epoch=27/50 cls=0.1397 domain=0.6930 val=0.1169 val_f1=0.9579 alpha=0.9910
# DANN seed=43:  56%|██████████████████████████████████████▋                              | 28/50 [13:29<10:34, 28.86s/it]
#       epoch=28/50 cls=0.1356 domain=0.6930 val=0.1159 val_f1=0.9591 alpha=0.9926
# DANN seed=43:  58%|████████████████████████████████████████                             | 29/50 [13:57<10:05, 28.81s/it]
#       epoch=29/50 cls=0.1326 domain=0.6930 val=0.1142 val_f1=0.9596 alpha=0.9940
# DANN seed=43:  60%|█████████████████████████████████████████▍                           | 30/50 [14:26<09:35, 28.77s/it]
#       epoch=30/50 cls=0.1294 domain=0.6929 val=0.1083 val_f1=0.9616 alpha=0.9951
# DANN seed=43:  62%|██████████████████████████████████████████▊                          | 31/50 [14:55<09:05, 28.73s/it]
#       epoch=31/50 cls=0.1249 domain=0.6930 val=0.1053 val_f1=0.9632 alpha=0.9959
# DANN seed=43:  64%|████████████████████████████████████████████▏                        | 32/50 [15:23<08:35, 28.63s/it]
#       epoch=32/50 cls=0.1234 domain=0.6930 val=0.1032 val_f1=0.9646 alpha=0.9967
# DANN seed=43:  66%|█████████████████████████████████████████████▌                       | 33/50 [15:52<08:06, 28.61s/it]
#       epoch=33/50 cls=0.1208 domain=0.6929 val=0.1025 val_f1=0.9639 alpha=0.9973
# DANN seed=43:  68%|██████████████████████████████████████████████▉                      | 34/50 [16:20<07:37, 28.61s/it]
#       epoch=34/50 cls=0.1175 domain=0.6929 val=0.1030 val_f1=0.9637 alpha=0.9978
# DANN seed=43:  70%|████████████████████████████████████████████████▎                    | 35/50 [16:49<07:09, 28.63s/it]
#       epoch=35/50 cls=0.1150 domain=0.6929 val=0.0959 val_f1=0.9669 alpha=0.9982
# DANN seed=43:  72%|█████████████████████████████████████████████████▋                   | 36/50 [17:17<06:39, 28.56s/it]
#       epoch=36/50 cls=0.1122 domain=0.6929 val=0.0950 val_f1=0.9671 alpha=0.9985
# DANN seed=43:  74%|███████████████████████████████████████████████████                  | 37/50 [17:46<06:11, 28.57s/it]
#       epoch=37/50 cls=0.1104 domain=0.6929 val=0.0926 val_f1=0.9680 alpha=0.9988
# DANN seed=43:  76%|████████████████████████████████████████████████████▍                | 38/50 [18:14<05:41, 28.47s/it]
#       epoch=38/50 cls=0.1087 domain=0.6929 val=0.0924 val_f1=0.9684 alpha=0.9990
# DANN seed=43:  78%|█████████████████████████████████████████████████████▊               | 39/50 [18:43<05:13, 28.47s/it]
#       epoch=39/50 cls=0.1061 domain=0.6929 val=0.0917 val_f1=0.9683 alpha=0.9992
# DANN seed=43:  80%|███████████████████████████████████████████████████████▏             | 40/50 [19:11<04:43, 28.38s/it]
#       epoch=40/50 cls=0.1031 domain=0.6929 val=0.0967 val_f1=0.9661 alpha=0.9993
# DANN seed=43:  82%|████████████████████████████████████████████████████████▌            | 41/50 [19:39<04:14, 28.33s/it]
#       epoch=41/50 cls=0.1020 domain=0.6930 val=0.0896 val_f1=0.9690 alpha=0.9995
# DANN seed=43:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [20:07<03:45, 28.24s/it]
#       epoch=42/50 cls=0.1008 domain=0.6929 val=0.0891 val_f1=0.9694 alpha=0.9996
# DANN seed=43:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [20:35<03:18, 28.29s/it]
#       epoch=43/50 cls=0.0993 domain=0.6929 val=0.0915 val_f1=0.9687 alpha=0.9996
# DANN seed=43:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [21:03<02:49, 28.23s/it]
#       epoch=44/50 cls=0.0966 domain=0.6929 val=0.0850 val_f1=0.9710 alpha=0.9997
# DANN seed=43:  90%|██████████████████████████████████████████████████████████████       | 45/50 [21:31<02:20, 28.17s/it]
#       epoch=45/50 cls=0.0955 domain=0.6929 val=0.0868 val_f1=0.9706 alpha=0.9998
# DANN seed=43:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [22:00<01:52, 28.16s/it]
#       epoch=46/50 cls=0.0937 domain=0.6929 val=0.0784 val_f1=0.9734 alpha=0.9998
# DANN seed=43:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [22:28<01:24, 28.20s/it]
#       epoch=47/50 cls=0.0918 domain=0.6929 val=0.0811 val_f1=0.9725 alpha=0.9998
# DANN seed=43:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [22:56<00:56, 28.21s/it]
#       epoch=48/50 cls=0.0908 domain=0.6930 val=0.0803 val_f1=0.9727 alpha=0.9999
# DANN seed=43:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [23:25<00:28, 28.28s/it]
#       epoch=49/50 cls=0.0893 domain=0.6929 val=0.0781 val_f1=0.9738 alpha=0.9999
#       epoch=50/50 cls=0.0882 domain=0.6929 val=0.0785 val_f1=0.9737 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/FFmpeg/run_02/confusion_matrix.png
#       Saved run 2 to results/smote_oversampling/FFmpeg/run_02
#
#       Run 3/3
# DANN seed=44:   2%|█▍                                                                    | 1/50 [00:28<23:19, 28.56s/it]
#       epoch=1/50 cls=0.5339 domain=0.6935 val=0.4736 val_f1=0.7849 alpha=0.0997
# DANN seed=44:   4%|██▊                                                                   | 2/50 [00:56<22:39, 28.31s/it]
#       epoch=2/50 cls=0.4514 domain=0.6923 val=0.4195 val_f1=0.8208 alpha=0.1974
# DANN seed=44:   6%|████▏                                                                 | 3/50 [01:24<22:05, 28.21s/it]
#       epoch=3/50 cls=0.4096 domain=0.6931 val=0.3783 val_f1=0.8418 alpha=0.2913
# DANN seed=44:   8%|█████▌                                                                | 4/50 [01:53<21:39, 28.25s/it]
#       epoch=4/50 cls=0.3782 domain=0.6935 val=0.3430 val_f1=0.8584 alpha=0.3799
# DANN seed=44:  10%|███████                                                               | 5/50 [02:21<21:15, 28.34s/it]
#       epoch=5/50 cls=0.3500 domain=0.6931 val=0.3142 val_f1=0.8730 alpha=0.4621
# DANN seed=44:  12%|████████▍                                                             | 6/50 [02:50<20:48, 28.37s/it]
#       epoch=6/50 cls=0.3266 domain=0.6928 val=0.2884 val_f1=0.8848 alpha=0.5370
# DANN seed=44:  14%|█████████▊                                                            | 7/50 [03:18<20:14, 28.25s/it]
#       epoch=7/50 cls=0.3060 domain=0.6928 val=0.2671 val_f1=0.8965 alpha=0.6044
# DANN seed=44:  16%|███████████▏                                                          | 8/50 [03:46<19:43, 28.18s/it]
#       epoch=8/50 cls=0.2879 domain=0.6927 val=0.2492 val_f1=0.9042 alpha=0.6640
# DANN seed=44:  18%|████████████▌                                                         | 9/50 [04:14<19:12, 28.10s/it]
#       epoch=9/50 cls=0.2707 domain=0.6927 val=0.2346 val_f1=0.9098 alpha=0.7163
# DANN seed=44:  20%|█████████████▊                                                       | 10/50 [04:42<18:45, 28.14s/it]
#       epoch=10/50 cls=0.2563 domain=0.6926 val=0.2176 val_f1=0.9175 alpha=0.7616
# DANN seed=44:  22%|███████████████▏                                                     | 11/50 [05:10<18:14, 28.08s/it]
#       epoch=11/50 cls=0.2445 domain=0.6926 val=0.2057 val_f1=0.9230 alpha=0.8005
# DANN seed=44:  24%|████████████████▌                                                    | 12/50 [05:38<17:49, 28.13s/it]
#       epoch=12/50 cls=0.2328 domain=0.6925 val=0.2007 val_f1=0.9242 alpha=0.8337
# DANN seed=44:  26%|█████████████████▉                                                   | 13/50 [06:06<17:22, 28.16s/it]
#       epoch=13/50 cls=0.2232 domain=0.6927 val=0.1850 val_f1=0.9314 alpha=0.8617
# DANN seed=44:  28%|███████████████████▎                                                 | 14/50 [06:35<16:57, 28.27s/it]
#       epoch=14/50 cls=0.2129 domain=0.6927 val=0.1768 val_f1=0.9345 alpha=0.8853
# DANN seed=44:  30%|████████████████████▋                                                | 15/50 [07:03<16:26, 28.20s/it]
#       epoch=15/50 cls=0.2041 domain=0.6928 val=0.1687 val_f1=0.9371 alpha=0.9051
# DANN seed=44:  32%|██████████████████████                                               | 16/50 [07:31<15:56, 28.15s/it]
#       epoch=16/50 cls=0.1971 domain=0.6928 val=0.1618 val_f1=0.9402 alpha=0.9217
# DANN seed=44:  34%|███████████████████████▍                                             | 17/50 [07:59<15:28, 28.14s/it]
#       epoch=17/50 cls=0.1893 domain=0.6929 val=0.1597 val_f1=0.9411 alpha=0.9354
# DANN seed=44:  36%|████████████████████████▊                                            | 18/50 [08:27<14:59, 28.11s/it]
#       epoch=18/50 cls=0.1829 domain=0.6929 val=0.1489 val_f1=0.9465 alpha=0.9468
# DANN seed=44:  38%|██████████████████████████▏                                          | 19/50 [08:55<14:30, 28.09s/it]
#       epoch=19/50 cls=0.1759 domain=0.6930 val=0.1421 val_f1=0.9494 alpha=0.9562
# DANN seed=44:  40%|███████████████████████████▌                                         | 20/50 [09:23<14:02, 28.08s/it]
#       epoch=20/50 cls=0.1698 domain=0.6929 val=0.1417 val_f1=0.9492 alpha=0.9640
# DANN seed=44:  42%|████████████████████████████▉                                        | 21/50 [09:51<13:33, 28.05s/it]
#       epoch=21/50 cls=0.1644 domain=0.6929 val=0.1330 val_f1=0.9528 alpha=0.9705
# DANN seed=44:  44%|██████████████████████████████▎                                      | 22/50 [10:19<13:05, 28.06s/it]
#       epoch=22/50 cls=0.1591 domain=0.6929 val=0.1300 val_f1=0.9538 alpha=0.9757
# DANN seed=44:  46%|███████████████████████████████▋                                     | 23/50 [10:47<12:36, 28.03s/it]
#       epoch=23/50 cls=0.1546 domain=0.6929 val=0.1271 val_f1=0.9552 alpha=0.9801
# DANN seed=44:  48%|█████████████████████████████████                                    | 24/50 [11:15<12:08, 28.02s/it]
#       epoch=24/50 cls=0.1500 domain=0.6929 val=0.1230 val_f1=0.9570 alpha=0.9837
# DANN seed=44:  50%|██████████████████████████████████▌                                  | 25/50 [11:43<11:40, 28.02s/it]
#       epoch=25/50 cls=0.1455 domain=0.6929 val=0.1184 val_f1=0.9582 alpha=0.9866
# DANN seed=44:  52%|███████████████████████████████████▉                                 | 26/50 [12:11<11:13, 28.08s/it]
#       epoch=26/50 cls=0.1416 domain=0.6929 val=0.1172 val_f1=0.9593 alpha=0.9890
# DANN seed=44:  54%|█████████████████████████████████████▎                               | 27/50 [12:40<10:51, 28.31s/it]
#       epoch=27/50 cls=0.1385 domain=0.6929 val=0.1184 val_f1=0.9578 alpha=0.9910
# DANN seed=44:  56%|██████████████████████████████████████▋                              | 28/50 [13:08<10:21, 28.27s/it]
#       epoch=28/50 cls=0.1352 domain=0.6929 val=0.1306 val_f1=0.9541 alpha=0.9926
# DANN seed=44:  58%|████████████████████████████████████████                             | 29/50 [13:36<09:51, 28.16s/it]
#       epoch=29/50 cls=0.1305 domain=0.6929 val=0.1097 val_f1=0.9615 alpha=0.9940
# DANN seed=44:  60%|█████████████████████████████████████████▍                           | 30/50 [14:04<09:21, 28.08s/it]
#       epoch=30/50 cls=0.1284 domain=0.6929 val=0.1091 val_f1=0.9621 alpha=0.9951
# DANN seed=44:  62%|██████████████████████████████████████████▊                          | 31/50 [14:32<08:53, 28.10s/it]
#       epoch=31/50 cls=0.1255 domain=0.6929 val=0.1068 val_f1=0.9629 alpha=0.9959
# DANN seed=44:  64%|████████████████████████████████████████████▏                        | 32/50 [15:00<08:23, 27.97s/it]
#       epoch=32/50 cls=0.1224 domain=0.6929 val=0.1076 val_f1=0.9609 alpha=0.9967
# DANN seed=44:  66%|█████████████████████████████████████████████▌                       | 33/50 [15:28<07:54, 27.94s/it]
#       epoch=33/50 cls=0.1205 domain=0.6929 val=0.1002 val_f1=0.9653 alpha=0.9973
# DANN seed=44:  68%|██████████████████████████████████████████████▉                      | 34/50 [15:56<07:26, 27.90s/it]
#       epoch=34/50 cls=0.1178 domain=0.6929 val=0.0963 val_f1=0.9666 alpha=0.9978
# DANN seed=44:  70%|████████████████████████████████████████████████▎                    | 35/50 [16:24<06:58, 27.93s/it]
#       epoch=35/50 cls=0.1151 domain=0.6929 val=0.0954 val_f1=0.9674 alpha=0.9982
# DANN seed=44:  72%|█████████████████████████████████████████████████▋                   | 36/50 [16:52<06:32, 28.02s/it]
#       epoch=36/50 cls=0.1122 domain=0.6929 val=0.0924 val_f1=0.9677 alpha=0.9985
# DANN seed=44:  74%|███████████████████████████████████████████████████                  | 37/50 [17:19<06:03, 27.93s/it]
#       epoch=37/50 cls=0.1108 domain=0.6929 val=0.0903 val_f1=0.9682 alpha=0.9988
# DANN seed=44:  76%|████████████████████████████████████████████████████▍                | 38/50 [17:47<05:34, 27.90s/it]
#       epoch=38/50 cls=0.1082 domain=0.6929 val=0.0930 val_f1=0.9680 alpha=0.9990
# DANN seed=44:  78%|█████████████████████████████████████████████████████▊               | 39/50 [18:15<05:06, 27.87s/it]
#       epoch=39/50 cls=0.1066 domain=0.6929 val=0.0892 val_f1=0.9697 alpha=0.9992
# DANN seed=44:  80%|███████████████████████████████████████████████████████▏             | 40/50 [18:43<04:39, 27.93s/it]
#       epoch=40/50 cls=0.1041 domain=0.6929 val=0.1031 val_f1=0.9649 alpha=0.9993
# DANN seed=44:  82%|████████████████████████████████████████████████████████▌            | 41/50 [19:11<04:12, 28.01s/it]
#       epoch=41/50 cls=0.1023 domain=0.6930 val=0.0906 val_f1=0.9674 alpha=0.9995
# DANN seed=44:  84%|█████████████████████████████████████████████████████████▉           | 42/50 [19:39<03:43, 27.99s/it]
#       epoch=42/50 cls=0.1008 domain=0.6929 val=0.0860 val_f1=0.9705 alpha=0.9996
# DANN seed=44:  86%|███████████████████████████████████████████████████████████▎         | 43/50 [20:07<03:15, 27.94s/it]
#       epoch=43/50 cls=0.0994 domain=0.6929 val=0.0833 val_f1=0.9713 alpha=0.9996
# DANN seed=44:  88%|████████████████████████████████████████████████████████████▋        | 44/50 [20:35<02:47, 27.94s/it]
#       epoch=44/50 cls=0.0974 domain=0.6929 val=0.0889 val_f1=0.9697 alpha=0.9997
# DANN seed=44:  90%|██████████████████████████████████████████████████████████████       | 45/50 [21:03<02:19, 27.95s/it]
#       epoch=45/50 cls=0.0955 domain=0.6930 val=0.0794 val_f1=0.9728 alpha=0.9998
# DANN seed=44:  92%|███████████████████████████████████████████████████████████████▍     | 46/50 [21:31<01:51, 27.90s/it]
#       epoch=46/50 cls=0.0944 domain=0.6930 val=0.0816 val_f1=0.9718 alpha=0.9998
# DANN seed=44:  94%|████████████████████████████████████████████████████████████████▊    | 47/50 [21:59<01:23, 27.88s/it]
#       epoch=47/50 cls=0.0929 domain=0.6929 val=0.0832 val_f1=0.9718 alpha=0.9998
# DANN seed=44:  96%|██████████████████████████████████████████████████████████████████▏  | 48/50 [22:27<00:55, 27.89s/it]
#       epoch=48/50 cls=0.0914 domain=0.6929 val=0.0765 val_f1=0.9741 alpha=0.9999
# DANN seed=44:  98%|███████████████████████████████████████████████████████████████████▌ | 49/50 [22:55<00:27, 27.91s/it]
#       epoch=49/50 cls=0.0900 domain=0.6929 val=0.0754 val_f1=0.9744 alpha=0.9999
#       epoch=50/50 cls=0.0878 domain=0.6929 val=0.0807 val_f1=0.9724 alpha=0.9999
# Confusion matrix saved as results/smote_oversampling/FFmpeg/run_03/confusion_matrix.png
#       Saved run 3 to results/smote_oversampling/FFmpeg/run_03
#
# Aggregating ensemble results...
# Confusion matrix saved as results/smote_oversampling/FFmpeg/confusion_matrix_dann_xgboost_FFmpeg_smote.png
#
# === Ensemble Evaluation Results (FFmpeg Test Set, SMOTE) ===
# Accuracy:   0.527
# Precision:  0.063
# Recall:     0.876
# F1-score:   0.118
# ROC-AUC:    0.737
# PR-AUC:     0.073
# G-mean:     0.671
# PF value:   0.487
#
# Results saved to results/smote_oversampling/FFmpeg/dann_xgboost_FFmpeg_smote.json
# Confusion matrix saved to results/smote_oversampling/FFmpeg/confusion_matrix_dann_xgboost_FFmpeg_smote.png
