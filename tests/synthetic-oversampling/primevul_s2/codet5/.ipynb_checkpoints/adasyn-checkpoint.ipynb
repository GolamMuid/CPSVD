# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "poppler"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/poppler"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-poppler)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (poppler)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled poppler
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (poppler Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except poppler -> Test on poppler (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (poppler)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (poppler Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_poppler",
        "test"              : TEST_PROJ,
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_poppler.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_poppler.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except poppler -> Test on poppler (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (222735, 768)  vuln=5971  benign=216764
#       Projects in training pool : 753
#       Test set (poppler)          : (1798, 768)  vuln=33  benign=1765
#       Training imbalance ratio  : 0.0268
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (222735, 768)  vuln=5971  benign=216764
#       After ADASYN  : (434040, 768)  vuln=217276  benign=216764
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5325
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4748
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4358
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4048
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3741
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3463
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3287
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3002
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2793
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2637
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2477
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2301
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2169
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2040
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1984
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1858
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1778
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1747
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1642
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1559
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1487
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1452
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1408
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1333
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1327
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1238
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1250
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1179
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1136
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1109
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1090
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1057
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1001
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1018
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0961
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0947
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0929
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0903
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0912
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0940
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0854
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0869
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0856
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0863
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0806
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0791
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0779
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0782
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0769
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0752
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0775
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0681
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0673
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0642
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0617
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0597
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0588
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0579
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0613
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0530
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0553
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0606
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0519
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0549
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0491
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0499
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0531
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0491
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0467
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0509
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0438
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0473
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0467
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0451
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0465
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0467
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0462
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0419
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0421
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5235
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4604
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4216
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.3879
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3585
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3294
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3047
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.2816
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2682
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2450
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2283
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2152
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2035
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1923
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1879
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1727
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1681
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1606
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1575
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1509
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1417
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1354
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1301
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1268
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1217
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1190
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1121
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1102
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1069
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1003
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1003
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0986
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1022
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0930
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0947
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0938
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0956
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0884
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0849
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0842
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0843
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0843
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0794
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0804
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0833
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0827
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0748
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0792
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0756
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0706
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0701
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0644
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0690
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0652
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0716
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0563
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0568
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0550
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0542
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0554
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0547
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0523
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0505
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0539
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0501
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0476
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0581
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0492
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0466
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0489
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0448
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0466
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0452
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0462
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0442
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0415
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0424
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0428
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5289
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4717
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4387
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4097
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.3787
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3555
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3284
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.2994
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.2789
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2613
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2402
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2275
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2173
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2023
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1921
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1814
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1731
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1646
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1640
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1524
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1471
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1422
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1381
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1307
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1344
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1254
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1217
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1242
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1115
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1126
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1134
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1037
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1005
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0971
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0963
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0933
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1009
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0940
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0883
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0890
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0901
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0885
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0863
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0985
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0787
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0823
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0783
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0774
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0759
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0734
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0748
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0710
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0709
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0652
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0699
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0618
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0697
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0638
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0598
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0632
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0552
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0564
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0561
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0520
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0549
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0606
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0522
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0499
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0485
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0465
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0462
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0448
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0457
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0432
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0444
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0430
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0419
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (poppler Test Set) ===
# Accuracy  : 0.775
# Precision : 0.061
# Recall    : 0.788
# F1-score  : 0.114
# AUC       : 0.876
# G-mean    : 0.781
# PF value  : 0.225
#
# Confusion Matrix:
#   TN: 1368  FP: 397
#   FN: 7  TP: 26
#
# Results saved to results/adasyn/poppler/adasyn_poppler.json
# Confusion matrix saved as results/adasyn/poppler/confusion_matrix_adasyn_poppler.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/radare2"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-radare2)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (radare2)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled radare2
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_radare2",
        "test"              : TEST_PROJ,
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except radare2 -> Test on radare2 (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221730, 768)  vuln=5930  benign=215800
#       Projects in training pool : 753
#       Test set (radare2)          : (2803, 768)  vuln=74  benign=2729
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (221730, 768)  vuln=5930  benign=215800
#       After ADASYN  : (431662, 768)  vuln=215862  benign=215800
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5335
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4733
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4348
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4032
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3713
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3448
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3201
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.2969
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2778
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2574
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2433
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2308
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2198
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2044
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1970
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1870
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1794
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1747
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1620
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1600
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1610
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1451
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1422
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1394
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1308
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1267
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1226
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1192
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1156
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1127
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1182
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1118
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1012
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0994
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0988
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0966
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0925
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0887
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0881
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0878
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0848
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0876
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0824
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0941
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0800
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0838
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0801
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0757
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 374
#     370     plot_confusion_matrix(tn, fp, fn, tp, cm_path)
#     373 if __name__ == "__main__":
# --> 374     main()
#
# Cell In[2], line 291, in main()
#     289 for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
#     290     print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
# --> 291     model_nn, _ = semi_supervised_transfer_learning(
#     292         train_emb_ada, train_lbl_ada,
#     293         test_emb,
#     294         iteration=i+1
#     295     )
#     297     print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
#     298     model_nn.eval()
#
# Cell In[2], line 167, in semi_supervised_transfer_learning(x_train, y_train, x_test, iteration)
#     164 dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
#     165 dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)
# --> 167 model = train_neural_network(
#     168     model, dataloader_aug, x_aug_val_t, y_aug_val_t,
#     169     optimizer, criterion,
#     170     epochs=30,
#     171     desc=f"Iter {iteration} - Phase 2"
#     172 )
#     174 model.eval()
#     175 with torch.no_grad():
#
# Cell In[2], line 108, in train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc)
#     106 y_batch = y_batch.to(DEVICE)
#     107 optimizer.zero_grad()
# --> 108 loss = criterion(model(x_batch).squeeze(), y_batch)
#     109 loss.backward()
#     110 optimizer.step()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/loss.py:710, in BCELoss.forward(self, input, target)
#     706 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     707     """
#     708     Runs the forward pass.
#     709     """
# --> 710     return F.binary_cross_entropy(
#     711         input, target, weight=self.weight, reduction=self.reduction
#     712     )
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:3564, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3562     reduction_enum = _Reduction.get_enum(reduction)
#    3563 if target.size() != input.size():
# -> 3564     raise ValueError(
#    3565         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3566         "Please ensure they have the same size."
#    3567     )
#    3569 if weight is not None:
#    3570     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux-2.6"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/linux-2.6"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-linux-2.6)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (linux-2.6)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled linux-2.6
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux-2.6 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux-2.6)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux-2.6 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_linux-2.6",
        "test"              : TEST_PROJ,
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_linux-2.6.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_linux-2.6.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221163, 768)  vuln=5904  benign=215259
#       Projects in training pool : 753
#       Test set (linux-2.6)          : (3370, 768)  vuln=100  benign=3270
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (221163, 768)  vuln=5904  benign=215259
#       After ADASYN  : (429492, 768)  vuln=214233  benign=215259
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5336
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4747
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4378
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4076
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3756
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3497
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3249
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3006
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2801
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2653
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2453
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2321
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2203
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2080
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1981
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1853
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1785
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1739
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1623
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1591
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1495
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1473
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1410
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1375
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1337
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1273
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1271
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1194
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1172
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1180
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1094
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1087
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1021
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0977
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0959
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0949
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0993
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0915
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0894
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0875
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0862
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0924
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0833
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0806
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0800
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0817
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0778
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0766
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0739
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0820
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0711
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0784
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0736
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0623
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0630
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0624
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0627
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0620
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0595
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0570
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0524
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0530
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0526
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0519
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0504
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0486
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0457
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0485
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0463
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0448
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0452
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0456
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0458
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0421
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0408
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0409
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0439
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5238
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4609
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4214
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.3889
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3588
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3317
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3061
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.2864
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2637
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2471
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2344
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2200
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2082
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1952
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1854
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1766
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1675
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1609
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1539
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1540
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1469
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1374
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1305
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1294
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1238
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1223
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1206
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1171
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1096
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1090
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0982
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0986
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0971
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0923
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0961
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0960
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0869
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0835
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0837
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0816
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0859
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0868
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0812
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0784
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0775
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0766
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0794
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0791
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0743
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0684
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0644
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0777
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0620
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0602
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0590
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0575
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0550
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0608
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0556
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0520
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0523
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0515
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0516
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0506
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0500
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0524
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0472
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0454
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0483
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0509
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0458
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0540
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0569
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0456
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0454
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0436
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0446
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5314
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4736
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4377
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4068
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.3794
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3605
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3277
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3056
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.2828
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2620
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2469
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2334
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2196
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2053
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1945
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1842
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1778
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1737
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1609
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1561
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1486
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1429
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1385
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1377
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1314
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1267
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1248
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1198
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1166
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1101
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1090
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1016
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0975
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0941
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0913
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0994
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0893
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0945
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0869
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0850
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0826
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0814
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0790
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0804
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0847
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0789
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0750
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0802
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0739
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0705
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0690
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0641
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0657
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0620
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0647
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0600
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0566
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0557
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0575
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0537
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0501
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0497
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0505
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0508
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0459
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0440
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0451
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0456
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0558
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0443
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0463
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0493
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0454
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0437
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux-2.6 Test Set) ===
# Accuracy  : 0.743
# Precision : 0.066
# Recall    : 0.580
# F1-score  : 0.118
# AUC       : 0.732
# G-mean    : 0.659
# PF value  : 0.252
#
# Confusion Matrix:
#   TN: 2445  FP: 825
#   FN: 42  TP: 58
#
# Results saved to results/adasyn/linux-2.6/adasyn_linux-2.6.json
# Confusion matrix saved as results/adasyn/linux-2.6/confusion_matrix_adasyn_linux-2.6.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "vim"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/vim"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-vim)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (vim)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled vim
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_vim",
        "test"              : TEST_PROJ,
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221466, 768)  vuln=5898  benign=215568
#       Projects in training pool : 753
#       Test set (vim)          : (3067, 768)  vuln=106  benign=2961
#       Training imbalance ratio  : 0.0266
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (221466, 768)  vuln=5898  benign=215568
#       After ADASYN  : (431618, 768)  vuln=216050  benign=215568
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5355
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4746
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4374
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4062
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3752
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3483
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3220
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.2993
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2862
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2599
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2445
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2329
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2190
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2046
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.2009
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1859
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1786
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1687
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1640
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1570
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1497
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1457
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1394
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1355
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1295
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1309
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1209
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1211
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1154
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1118
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1114
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1025
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1013
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1002
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0966
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0962
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0923
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0904
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0934
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0871
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0881
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0839
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0860
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0824
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0820
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0781
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0769
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0846
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0776
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0801
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0943
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0709
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0698
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0642
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0624
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0623
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0580
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0577
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0560
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0568
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0530
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0555
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0526
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0517
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0548
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0548
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0499
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0505
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0472
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0469
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0502
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0449
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0459
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0438
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0427
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0464
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0424
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0544
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0403
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5249
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4601
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4229
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.3900
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3579
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3322
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3040
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.2819
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2618
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2442
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2279
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2164
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2033
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1929
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1795
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1716
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1645
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1589
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1508
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1468
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1425
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1341
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1277
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1312
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1205
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1186
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1132
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1106
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1030
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1003
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0967
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0961
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0957
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0951
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0909
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0885
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0864
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0854
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0815
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0824
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0836
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0826
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0775
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0766
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0783
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0832
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0753
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0743
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0720
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0712
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0694
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0633
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0640
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0593
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0580
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0561
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0597
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0589
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0552
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0556
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0536
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0486
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0506
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0508
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0523
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0455
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0465
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0470
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0516
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0460
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0477
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0471
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0457
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0451
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0419
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0502
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0429
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0433
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5324
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4710
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4358
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4052
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.3775
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3516
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3261
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.3003
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.2793
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2602
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2428
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2270
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2147
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2018
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1933
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1879
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1760
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1651
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1607
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1519
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1466
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1420
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1374
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1332
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1274
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1251
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1196
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1168
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1180
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1093
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1082
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1037
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1012
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1002
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0959
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0961
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0928
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0900
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0895
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0859
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0870
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0827
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0853
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0814
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0860
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0809
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0821
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0831
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0788
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0777
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0713
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0788
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0680
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0633
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0630
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0700
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0595
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0591
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0565
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0587
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0506
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0516
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0494
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0565
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0744
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0507
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0480
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0485
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0519
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0522
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0465
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0453
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0450
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0444
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0420
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0438
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0432
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0399
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (vim Test Set) ===
# Accuracy  : 0.591
# Precision : 0.068
# Recall    : 0.849
# F1-score  : 0.126
# AUC       : 0.798
# G-mean    : 0.703
# PF value  : 0.418
#
# Confusion Matrix:
#   TN: 1723  FP: 1238
#   FN: 16  TP: 90
#
# Results saved to results/adasyn/vim/adasyn_vim.json
# Confusion matrix saved as results/adasyn/vim/confusion_matrix_adasyn_vim.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FFmpeg"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/FFmpeg"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-FFmpeg)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (FFmpeg)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled FFmpeg
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FFmpeg)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_FFmpeg",
        "test"              : TEST_PROJ,
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_FFmpeg.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_FFmpeg.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (222072, 768)  vuln=5915  benign=216157
#       Projects in training pool : 753
#       Test set (FFmpeg)          : (2461, 768)  vuln=89  benign=2372
#       Training imbalance ratio  : 0.0266
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (222072, 768)  vuln=5915  benign=216157
#       After ADASYN  : (432378, 768)  vuln=216221  benign=216157
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5317
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4725
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4365
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4045
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3743
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3462
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3233
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.2993
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2812
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2609
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2443
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2290
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2164
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2057
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1960
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1849
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1764
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1692
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1618
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1552
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1496
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1434
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1399
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1369
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1307
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1349
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1207
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1165
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1328
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1148
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1083
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1046
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1020
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0987
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0983
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0976
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0925
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0902
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0880
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0883
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0844
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0859
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0846
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0843
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0834
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0816
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0808
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0771
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0862
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0771
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0852
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0734
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0654
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0679
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0618
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0637
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0608
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0597
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0578
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0571
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0567
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0520
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0539
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0527
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0498
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0490
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0474
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0469
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0479
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0453
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0448
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0458
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0435
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0424
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0435
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0548
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0514
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0386
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5215
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4615
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4189
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.3855
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3547
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3275
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3030
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.2862
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2603
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2422
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2254
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2133
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2037
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1890
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1834
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1770
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1690
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1582
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1493
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1438
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1431
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1330
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1281
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1255
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1204
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1153
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1140
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1104
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1099
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0992
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0970
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0994
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0931
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0940
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0882
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0891
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0865
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0877
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0877
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0845
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0834
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0781
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0777
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0761
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0778
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0749
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0759
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0782
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0766
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0704
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0669
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0642
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0658
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0622
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0585
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0576
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0575
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0600
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0544
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0557
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0523
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0486
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0500
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0461
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0474
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0506
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0466
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0444
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0459
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0429
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0468
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0441
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0438
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0429
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0443
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0422
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0401
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0449
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5270
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4727
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4362
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4058
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.3778
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3510
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3222
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.2984
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.2776
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2591
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2459
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2312
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2199
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2030
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1955
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1826
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1734
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1660
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1605
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1516
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1459
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1424
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1378
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1308
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1314
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1244
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1227
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1165
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1168
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1125
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1161
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0996
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0974
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0998
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0943
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0924
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0915
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0920
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0862
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0857
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0936
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0839
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0807
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0815
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0907
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0806
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0801
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0791
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0780
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0711
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0692
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0703
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0701
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0631
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0714
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0631
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0581
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0587
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0537
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0533
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0543
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0578
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0529
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0549
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0491
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0535
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0501
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0476
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0527
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0465
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0455
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0432
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0431
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0433
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0444
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy  : 0.574
# Precision : 0.064
# Recall    : 0.798
# F1-score  : 0.119
# AUC       : 0.734
# G-mean    : 0.672
# PF value  : 0.434
#
# Confusion Matrix:
#   TN: 1342  FP: 1030
#   FN: 18  TP: 71
#
# Results saved to results/adasyn/FFmpeg/adasyn_FFmpeg.json
# Confusion matrix saved as results/adasyn/FFmpeg/confusion_matrix_adasyn_FFmpeg.png
