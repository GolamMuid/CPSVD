# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT tcpdump -> Test on tcpdump
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "tcpdump"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/tcpdump"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-tcpdump)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (tcpdump)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled tcpdump
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (tcpdump Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except tcpdump -> Test on tcpdump (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (tcpdump)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (tcpdump Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_tcpdump",
        "test"              : "tcpdump",
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_tcpdump.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_tcpdump.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except tcpdump -> Test on tcpdump (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (223901, 768)  vuln=5904  benign=217997
#       Projects in training pool : 753
#       Test set (tcpdump)          : (632, 768)  vuln=100  benign=532
#       Training imbalance ratio  : 0.0264
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (223901, 768)  vuln=5904  benign=217997
#       After ADASYN  : (435002, 768)  vuln=217005  benign=217997
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5323
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4735
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4359
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4032
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3732
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3458
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3240
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.3024
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2773
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2596
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2444
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2300
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2179
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2046
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1945
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1861
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1783
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1711
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1639
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1556
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1505
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1439
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1427
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1398
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1311
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1279
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1220
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1199
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1132
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1162
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1016
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0972
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0970
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0922
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0931
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0913
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0973
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0879
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0840
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0897
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0824
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0821
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0821
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0817
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0794
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0751
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0762
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0719
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0683
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0754
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0675
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0745
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0614
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0593
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0640
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0631
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0557
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0590
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0542
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0533
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0544
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0542
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0482
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0485
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0507
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0488
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0495
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0459
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0456
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0472
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0442
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0434
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0457
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0430
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0424
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0417
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.5222
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.4596
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.4200
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.3913
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.3581
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.3342
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.3028
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.2819
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.2677
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.2438
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.2299
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.2144
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.2035
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1940
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1829
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1741
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1661
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1599
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1517
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1465
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1411
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1376
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1356
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1325
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1244
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1187
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1184
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1134
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1086
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1117
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1046
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0984
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1009
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1004
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0923
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0895
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0906
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0894
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0890
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0890
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0814
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0808
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0803
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0790
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0802
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0822
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0792
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0755
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1045
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0733
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0683
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0708
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0650
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0612
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0726
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0588
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0677
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0607
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0566
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0562
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0535
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0535
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0606
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0525
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0579
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0528
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0565
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0483
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0484
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0494
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0462
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0479
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0438
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0435
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0469
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0426
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0458
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0457
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.5282
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.4730
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.4358
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.4026
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.3769
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.3506
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.3252
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.2981
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.2789
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.2600
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.2412
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.2307
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.2156
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.2036
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1918
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1850
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1749
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1699
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1568
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1515
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1451
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1441
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1375
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1386
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1297
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1236
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1183
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1146
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1139
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1097
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1078
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1048
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0999
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0994
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0960
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0955
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0943
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0922
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0872
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0895
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0868
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0826
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0908
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0830
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0794
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0819
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0779
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0827
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0882
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0765
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0718
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0745
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0655
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0657
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0651
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0644
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0587
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0631
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0577
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0552
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0541
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0562
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0549
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0571
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0508
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0509
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0592
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0504
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0490
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0475
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0469
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0491
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0501
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0447
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0425
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0451
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0413
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0435
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (tcpdump Test Set) ===
# Accuracy  : 0.521
# Precision : 0.234
# Recall    : 0.890
# F1-score  : 0.370
# AUC       : 0.764
# G-mean    : 0.634
# PF value  : 0.549
#
# Confusion Matrix:
#   TN: 240  FP: 292
#   FN: 11  TP: 89
#
# Results saved to results/adasyn/tcpdump/adasyn_tcpdump.json
# Confusion matrix saved as results/adasyn/tcpdump/confusion_matrix_adasyn_tcpdump.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/radare2"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-radare2)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (radare2)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled radare2
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_radare2",
        "test"              : "radare2",
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except radare2 -> Test on radare2 (ADASYN) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221730, 768)  vuln=5930  benign=215800
#       Projects in training pool : 753
#       Test set (radare2)          : (2803, 768)  vuln=74  benign=2729
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Applying ADASYN...
#       Before ADASYN : (221730, 768)  vuln=5930  benign=215800
#       After ADASYN  : (431662, 768)  vuln=215862  benign=215800
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.5335
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.4733
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.4348
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.4032
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.3713
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.3448
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.3201
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.2969
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.2778
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.2574
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.2433
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.2308
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.2198
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.2044
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1970
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1870
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1794
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1747
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1620
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1600
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1610
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1451
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1422
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1394
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1308
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1267
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1226
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1192
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1156
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1127
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1182
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1118
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1012
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0994
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0988
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0966
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0925
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0887
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0881
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0878
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0848
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0876
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0824
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0941
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0800
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0838
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0801
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0757
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 374
#     370     plot_confusion_matrix(tn, fp, fn, tp, cm_path)
#     373 if __name__ == "__main__":
# --> 374     main()
#
# Cell In[2], line 291, in main()
#     289 for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
#     290     print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
# --> 291     model_nn, _ = semi_supervised_transfer_learning(
#     292         train_emb_ada, train_lbl_ada,
#     293         test_emb,
#     294         iteration=i+1
#     295     )
#     297     print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
#     298     model_nn.eval()
#
# Cell In[2], line 167, in semi_supervised_transfer_learning(x_train, y_train, x_test, iteration)
#     164 dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
#     165 dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)
# --> 167 model = train_neural_network(
#     168     model, dataloader_aug, x_aug_val_t, y_aug_val_t,
#     169     optimizer, criterion,
#     170     epochs=30,
#     171     desc=f"Iter {iteration} - Phase 2"
#     172 )
#     174 model.eval()
#     175 with torch.no_grad():
#
# Cell In[2], line 108, in train_neural_network(model, dataloader, x_val, y_val, optimizer, criterion, epochs, desc)
#     106 y_batch = y_batch.to(DEVICE)
#     107 optimizer.zero_grad()
# --> 108 loss = criterion(model(x_batch).squeeze(), y_batch)
#     109 loss.backward()
#     110 optimizer.step()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/modules/loss.py:710, in BCELoss.forward(self, input, target)
#     706 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     707     """
#     708     Runs the forward pass.
#     709     """
# --> 710     return F.binary_cross_entropy(
#     711         input, target, weight=self.weight, reduction=self.reduction
#     712     )
#
# File /opt/miniconda3/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:3564, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3562     reduction_enum = _Reduction.get_enum(reduction)
#    3563 if target.size() != input.size():
# -> 3564     raise ValueError(
#    3565         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3566         "Please ensure they have the same size."
#    3567     )
#    3569 if weight is not None:
#    3570     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FreeRDP -> Test on FreeRDP
ADASYN Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FreeRDP"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/adasyn/FreeRDP"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(x_batch).squeeze(), y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = nn.BCELoss()

    # Phase 1: Train on ADASYN-oversampled source (all-except-FreeRDP)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (FreeRDP)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled FreeRDP
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, sample_weights=None):
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FreeRDP Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FreeRDP -> Test on FreeRDP (ADASYN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FreeRDP)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Apply ADASYN to training pool only
    # ----------------------------------------------------------
    print("\n[3/5] Applying ADASYN...")
    adasyn                        = ADASYN(random_state=SEED)
    train_emb_ada, train_lbl_ada  = adasyn.fit_resample(train_emb, train_lbl)
    train_emb_ada                 = train_emb_ada.astype(np.float32)
    train_lbl_ada                 = train_lbl_ada.astype(np.int32)
    print(f"      Before ADASYN : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      After ADASYN  : {train_emb_ada.shape}  "
          f"vuln={train_lbl_ada.sum()}  benign={int((train_lbl_ada == 0).sum())}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb_ada, train_lbl_ada,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_ada, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl_ada == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(train_emb_ada, train_lbl_ada, sample_weights)
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FreeRDP Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"        : "adasyn",
        "train"             : "all_except_FreeRDP",
        "test"              : "FreeRDP",
        "n_train_projects"  : int(len(set(proj_all[train_mask]))),
        "n_train_samples"   : int(len(train_lbl)),
        "n_train_adasyn"    : int(len(train_lbl_ada)),
        "n_test_samples"    : int(len(test_lbl)),
        "n_vuln_train"      : int(train_lbl.sum()),
        "n_vuln_train_adasyn": int(train_lbl_ada.sum()),
        "n_vuln_test"       : int(test_lbl.sum()),
        "accuracy"          : round(float(accuracy),  4),
        "precision"         : round(float(precision), 4),
        "recall"            : round(float(recall),    4),
        "f1"                : round(float(f1),        4),
        "auc"               : round(float(auc),        4),
        "g_mean"            : round(float(g_mean),    4),
        "pf"                : round(float(pf),        4),
        "confusion_matrix"  : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "adasyn_FreeRDP.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_adasyn_FreeRDP.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
