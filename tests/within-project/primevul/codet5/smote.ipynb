# %%
"""
Within-Project Vulnerability Detection on PrimeVul
---------------------------------------------------
Train on linux (train split) -> Test on linux (test split)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
PROJECT    = "linux"
TRAIN_FILE = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE  = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/smote"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc,
                         class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (nn.BCELoss(reduction='none')(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (nn.BCELoss(reduction='none')(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Within-Project Training (no pseudo-labelling)
# =========================================================
def train_within_project(x_train, y_train, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t  = torch.tensor(x_tr,  dtype=torch.float32)
    y_tr_t  = torch.tensor(y_tr,  dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, None,
        epochs=50,
        desc=f"Iter {iteration} - Within-Project",
        class_weights=class_weights
    )

    return model


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights,
                         sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({PROJECT} Within-Project — SMOTE)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Within-Project: {PROJECT} | SMOTE ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Filter both splits to linux only
    train_mask = proj_tr == PROJECT
    test_mask  = proj_te == PROJECT

    train_emb = X_tr[train_mask].astype(np.float32)
    train_lbl = y_tr[train_mask].astype(np.int32)
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError(f"No training samples found for '{PROJECT}' in {TRAIN_FILE}.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No test samples found for '{PROJECT}' in {TEST_FILE}.")

    print(f"      Train ({PROJECT}): {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test  ({PROJECT}): {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Train imbalance ratio: {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/6] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] Apply SMOTE on training split only
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE...")
    n_neg_before = int(np.sum(train_lbl == 0))
    n_pos_before = int(np.sum(train_lbl == 1))
    print(f"      Before SMOTE — benign: {n_neg_before} | vuln: {n_pos_before} "
          f"| ratio: {n_neg_before / n_pos_before:.2f}")

    smote = SMOTE(random_state=SEED)
    train_emb_res, train_lbl_res = smote.fit_resample(train_emb, train_lbl)
    train_emb_res = train_emb_res.astype(np.float32)
    train_lbl_res = train_lbl_res.astype(np.int32)

    n_neg_after = int(np.sum(train_lbl_res == 0))
    n_pos_after = int(np.sum(train_lbl_res == 1))
    print(f"      After  SMOTE — benign: {n_neg_after} | vuln: {n_pos_after} "
          f"| ratio: {n_neg_after / n_pos_after:.2f}")

    # ----------------------------------------------------------
    # [4/6] Compute class weights from RESAMPLED train split
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_res)
    class_weights_arr = compute_class_weight(
                            class_weight='balanced',
                            classes=classes,
                            y=train_lbl_res
                        )
    class_weights     = {int(cls): float(w)
                         for cls, w in zip(classes, class_weights_arr)}
    print(f"      Class weights (post-SMOTE): {class_weights}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn = train_within_project(
            train_emb_res, train_lbl_res,
            class_weights,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_res, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(
                                    train_lbl_res == 1,
                                    y_train_pred,
                                    1 - y_train_pred
                                )
        model_xgb             = train_base_model_xgb(
                                    train_emb_res, train_lbl_res,
                                    class_weights,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({PROJECT} Within-Project Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"         : "smote_within_project",
        "setting"            : "within_project",
        "project"            : PROJECT,
        "n_train_before_smote": int(len(train_lbl)),
        "n_train_after_smote" : int(len(train_lbl_res)),
        "n_vuln_before_smote" : n_pos_before,
        "n_benign_before_smote": n_neg_before,
        "n_vuln_after_smote"  : n_pos_after,
        "n_benign_after_smote": n_neg_after,
        "n_test_samples"      : int(len(test_lbl)),
        "n_vuln_test"         : int(test_lbl.sum()),
        "class_weights"       : class_weights,
        "accuracy"            : round(float(accuracy),  4),
        "precision"           : round(float(precision), 4),
        "recall"              : round(float(recall),    4),
        "f1"                  : round(float(f1),        4),
        "auc"                 : round(float(auc),       4),
        "g_mean"              : round(float(g_mean),    4),
        "pf"                  : round(float(pf),        4),
        "confusion_matrix"    : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_within_{PROJECT}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_within_{PROJECT}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Within-Project: linux | SMOTE ===
#     Device: mps
#
# [1/6] Loading embeddings...
#       Train (linux): (43212, 256)  vuln=1002  benign=42210
#       Test  (linux): (4140, 256)  vuln=70  benign=4070
#       Train imbalance ratio: 0.0232
#
# [2/6] Normalising embeddings...
#
# [3/6] Applying SMOTE...
#       Before SMOTE — benign: 42210 | vuln: 1002 | ratio: 42.13
#       After  SMOTE — benign: 42210 | vuln: 42210 | ratio: 1.00
#
# [4/6] Computing class weights...
#       Class weights (post-SMOTE): {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Within-Project | Epoch 1/50 - val_loss: 0.6814
#       Iter 1 - Within-Project | Epoch 2/50 - val_loss: 0.5691
#       Iter 1 - Within-Project | Epoch 3/50 - val_loss: 0.4856
#       Iter 1 - Within-Project | Epoch 4/50 - val_loss: 0.4380
#       Iter 1 - Within-Project | Epoch 5/50 - val_loss: 0.4095
#       Iter 1 - Within-Project | Epoch 6/50 - val_loss: 0.3854
#       Iter 1 - Within-Project | Epoch 7/50 - val_loss: 0.3623
#       Iter 1 - Within-Project | Epoch 8/50 - val_loss: 0.3385
#       Iter 1 - Within-Project | Epoch 9/50 - val_loss: 0.3153
#       Iter 1 - Within-Project | Epoch 10/50 - val_loss: 0.2943
#       Iter 1 - Within-Project | Epoch 11/50 - val_loss: 0.2732
#       Iter 1 - Within-Project | Epoch 12/50 - val_loss: 0.2539
#       Iter 1 - Within-Project | Epoch 13/50 - val_loss: 0.2385
#       Iter 1 - Within-Project | Epoch 14/50 - val_loss: 0.2209
#       Iter 1 - Within-Project | Epoch 15/50 - val_loss: 0.2072
#       Iter 1 - Within-Project | Epoch 16/50 - val_loss: 0.1948
#       Iter 1 - Within-Project | Epoch 17/50 - val_loss: 0.1839
#       Iter 1 - Within-Project | Epoch 18/50 - val_loss: 0.1736
#       Iter 1 - Within-Project | Epoch 19/50 - val_loss: 0.1650
#       Iter 1 - Within-Project | Epoch 20/50 - val_loss: 0.1556
#       Iter 1 - Within-Project | Epoch 21/50 - val_loss: 0.1465
#       Iter 1 - Within-Project | Epoch 22/50 - val_loss: 0.1391
#       Iter 1 - Within-Project | Epoch 23/50 - val_loss: 0.1321
#       Iter 1 - Within-Project | Epoch 24/50 - val_loss: 0.1266
#       Iter 1 - Within-Project | Epoch 25/50 - val_loss: 0.1246
#       Iter 1 - Within-Project | Epoch 26/50 - val_loss: 0.1170
#       Iter 1 - Within-Project | Epoch 27/50 - val_loss: 0.1119
#       Iter 1 - Within-Project | Epoch 28/50 - val_loss: 0.1081
#       Iter 1 - Within-Project | Epoch 29/50 - val_loss: 0.1023
#       Iter 1 - Within-Project | Epoch 30/50 - val_loss: 0.1017
#       Iter 1 - Within-Project | Epoch 31/50 - val_loss: 0.0969
#       Iter 1 - Within-Project | Epoch 32/50 - val_loss: 0.0932
#       Iter 1 - Within-Project | Epoch 33/50 - val_loss: 0.0947
#       Iter 1 - Within-Project | Epoch 34/50 - val_loss: 0.0878
#       Iter 1 - Within-Project | Epoch 35/50 - val_loss: 0.0862
#       Iter 1 - Within-Project | Epoch 36/50 - val_loss: 0.0849
#       Iter 1 - Within-Project | Epoch 37/50 - val_loss: 0.0836
#       Iter 1 - Within-Project | Epoch 38/50 - val_loss: 0.0810
#       Iter 1 - Within-Project | Epoch 39/50 - val_loss: 0.0816
#       Iter 1 - Within-Project | Epoch 40/50 - val_loss: 0.0802
#       Iter 1 - Within-Project | Epoch 41/50 - val_loss: 0.0769
#       Iter 1 - Within-Project | Epoch 42/50 - val_loss: 0.0757
#       Iter 1 - Within-Project | Epoch 43/50 - val_loss: 0.0767
#       Iter 1 - Within-Project | Epoch 44/50 - val_loss: 0.0726
#       Iter 1 - Within-Project | Epoch 45/50 - val_loss: 0.0715
#       Iter 1 - Within-Project | Epoch 46/50 - val_loss: 0.0715
#       Iter 1 - Within-Project | Epoch 47/50 - val_loss: 0.0697
#       Iter 1 - Within-Project | Epoch 48/50 - val_loss: 0.0707
#       Iter 1 - Within-Project | Epoch 49/50 - val_loss: 0.0687
#       Iter 1 - Within-Project | Epoch 50/50 - val_loss: 0.0682
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Within-Project | Epoch 1/50 - val_loss: 0.6845
#       Iter 2 - Within-Project | Epoch 2/50 - val_loss: 0.5868
#       Iter 2 - Within-Project | Epoch 3/50 - val_loss: 0.4774
#       Iter 2 - Within-Project | Epoch 4/50 - val_loss: 0.4323
#       Iter 2 - Within-Project | Epoch 5/50 - val_loss: 0.4049
#       Iter 2 - Within-Project | Epoch 6/50 - val_loss: 0.3803
#       Iter 2 - Within-Project | Epoch 7/50 - val_loss: 0.3558
#       Iter 2 - Within-Project | Epoch 8/50 - val_loss: 0.3329
#       Iter 2 - Within-Project | Epoch 9/50 - val_loss: 0.3123
#       Iter 2 - Within-Project | Epoch 10/50 - val_loss: 0.2910
#       Iter 2 - Within-Project | Epoch 11/50 - val_loss: 0.2757
#       Iter 2 - Within-Project | Epoch 12/50 - val_loss: 0.2552
#       Iter 2 - Within-Project | Epoch 13/50 - val_loss: 0.2419
#       Iter 2 - Within-Project | Epoch 14/50 - val_loss: 0.2248
#       Iter 2 - Within-Project | Epoch 15/50 - val_loss: 0.2122
#       Iter 2 - Within-Project | Epoch 16/50 - val_loss: 0.2002
#       Iter 2 - Within-Project | Epoch 17/50 - val_loss: 0.1889
#       Iter 2 - Within-Project | Epoch 18/50 - val_loss: 0.1795
#       Iter 2 - Within-Project | Epoch 19/50 - val_loss: 0.1701
#       Iter 2 - Within-Project | Epoch 20/50 - val_loss: 0.1599
#       Iter 2 - Within-Project | Epoch 21/50 - val_loss: 0.1538
#       Iter 2 - Within-Project | Epoch 22/50 - val_loss: 0.1476
#       Iter 2 - Within-Project | Epoch 23/50 - val_loss: 0.1374
#       Iter 2 - Within-Project | Epoch 24/50 - val_loss: 0.1341
#       Iter 2 - Within-Project | Epoch 25/50 - val_loss: 0.1282
#       Iter 2 - Within-Project | Epoch 26/50 - val_loss: 0.1256
#       Iter 2 - Within-Project | Epoch 27/50 - val_loss: 0.1192
#       Iter 2 - Within-Project | Epoch 28/50 - val_loss: 0.1156
#       Iter 2 - Within-Project | Epoch 29/50 - val_loss: 0.1094
#       Iter 2 - Within-Project | Epoch 30/50 - val_loss: 0.1072
#       Iter 2 - Within-Project | Epoch 31/50 - val_loss: 0.1027
#       Iter 2 - Within-Project | Epoch 32/50 - val_loss: 0.1021
#       Iter 2 - Within-Project | Epoch 33/50 - val_loss: 0.0973
#       Iter 2 - Within-Project | Epoch 34/50 - val_loss: 0.0957
#       Iter 2 - Within-Project | Epoch 35/50 - val_loss: 0.0905
#       Iter 2 - Within-Project | Epoch 36/50 - val_loss: 0.0903
#       Iter 2 - Within-Project | Epoch 37/50 - val_loss: 0.0868
#       Iter 2 - Within-Project | Epoch 38/50 - val_loss: 0.0890
#       Iter 2 - Within-Project | Epoch 39/50 - val_loss: 0.0846
#       Iter 2 - Within-Project | Epoch 40/50 - val_loss: 0.0841
#       Iter 2 - Within-Project | Epoch 41/50 - val_loss: 0.0824
#       Iter 2 - Within-Project | Epoch 42/50 - val_loss: 0.0810
#       Iter 2 - Within-Project | Epoch 43/50 - val_loss: 0.0805
#       Iter 2 - Within-Project | Epoch 44/50 - val_loss: 0.0785
#       Iter 2 - Within-Project | Epoch 45/50 - val_loss: 0.0753
#       Iter 2 - Within-Project | Epoch 46/50 - val_loss: 0.0777
#       Iter 2 - Within-Project | Epoch 47/50 - val_loss: 0.0750
#       Iter 2 - Within-Project | Epoch 48/50 - val_loss: 0.0769
#       Iter 2 - Within-Project | Epoch 49/50 - val_loss: 0.0758
#       Iter 2 - Within-Project | Epoch 50/50 - val_loss: 0.0726
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Within-Project | Epoch 1/50 - val_loss: 0.6785
#       Iter 3 - Within-Project | Epoch 2/50 - val_loss: 0.5722
#       Iter 3 - Within-Project | Epoch 3/50 - val_loss: 0.4902
#       Iter 3 - Within-Project | Epoch 4/50 - val_loss: 0.4439
#       Iter 3 - Within-Project | Epoch 5/50 - val_loss: 0.4144
#       Iter 3 - Within-Project | Epoch 6/50 - val_loss: 0.3897
#       Iter 3 - Within-Project | Epoch 7/50 - val_loss: 0.3660
#       Iter 3 - Within-Project | Epoch 8/50 - val_loss: 0.3426
#       Iter 3 - Within-Project | Epoch 9/50 - val_loss: 0.3202
#       Iter 3 - Within-Project | Epoch 10/50 - val_loss: 0.2980
#       Iter 3 - Within-Project | Epoch 11/50 - val_loss: 0.2778
#       Iter 3 - Within-Project | Epoch 12/50 - val_loss: 0.2594
#       Iter 3 - Within-Project | Epoch 13/50 - val_loss: 0.2434
#       Iter 3 - Within-Project | Epoch 14/50 - val_loss: 0.2274
#       Iter 3 - Within-Project | Epoch 15/50 - val_loss: 0.2148
#       Iter 3 - Within-Project | Epoch 16/50 - val_loss: 0.2019
#       Iter 3 - Within-Project | Epoch 17/50 - val_loss: 0.1921
#       Iter 3 - Within-Project | Epoch 18/50 - val_loss: 0.1807
#       Iter 3 - Within-Project | Epoch 19/50 - val_loss: 0.1709
#       Iter 3 - Within-Project | Epoch 20/50 - val_loss: 0.1629
#       Iter 3 - Within-Project | Epoch 21/50 - val_loss: 0.1563
#       Iter 3 - Within-Project | Epoch 22/50 - val_loss: 0.1501
#       Iter 3 - Within-Project | Epoch 23/50 - val_loss: 0.1409
#       Iter 3 - Within-Project | Epoch 24/50 - val_loss: 0.1350
#       Iter 3 - Within-Project | Epoch 25/50 - val_loss: 0.1289
#       Iter 3 - Within-Project | Epoch 26/50 - val_loss: 0.1241
#       Iter 3 - Within-Project | Epoch 27/50 - val_loss: 0.1171
#       Iter 3 - Within-Project | Epoch 28/50 - val_loss: 0.1127
#       Iter 3 - Within-Project | Epoch 29/50 - val_loss: 0.1098
#       Iter 3 - Within-Project | Epoch 30/50 - val_loss: 0.1054
#       Iter 3 - Within-Project | Epoch 31/50 - val_loss: 0.1024
#       Iter 3 - Within-Project | Epoch 32/50 - val_loss: 0.0972
#       Iter 3 - Within-Project | Epoch 33/50 - val_loss: 0.0967
#       Iter 3 - Within-Project | Epoch 34/50 - val_loss: 0.0946
#       Iter 3 - Within-Project | Epoch 35/50 - val_loss: 0.0923
#       Iter 3 - Within-Project | Epoch 36/50 - val_loss: 0.0892
#       Iter 3 - Within-Project | Epoch 37/50 - val_loss: 0.0855
#       Iter 3 - Within-Project | Epoch 38/50 - val_loss: 0.0826
#       Iter 3 - Within-Project | Epoch 39/50 - val_loss: 0.0844
#       Iter 3 - Within-Project | Epoch 40/50 - val_loss: 0.0820
#       Iter 3 - Within-Project | Epoch 41/50 - val_loss: 0.0826
#       Iter 3 - Within-Project | Epoch 42/50 - val_loss: 0.0798
#       Iter 3 - Within-Project | Epoch 43/50 - val_loss: 0.0793
#       Iter 3 - Within-Project | Epoch 44/50 - val_loss: 0.0786
#       Iter 3 - Within-Project | Epoch 45/50 - val_loss: 0.0744
#       Iter 3 - Within-Project | Epoch 46/50 - val_loss: 0.0751
#       Iter 3 - Within-Project | Epoch 47/50 - val_loss: 0.0733
#       Iter 3 - Within-Project | Epoch 48/50 - val_loss: 0.0748
#       Iter 3 - Within-Project | Epoch 49/50 - val_loss: 0.0726
#       Iter 3 - Within-Project | Epoch 50/50 - val_loss: 0.0736
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (linux Within-Project Test Set) ===
# Accuracy  : 0.889
# Precision : 0.047
# Recall    : 0.286
# F1-score  : 0.080
# AUC       : 0.673
# G-mean    : 0.507
# PF value  : 0.101
#
# Confusion Matrix:
#   TN: 3660  FP: 410
#   FN: 50  TP: 20
#
# Results saved to results/smote/smote_within_linux.json
# Confusion matrix saved as results/smote/confusion_matrix_smote_within_linux.png

# %%
"""
Within-Project Vulnerability Detection on PrimeVul
---------------------------------------------------
Train on tensorflow (train split) -> Test on tensorflow (test split)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
PROJECT    = "tensorflow"
TRAIN_FILE = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE  = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/smote"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc,
                         class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (nn.BCELoss(reduction='none')(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (nn.BCELoss(reduction='none')(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Within-Project Training (no pseudo-labelling)
# =========================================================
def train_within_project(x_train, y_train, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t  = torch.tensor(x_tr,  dtype=torch.float32)
    y_tr_t  = torch.tensor(y_tr,  dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, None,
        epochs=50,
        desc=f"Iter {iteration} - Within-Project",
        class_weights=class_weights
    )

    return model


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights,
                         sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({PROJECT} Within-Project — SMOTE)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Within-Project: {PROJECT} | SMOTE ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Filter both splits to tensorflow only
    train_mask = proj_tr == PROJECT
    test_mask  = proj_te == PROJECT

    train_emb = X_tr[train_mask].astype(np.float32)
    train_lbl = y_tr[train_mask].astype(np.int32)
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError(f"No training samples found for '{PROJECT}' in {TRAIN_FILE}.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No test samples found for '{PROJECT}' in {TEST_FILE}.")

    print(f"      Train ({PROJECT}): {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test  ({PROJECT}): {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Train imbalance ratio: {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/6] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] Apply SMOTE on training split only
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE...")
    n_neg_before = int(np.sum(train_lbl == 0))
    n_pos_before = int(np.sum(train_lbl == 1))
    print(f"      Before SMOTE — benign: {n_neg_before} | vuln: {n_pos_before} "
          f"| ratio: {n_neg_before / n_pos_before:.2f}")

    smote = SMOTE(random_state=SEED)
    train_emb_res, train_lbl_res = smote.fit_resample(train_emb, train_lbl)
    train_emb_res = train_emb_res.astype(np.float32)
    train_lbl_res = train_lbl_res.astype(np.int32)

    n_neg_after = int(np.sum(train_lbl_res == 0))
    n_pos_after = int(np.sum(train_lbl_res == 1))
    print(f"      After  SMOTE — benign: {n_neg_after} | vuln: {n_pos_after} "
          f"| ratio: {n_neg_after / n_pos_after:.2f}")

    # ----------------------------------------------------------
    # [4/6] Compute class weights from RESAMPLED train split
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_res)
    class_weights_arr = compute_class_weight(
                            class_weight='balanced',
                            classes=classes,
                            y=train_lbl_res
                        )
    class_weights     = {int(cls): float(w)
                         for cls, w in zip(classes, class_weights_arr)}
    print(f"      Class weights (post-SMOTE): {class_weights}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn = train_within_project(
            train_emb_res, train_lbl_res,
            class_weights,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_res, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(
                                    train_lbl_res == 1,
                                    y_train_pred,
                                    1 - y_train_pred
                                )
        model_xgb             = train_base_model_xgb(
                                    train_emb_res, train_lbl_res,
                                    class_weights,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({PROJECT} Within-Project Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"         : "smote_within_project",
        "setting"            : "within_project",
        "project"            : PROJECT,
        "n_train_before_smote": int(len(train_lbl)),
        "n_train_after_smote" : int(len(train_lbl_res)),
        "n_vuln_before_smote" : n_pos_before,
        "n_benign_before_smote": n_neg_before,
        "n_vuln_after_smote"  : n_pos_after,
        "n_benign_after_smote": n_neg_after,
        "n_test_samples"      : int(len(test_lbl)),
        "n_vuln_test"         : int(test_lbl.sum()),
        "class_weights"       : class_weights,
        "accuracy"            : round(float(accuracy),  4),
        "precision"           : round(float(precision), 4),
        "recall"              : round(float(recall),    4),
        "f1"                  : round(float(f1),        4),
        "auc"                 : round(float(auc),       4),
        "g_mean"              : round(float(g_mean),    4),
        "pf"                  : round(float(pf),        4),
        "confusion_matrix"    : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_within_{PROJECT}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_within_{PROJECT}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Within-Project: tensorflow | SMOTE ===
#     Device: mps
#
# [1/6] Loading embeddings...
#       Train (tensorflow): (1089, 768)  vuln=76  benign=1013
#       Test  (tensorflow): (1313, 768)  vuln=91  benign=1222
#       Train imbalance ratio: 0.0698
#
# [2/6] Normalising embeddings...
#
# [3/6] Applying SMOTE...
#       Before SMOTE — benign: 1013 | vuln: 76 | ratio: 13.33
#       After  SMOTE — benign: 1013 | vuln: 1013 | ratio: 1.00
#
# [4/6] Computing class weights...
#       Class weights (post-SMOTE): {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Within-Project | Epoch 1/50 - val_loss: 0.6909
#       Iter 1 - Within-Project | Epoch 2/50 - val_loss: 0.6893
#       Iter 1 - Within-Project | Epoch 3/50 - val_loss: 0.6877
#       Iter 1 - Within-Project | Epoch 4/50 - val_loss: 0.6860
#       Iter 1 - Within-Project | Epoch 5/50 - val_loss: 0.6842
#       Iter 1 - Within-Project | Epoch 6/50 - val_loss: 0.6823
#       Iter 1 - Within-Project | Epoch 7/50 - val_loss: 0.6801
#       Iter 1 - Within-Project | Epoch 8/50 - val_loss: 0.6776
#       Iter 1 - Within-Project | Epoch 9/50 - val_loss: 0.6745
#       Iter 1 - Within-Project | Epoch 10/50 - val_loss: 0.6709
#       Iter 1 - Within-Project | Epoch 11/50 - val_loss: 0.6666
#       Iter 1 - Within-Project | Epoch 12/50 - val_loss: 0.6621
#       Iter 1 - Within-Project | Epoch 13/50 - val_loss: 0.6568
#       Iter 1 - Within-Project | Epoch 14/50 - val_loss: 0.6509
#       Iter 1 - Within-Project | Epoch 15/50 - val_loss: 0.6444
#       Iter 1 - Within-Project | Epoch 16/50 - val_loss: 0.6374
#       Iter 1 - Within-Project | Epoch 17/50 - val_loss: 0.6299
#       Iter 1 - Within-Project | Epoch 18/50 - val_loss: 0.6219
#       Iter 1 - Within-Project | Epoch 19/50 - val_loss: 0.6138
#       Iter 1 - Within-Project | Epoch 20/50 - val_loss: 0.6048
#       Iter 1 - Within-Project | Epoch 21/50 - val_loss: 0.5959
#       Iter 1 - Within-Project | Epoch 22/50 - val_loss: 0.5875
#       Iter 1 - Within-Project | Epoch 23/50 - val_loss: 0.5791
#       Iter 1 - Within-Project | Epoch 24/50 - val_loss: 0.5705
#       Iter 1 - Within-Project | Epoch 25/50 - val_loss: 0.5623
#       Iter 1 - Within-Project | Epoch 26/50 - val_loss: 0.5543
#       Iter 1 - Within-Project | Epoch 27/50 - val_loss: 0.5463
#       Iter 1 - Within-Project | Epoch 28/50 - val_loss: 0.5385
#       Iter 1 - Within-Project | Epoch 29/50 - val_loss: 0.5314
#       Iter 1 - Within-Project | Epoch 30/50 - val_loss: 0.5244
#       Iter 1 - Within-Project | Epoch 31/50 - val_loss: 0.5176
#       Iter 1 - Within-Project | Epoch 32/50 - val_loss: 0.5112
#       Iter 1 - Within-Project | Epoch 33/50 - val_loss: 0.5049
#       Iter 1 - Within-Project | Epoch 34/50 - val_loss: 0.4988
#       Iter 1 - Within-Project | Epoch 35/50 - val_loss: 0.4927
#       Iter 1 - Within-Project | Epoch 36/50 - val_loss: 0.4871
#       Iter 1 - Within-Project | Epoch 37/50 - val_loss: 0.4819
#       Iter 1 - Within-Project | Epoch 38/50 - val_loss: 0.4771
#       Iter 1 - Within-Project | Epoch 39/50 - val_loss: 0.4727
#       Iter 1 - Within-Project | Epoch 40/50 - val_loss: 0.4688
#       Iter 1 - Within-Project | Epoch 41/50 - val_loss: 0.4654
#       Iter 1 - Within-Project | Epoch 42/50 - val_loss: 0.4622
#       Iter 1 - Within-Project | Epoch 43/50 - val_loss: 0.4597
#       Iter 1 - Within-Project | Epoch 44/50 - val_loss: 0.4573
#       Iter 1 - Within-Project | Epoch 45/50 - val_loss: 0.4552
#       Iter 1 - Within-Project | Epoch 46/50 - val_loss: 0.4535
#       Iter 1 - Within-Project | Epoch 47/50 - val_loss: 0.4520
#       Iter 1 - Within-Project | Epoch 48/50 - val_loss: 0.4506
#       Iter 1 - Within-Project | Epoch 49/50 - val_loss: 0.4491
#       Iter 1 - Within-Project | Epoch 50/50 - val_loss: 0.4477
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Within-Project | Epoch 1/50 - val_loss: 0.6966
#       Iter 2 - Within-Project | Epoch 2/50 - val_loss: 0.6947
#       Iter 2 - Within-Project | Epoch 3/50 - val_loss: 0.6931
#       Iter 2 - Within-Project | Epoch 4/50 - val_loss: 0.6916
#       Iter 2 - Within-Project | Epoch 5/50 - val_loss: 0.6902
#       Iter 2 - Within-Project | Epoch 6/50 - val_loss: 0.6887
#       Iter 2 - Within-Project | Epoch 7/50 - val_loss: 0.6868
#       Iter 2 - Within-Project | Epoch 8/50 - val_loss: 0.6846
#       Iter 2 - Within-Project | Epoch 9/50 - val_loss: 0.6822
#       Iter 2 - Within-Project | Epoch 10/50 - val_loss: 0.6796
#       Iter 2 - Within-Project | Epoch 11/50 - val_loss: 0.6769
#       Iter 2 - Within-Project | Epoch 12/50 - val_loss: 0.6734
#       Iter 2 - Within-Project | Epoch 13/50 - val_loss: 0.6693
#       Iter 2 - Within-Project | Epoch 14/50 - val_loss: 0.6645
#       Iter 2 - Within-Project | Epoch 15/50 - val_loss: 0.6590
#       Iter 2 - Within-Project | Epoch 16/50 - val_loss: 0.6527
#       Iter 2 - Within-Project | Epoch 17/50 - val_loss: 0.6458
#       Iter 2 - Within-Project | Epoch 18/50 - val_loss: 0.6382
#       Iter 2 - Within-Project | Epoch 19/50 - val_loss: 0.6297
#       Iter 2 - Within-Project | Epoch 20/50 - val_loss: 0.6205
#       Iter 2 - Within-Project | Epoch 21/50 - val_loss: 0.6105
#       Iter 2 - Within-Project | Epoch 22/50 - val_loss: 0.6000
#       Iter 2 - Within-Project | Epoch 23/50 - val_loss: 0.5894
#       Iter 2 - Within-Project | Epoch 24/50 - val_loss: 0.5783
#       Iter 2 - Within-Project | Epoch 25/50 - val_loss: 0.5673
#       Iter 2 - Within-Project | Epoch 26/50 - val_loss: 0.5566
#       Iter 2 - Within-Project | Epoch 27/50 - val_loss: 0.5459
#       Iter 2 - Within-Project | Epoch 28/50 - val_loss: 0.5355
#       Iter 2 - Within-Project | Epoch 29/50 - val_loss: 0.5255
#       Iter 2 - Within-Project | Epoch 30/50 - val_loss: 0.5159
#       Iter 2 - Within-Project | Epoch 31/50 - val_loss: 0.5069
#       Iter 2 - Within-Project | Epoch 32/50 - val_loss: 0.4983
#       Iter 2 - Within-Project | Epoch 33/50 - val_loss: 0.4903
#       Iter 2 - Within-Project | Epoch 34/50 - val_loss: 0.4836
#       Iter 2 - Within-Project | Epoch 35/50 - val_loss: 0.4776
#       Iter 2 - Within-Project | Epoch 36/50 - val_loss: 0.4725
#       Iter 2 - Within-Project | Epoch 37/50 - val_loss: 0.4685
#       Iter 2 - Within-Project | Epoch 38/50 - val_loss: 0.4646
#       Iter 2 - Within-Project | Epoch 39/50 - val_loss: 0.4618
#       Iter 2 - Within-Project | Epoch 40/50 - val_loss: 0.4595
#       Iter 2 - Within-Project | Epoch 41/50 - val_loss: 0.4574
#       Iter 2 - Within-Project | Epoch 42/50 - val_loss: 0.4555
#       Iter 2 - Within-Project | Epoch 43/50 - val_loss: 0.4538
#       Iter 2 - Within-Project | Epoch 44/50 - val_loss: 0.4524
#       Iter 2 - Within-Project | Epoch 45/50 - val_loss: 0.4510
#       Iter 2 - Within-Project | Epoch 46/50 - val_loss: 0.4497
#       Iter 2 - Within-Project | Epoch 47/50 - val_loss: 0.4484
#       Iter 2 - Within-Project | Epoch 48/50 - val_loss: 0.4474
#       Iter 2 - Within-Project | Epoch 49/50 - val_loss: 0.4464
#       Iter 2 - Within-Project | Epoch 50/50 - val_loss: 0.4453
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Within-Project | Epoch 1/50 - val_loss: 0.6927
#       Iter 3 - Within-Project | Epoch 2/50 - val_loss: 0.6917
#       Iter 3 - Within-Project | Epoch 3/50 - val_loss: 0.6905
#       Iter 3 - Within-Project | Epoch 4/50 - val_loss: 0.6889
#       Iter 3 - Within-Project | Epoch 5/50 - val_loss: 0.6869
#       Iter 3 - Within-Project | Epoch 6/50 - val_loss: 0.6847
#       Iter 3 - Within-Project | Epoch 7/50 - val_loss: 0.6822
#       Iter 3 - Within-Project | Epoch 8/50 - val_loss: 0.6791
#       Iter 3 - Within-Project | Epoch 9/50 - val_loss: 0.6751
#       Iter 3 - Within-Project | Epoch 10/50 - val_loss: 0.6701
#       Iter 3 - Within-Project | Epoch 11/50 - val_loss: 0.6639
#       Iter 3 - Within-Project | Epoch 12/50 - val_loss: 0.6567
#       Iter 3 - Within-Project | Epoch 13/50 - val_loss: 0.6481
#       Iter 3 - Within-Project | Epoch 14/50 - val_loss: 0.6384
#       Iter 3 - Within-Project | Epoch 15/50 - val_loss: 0.6271
#       Iter 3 - Within-Project | Epoch 16/50 - val_loss: 0.6147
#       Iter 3 - Within-Project | Epoch 17/50 - val_loss: 0.6011
#       Iter 3 - Within-Project | Epoch 18/50 - val_loss: 0.5873
#       Iter 3 - Within-Project | Epoch 19/50 - val_loss: 0.5733
#       Iter 3 - Within-Project | Epoch 20/50 - val_loss: 0.5592
#       Iter 3 - Within-Project | Epoch 21/50 - val_loss: 0.5462
#       Iter 3 - Within-Project | Epoch 22/50 - val_loss: 0.5335
#       Iter 3 - Within-Project | Epoch 23/50 - val_loss: 0.5219
#       Iter 3 - Within-Project | Epoch 24/50 - val_loss: 0.5112
#       Iter 3 - Within-Project | Epoch 25/50 - val_loss: 0.5018
#       Iter 3 - Within-Project | Epoch 26/50 - val_loss: 0.4938
#       Iter 3 - Within-Project | Epoch 27/50 - val_loss: 0.4863
#       Iter 3 - Within-Project | Epoch 28/50 - val_loss: 0.4804
#       Iter 3 - Within-Project | Epoch 29/50 - val_loss: 0.4757
#       Iter 3 - Within-Project | Epoch 30/50 - val_loss: 0.4717
#       Iter 3 - Within-Project | Epoch 31/50 - val_loss: 0.4682
#       Iter 3 - Within-Project | Epoch 32/50 - val_loss: 0.4651
#       Iter 3 - Within-Project | Epoch 33/50 - val_loss: 0.4625
#       Iter 3 - Within-Project | Epoch 34/50 - val_loss: 0.4602
#       Iter 3 - Within-Project | Epoch 35/50 - val_loss: 0.4581
#       Iter 3 - Within-Project | Epoch 36/50 - val_loss: 0.4560
#       Iter 3 - Within-Project | Epoch 37/50 - val_loss: 0.4540
#       Iter 3 - Within-Project | Epoch 38/50 - val_loss: 0.4524
#       Iter 3 - Within-Project | Epoch 39/50 - val_loss: 0.4507
#       Iter 3 - Within-Project | Epoch 40/50 - val_loss: 0.4492
#       Iter 3 - Within-Project | Epoch 41/50 - val_loss: 0.4474
#       Iter 3 - Within-Project | Epoch 42/50 - val_loss: 0.4458
#       Iter 3 - Within-Project | Epoch 43/50 - val_loss: 0.4443
#       Iter 3 - Within-Project | Epoch 44/50 - val_loss: 0.4426
#       Iter 3 - Within-Project | Epoch 45/50 - val_loss: 0.4411
#       Iter 3 - Within-Project | Epoch 46/50 - val_loss: 0.4390
#       Iter 3 - Within-Project | Epoch 47/50 - val_loss: 0.4368
#       Iter 3 - Within-Project | Epoch 48/50 - val_loss: 0.4349
#       Iter 3 - Within-Project | Epoch 49/50 - val_loss: 0.4320
#       Iter 3 - Within-Project | Epoch 50/50 - val_loss: 0.4301
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (tensorflow Within-Project Test Set) ===
# Accuracy  : 0.881
# Precision : 0.240
# Recall    : 0.330
# F1-score  : 0.278
# AUC       : 0.787
# G-mean    : 0.551
# PF value  : 0.078
#
# Confusion Matrix:
#   TN: 1127  FP: 95
#   FN: 61  TP: 30
#
# Results saved to results/smote/smote_within_tensorflow.json
# Confusion matrix saved as results/smote/confusion_matrix_smote_within_tensorflow.png

# %%
"""
Within-Project Vulnerability Detection on PrimeVul
---------------------------------------------------
Train on vim (train split) -> Test on vim (test split)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
PROJECT    = "vim"
TRAIN_FILE = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE  = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/smote"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc,
                         class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (nn.BCELoss(reduction='none')(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (nn.BCELoss(reduction='none')(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Within-Project Training (no pseudo-labelling)
# =========================================================
def train_within_project(x_train, y_train, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t  = torch.tensor(x_tr,  dtype=torch.float32)
    y_tr_t  = torch.tensor(y_tr,  dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, None,
        epochs=50,
        desc=f"Iter {iteration} - Within-Project",
        class_weights=class_weights
    )

    return model


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights,
                         sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({PROJECT} Within-Project — SMOTE)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Within-Project: {PROJECT} | SMOTE ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Filter both splits to vim only
    train_mask = proj_tr == PROJECT
    test_mask  = proj_te == PROJECT

    train_emb = X_tr[train_mask].astype(np.float32)
    train_lbl = y_tr[train_mask].astype(np.int32)
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError(f"No training samples found for '{PROJECT}' in {TRAIN_FILE}.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No test samples found for '{PROJECT}' in {TEST_FILE}.")

    print(f"      Train ({PROJECT}): {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test  ({PROJECT}): {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Train imbalance ratio: {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/6] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] Apply SMOTE on training split only
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE...")
    n_neg_before = int(np.sum(train_lbl == 0))
    n_pos_before = int(np.sum(train_lbl == 1))
    print(f"      Before SMOTE — benign: {n_neg_before} | vuln: {n_pos_before} "
          f"| ratio: {n_neg_before / n_pos_before:.2f}")

    smote = SMOTE(random_state=SEED)
    train_emb_res, train_lbl_res = smote.fit_resample(train_emb, train_lbl)
    train_emb_res = train_emb_res.astype(np.float32)
    train_lbl_res = train_lbl_res.astype(np.int32)

    n_neg_after = int(np.sum(train_lbl_res == 0))
    n_pos_after = int(np.sum(train_lbl_res == 1))
    print(f"      After  SMOTE — benign: {n_neg_after} | vuln: {n_pos_after} "
          f"| ratio: {n_neg_after / n_pos_after:.2f}")

    # ----------------------------------------------------------
    # [4/6] Compute class weights from RESAMPLED train split
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_res)
    class_weights_arr = compute_class_weight(
                            class_weight='balanced',
                            classes=classes,
                            y=train_lbl_res
                        )
    class_weights     = {int(cls): float(w)
                         for cls, w in zip(classes, class_weights_arr)}
    print(f"      Class weights (post-SMOTE): {class_weights}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn = train_within_project(
            train_emb_res, train_lbl_res,
            class_weights,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_res, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(
                                    train_lbl_res == 1,
                                    y_train_pred,
                                    1 - y_train_pred
                                )
        model_xgb             = train_base_model_xgb(
                                    train_emb_res, train_lbl_res,
                                    class_weights,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({PROJECT} Within-Project Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"         : "smote_within_project",
        "setting"            : "within_project",
        "project"            : PROJECT,
        "n_train_before_smote": int(len(train_lbl)),
        "n_train_after_smote" : int(len(train_lbl_res)),
        "n_vuln_before_smote" : n_pos_before,
        "n_benign_before_smote": n_neg_before,
        "n_vuln_after_smote"  : n_pos_after,
        "n_benign_after_smote": n_neg_after,
        "n_test_samples"      : int(len(test_lbl)),
        "n_vuln_test"         : int(test_lbl.sum()),
        "class_weights"       : class_weights,
        "accuracy"            : round(float(accuracy),  4),
        "precision"           : round(float(precision), 4),
        "recall"              : round(float(recall),    4),
        "f1"                  : round(float(f1),        4),
        "auc"                 : round(float(auc),       4),
        "g_mean"              : round(float(g_mean),    4),
        "pf"                  : round(float(pf),        4),
        "confusion_matrix"    : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_within_{PROJECT}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_within_{PROJECT}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Within-Project: vim | SMOTE ===
#     Device: mps
#
# [1/6] Loading embeddings...
#       Train (vim): (951, 768)  vuln=38  benign=913
#       Test  (vim): (1669, 768)  vuln=61  benign=1608
#       Train imbalance ratio: 0.0400
#
# [2/6] Normalising embeddings...
#
# [3/6] Applying SMOTE...
#       Before SMOTE — benign: 913 | vuln: 38 | ratio: 24.03
#       After  SMOTE — benign: 913 | vuln: 913 | ratio: 1.00
#
# [4/6] Computing class weights...
#       Class weights (post-SMOTE): {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Within-Project | Epoch 1/50 - val_loss: 0.6926
#       Iter 1 - Within-Project | Epoch 2/50 - val_loss: 0.6914
#       Iter 1 - Within-Project | Epoch 3/50 - val_loss: 0.6904
#       Iter 1 - Within-Project | Epoch 4/50 - val_loss: 0.6894
#       Iter 1 - Within-Project | Epoch 5/50 - val_loss: 0.6884
#       Iter 1 - Within-Project | Epoch 6/50 - val_loss: 0.6874
#       Iter 1 - Within-Project | Epoch 7/50 - val_loss: 0.6860
#       Iter 1 - Within-Project | Epoch 8/50 - val_loss: 0.6844
#       Iter 1 - Within-Project | Epoch 9/50 - val_loss: 0.6824
#       Iter 1 - Within-Project | Epoch 10/50 - val_loss: 0.6800
#       Iter 1 - Within-Project | Epoch 11/50 - val_loss: 0.6774
#       Iter 1 - Within-Project | Epoch 12/50 - val_loss: 0.6745
#       Iter 1 - Within-Project | Epoch 13/50 - val_loss: 0.6713
#       Iter 1 - Within-Project | Epoch 14/50 - val_loss: 0.6678
#       Iter 1 - Within-Project | Epoch 15/50 - val_loss: 0.6640
#       Iter 1 - Within-Project | Epoch 16/50 - val_loss: 0.6602
#       Iter 1 - Within-Project | Epoch 17/50 - val_loss: 0.6561
#       Iter 1 - Within-Project | Epoch 18/50 - val_loss: 0.6520
#       Iter 1 - Within-Project | Epoch 19/50 - val_loss: 0.6477
#       Iter 1 - Within-Project | Epoch 20/50 - val_loss: 0.6432
#       Iter 1 - Within-Project | Epoch 21/50 - val_loss: 0.6388
#       Iter 1 - Within-Project | Epoch 22/50 - val_loss: 0.6345
#       Iter 1 - Within-Project | Epoch 23/50 - val_loss: 0.6302
#       Iter 1 - Within-Project | Epoch 24/50 - val_loss: 0.6261
#       Iter 1 - Within-Project | Epoch 25/50 - val_loss: 0.6222
#       Iter 1 - Within-Project | Epoch 26/50 - val_loss: 0.6187
#       Iter 1 - Within-Project | Epoch 27/50 - val_loss: 0.6154
#       Iter 1 - Within-Project | Epoch 28/50 - val_loss: 0.6122
#       Iter 1 - Within-Project | Epoch 29/50 - val_loss: 0.6095
#       Iter 1 - Within-Project | Epoch 30/50 - val_loss: 0.6070
#       Iter 1 - Within-Project | Epoch 31/50 - val_loss: 0.6047
#       Iter 1 - Within-Project | Epoch 32/50 - val_loss: 0.6025
#       Iter 1 - Within-Project | Epoch 33/50 - val_loss: 0.6003
#       Iter 1 - Within-Project | Epoch 34/50 - val_loss: 0.5984
#       Iter 1 - Within-Project | Epoch 35/50 - val_loss: 0.5964
#       Iter 1 - Within-Project | Epoch 36/50 - val_loss: 0.5944
#       Iter 1 - Within-Project | Epoch 37/50 - val_loss: 0.5924
#       Iter 1 - Within-Project | Epoch 38/50 - val_loss: 0.5902
#       Iter 1 - Within-Project | Epoch 39/50 - val_loss: 0.5881
#       Iter 1 - Within-Project | Epoch 40/50 - val_loss: 0.5855
#       Iter 1 - Within-Project | Epoch 41/50 - val_loss: 0.5831
#       Iter 1 - Within-Project | Epoch 42/50 - val_loss: 0.5808
#       Iter 1 - Within-Project | Epoch 43/50 - val_loss: 0.5784
#       Iter 1 - Within-Project | Epoch 44/50 - val_loss: 0.5761
#       Iter 1 - Within-Project | Epoch 45/50 - val_loss: 0.5736
#       Iter 1 - Within-Project | Epoch 46/50 - val_loss: 0.5711
#       Iter 1 - Within-Project | Epoch 47/50 - val_loss: 0.5687
#       Iter 1 - Within-Project | Epoch 48/50 - val_loss: 0.5662
#       Iter 1 - Within-Project | Epoch 49/50 - val_loss: 0.5642
#       Iter 1 - Within-Project | Epoch 50/50 - val_loss: 0.5616
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Within-Project | Epoch 1/50 - val_loss: 0.7016
#       Iter 2 - Within-Project | Epoch 2/50 - val_loss: 0.7005
#       Iter 2 - Within-Project | Epoch 3/50 - val_loss: 0.6994
#       Iter 2 - Within-Project | Epoch 4/50 - val_loss: 0.6982
#       Iter 2 - Within-Project | Epoch 5/50 - val_loss: 0.6971
#       Iter 2 - Within-Project | Epoch 6/50 - val_loss: 0.6960
#       Iter 2 - Within-Project | Epoch 7/50 - val_loss: 0.6950
#       Iter 2 - Within-Project | Epoch 8/50 - val_loss: 0.6940
#       Iter 2 - Within-Project | Epoch 9/50 - val_loss: 0.6926
#       Iter 2 - Within-Project | Epoch 10/50 - val_loss: 0.6910
#       Iter 2 - Within-Project | Epoch 11/50 - val_loss: 0.6890
#       Iter 2 - Within-Project | Epoch 12/50 - val_loss: 0.6864
#       Iter 2 - Within-Project | Epoch 13/50 - val_loss: 0.6835
#       Iter 2 - Within-Project | Epoch 14/50 - val_loss: 0.6804
#       Iter 2 - Within-Project | Epoch 15/50 - val_loss: 0.6772
#       Iter 2 - Within-Project | Epoch 16/50 - val_loss: 0.6738
#       Iter 2 - Within-Project | Epoch 17/50 - val_loss: 0.6702
#       Iter 2 - Within-Project | Epoch 18/50 - val_loss: 0.6664
#       Iter 2 - Within-Project | Epoch 19/50 - val_loss: 0.6623
#       Iter 2 - Within-Project | Epoch 20/50 - val_loss: 0.6579
#       Iter 2 - Within-Project | Epoch 21/50 - val_loss: 0.6534
#       Iter 2 - Within-Project | Epoch 22/50 - val_loss: 0.6488
#       Iter 2 - Within-Project | Epoch 23/50 - val_loss: 0.6442
#       Iter 2 - Within-Project | Epoch 24/50 - val_loss: 0.6398
#       Iter 2 - Within-Project | Epoch 25/50 - val_loss: 0.6351
#       Iter 2 - Within-Project | Epoch 26/50 - val_loss: 0.6305
#       Iter 2 - Within-Project | Epoch 27/50 - val_loss: 0.6262
#       Iter 2 - Within-Project | Epoch 28/50 - val_loss: 0.6221
#       Iter 2 - Within-Project | Epoch 29/50 - val_loss: 0.6181
#       Iter 2 - Within-Project | Epoch 30/50 - val_loss: 0.6142
#       Iter 2 - Within-Project | Epoch 31/50 - val_loss: 0.6103
#       Iter 2 - Within-Project | Epoch 32/50 - val_loss: 0.6065
#       Iter 2 - Within-Project | Epoch 33/50 - val_loss: 0.6031
#       Iter 2 - Within-Project | Epoch 34/50 - val_loss: 0.5995
#       Iter 2 - Within-Project | Epoch 35/50 - val_loss: 0.5958
#       Iter 2 - Within-Project | Epoch 36/50 - val_loss: 0.5919
#       Iter 2 - Within-Project | Epoch 37/50 - val_loss: 0.5883
#       Iter 2 - Within-Project | Epoch 38/50 - val_loss: 0.5846
#       Iter 2 - Within-Project | Epoch 39/50 - val_loss: 0.5813
#       Iter 2 - Within-Project | Epoch 40/50 - val_loss: 0.5782
#       Iter 2 - Within-Project | Epoch 41/50 - val_loss: 0.5753
#       Iter 2 - Within-Project | Epoch 42/50 - val_loss: 0.5722
#       Iter 2 - Within-Project | Epoch 43/50 - val_loss: 0.5699
#       Iter 2 - Within-Project | Epoch 44/50 - val_loss: 0.5674
#       Iter 2 - Within-Project | Epoch 45/50 - val_loss: 0.5651
#       Iter 2 - Within-Project | Epoch 46/50 - val_loss: 0.5632
#       Iter 2 - Within-Project | Epoch 47/50 - val_loss: 0.5613
#       Iter 2 - Within-Project | Epoch 48/50 - val_loss: 0.5594
#       Iter 2 - Within-Project | Epoch 49/50 - val_loss: 0.5578
#       Iter 2 - Within-Project | Epoch 50/50 - val_loss: 0.5564
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Within-Project | Epoch 1/50 - val_loss: 0.6928
#       Iter 3 - Within-Project | Epoch 2/50 - val_loss: 0.6921
#       Iter 3 - Within-Project | Epoch 3/50 - val_loss: 0.6913
#       Iter 3 - Within-Project | Epoch 4/50 - val_loss: 0.6903
#       Iter 3 - Within-Project | Epoch 5/50 - val_loss: 0.6890
#       Iter 3 - Within-Project | Epoch 6/50 - val_loss: 0.6874
#       Iter 3 - Within-Project | Epoch 7/50 - val_loss: 0.6856
#       Iter 3 - Within-Project | Epoch 8/50 - val_loss: 0.6837
#       Iter 3 - Within-Project | Epoch 9/50 - val_loss: 0.6813
#       Iter 3 - Within-Project | Epoch 10/50 - val_loss: 0.6786
#       Iter 3 - Within-Project | Epoch 11/50 - val_loss: 0.6753
#       Iter 3 - Within-Project | Epoch 12/50 - val_loss: 0.6715
#       Iter 3 - Within-Project | Epoch 13/50 - val_loss: 0.6670
#       Iter 3 - Within-Project | Epoch 14/50 - val_loss: 0.6622
#       Iter 3 - Within-Project | Epoch 15/50 - val_loss: 0.6568
#       Iter 3 - Within-Project | Epoch 16/50 - val_loss: 0.6509
#       Iter 3 - Within-Project | Epoch 17/50 - val_loss: 0.6449
#       Iter 3 - Within-Project | Epoch 18/50 - val_loss: 0.6384
#       Iter 3 - Within-Project | Epoch 19/50 - val_loss: 0.6324
#       Iter 3 - Within-Project | Epoch 20/50 - val_loss: 0.6260
#       Iter 3 - Within-Project | Epoch 21/50 - val_loss: 0.6200
#       Iter 3 - Within-Project | Epoch 22/50 - val_loss: 0.6144
#       Iter 3 - Within-Project | Epoch 23/50 - val_loss: 0.6089
#       Iter 3 - Within-Project | Epoch 24/50 - val_loss: 0.6036
#       Iter 3 - Within-Project | Epoch 25/50 - val_loss: 0.5988
#       Iter 3 - Within-Project | Epoch 26/50 - val_loss: 0.5947
#       Iter 3 - Within-Project | Epoch 27/50 - val_loss: 0.5906
#       Iter 3 - Within-Project | Epoch 28/50 - val_loss: 0.5869
#       Iter 3 - Within-Project | Epoch 29/50 - val_loss: 0.5836
#       Iter 3 - Within-Project | Epoch 30/50 - val_loss: 0.5807
#       Iter 3 - Within-Project | Epoch 31/50 - val_loss: 0.5781
#       Iter 3 - Within-Project | Epoch 32/50 - val_loss: 0.5757
#       Iter 3 - Within-Project | Epoch 33/50 - val_loss: 0.5734
#       Iter 3 - Within-Project | Epoch 34/50 - val_loss: 0.5714
#       Iter 3 - Within-Project | Epoch 35/50 - val_loss: 0.5694
#       Iter 3 - Within-Project | Epoch 36/50 - val_loss: 0.5676
#       Iter 3 - Within-Project | Epoch 37/50 - val_loss: 0.5659
#       Iter 3 - Within-Project | Epoch 38/50 - val_loss: 0.5644
#       Iter 3 - Within-Project | Epoch 39/50 - val_loss: 0.5631
#       Iter 3 - Within-Project | Epoch 40/50 - val_loss: 0.5615
#       Iter 3 - Within-Project | Epoch 41/50 - val_loss: 0.5600
#       Iter 3 - Within-Project | Epoch 42/50 - val_loss: 0.5587
#       Iter 3 - Within-Project | Epoch 43/50 - val_loss: 0.5570
#       Iter 3 - Within-Project | Epoch 44/50 - val_loss: 0.5555
#       Iter 3 - Within-Project | Epoch 45/50 - val_loss: 0.5537
#       Iter 3 - Within-Project | Epoch 46/50 - val_loss: 0.5522
#       Iter 3 - Within-Project | Epoch 47/50 - val_loss: 0.5508
#       Iter 3 - Within-Project | Epoch 48/50 - val_loss: 0.5493
#       Iter 3 - Within-Project | Epoch 49/50 - val_loss: 0.5473
#       Iter 3 - Within-Project | Epoch 50/50 - val_loss: 0.5454
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (vim Within-Project Test Set) ===
# Accuracy  : 0.945
# Precision : 0.170
# Recall    : 0.131
# F1-score  : 0.148
# AUC       : 0.785
# G-mean    : 0.358
# PF value  : 0.024
#
# Confusion Matrix:
#   TN: 1569  FP: 39
#   FN: 53  TP: 8
#
# Results saved to results/smote/smote_within_vim.json
# Confusion matrix saved as results/smote/confusion_matrix_smote_within_vim.png

# %%
"""
Within-Project Vulnerability Detection on PrimeVul
---------------------------------------------------
Train on gpac (train split) -> Test on gpac (test split)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
PROJECT    = "gpac"
TRAIN_FILE = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE  = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/smote"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc,
                         class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (nn.BCELoss(reduction='none')(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (nn.BCELoss(reduction='none')(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Within-Project Training (no pseudo-labelling)
# =========================================================
def train_within_project(x_train, y_train, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t  = torch.tensor(x_tr,  dtype=torch.float32)
    y_tr_t  = torch.tensor(y_tr,  dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, None,
        epochs=50,
        desc=f"Iter {iteration} - Within-Project",
        class_weights=class_weights
    )

    return model


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights,
                         sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({PROJECT} Within-Project — SMOTE)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Within-Project: {PROJECT} | SMOTE ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Filter both splits to gpac only
    train_mask = proj_tr == PROJECT
    test_mask  = proj_te == PROJECT

    train_emb = X_tr[train_mask].astype(np.float32)
    train_lbl = y_tr[train_mask].astype(np.int32)
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError(f"No training samples found for '{PROJECT}' in {TRAIN_FILE}.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No test samples found for '{PROJECT}' in {TEST_FILE}.")

    print(f"      Train ({PROJECT}): {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test  ({PROJECT}): {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Train imbalance ratio: {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/6] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] Apply SMOTE on training split only
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE...")
    n_neg_before = int(np.sum(train_lbl == 0))
    n_pos_before = int(np.sum(train_lbl == 1))
    print(f"      Before SMOTE — benign: {n_neg_before} | vuln: {n_pos_before} "
          f"| ratio: {n_neg_before / n_pos_before:.2f}")

    smote = SMOTE(random_state=SEED)
    train_emb_res, train_lbl_res = smote.fit_resample(train_emb, train_lbl)
    train_emb_res = train_emb_res.astype(np.float32)
    train_lbl_res = train_lbl_res.astype(np.int32)

    n_neg_after = int(np.sum(train_lbl_res == 0))
    n_pos_after = int(np.sum(train_lbl_res == 1))
    print(f"      After  SMOTE — benign: {n_neg_after} | vuln: {n_pos_after} "
          f"| ratio: {n_neg_after / n_pos_after:.2f}")

    # ----------------------------------------------------------
    # [4/6] Compute class weights from RESAMPLED train split
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_res)
    class_weights_arr = compute_class_weight(
                            class_weight='balanced',
                            classes=classes,
                            y=train_lbl_res
                        )
    class_weights     = {int(cls): float(w)
                         for cls, w in zip(classes, class_weights_arr)}
    print(f"      Class weights (post-SMOTE): {class_weights}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn = train_within_project(
            train_emb_res, train_lbl_res,
            class_weights,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_res, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(
                                    train_lbl_res == 1,
                                    y_train_pred,
                                    1 - y_train_pred
                                )
        model_xgb             = train_base_model_xgb(
                                    train_emb_res, train_lbl_res,
                                    class_weights,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({PROJECT} Within-Project Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"         : "smote_within_project",
        "setting"            : "within_project",
        "project"            : PROJECT,
        "n_train_before_smote": int(len(train_lbl)),
        "n_train_after_smote" : int(len(train_lbl_res)),
        "n_vuln_before_smote" : n_pos_before,
        "n_benign_before_smote": n_neg_before,
        "n_vuln_after_smote"  : n_pos_after,
        "n_benign_after_smote": n_neg_after,
        "n_test_samples"      : int(len(test_lbl)),
        "n_vuln_test"         : int(test_lbl.sum()),
        "class_weights"       : class_weights,
        "accuracy"            : round(float(accuracy),  4),
        "precision"           : round(float(precision), 4),
        "recall"              : round(float(recall),    4),
        "f1"                  : round(float(f1),        4),
        "auc"                 : round(float(auc),       4),
        "g_mean"              : round(float(g_mean),    4),
        "pf"                  : round(float(pf),        4),
        "confusion_matrix"    : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_within_{PROJECT}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_within_{PROJECT}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Within-Project: gpac | SMOTE ===
#     Device: mps
#
# [1/6] Loading embeddings...
#       Train (gpac): (2775, 768)  vuln=32  benign=2743
#       Test  (gpac): (1884, 768)  vuln=18  benign=1866
#       Train imbalance ratio: 0.0115
#
# [2/6] Normalising embeddings...
#
# [3/6] Applying SMOTE...
#       Before SMOTE — benign: 2743 | vuln: 32 | ratio: 85.72
#       After  SMOTE — benign: 2743 | vuln: 2743 | ratio: 1.00
#
# [4/6] Computing class weights...
#       Class weights (post-SMOTE): {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Within-Project | Epoch 1/50 - val_loss: 0.6880
#       Iter 1 - Within-Project | Epoch 2/50 - val_loss: 0.6825
#       Iter 1 - Within-Project | Epoch 3/50 - val_loss: 0.6753
#       Iter 1 - Within-Project | Epoch 4/50 - val_loss: 0.6651
#       Iter 1 - Within-Project | Epoch 5/50 - val_loss: 0.6506
#       Iter 1 - Within-Project | Epoch 6/50 - val_loss: 0.6319
#       Iter 1 - Within-Project | Epoch 7/50 - val_loss: 0.6078
#       Iter 1 - Within-Project | Epoch 8/50 - val_loss: 0.5803
#       Iter 1 - Within-Project | Epoch 9/50 - val_loss: 0.5516
#       Iter 1 - Within-Project | Epoch 10/50 - val_loss: 0.5235
#       Iter 1 - Within-Project | Epoch 11/50 - val_loss: 0.4986
#       Iter 1 - Within-Project | Epoch 12/50 - val_loss: 0.4779
#       Iter 1 - Within-Project | Epoch 13/50 - val_loss: 0.4608
#       Iter 1 - Within-Project | Epoch 14/50 - val_loss: 0.4485
#       Iter 1 - Within-Project | Epoch 15/50 - val_loss: 0.4395
#       Iter 1 - Within-Project | Epoch 16/50 - val_loss: 0.4328
#       Iter 1 - Within-Project | Epoch 17/50 - val_loss: 0.4272
#       Iter 1 - Within-Project | Epoch 18/50 - val_loss: 0.4223
#       Iter 1 - Within-Project | Epoch 19/50 - val_loss: 0.4174
#       Iter 1 - Within-Project | Epoch 20/50 - val_loss: 0.4125
#       Iter 1 - Within-Project | Epoch 21/50 - val_loss: 0.4071
#       Iter 1 - Within-Project | Epoch 22/50 - val_loss: 0.3995
#       Iter 1 - Within-Project | Epoch 23/50 - val_loss: 0.3835
#       Iter 1 - Within-Project | Epoch 24/50 - val_loss: 0.3605
#       Iter 1 - Within-Project | Epoch 25/50 - val_loss: 0.3466
#       Iter 1 - Within-Project | Epoch 26/50 - val_loss: 0.3352
#       Iter 1 - Within-Project | Epoch 27/50 - val_loss: 0.3242
#       Iter 1 - Within-Project | Epoch 28/50 - val_loss: 0.3170
#       Iter 1 - Within-Project | Epoch 29/50 - val_loss: 0.3073
#       Iter 1 - Within-Project | Epoch 30/50 - val_loss: 0.2982
#       Iter 1 - Within-Project | Epoch 31/50 - val_loss: 0.2972
#       Iter 1 - Within-Project | Epoch 32/50 - val_loss: 0.2841
#       Iter 1 - Within-Project | Epoch 33/50 - val_loss: 0.2774
#       Iter 1 - Within-Project | Epoch 34/50 - val_loss: 0.2738
#       Iter 1 - Within-Project | Epoch 35/50 - val_loss: 0.2712
#       Iter 1 - Within-Project | Epoch 36/50 - val_loss: 0.2654
#       Iter 1 - Within-Project | Epoch 37/50 - val_loss: 0.2611
#       Iter 1 - Within-Project | Epoch 38/50 - val_loss: 0.2579
#       Iter 1 - Within-Project | Epoch 39/50 - val_loss: 0.2528
#       Iter 1 - Within-Project | Epoch 40/50 - val_loss: 0.2468
#       Iter 1 - Within-Project | Epoch 41/50 - val_loss: 0.2473
#       Iter 1 - Within-Project | Epoch 42/50 - val_loss: 0.2399
#       Iter 1 - Within-Project | Epoch 43/50 - val_loss: 0.2386
#       Iter 1 - Within-Project | Epoch 44/50 - val_loss: 0.2392
#       Iter 1 - Within-Project | Epoch 45/50 - val_loss: 0.2314
#       Iter 1 - Within-Project | Epoch 46/50 - val_loss: 0.2283
#       Iter 1 - Within-Project | Epoch 47/50 - val_loss: 0.2280
#       Iter 1 - Within-Project | Epoch 48/50 - val_loss: 0.2236
#       Iter 1 - Within-Project | Epoch 49/50 - val_loss: 0.2227
#       Iter 1 - Within-Project | Epoch 50/50 - val_loss: 0.2173
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Within-Project | Epoch 1/50 - val_loss: 0.6939
#       Iter 2 - Within-Project | Epoch 2/50 - val_loss: 0.6902
#       Iter 2 - Within-Project | Epoch 3/50 - val_loss: 0.6842
#       Iter 2 - Within-Project | Epoch 4/50 - val_loss: 0.6764
#       Iter 2 - Within-Project | Epoch 5/50 - val_loss: 0.6650
#       Iter 2 - Within-Project | Epoch 6/50 - val_loss: 0.6472
#       Iter 2 - Within-Project | Epoch 7/50 - val_loss: 0.6223
#       Iter 2 - Within-Project | Epoch 8/50 - val_loss: 0.5917
#       Iter 2 - Within-Project | Epoch 9/50 - val_loss: 0.5590
#       Iter 2 - Within-Project | Epoch 10/50 - val_loss: 0.5260
#       Iter 2 - Within-Project | Epoch 11/50 - val_loss: 0.4968
#       Iter 2 - Within-Project | Epoch 12/50 - val_loss: 0.4722
#       Iter 2 - Within-Project | Epoch 13/50 - val_loss: 0.4550
#       Iter 2 - Within-Project | Epoch 14/50 - val_loss: 0.4434
#       Iter 2 - Within-Project | Epoch 15/50 - val_loss: 0.4355
#       Iter 2 - Within-Project | Epoch 16/50 - val_loss: 0.4293
#       Iter 2 - Within-Project | Epoch 17/50 - val_loss: 0.4238
#       Iter 2 - Within-Project | Epoch 18/50 - val_loss: 0.4184
#       Iter 2 - Within-Project | Epoch 19/50 - val_loss: 0.4129
#       Iter 2 - Within-Project | Epoch 20/50 - val_loss: 0.4072
#       Iter 2 - Within-Project | Epoch 21/50 - val_loss: 0.4012
#       Iter 2 - Within-Project | Epoch 22/50 - val_loss: 0.3945
#       Iter 2 - Within-Project | Epoch 23/50 - val_loss: 0.3852
#       Iter 2 - Within-Project | Epoch 24/50 - val_loss: 0.3684
#       Iter 2 - Within-Project | Epoch 25/50 - val_loss: 0.3498
#       Iter 2 - Within-Project | Epoch 26/50 - val_loss: 0.3382
#       Iter 2 - Within-Project | Epoch 27/50 - val_loss: 0.3276
#       Iter 2 - Within-Project | Epoch 28/50 - val_loss: 0.3180
#       Iter 2 - Within-Project | Epoch 29/50 - val_loss: 0.3108
#       Iter 2 - Within-Project | Epoch 30/50 - val_loss: 0.3021
#       Iter 2 - Within-Project | Epoch 31/50 - val_loss: 0.3006
#       Iter 2 - Within-Project | Epoch 32/50 - val_loss: 0.2919
#       Iter 2 - Within-Project | Epoch 33/50 - val_loss: 0.2876
#       Iter 2 - Within-Project | Epoch 34/50 - val_loss: 0.2804
#       Iter 2 - Within-Project | Epoch 35/50 - val_loss: 0.2768
#       Iter 2 - Within-Project | Epoch 36/50 - val_loss: 0.2730
#       Iter 2 - Within-Project | Epoch 37/50 - val_loss: 0.2669
#       Iter 2 - Within-Project | Epoch 38/50 - val_loss: 0.2656
#       Iter 2 - Within-Project | Epoch 39/50 - val_loss: 0.2623
#       Iter 2 - Within-Project | Epoch 40/50 - val_loss: 0.2611
#       Iter 2 - Within-Project | Epoch 41/50 - val_loss: 0.2547
#       Iter 2 - Within-Project | Epoch 42/50 - val_loss: 0.2532
#       Iter 2 - Within-Project | Epoch 43/50 - val_loss: 0.2495
#       Iter 2 - Within-Project | Epoch 44/50 - val_loss: 0.2441
#       Iter 2 - Within-Project | Epoch 45/50 - val_loss: 0.2404
#       Iter 2 - Within-Project | Epoch 46/50 - val_loss: 0.2382
#       Iter 2 - Within-Project | Epoch 47/50 - val_loss: 0.2362
#       Iter 2 - Within-Project | Epoch 48/50 - val_loss: 0.2332
#       Iter 2 - Within-Project | Epoch 49/50 - val_loss: 0.2340
#       Iter 2 - Within-Project | Epoch 50/50 - val_loss: 0.2281
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Within-Project | Epoch 1/50 - val_loss: 0.6905
#       Iter 3 - Within-Project | Epoch 2/50 - val_loss: 0.6853
#       Iter 3 - Within-Project | Epoch 3/50 - val_loss: 0.6773
#       Iter 3 - Within-Project | Epoch 4/50 - val_loss: 0.6628
#       Iter 3 - Within-Project | Epoch 5/50 - val_loss: 0.6384
#       Iter 3 - Within-Project | Epoch 6/50 - val_loss: 0.6030
#       Iter 3 - Within-Project | Epoch 7/50 - val_loss: 0.5621
#       Iter 3 - Within-Project | Epoch 8/50 - val_loss: 0.5231
#       Iter 3 - Within-Project | Epoch 9/50 - val_loss: 0.4914
#       Iter 3 - Within-Project | Epoch 10/50 - val_loss: 0.4694
#       Iter 3 - Within-Project | Epoch 11/50 - val_loss: 0.4541
#       Iter 3 - Within-Project | Epoch 12/50 - val_loss: 0.4427
#       Iter 3 - Within-Project | Epoch 13/50 - val_loss: 0.4332
#       Iter 3 - Within-Project | Epoch 14/50 - val_loss: 0.4242
#       Iter 3 - Within-Project | Epoch 15/50 - val_loss: 0.4123
#       Iter 3 - Within-Project | Epoch 16/50 - val_loss: 0.3930
#       Iter 3 - Within-Project | Epoch 17/50 - val_loss: 0.3739
#       Iter 3 - Within-Project | Epoch 18/50 - val_loss: 0.3572
#       Iter 3 - Within-Project | Epoch 19/50 - val_loss: 0.3466
#       Iter 3 - Within-Project | Epoch 20/50 - val_loss: 0.3338
#       Iter 3 - Within-Project | Epoch 21/50 - val_loss: 0.3227
#       Iter 3 - Within-Project | Epoch 22/50 - val_loss: 0.3132
#       Iter 3 - Within-Project | Epoch 23/50 - val_loss: 0.3049
#       Iter 3 - Within-Project | Epoch 24/50 - val_loss: 0.2985
#       Iter 3 - Within-Project | Epoch 25/50 - val_loss: 0.2918
#       Iter 3 - Within-Project | Epoch 26/50 - val_loss: 0.2861
#       Iter 3 - Within-Project | Epoch 27/50 - val_loss: 0.2820
#       Iter 3 - Within-Project | Epoch 28/50 - val_loss: 0.2742
#       Iter 3 - Within-Project | Epoch 29/50 - val_loss: 0.2686
#       Iter 3 - Within-Project | Epoch 30/50 - val_loss: 0.2651
#       Iter 3 - Within-Project | Epoch 31/50 - val_loss: 0.2609
#       Iter 3 - Within-Project | Epoch 32/50 - val_loss: 0.2566
#       Iter 3 - Within-Project | Epoch 33/50 - val_loss: 0.2508
#       Iter 3 - Within-Project | Epoch 34/50 - val_loss: 0.2481
#       Iter 3 - Within-Project | Epoch 35/50 - val_loss: 0.2428
#       Iter 3 - Within-Project | Epoch 36/50 - val_loss: 0.2396
#       Iter 3 - Within-Project | Epoch 37/50 - val_loss: 0.2346
#       Iter 3 - Within-Project | Epoch 38/50 - val_loss: 0.2331
#       Iter 3 - Within-Project | Epoch 39/50 - val_loss: 0.2281
#       Iter 3 - Within-Project | Epoch 40/50 - val_loss: 0.2235
#       Iter 3 - Within-Project | Epoch 41/50 - val_loss: 0.2201
#       Iter 3 - Within-Project | Epoch 42/50 - val_loss: 0.2177
#       Iter 3 - Within-Project | Epoch 43/50 - val_loss: 0.2149
#       Iter 3 - Within-Project | Epoch 44/50 - val_loss: 0.2134
#       Iter 3 - Within-Project | Epoch 45/50 - val_loss: 0.2084
#       Iter 3 - Within-Project | Epoch 46/50 - val_loss: 0.2043
#       Iter 3 - Within-Project | Epoch 47/50 - val_loss: 0.2014
#       Iter 3 - Within-Project | Epoch 48/50 - val_loss: 0.1986
#       Iter 3 - Within-Project | Epoch 49/50 - val_loss: 0.1959
#       Iter 3 - Within-Project | Epoch 50/50 - val_loss: 0.1931
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (gpac Within-Project Test Set) ===
# Accuracy  : 0.979
# Precision : 0.077
# Recall    : 0.111
# F1-score  : 0.091
# AUC       : 0.851
# G-mean    : 0.331
# PF value  : 0.013
#
# Confusion Matrix:
#   TN: 1842  FP: 24
#   FN: 16  TP: 2
#
# Results saved to results/smote/smote_within_gpac.json
# Confusion matrix saved as results/smote/confusion_matrix_smote_within_gpac.png

# %%
"""
Within-Project Vulnerability Detection on PrimeVul
---------------------------------------------------
Train on FreeRDP (train split) -> Test on FreeRDP (test split)
SMOTE Oversampling
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED       = 42
PROJECT    = "FreeRDP"
TRAIN_FILE = "../../../../embedding/primevul/codet5/p_train_embedded.jsonl"
TEST_FILE  = "../../../../embedding/primevul/codet5/p_test_embedded.jsonl"
EMB_KEY    = "emb"
OUTPUT_DIR = "results/smote"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    """Load a PrimeVul embedded JSONL file.
    Returns X (embeddings), y (labels), projects (project names).
    """
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc,
                         class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (nn.BCELoss(reduction='none')(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            weights   = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss  = (nn.BCELoss(reduction='none')(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Within-Project Training (no pseudo-labelling)
# =========================================================
def train_within_project(x_train, y_train, class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t  = torch.tensor(x_tr,  dtype=torch.float32)
    y_tr_t  = torch.tensor(y_tr,  dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, None,
        epochs=50,
        desc=f"Iter {iteration} - Within-Project",
        class_weights=class_weights
    )

    return model


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights,
                         sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title(f"Confusion Matrix ({PROJECT} Within-Project — SMOTE)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Within-Project: {PROJECT} | SMOTE ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/6] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/6] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Filter both splits to FreeRDP only
    train_mask = proj_tr == PROJECT
    test_mask  = proj_te == PROJECT

    train_emb = X_tr[train_mask].astype(np.float32)
    train_lbl = y_tr[train_mask].astype(np.int32)
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError(f"No training samples found for '{PROJECT}' in {TRAIN_FILE}.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No test samples found for '{PROJECT}' in {TEST_FILE}.")

    print(f"      Train ({PROJECT}): {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Test  ({PROJECT}): {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Train imbalance ratio: {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/6] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/6] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/6] Apply SMOTE on training split only
    # ----------------------------------------------------------
    print("\n[3/6] Applying SMOTE...")
    n_neg_before = int(np.sum(train_lbl == 0))
    n_pos_before = int(np.sum(train_lbl == 1))
    print(f"      Before SMOTE — benign: {n_neg_before} | vuln: {n_pos_before} "
          f"| ratio: {n_neg_before / n_pos_before:.2f}")

    smote = SMOTE(random_state=SEED)
    train_emb_res, train_lbl_res = smote.fit_resample(train_emb, train_lbl)
    train_emb_res = train_emb_res.astype(np.float32)
    train_lbl_res = train_lbl_res.astype(np.int32)

    n_neg_after = int(np.sum(train_lbl_res == 0))
    n_pos_after = int(np.sum(train_lbl_res == 1))
    print(f"      After  SMOTE — benign: {n_neg_after} | vuln: {n_pos_after} "
          f"| ratio: {n_neg_after / n_pos_after:.2f}")

    # ----------------------------------------------------------
    # [4/6] Compute class weights from RESAMPLED train split
    # ----------------------------------------------------------
    print("\n[4/6] Computing class weights...")
    classes           = np.unique(train_lbl_res)
    class_weights_arr = compute_class_weight(
                            class_weight='balanced',
                            classes=classes,
                            y=train_lbl_res
                        )
    class_weights     = {int(cls): float(w)
                         for cls, w in zip(classes, class_weights_arr)}
    print(f"      Class weights (post-SMOTE): {class_weights}")

    # ----------------------------------------------------------
    # [5/6] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[5/6] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn = train_within_project(
            train_emb_res, train_lbl_res,
            class_weights,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb_res, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(
                                    train_lbl_res == 1,
                                    y_train_pred,
                                    1 - y_train_pred
                                )
        model_xgb             = train_base_model_xgb(
                                    train_emb_res, train_lbl_res,
                                    class_weights,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [6/6] Metrics
    # ----------------------------------------------------------
    print("\n[6/6] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print(f"\n=== Evaluation Results ({PROJECT} Within-Project Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"         : "smote_within_project",
        "setting"            : "within_project",
        "project"            : PROJECT,
        "n_train_before_smote": int(len(train_lbl)),
        "n_train_after_smote" : int(len(train_lbl_res)),
        "n_vuln_before_smote" : n_pos_before,
        "n_benign_before_smote": n_neg_before,
        "n_vuln_after_smote"  : n_pos_after,
        "n_benign_after_smote": n_neg_after,
        "n_test_samples"      : int(len(test_lbl)),
        "n_vuln_test"         : int(test_lbl.sum()),
        "class_weights"       : class_weights,
        "accuracy"            : round(float(accuracy),  4),
        "precision"           : round(float(precision), 4),
        "recall"              : round(float(recall),    4),
        "f1"                  : round(float(f1),        4),
        "auc"                 : round(float(auc),       4),
        "g_mean"              : round(float(g_mean),    4),
        "pf"                  : round(float(pf),        4),
        "confusion_matrix"    : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, f"smote_within_{PROJECT}.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, f"confusion_matrix_smote_within_{PROJECT}.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Within-Project: FreeRDP | SMOTE ===
#     Device: mps
#
# [1/6] Loading embeddings...
#       Train (FreeRDP): (872, 768)  vuln=23  benign=849
#       Test  (FreeRDP): (26, 768)  vuln=1  benign=25
#       Train imbalance ratio: 0.0264
#
# [2/6] Normalising embeddings...
#
# [3/6] Applying SMOTE...
#       Before SMOTE — benign: 849 | vuln: 23 | ratio: 36.91
#       After  SMOTE — benign: 849 | vuln: 849 | ratio: 1.00
#
# [4/6] Computing class weights...
#       Class weights (post-SMOTE): {0: 1.0, 1: 1.0}
#
# [5/6] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Within-Project | Epoch 1/50 - val_loss: 0.6899
#       Iter 1 - Within-Project | Epoch 2/50 - val_loss: 0.6887
#       Iter 1 - Within-Project | Epoch 3/50 - val_loss: 0.6877
#       Iter 1 - Within-Project | Epoch 4/50 - val_loss: 0.6867
#       Iter 1 - Within-Project | Epoch 5/50 - val_loss: 0.6857
#       Iter 1 - Within-Project | Epoch 6/50 - val_loss: 0.6846
#       Iter 1 - Within-Project | Epoch 7/50 - val_loss: 0.6833
#       Iter 1 - Within-Project | Epoch 8/50 - val_loss: 0.6818
#       Iter 1 - Within-Project | Epoch 9/50 - val_loss: 0.6802
#       Iter 1 - Within-Project | Epoch 10/50 - val_loss: 0.6784
#       Iter 1 - Within-Project | Epoch 11/50 - val_loss: 0.6764
#       Iter 1 - Within-Project | Epoch 12/50 - val_loss: 0.6742
#       Iter 1 - Within-Project | Epoch 13/50 - val_loss: 0.6717
#       Iter 1 - Within-Project | Epoch 14/50 - val_loss: 0.6689
#       Iter 1 - Within-Project | Epoch 15/50 - val_loss: 0.6658
#       Iter 1 - Within-Project | Epoch 16/50 - val_loss: 0.6622
#       Iter 1 - Within-Project | Epoch 17/50 - val_loss: 0.6583
#       Iter 1 - Within-Project | Epoch 18/50 - val_loss: 0.6540
#       Iter 1 - Within-Project | Epoch 19/50 - val_loss: 0.6495
#       Iter 1 - Within-Project | Epoch 20/50 - val_loss: 0.6445
#       Iter 1 - Within-Project | Epoch 21/50 - val_loss: 0.6394
#       Iter 1 - Within-Project | Epoch 22/50 - val_loss: 0.6338
#       Iter 1 - Within-Project | Epoch 23/50 - val_loss: 0.6280
#       Iter 1 - Within-Project | Epoch 24/50 - val_loss: 0.6220
#       Iter 1 - Within-Project | Epoch 25/50 - val_loss: 0.6160
#       Iter 1 - Within-Project | Epoch 26/50 - val_loss: 0.6102
#       Iter 1 - Within-Project | Epoch 27/50 - val_loss: 0.6042
#       Iter 1 - Within-Project | Epoch 28/50 - val_loss: 0.5984
#       Iter 1 - Within-Project | Epoch 29/50 - val_loss: 0.5923
#       Iter 1 - Within-Project | Epoch 30/50 - val_loss: 0.5864
#       Iter 1 - Within-Project | Epoch 31/50 - val_loss: 0.5807
#       Iter 1 - Within-Project | Epoch 32/50 - val_loss: 0.5755
#       Iter 1 - Within-Project | Epoch 33/50 - val_loss: 0.5705
#       Iter 1 - Within-Project | Epoch 34/50 - val_loss: 0.5653
#       Iter 1 - Within-Project | Epoch 35/50 - val_loss: 0.5603
#       Iter 1 - Within-Project | Epoch 36/50 - val_loss: 0.5556
#       Iter 1 - Within-Project | Epoch 37/50 - val_loss: 0.5512
#       Iter 1 - Within-Project | Epoch 38/50 - val_loss: 0.5466
#       Iter 1 - Within-Project | Epoch 39/50 - val_loss: 0.5420
#       Iter 1 - Within-Project | Epoch 40/50 - val_loss: 0.5370
#       Iter 1 - Within-Project | Epoch 41/50 - val_loss: 0.5323
#       Iter 1 - Within-Project | Epoch 42/50 - val_loss: 0.5277
#       Iter 1 - Within-Project | Epoch 43/50 - val_loss: 0.5229
#       Iter 1 - Within-Project | Epoch 44/50 - val_loss: 0.5180
#       Iter 1 - Within-Project | Epoch 45/50 - val_loss: 0.5132
#       Iter 1 - Within-Project | Epoch 46/50 - val_loss: 0.5080
#       Iter 1 - Within-Project | Epoch 47/50 - val_loss: 0.5032
#       Iter 1 - Within-Project | Epoch 48/50 - val_loss: 0.4981
#       Iter 1 - Within-Project | Epoch 49/50 - val_loss: 0.4928
#       Iter 1 - Within-Project | Epoch 50/50 - val_loss: 0.4876
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Within-Project | Epoch 1/50 - val_loss: 0.6907
#       Iter 2 - Within-Project | Epoch 2/50 - val_loss: 0.6896
#       Iter 2 - Within-Project | Epoch 3/50 - val_loss: 0.6886
#       Iter 2 - Within-Project | Epoch 4/50 - val_loss: 0.6874
#       Iter 2 - Within-Project | Epoch 5/50 - val_loss: 0.6861
#       Iter 2 - Within-Project | Epoch 6/50 - val_loss: 0.6849
#       Iter 2 - Within-Project | Epoch 7/50 - val_loss: 0.6839
#       Iter 2 - Within-Project | Epoch 8/50 - val_loss: 0.6828
#       Iter 2 - Within-Project | Epoch 9/50 - val_loss: 0.6816
#       Iter 2 - Within-Project | Epoch 10/50 - val_loss: 0.6803
#       Iter 2 - Within-Project | Epoch 11/50 - val_loss: 0.6789
#       Iter 2 - Within-Project | Epoch 12/50 - val_loss: 0.6773
#       Iter 2 - Within-Project | Epoch 13/50 - val_loss: 0.6755
#       Iter 2 - Within-Project | Epoch 14/50 - val_loss: 0.6735
#       Iter 2 - Within-Project | Epoch 15/50 - val_loss: 0.6711
#       Iter 2 - Within-Project | Epoch 16/50 - val_loss: 0.6687
#       Iter 2 - Within-Project | Epoch 17/50 - val_loss: 0.6660
#       Iter 2 - Within-Project | Epoch 18/50 - val_loss: 0.6629
#       Iter 2 - Within-Project | Epoch 19/50 - val_loss: 0.6593
#       Iter 2 - Within-Project | Epoch 20/50 - val_loss: 0.6554
#       Iter 2 - Within-Project | Epoch 21/50 - val_loss: 0.6511
#       Iter 2 - Within-Project | Epoch 22/50 - val_loss: 0.6463
#       Iter 2 - Within-Project | Epoch 23/50 - val_loss: 0.6412
#       Iter 2 - Within-Project | Epoch 24/50 - val_loss: 0.6357
#       Iter 2 - Within-Project | Epoch 25/50 - val_loss: 0.6300
#       Iter 2 - Within-Project | Epoch 26/50 - val_loss: 0.6240
#       Iter 2 - Within-Project | Epoch 27/50 - val_loss: 0.6180
#       Iter 2 - Within-Project | Epoch 28/50 - val_loss: 0.6115
#       Iter 2 - Within-Project | Epoch 29/50 - val_loss: 0.6051
#       Iter 2 - Within-Project | Epoch 30/50 - val_loss: 0.5983
#       Iter 2 - Within-Project | Epoch 31/50 - val_loss: 0.5920
#       Iter 2 - Within-Project | Epoch 32/50 - val_loss: 0.5851
#       Iter 2 - Within-Project | Epoch 33/50 - val_loss: 0.5789
#       Iter 2 - Within-Project | Epoch 34/50 - val_loss: 0.5727
#       Iter 2 - Within-Project | Epoch 35/50 - val_loss: 0.5669
#       Iter 2 - Within-Project | Epoch 36/50 - val_loss: 0.5607
#       Iter 2 - Within-Project | Epoch 37/50 - val_loss: 0.5547
#       Iter 2 - Within-Project | Epoch 38/50 - val_loss: 0.5488
#       Iter 2 - Within-Project | Epoch 39/50 - val_loss: 0.5428
#       Iter 2 - Within-Project | Epoch 40/50 - val_loss: 0.5372
#       Iter 2 - Within-Project | Epoch 41/50 - val_loss: 0.5316
#       Iter 2 - Within-Project | Epoch 42/50 - val_loss: 0.5259
#       Iter 2 - Within-Project | Epoch 43/50 - val_loss: 0.5206
#       Iter 2 - Within-Project | Epoch 44/50 - val_loss: 0.5156
#       Iter 2 - Within-Project | Epoch 45/50 - val_loss: 0.5106
#       Iter 2 - Within-Project | Epoch 46/50 - val_loss: 0.5056
#       Iter 2 - Within-Project | Epoch 47/50 - val_loss: 0.5016
#       Iter 2 - Within-Project | Epoch 48/50 - val_loss: 0.4972
#       Iter 2 - Within-Project | Epoch 49/50 - val_loss: 0.4935
#       Iter 2 - Within-Project | Epoch 50/50 - val_loss: 0.4897
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Within-Project:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Within-Project | Epoch 1/50 - val_loss: 0.6932
#       Iter 3 - Within-Project | Epoch 2/50 - val_loss: 0.6925
#       Iter 3 - Within-Project | Epoch 3/50 - val_loss: 0.6918
#       Iter 3 - Within-Project | Epoch 4/50 - val_loss: 0.6909
#       Iter 3 - Within-Project | Epoch 5/50 - val_loss: 0.6898
#       Iter 3 - Within-Project | Epoch 6/50 - val_loss: 0.6884
#       Iter 3 - Within-Project | Epoch 7/50 - val_loss: 0.6867
#       Iter 3 - Within-Project | Epoch 8/50 - val_loss: 0.6850
#       Iter 3 - Within-Project | Epoch 9/50 - val_loss: 0.6829
#       Iter 3 - Within-Project | Epoch 10/50 - val_loss: 0.6805
#       Iter 3 - Within-Project | Epoch 11/50 - val_loss: 0.6776
#       Iter 3 - Within-Project | Epoch 12/50 - val_loss: 0.6744
#       Iter 3 - Within-Project | Epoch 13/50 - val_loss: 0.6707
#       Iter 3 - Within-Project | Epoch 14/50 - val_loss: 0.6662
#       Iter 3 - Within-Project | Epoch 15/50 - val_loss: 0.6611
#       Iter 3 - Within-Project | Epoch 16/50 - val_loss: 0.6553
#       Iter 3 - Within-Project | Epoch 17/50 - val_loss: 0.6491
#       Iter 3 - Within-Project | Epoch 18/50 - val_loss: 0.6423
#       Iter 3 - Within-Project | Epoch 19/50 - val_loss: 0.6350
#       Iter 3 - Within-Project | Epoch 20/50 - val_loss: 0.6270
#       Iter 3 - Within-Project | Epoch 21/50 - val_loss: 0.6188
#       Iter 3 - Within-Project | Epoch 22/50 - val_loss: 0.6103
#       Iter 3 - Within-Project | Epoch 23/50 - val_loss: 0.6017
#       Iter 3 - Within-Project | Epoch 24/50 - val_loss: 0.5930
#       Iter 3 - Within-Project | Epoch 25/50 - val_loss: 0.5845
#       Iter 3 - Within-Project | Epoch 26/50 - val_loss: 0.5764
#       Iter 3 - Within-Project | Epoch 27/50 - val_loss: 0.5689
#       Iter 3 - Within-Project | Epoch 28/50 - val_loss: 0.5612
#       Iter 3 - Within-Project | Epoch 29/50 - val_loss: 0.5541
#       Iter 3 - Within-Project | Epoch 30/50 - val_loss: 0.5479
#       Iter 3 - Within-Project | Epoch 31/50 - val_loss: 0.5412
#       Iter 3 - Within-Project | Epoch 32/50 - val_loss: 0.5353
#       Iter 3 - Within-Project | Epoch 33/50 - val_loss: 0.5290
#       Iter 3 - Within-Project | Epoch 34/50 - val_loss: 0.5232
#       Iter 3 - Within-Project | Epoch 35/50 - val_loss: 0.5174
#       Iter 3 - Within-Project | Epoch 36/50 - val_loss: 0.5117
#       Iter 3 - Within-Project | Epoch 37/50 - val_loss: 0.5064
#       Iter 3 - Within-Project | Epoch 38/50 - val_loss: 0.5008
#       Iter 3 - Within-Project | Epoch 39/50 - val_loss: 0.4949
#       Iter 3 - Within-Project | Epoch 40/50 - val_loss: 0.4896
#       Iter 3 - Within-Project | Epoch 41/50 - val_loss: 0.4846
#       Iter 3 - Within-Project | Epoch 42/50 - val_loss: 0.4795
#       Iter 3 - Within-Project | Epoch 43/50 - val_loss: 0.4744
#       Iter 3 - Within-Project | Epoch 44/50 - val_loss: 0.4690
#       Iter 3 - Within-Project | Epoch 45/50 - val_loss: 0.4633
#       Iter 3 - Within-Project | Epoch 46/50 - val_loss: 0.4579
#       Iter 3 - Within-Project | Epoch 47/50 - val_loss: 0.4525
#       Iter 3 - Within-Project | Epoch 48/50 - val_loss: 0.4474
#       Iter 3 - Within-Project | Epoch 49/50 - val_loss: 0.4419
#       Iter 3 - Within-Project | Epoch 50/50 - val_loss: 0.4371
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [6/6] Computing metrics...
#
# === Evaluation Results (FreeRDP Within-Project Test Set) ===
# Accuracy  : 0.962
# Precision : 0.000
# Recall    : 0.000
# F1-score  : 0.000
# AUC       : 1.000
# G-mean    : 0.000
# PF value  : 0.000
#
# Confusion Matrix:
#   TN: 25  FP: 0
#   FN: 1  TP: 0
#
# Results saved to results/smote/smote_within_FreeRDP.json
# Confusion matrix saved as results/smote/confusion_matrix_smote_within_FreeRDP.png
