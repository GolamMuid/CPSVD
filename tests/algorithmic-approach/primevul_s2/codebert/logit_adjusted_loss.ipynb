# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "poppler"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/poppler"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (poppler Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except poppler -> Test on poppler (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (poppler)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (poppler Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_poppler",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_poppler.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_poppler.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except poppler -> Test on poppler (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (222735, 768)  vuln=5971  benign=216764
#       Projects in training pool : 753
#       Test set (poppler)          : (1798, 768)  vuln=33  benign=1765
#       Training imbalance ratio  : 0.0268
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026808
#       pi_neg   = 0.973192
#       offset   = -3.5919
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1177
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1143
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1131
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1120
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1112
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1105
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1098
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1093
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1089
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1085
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1069
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1067
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1058
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1054
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1054
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1052
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1049
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1046
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1046
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1052
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1049
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1046
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1051
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000007, max: 0.941143, mean: 0.238537, pseudo-labels flagged vulnerable: 442 / 1798
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1029
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1011
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1010
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1006
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0993
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0982
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0978
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0969
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0969
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0956
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0944
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0938
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0932
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0923
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0913
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0908
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0910
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0896
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0888
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0882
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0871
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0877
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0857
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0862
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0845
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0837
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0834
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0834
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0825
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999688, mean: 0.288626
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1152
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1138
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1123
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1113
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1105
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1097
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1093
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1087
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1083
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1079
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1075
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1063
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1059
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1051
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1047
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1044
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1044
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1040
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000002, max: 0.952654, mean: 0.238651, pseudo-labels flagged vulnerable: 437 / 1798
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1018
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1016
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1001
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0993
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0980
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0977
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0963
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0959
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0955
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0947
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0942
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0925
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0923
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0911
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0908
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0899
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0895
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0893
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0883
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0881
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0863
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0866
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0856
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0842
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0832
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0830
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0820
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0847
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0810
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0808
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999624, mean: 0.298755
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1159
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1135
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1121
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1113
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1103
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1095
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1091
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1085
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1080
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1076
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1061
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1058
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1046
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1041
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1038
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1035
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1033
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1033
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1027
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000037, max: 0.936158, mean: 0.248661, pseudo-labels flagged vulnerable: 384 / 1798
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1007
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1006
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1001
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0986
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0983
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0972
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0973
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0959
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0959
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0948
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0943
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0939
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0931
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0931
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0917
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0913
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0908
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0908
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0897
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0890
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0885
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0889
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0878
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0871
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0865
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0855
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0843
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0850
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0847
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0831
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999592, mean: 0.292586
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (poppler Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.717
# Precision : 0.058
# Recall    : 0.939
# F1-score  : 0.109
# AUC       : 0.884
# G-mean    : 0.819
# PF value  : 0.287
#
# Confusion Matrix:
#   TN: 1259  FP: 506
#   FN: 2  TP: 31
#
# Results saved to results/logit_adjusted_loss/poppler/logit_adjusted_loss_no_oversampling_poppler.json
# Confusion matrix saved as results/logit_adjusted_loss/poppler/confusion_matrix_logit_adjusted_loss_poppler.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/radare2"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_radare2",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except radare2 -> Test on radare2 (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221730, 768)  vuln=5930  benign=215800
#       Projects in training pool : 753
#       Test set (radare2)          : (2803, 768)  vuln=74  benign=2729
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026744
#       pi_neg   = 0.973256
#       offset   = -3.5943
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1180
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1143
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1130
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1120
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1111
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1104
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1097
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1090
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1085
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1059
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1049
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1049
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1049
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1050
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1046
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1039
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1042
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1039
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1036
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1042
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1041
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000039, max: 0.941963, mean: 0.242931, pseudo-labels flagged vulnerable: 572 / 2803
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1021
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1019
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1007
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1000
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0994
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0992
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0986
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0979
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0974
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0974
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0958
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0942
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0944
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0932
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0926
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0915
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0922
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0904
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0897
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0892
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0889
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0882
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0879
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0872
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0867
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0858
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0852
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0848
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000001, max: 0.999251, mean: 0.290582
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1154
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1137
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1122
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1112
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1103
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1096
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1090
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1083
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1078
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1078
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1072
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1064
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1052
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1051
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1044
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1032
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1046
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1046
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000013, max: 0.970380, mean: 0.234698, pseudo-labels flagged vulnerable: 514 / 2803
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1022
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1014
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1005
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1008
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0993
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0988
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0984
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0973
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0977
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0960
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0953
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0950
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0938
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0945
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0931
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0919
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0931
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0906
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0915
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0898
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0884
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0878
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0874
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0873
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0859
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0852
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0846
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0843
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0836
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0830
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999743, mean: 0.278903
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1162
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1135
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1122
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1111
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1103
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1093
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1086
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1082
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1073
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1059
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1054
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1046
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1043
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1038
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1037
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1032
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1028
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1035
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1029
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000026, max: 0.978023, mean: 0.259053, pseudo-labels flagged vulnerable: 490 / 2803
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1013
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1005
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0999
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1003
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0991
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0986
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0985
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0972
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0970
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0964
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0952
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0949
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0941
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0946
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0928
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0924
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0919
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0909
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0902
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0900
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0901
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0885
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0890
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0896
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0873
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0871
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0861
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0860
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0844
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0842
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999673, mean: 0.289353
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (radare2 Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.745
# Precision : 0.081
# Recall    : 0.838
# F1-score  : 0.148
# AUC       : 0.843
# G-mean    : 0.789
# PF value  : 0.258
#
# Confusion Matrix:
#   TN: 2026  FP: 703
#   FN: 12  TP: 62
#
# Results saved to results/logit_adjusted_loss/radare2/logit_adjusted_loss_no_oversampling_radare2.json
# Confusion matrix saved as results/logit_adjusted_loss/radare2/confusion_matrix_logit_adjusted_loss_radare2.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "linux-2.6"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/linux-2.6"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux-2.6 Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux-2.6)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux-2.6 Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_linux-2.6",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_linux-2.6.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_linux-2.6.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221163, 768)  vuln=5904  benign=215259
#       Projects in training pool : 753
#       Test set (linux-2.6)          : (3370, 768)  vuln=100  benign=3270
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026695
#       pi_neg   = 0.973305
#       offset   = -3.5962
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1135
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1123
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1112
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1105
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1098
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1091
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1087
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1082
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1073
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1069
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1055
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1055
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1035
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1034
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1031
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1033
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1033
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1033
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1034
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1035
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1034
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1036
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1035
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1034
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1032
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1035
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1033
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1036
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1037
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000020, max: 0.963252, mean: 0.273310, pseudo-labels flagged vulnerable: 920 / 3370
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1022
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1015
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1013
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0994
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1005
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0983
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0984
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0972
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0966
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0960
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0964
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0957
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0940
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0936
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0941
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0934
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0910
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0913
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0908
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0905
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0896
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0887
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0884
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0881
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0870
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0865
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0870
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0861
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0849
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0848
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999653, mean: 0.282014
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1144
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1128
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1116
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1106
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1097
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1091
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1083
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1080
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1076
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1069
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1064
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1063
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1050
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1047
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1046
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1032
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1030
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1027
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1027
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1032
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1032
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1038
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000024, max: 0.962726, mean: 0.280085, pseudo-labels flagged vulnerable: 930 / 3370
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1023
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1014
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1010
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0996
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0996
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0976
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0970
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0959
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0946
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0940
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0935
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0929
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0932
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0924
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0916
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0908
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0904
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0917
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0897
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0896
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0874
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0875
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0872
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0862
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0860
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0867
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0838
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0835
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999945, mean: 0.290812
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1150
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1126
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1113
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1103
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1095
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1089
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1081
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1076
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1074
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1065
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1058
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1043
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1040
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1040
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1038
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1035
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1032
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1025
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1023
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1022
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1022
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1021
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1021
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1022
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1023
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1022
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1028
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1024
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1025
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000009, max: 0.978657, mean: 0.255234, pseudo-labels flagged vulnerable: 638 / 3370
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1010
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1002
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1003
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0988
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0979
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0976
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0977
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0973
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0963
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0955
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0949
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0938
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0935
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0927
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0928
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0921
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0911
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0904
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0902
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0904
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0890
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0888
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0888
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0870
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0866
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0863
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0868
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0850
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0844
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0833
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.998589, mean: 0.278525
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux-2.6 Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.688
# Precision : 0.063
# Recall    : 0.680
# F1-score  : 0.115
# AUC       : 0.747
# G-mean    : 0.684
# PF value  : 0.312
#
# Confusion Matrix:
#   TN: 2251  FP: 1019
#   FN: 32  TP: 68
#
# Results saved to results/logit_adjusted_loss/linux-2.6/logit_adjusted_loss_no_oversampling_linux-2.6.json
# Confusion matrix saved as results/logit_adjusted_loss/linux-2.6/confusion_matrix_logit_adjusted_loss_linux-2.6.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "vim"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/vim"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_vim",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (221466, 768)  vuln=5898  benign=215568
#       Projects in training pool : 753
#       Test set (vim)          : (3067, 768)  vuln=106  benign=2961
#       Training imbalance ratio  : 0.0266
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026632
#       pi_neg   = 0.973368
#       offset   = -3.5987
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1145
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1111
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1100
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1092
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1084
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1076
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1070
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1042
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1039
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1033
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1032
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1030
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1028
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1030
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1025
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1024
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1028
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1021
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1023
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1022
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1022
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1018
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1018
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1017
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1015
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1015
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1016
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1013
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1013
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1014
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1020
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1013
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1011
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1013
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1011
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1010
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1010
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1016
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1010
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1011
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1011
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1020
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1013
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.976887, mean: 0.373471, pseudo-labels flagged vulnerable: 1271 / 3067
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1003
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0991
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0989
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0981
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0978
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0969
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0963
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0957
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0951
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0947
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0939
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0934
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0926
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0922
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0922
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0912
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0897
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0896
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0889
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0883
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0882
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0874
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0868
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0855
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0856
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0851
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0840
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0832
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0829
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0830
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 1.000000, mean: 0.449925
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1122
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1107
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1095
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1087
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1079
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1060
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1048
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1032
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1027
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1029
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1024
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1024
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1022
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1021
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1020
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1020
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1023
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1018
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1019
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1015
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1016
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1014
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1017
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1010
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1011
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1019
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1011
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1009
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1013
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1018
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1009
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1009
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1012
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1018
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1015
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.981255, mean: 0.369320, pseudo-labels flagged vulnerable: 1242 / 3067
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1002
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0993
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0988
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0979
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0973
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0966
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0959
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0950
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0949
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0944
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0938
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0928
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0917
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0912
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0907
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0899
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0890
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0887
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0878
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0868
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0872
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0869
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0861
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0848
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0841
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0843
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0841
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0832
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0823
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0815
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 1.000000, mean: 0.453872
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1129
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1105
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1094
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1087
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1070
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1060
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1046
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1037
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1033
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1028
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1023
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1021
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1020
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1017
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1014
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1012
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1013
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1019
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1012
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1016
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1008
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1008
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1006
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1010
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1005
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1004
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1008
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1003
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1003
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1003
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1006
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1008
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1005
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1000
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1001
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1009
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1003
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1002
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1005
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000001, max: 0.978770, mean: 0.393596, pseudo-labels flagged vulnerable: 1245 / 3067
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0990
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0988
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0988
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0980
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0973
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0969
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0961
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0954
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0951
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0944
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0937
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0928
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0929
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0917
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0913
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0905
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0897
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0895
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0887
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0881
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0871
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0874
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0864
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0855
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0858
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0843
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0837
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0836
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0835
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0821
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 1.000000, mean: 0.470869
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (vim Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.572
# Precision : 0.067
# Recall    : 0.887
# F1-score  : 0.125
# AUC       : 0.802
# G-mean    : 0.705
# PF value  : 0.439
#
# Confusion Matrix:
#   TN: 1661  FP: 1300
#   FN: 12  TP: 94
#
# Results saved to results/logit_adjusted_loss/vim/logit_adjusted_loss_no_oversampling_vim.json
# Confusion matrix saved as results/logit_adjusted_loss/vim/confusion_matrix_logit_adjusted_loss_vim.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "FFmpeg"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/FFmpeg"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FFmpeg)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FFmpeg Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_FFmpeg",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_FFmpeg.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_FFmpeg.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (222072, 768)  vuln=5915  benign=216157
#       Projects in training pool : 753
#       Test set (FFmpeg)          : (2461, 768)  vuln=89  benign=2372
#       Training imbalance ratio  : 0.0266
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026636
#       pi_neg   = 0.973364
#       offset   = -3.5985
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1165
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1133
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1122
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1111
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1104
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1096
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1090
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1085
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1073
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1059
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1054
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1047
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1045
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1044
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1048
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1038
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1043
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1042
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1037
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1039
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1039
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1040
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1041
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1046
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000184, max: 0.942756, mean: 0.452489, pseudo-labels flagged vulnerable: 1309 / 2461
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1034
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1018
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1015
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1005
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1005
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0994
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1000
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0985
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0979
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0979
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0962
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0962
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0954
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0945
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0941
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0925
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0920
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0913
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0910
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0900
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0890
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0891
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0876
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0871
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0863
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0856
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0847
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0850
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0833
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000002, max: 0.999938, mean: 0.595368
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1143
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1127
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1114
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1106
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1098
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1090
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1085
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1081
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1077
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1074
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1067
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1060
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1048
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1047
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1031
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1037
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1034
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1036
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1033
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1041
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1035
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1038
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1039
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1040
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1040
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000172, max: 0.952423, mean: 0.447629, pseudo-labels flagged vulnerable: 1268 / 2461
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1023
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1022
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1009
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1005
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1000
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1001
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0989
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0975
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0958
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0959
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0940
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0938
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0933
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0938
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0927
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0913
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0905
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0898
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0895
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0881
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0872
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0863
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0863
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0864
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0846
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0854
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0843
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0827
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0818
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000002, max: 0.999989, mean: 0.603376
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1148
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1125
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1112
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1102
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1094
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1088
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1083
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1078
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1074
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1060
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1048
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1045
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1040
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1038
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1041
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1036
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1039
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1037
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1033
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1034
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1032
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1032
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1031
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1035
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1030
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1027
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1029
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1028
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1026
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1028
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1029
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000221, max: 0.943168, mean: 0.473926, pseudo-labels flagged vulnerable: 1250 / 2461
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1015
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1013
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1010
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1011
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1008
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0994
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0998
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0982
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0967
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0962
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0953
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0953
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0949
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0939
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0936
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0928
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0922
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0916
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0906
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0900
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0893
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0888
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0891
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0876
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0876
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0872
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0855
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0859
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0847
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0839
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000002, max: 0.999954, mean: 0.578044
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.453
# Precision : 0.058
# Recall    : 0.933
# F1-score  : 0.110
# AUC       : 0.787
# G-mean    : 0.637
# PF value  : 0.565
#
# Confusion Matrix:
#   TN: 1033  FP: 1339
#   FN: 6  TP: 83
#
# Results saved to results/logit_adjusted_loss/FFmpeg/logit_adjusted_loss_no_oversampling_FFmpeg.json
# Confusion matrix saved as results/logit_adjusted_loss/FFmpeg/confusion_matrix_logit_adjusted_loss_FFmpeg.png
