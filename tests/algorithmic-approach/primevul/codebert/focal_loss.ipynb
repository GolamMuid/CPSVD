# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux -> Test on linux
Focal Loss
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux"
TRAIN_FILE  = "../../../../embedding/primevul/codebert/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codebert/p_test_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/focal_loss"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Focal Loss
# =========================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    # Phase 1: Train on source (all-except-linux) with focal loss
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (linux)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled linux with focal loss
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, n_neg, n_pos,
                         sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux -> Test on linux (Focal Loss) ===")
    print(f"    Device     : {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT linux
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only linux from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (linux)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/5] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class distribution check
    # ----------------------------------------------------------
    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(train_lbl == 0))
    n_pos = int(np.sum(train_lbl == 1))
    print(f"      Training pool — benign: {n_neg} | vuln: {n_pos} "
          f"| ratio: {n_neg / n_pos:.2f}")
    print(f"      scale_pos_weight for XGBoost: {n_neg / n_pos:.4f}")

    test_unique, test_counts = np.unique(test_lbl, return_counts=True)
    print(f"      linux test set: "
          f"{dict(zip(test_unique.astype(int), test_counts))}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
                                    train_emb, train_lbl,
                                    n_neg, n_pos,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "focal_loss",
        "train"            : "all_except_linux",
        "test"             : TEST_PROJ,
        "focal_alpha"      : FOCAL_ALPHA,
        "focal_gamma"      : FOCAL_GAMMA,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : n_pos,
        "n_benign_train"   : n_neg,
        "n_vuln_test"      : int(test_lbl.sum()),
        "scale_pos_weight" : round(n_neg / n_pos, 4),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss_linux.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss_linux.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux -> Test on linux (Focal Loss) ===
#     Device     : mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Training pool             : (132585, 768)  vuln=3860  benign=128725
#       Projects in training pool : 630
#       Test set (linux)          : (4140, 768)  vuln=70  benign=4070
#       Training imbalance ratio  : 0.0291
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Training pool — benign: 128725 | vuln: 3860 | ratio: 33.35
#       scale_pos_weight for XGBoost: 33.3484
#       linux test set: {np.int64(0): np.int64(4070), np.int64(1): np.int64(70)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0162
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0157
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0149
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0139
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0134
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0131
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0129
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0123
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0122
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0121
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0119
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0115
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0114
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0110
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0111
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0107
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0105
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0105
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0102
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0101
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0099
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0098
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0096
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0095
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0094
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0091
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0090
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0089
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0088
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0087
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0087
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0084
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0162
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0157
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0154
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0152
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0139
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0132
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0127
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0126
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0125
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0119
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0117
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0115
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0112
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0111
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0109
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0106
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0106
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0102
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0101
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0100
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0098
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0096
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0095
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0092
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0090
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0089
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0087
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0087
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0085
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0084
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0170
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0161
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0157
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0155
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0153
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0151
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0145
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0136
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0131
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0131
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0128
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0125
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0124
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0122
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0120
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0117
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0115
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0113
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0113
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0110
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0108
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0107
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0105
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0103
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0104
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0100
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0100
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0098
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0097
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0098
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0095
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0095
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0092
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0090
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0090
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0089
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0088
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux Test Set) ===
# Accuracy  : 0.863
# Precision : 0.046
# Recall    : 0.357
# F1-score  : 0.081
# AUC       : 0.716
# G-mean    : 0.558
# PF value  : 0.128
#
# Confusion Matrix:
#   TN: 3548  FP: 522
#   FN: 45  TP: 25
#
# Results saved to results/focal_loss/focal_loss_linux.json
# Confusion matrix saved as results/focal_loss/confusion_matrix_focal_loss_linux.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT tensorflow -> Test on tensorflow
Focal Loss
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "tensorflow"
TRAIN_FILE  = "../../../../embedding/primevul/codebert/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codebert/p_test_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/focal_loss"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Focal Loss
# =========================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    # Phase 1: Train on source (all-except-tensorflow) with focal loss
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (tensorflow)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled tensorflow with focal loss
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, n_neg, n_pos,
                         sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (tensorflow Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except tensorflow -> Test on tensorflow (Focal Loss) ===")
    print(f"    Device     : {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT tensorflow
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only tensorflow from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (tensorflow)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/5] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class distribution check
    # ----------------------------------------------------------
    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(train_lbl == 0))
    n_pos = int(np.sum(train_lbl == 1))
    print(f"      Training pool — benign: {n_neg} | vuln: {n_pos} "
          f"| ratio: {n_neg / n_pos:.2f}")
    print(f"      scale_pos_weight for XGBoost: {n_neg / n_pos:.4f}")

    test_unique, test_counts = np.unique(test_lbl, return_counts=True)
    print(f"      tensorflow test set: "
          f"{dict(zip(test_unique.astype(int), test_counts))}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
                                    train_emb, train_lbl,
                                    n_neg, n_pos,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (tensorflow Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "focal_loss",
        "train"            : "all_except_tensorflow",
        "test"             : TEST_PROJ,
        "focal_alpha"      : FOCAL_ALPHA,
        "focal_gamma"      : FOCAL_GAMMA,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : n_pos,
        "n_benign_train"   : n_neg,
        "n_vuln_test"      : int(test_lbl.sum()),
        "scale_pos_weight" : round(n_neg / n_pos, 4),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss_tensorflow.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss_tensorflow.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except tensorflow -> Test on tensorflow (Focal Loss) ===
#     Device     : mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Training pool             : (174708, 768)  vuln=4786  benign=169922
#       Projects in training pool : 630
#       Test set (tensorflow)          : (1313, 768)  vuln=91  benign=1222
#       Training imbalance ratio  : 0.0274
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Training pool — benign: 169922 | vuln: 4786 | ratio: 35.50
#       scale_pos_weight for XGBoost: 35.5040
#       tensorflow test set: {np.int64(0): np.int64(1222), np.int64(1): np.int64(91)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0160
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0149
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0136
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0137
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0138
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0139
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0145
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0130
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0130
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0125
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0123
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0119
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0120
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0115
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0115
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0112
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0107
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0107
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0104
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0102
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0101
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0098
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0098
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0095
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0096
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0092
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0091
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0089
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0087
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0087
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0086
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0085
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0082
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0079
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0159
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0153
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0137
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0138
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0139
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0154
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0132
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0128
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0124
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0122
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0121
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0119
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0114
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0111
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0108
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0110
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0104
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0102
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0100
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0098
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0097
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0097
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0093
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0090
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0088
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0087
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0085
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0085
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0082
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0085
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0082
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0081
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0079
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0165
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0156
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0135
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0135
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0135
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0136
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0135
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0137
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0138
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0142
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0132
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0128
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0124
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0121
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0121
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0117
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0115
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0112
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0112
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0109
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0108
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0109
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0104
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0103
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0102
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0097
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0094
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0094
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0092
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0091
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0090
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0089
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0088
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0085
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0084
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0082
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (tensorflow Test Set) ===
# Accuracy  : 0.807
# Precision : 0.132
# Recall    : 0.319
# F1-score  : 0.186
# AUC       : 0.749
# G-mean    : 0.519
# PF value  : 0.156
#
# Confusion Matrix:
#   TN: 1031  FP: 191
#   FN: 62  TP: 29
#
# Results saved to results/focal_loss/focal_loss_tensorflow.json
# Confusion matrix saved as results/focal_loss/confusion_matrix_focal_loss_tensorflow.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
Focal Loss
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "vim"
TRAIN_FILE  = "../../../../embedding/primevul/codebert/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codebert/p_test_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/focal_loss"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Focal Loss
# =========================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    # Phase 1: Train on source (all-except-vim) with focal loss
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (vim)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled vim with focal loss
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, n_neg, n_pos,
                         sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (Focal Loss) ===")
    print(f"    Device     : {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT vim
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only vim from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/5] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class distribution check
    # ----------------------------------------------------------
    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(train_lbl == 0))
    n_pos = int(np.sum(train_lbl == 1))
    print(f"      Training pool — benign: {n_neg} | vuln: {n_pos} "
          f"| ratio: {n_neg / n_pos:.2f}")
    print(f"      scale_pos_weight for XGBoost: {n_neg / n_pos:.4f}")

    test_unique, test_counts = np.unique(test_lbl, return_counts=True)
    print(f"      vim test set: "
          f"{dict(zip(test_unique.astype(int), test_counts))}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
                                    train_emb, train_lbl,
                                    n_neg, n_pos,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "focal_loss",
        "train"            : "all_except_vim",
        "test"             : TEST_PROJ,
        "focal_alpha"      : FOCAL_ALPHA,
        "focal_gamma"      : FOCAL_GAMMA,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : n_pos,
        "n_benign_train"   : n_neg,
        "n_vuln_test"      : int(test_lbl.sum()),
        "scale_pos_weight" : round(n_neg / n_pos, 4),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except vim -> Test on vim (Focal Loss) ===
#     Device     : mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Training pool             : (174846, 768)  vuln=4824  benign=170022
#       Projects in training pool : 630
#       Test set (vim)          : (1669, 768)  vuln=61  benign=1608
#       Training imbalance ratio  : 0.0276
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Training pool — benign: 170022 | vuln: 4824 | ratio: 35.25
#       scale_pos_weight for XGBoost: 35.2450
#       vim test set: {np.int64(0): np.int64(1608), np.int64(1): np.int64(61)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0164
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0158
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0149
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0156
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0156
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0142
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0134
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0129
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0127
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0126
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0123
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0121
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0118
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0114
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0113
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0112
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0109
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0106
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0105
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0102
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0102
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0100
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0098
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0097
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0097
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0093
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0093
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0091
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0089
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0088
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0088
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0086
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0083
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0083
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0164
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0158
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0155
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0156
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0157
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0159
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0161
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0160
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0162
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0139
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0137
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0129
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0127
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0125
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0124
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0118
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0120
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0114
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0111
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0109
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0108
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0105
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0103
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0104
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0099
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0098
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0098
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0096
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0089
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0088
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0087
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0086
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0083
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0083
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0082
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0083
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0170
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0161
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0156
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0150
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0150
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0154
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0136
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0134
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0132
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0127
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0123
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0122
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0122
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0117
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0117
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0114
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0113
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0111
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0108
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0107
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0105
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0103
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0100
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0105
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0098
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0097
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0095
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0097
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0094
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0092
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0089
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0089
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0086
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0085
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (vim Test Set) ===
# Accuracy  : 0.652
# Precision : 0.090
# Recall    : 0.934
# F1-score  : 0.164
# AUC       : 0.852
# G-mean    : 0.774
# PF value  : 0.358
#
# Confusion Matrix:
#   TN: 1032  FP: 576
#   FN: 4  TP: 57
#
# Results saved to results/focal_loss/focal_loss_vim.json
# Confusion matrix saved as results/focal_loss/confusion_matrix_focal_loss_vim.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT gpac -> Test on gpac
Focal Loss
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "gpac"
TRAIN_FILE  = "../../../../embedding/primevul/codebert/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codebert/p_test_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/focal_loss"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Focal Loss
# =========================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    # Phase 1: Train on source (all-except-gpac) with focal loss
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (gpac)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled gpac with focal loss
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, n_neg, n_pos,
                         sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (gpac Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except gpac -> Test on gpac (Focal Loss) ===")
    print(f"    Device     : {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT gpac
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only gpac from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (gpac)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/5] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class distribution check
    # ----------------------------------------------------------
    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(train_lbl == 0))
    n_pos = int(np.sum(train_lbl == 1))
    print(f"      Training pool — benign: {n_neg} | vuln: {n_pos} "
          f"| ratio: {n_neg / n_pos:.2f}")
    print(f"      scale_pos_weight for XGBoost: {n_neg / n_pos:.4f}")

    test_unique, test_counts = np.unique(test_lbl, return_counts=True)
    print(f"      gpac test set: "
          f"{dict(zip(test_unique.astype(int), test_counts))}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
                                    train_emb, train_lbl,
                                    n_neg, n_pos,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (gpac Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "focal_loss",
        "train"            : "all_except_gpac",
        "test"             : TEST_PROJ,
        "focal_alpha"      : FOCAL_ALPHA,
        "focal_gamma"      : FOCAL_GAMMA,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : n_pos,
        "n_benign_train"   : n_neg,
        "n_vuln_test"      : int(test_lbl.sum()),
        "scale_pos_weight" : round(n_neg / n_pos, 4),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss_gpac.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss_gpac.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except gpac -> Test on gpac (Focal Loss) ===
#     Device     : mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Training pool             : (173022, 768)  vuln=4830  benign=168192
#       Projects in training pool : 630
#       Test set (gpac)          : (1884, 768)  vuln=18  benign=1866
#       Training imbalance ratio  : 0.0279
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Training pool — benign: 168192 | vuln: 4830 | ratio: 34.82
#       scale_pos_weight for XGBoost: 34.8224
#       gpac test set: {np.int64(0): np.int64(1866), np.int64(1): np.int64(18)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0167
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0161
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0158
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0156
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0155
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0149
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0149
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0152
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0156
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0154
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0155
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0158
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0159
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0162
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0141
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0138
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0133
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0130
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0128
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0127
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0122
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0120
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0118
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0115
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0114
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0112
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0110
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0108
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0105
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0104
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0103
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0100
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0096
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0099
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0095
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0093
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0091
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0090
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0094
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0089
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0086
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0085
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0084
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0168
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0161
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0159
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0157
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0155
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0154
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0153
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0154
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0156
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0154
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0155
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0154
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0160
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0160
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0161
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0162
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0166
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0164
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0164
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0143
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0143
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0132
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0129
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0127
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0128
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0121
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0120
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0115
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0114
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0115
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0110
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0108
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0107
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0104
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0100
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0100
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0098
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0097
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0095
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0092
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0088
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0087
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0088
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0085
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0083
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0174
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0165
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0160
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0158
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0156
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0153
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0151
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0150
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0151
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0151
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0150
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0153
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0152
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0155
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0141
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0137
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0136
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0132
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0127
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0124
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0122
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0121
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0120
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0117
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0116
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0112
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0114
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0109
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0106
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0104
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0104
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0102
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0096
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0096
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0094
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0093
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0093
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0091
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0088
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0086
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (gpac Test Set) ===
# Accuracy  : 0.944
# Precision : 0.042
# Recall    : 0.222
# F1-score  : 0.070
# AUC       : 0.876
# G-mean    : 0.460
# PF value  : 0.049
#
# Confusion Matrix:
#   TN: 1774  FP: 92
#   FN: 14  TP: 4
#
# Results saved to results/focal_loss/focal_loss_gpac.json
# Confusion matrix saved as results/focal_loss/confusion_matrix_focal_loss_gpac.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FreeRDP -> Test on FreeRDP
Focal Loss
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FreeRDP"
TRAIN_FILE  = "../../../../embedding/primevul/codebert/p_train_embedded.jsonl"
TEST_FILE   = "../../../../embedding/primevul/codebert/p_test_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/focal_loss"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Focal Loss
# =========================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Training Loop
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    # Phase 1: Train on source (all-except-FreeRDP) with focal loss
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (FreeRDP)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled FreeRDP with focal loss
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, n_neg, n_pos,
                         sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FreeRDP Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FreeRDP -> Test on FreeRDP (Focal Loss) ===")
    print(f"    Device     : {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    # ----------------------------------------------------------
    # [1/5] Load embeddings
    # ----------------------------------------------------------
    print("\n[1/5] Loading embeddings...")

    X_tr, y_tr, proj_tr = load_jsonl(TRAIN_FILE)
    X_te, y_te, proj_te = load_jsonl(TEST_FILE)

    # Training pool: all projects in train file EXCEPT FreeRDP
    train_mask = proj_tr != TEST_PROJ
    train_emb  = X_tr[train_mask].astype(np.float32)
    train_lbl  = y_tr[train_mask].astype(np.int32)

    # Test set: only FreeRDP from test file
    test_mask = proj_te == TEST_PROJ
    test_emb  = X_te[test_mask].astype(np.float32)
    test_lbl  = y_te[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check TRAIN_FILE path and project names.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {TEST_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_tr[train_mask]))}")
    print(f"      Test set (FreeRDP)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalise embeddings
    # ----------------------------------------------------------
    print("\n[2/5] Normalising embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class distribution check
    # ----------------------------------------------------------
    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(train_lbl == 0))
    n_pos = int(np.sum(train_lbl == 1))
    print(f"      Training pool — benign: {n_neg} | vuln: {n_pos} "
          f"| ratio: {n_neg / n_pos:.2f}")
    print(f"      scale_pos_weight for XGBoost: {n_neg / n_pos:.4f}")

    test_unique, test_counts = np.unique(test_lbl, return_counts=True)
    print(f"      FreeRDP test set: "
          f"{dict(zip(test_unique.astype(int), test_counts))}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze(-1).cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
                                    train_emb, train_lbl,
                                    n_neg, n_pos,
                                    sample_weights
                                )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FreeRDP Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "focal_loss",
        "train"            : "all_except_FreeRDP",
        "test"             : TEST_PROJ,
        "focal_alpha"      : FOCAL_ALPHA,
        "focal_gamma"      : FOCAL_GAMMA,
        "n_train_projects" : int(len(set(proj_tr[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : n_pos,
        "n_benign_train"   : n_neg,
        "n_vuln_test"      : int(test_lbl.sum()),
        "scale_pos_weight" : round(n_neg / n_pos, 4),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),       4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss_FreeRDP.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss_FreeRDP.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except FreeRDP -> Test on FreeRDP (Focal Loss) ===
#     Device     : mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Training pool             : (174925, 768)  vuln=4839  benign=170086
#       Projects in training pool : 630
#       Test set (FreeRDP)          : (26, 768)  vuln=1  benign=25
#       Training imbalance ratio  : 0.0277
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Training pool — benign: 170086 | vuln: 4839 | ratio: 35.15
#       scale_pos_weight for XGBoost: 35.1490
#       FreeRDP test set: {np.int64(0): np.int64(25), np.int64(1): np.int64(1)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0164
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0158
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0155
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0153
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0151
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0150
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0140
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0141
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0144
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0142
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0143
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0146
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0147
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0148
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0149
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0150
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0138
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0133
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0129
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0130
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0124
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0121
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0120
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0118
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0115
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0113
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0111
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0112
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0108
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0106
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0107
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0104
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0100
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0101
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0099
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0097
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0096
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0094
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0094
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0090
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0090
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0089
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0090
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0086
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0086
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0085
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0164
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0157
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0155
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0152
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0151
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0148
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0140
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0141
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0142
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0144
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0143
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0145
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0147
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0146
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0150
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0149
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0153
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0155
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0142
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0134
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0128
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0126
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0123
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0120
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0118
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0115
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0114
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0115
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0109
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0108
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0106
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0103
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0103
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0100
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0099
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0097
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0095
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0094
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0093
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0091
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0090
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0088
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0089
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0086
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0084
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0083
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0170
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0161
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0157
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0154
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0153
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0151
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0149
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0147
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0143
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0139
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0140
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0141
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0142
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0145
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0144
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0146
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0148
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0146
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0136
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0132
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0130
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0126
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0124
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0123
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0123
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0120
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0116
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0115
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0113
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0113
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0110
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0108
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0109
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0106
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0106
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0102
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0100
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0099
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0097
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0094
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0093
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0092
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0091
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0090
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0089
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0087
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0086
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FreeRDP Test Set) ===
# Accuracy  : 0.538
# Precision : 0.077
# Recall    : 1.000
# F1-score  : 0.143
# AUC       : 0.840
# G-mean    : 0.721
# PF value  : 0.480
#
# Confusion Matrix:
#   TN: 13  FP: 12
#   FN: 0  TP: 1
#
# Results saved to results/focal_loss/focal_loss_FreeRDP.json
# Confusion matrix saved as results/focal_loss/confusion_matrix_focal_loss_FreeRDP.png
