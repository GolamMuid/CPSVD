# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux -> Test on linux
Class-Balanced Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/class_balanced_loss/linux"

CB_BETA = 0.9999

BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Class-Balanced Loss 
# =========================================================
def compute_effective_number_weights(class_counts, beta):
    weights = {}
    for cls, n in class_counts.items():
        effective_num = 1.0 - np.power(beta, n)
        weights[cls] = (1.0 - beta) / effective_num
    total = sum(weights.values())
    num_classes = len(class_counts)
    weights = {cls: w * num_classes / total for cls, w in weights.items()}
    return weights


class ClassBalancedLoss(nn.Module):
    def __init__(self, cb_weights, eps=1e-7):
        super().__init__()
        self.weight_pos = float(cb_weights[1])
        self.weight_neg = float(cb_weights[0])
        self.eps = eps

    def forward(self, predictions, targets):
        p = predictions.clamp(self.eps, 1 - self.eps)
        bce = -(targets * torch.log(p) + (1 - targets) * torch.log(1 - p))
        weights = torch.where(
            targets == 1,
            torch.tensor(self.weight_pos, device=predictions.device),
            torch.tensor(self.weight_neg, device=predictions.device)
        )
        return (bce * weights).mean()


# =========================================================
# Training Loop with Validation
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze()
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze()
            val_loss  = criterion(val_preds, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning (Class-Balanced Loss throughout)
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       cb_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    # Phase 1: Train on source (all-except-linux)
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, cb_criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    # Pseudo-label the test set (linux)
    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2: Fine-tune on source + pseudo-labelled linux
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, cb_criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Class-Balanced objective for XGBoost (custom objective)
# =========================================================
def make_xgb_class_balanced_obj(weight_pos, weight_neg):

    def cb_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        z = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-z))

        class_weight = np.where(y == 1, weight_pos, weight_neg)
        grad = class_weight * (p - y)
        hess = class_weight * p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return cb_obj


def train_base_model_xgb(x_train, y_train, weight_pos, weight_neg, sample_weights=None):
    cb_obj = make_xgb_class_balanced_obj(weight_pos, weight_neg)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=cb_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux Test Set) - Class-Balanced Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux -> Test on linux (Class-Balanced Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Class-Balanced weights (effective number of samples)...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    cb_weights = compute_effective_number_weights({0: n_neg, 1: n_pos}, beta=CB_BETA)
    print(f"      beta = {CB_BETA}")
    print(f"      n_pos = {n_pos}, n_neg = {n_neg}")
    print(f"      Class-Balanced weights   : {cb_weights}")
    print(f"      (for comparison) simple inverse-frequency ratio would be: "
          f"{n_neg / n_pos:.4f}  vs.  CB weight ratio: {cb_weights[1] / cb_weights[0]:.4f}")

    cb_criterion = ClassBalancedLoss(cb_weights)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Class-Balanced Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl,
            test_emb,
            cb_criterion,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Class-Balanced objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_tr_t).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, cb_weights[1], cb_weights[0], sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux Test Set) - Class-Balanced Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "class_balanced_loss_no_oversampling",
        "train"            : "all_except_linux",
        "test"             : TEST_PROJ,
        "cb_beta"          : CB_BETA,
        "cb_weight_pos"    : round(float(cb_weights[1]), 4),
        "cb_weight_neg"    : round(float(cb_weights[0]), 4),
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "class_balanced_loss_no_oversampling_linux.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_class_balanced_loss_linux.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux -> Test on linux (Class-Balanced Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (170682, 768)  vuln=4852  benign=165830
#       Projects in training pool : 753
#       Test set (linux)          : (53851, 768)  vuln=1152  benign=52699
#       Training imbalance ratio  : 0.0284
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Class-Balanced weights (effective number of samples)...
#       beta = 0.9999
#       n_pos = 4852, n_neg = 165830
#       Class-Balanced weights   : {0: np.float64(0.5553734972018434), 1: np.float64(1.4446265027981566)}
#       (for comparison) simple inverse-frequency ratio would be: 34.1777  vs.  CB weight ratio: 2.6012
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Class-Balanced Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1440
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1341
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1304
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1282
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1270
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1257
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1247
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1239
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1231
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1225
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1218
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1212
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1208
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1205
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1204
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1198
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1197
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1192
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1193
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1189
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1186
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1191
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1184
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1184
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1180
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1181
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1179
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1177
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1177
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1176
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1177
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1175
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1171
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1173
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1171
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1171
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1169
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1173
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1167
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1168
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1169
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1168
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1173
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1170
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1171
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1172
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1174
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.490162, mean: 0.046576, pseudo-labels flagged vulnerable: 0 / 53851
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1174
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1159
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1148
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1148
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1138
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1120
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1109
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1115
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1101
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1085
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1081
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1069
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1069
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1049
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1037
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1028
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1034
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1020
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1023
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1002
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0995
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0970
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0989
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0947
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0956
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0938
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0920
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0919
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0904
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0889
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.616320, mean: 0.009746
#       [Iteration 1/3] Training XGBoost (Class-Balanced objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Class-Balanced Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1432
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1334
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1295
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1274
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1260
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1252
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1241
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1232
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1224
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1220
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1213
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1208
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1205
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1200
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1197
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1194
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1191
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1189
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1188
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1188
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1184
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1181
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1178
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1177
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1177
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1175
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1174
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1173
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1170
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1170
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1169
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1168
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1167
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1162
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1163
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1164
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1165
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1163
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1164
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1162
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1160
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1167
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1163
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1164
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1164
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1166
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.484837, mean: 0.045725, pseudo-labels flagged vulnerable: 0 / 53851
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1158
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1154
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1147
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1131
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1121
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1122
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1111
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1102
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1091
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1105
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1072
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1068
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1063
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1048
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1042
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1023
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1020
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1009
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0988
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0985
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0968
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0976
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0960
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0954
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0934
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0922
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0927
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0914
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0907
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0889
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.506034, mean: 0.007842
#       [Iteration 2/3] Training XGBoost (Class-Balanced objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Class-Balanced Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1469
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1354
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1312
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1291
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1276
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1261
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1250
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1240
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1236
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1227
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1219
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1215
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1215
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1206
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1203
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1200
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1197
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1195
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1192
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1190
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1189
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1187
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1186
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1183
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1180
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1181
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1179
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1176
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1178
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1173
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1177
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1172
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1170
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1169
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1169
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1173
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1168
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1167
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1168
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1170
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1169
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1166
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1166
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1165
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1169
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1171
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1166
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1170
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1164
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1167
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.512407, mean: 0.050335, pseudo-labels flagged vulnerable: 14 / 53851
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1169
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1159
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1149
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1152
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1128
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1119
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1119
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1109
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1099
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1096
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1084
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1076
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1056
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1052
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1051
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1055
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1036
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1016
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1001
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1002
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0997
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0977
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0969
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0980
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0946
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0932
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0943
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0936
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0917
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0910
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.562586, mean: 0.007335
#       [Iteration 3/3] Training XGBoost (Class-Balanced objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux Test Set) - Class-Balanced Loss ===
# Accuracy  : 0.979
# Precision : 0.000
# Recall    : 0.000
# F1-score  : 0.000
# AUC       : 0.768
# G-mean    : 0.000
# PF value  : 0.000
#
# Confusion Matrix:
#   TN: 52699  FP: 0
#   FN: 1152  TP: 0
#
# Results saved to results/class_balanced_loss/linux/class_balanced_loss_no_oversampling_linux.json
# Confusion matrix saved as results/class_balanced_loss/linux/confusion_matrix_class_balanced_loss_linux.png
