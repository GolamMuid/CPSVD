# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux -> Test on linux
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "linux"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/linux"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux -> Test on linux (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_linux",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_linux.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_linux.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except linux -> Test on linux (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (170682, 768)  vuln=4852  benign=165830
#       Projects in training pool : 753
#       Test set (linux)          : (53851, 768)  vuln=1152  benign=52699
#       Training imbalance ratio  : 0.0284
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.028427
#       pi_neg   = 0.971573
#       offset   = -3.5316
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1226
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1177
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1165
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1154
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1146
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1139
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1133
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1126
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1121
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1115
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1111
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1107
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1103
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1102
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1104
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1095
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1091
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1089
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1089
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1086
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1083
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1082
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1086
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1079
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1076
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1076
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1070
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1069
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1070
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1073
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1079
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1078
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1078
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.952289, mean: 0.261613, pseudo-labels flagged vulnerable: 13400 / 53851
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1317
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1301
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1289
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1251
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1272
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1233
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1254
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1265
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1249
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1236
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1233
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1234
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.1204
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1230
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.1195
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.1207
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.1220
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.1185
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.1170
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.1208
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.1169
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.1189
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.1179
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.1201
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.1172
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.1202
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.1162
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.1189
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.1173
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.1141
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999999, mean: 0.310388
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1194
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1170
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1157
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1146
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1138
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1131
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1124
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1118
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1112
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1108
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1104
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1101
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1096
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1093
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1090
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1088
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1086
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1083
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1082
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1080
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1078
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1077
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1077
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1076
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1073
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1073
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1074
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1069
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1069
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1068
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1075
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1079
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1080
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1078
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1080
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1081
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.955589, mean: 0.235168, pseudo-labels flagged vulnerable: 11313 / 53851
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1257
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1211
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1213
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1217
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1205
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1196
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1166
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1220
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1227
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1194
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1147
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.1124
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.1172
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.1158
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.1163
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.1151
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.1150
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.1119
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.1115
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.1157
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.1122
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.1144
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.1146
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.1120
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.1112
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.1126
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.1094
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.1098
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.1087
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.1090
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999994, mean: 0.266099
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1202
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1172
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1155
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1145
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1136
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1128
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1122
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1115
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1111
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1105
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1102
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1098
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1095
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1092
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1089
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1086
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1085
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1082
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1080
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1079
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1074
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1082
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1075
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1068
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1073
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1066
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1065
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1065
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1065
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1066
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1065
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1073
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1068
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1072
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1066
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.978621, mean: 0.268000, pseudo-labels flagged vulnerable: 11657 / 53851
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1264
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1235
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1245
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1235
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1190
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1184
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1236
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1198
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1209
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1184
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.1216
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.1167
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.1186
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.1160
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.1155
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.1124
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.1130
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.1171
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.1140
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.1145
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.1131
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.1098
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.1134
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.1127
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.1106
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.1091
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.1100
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.1122
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.1123
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.1128
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999999, mean: 0.295270
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (linux Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.712
# Precision : 0.053
# Recall    : 0.740
# F1-score  : 0.099
# AUC       : 0.788
# G-mean    : 0.725
# PF value  : 0.288
#
# Confusion Matrix:
#   TN: 37499  FP: 15200
#   FN: 300  TP: 852
#
# Results saved to results/logit_adjusted_loss/linux/logit_adjusted_loss_no_oversampling_linux.json
# Confusion matrix saved as results/logit_adjusted_loss/linux/confusion_matrix_logit_adjusted_loss_linux.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT Chrome -> Test on Chrome
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "Chrome"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/Chrome"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except Chrome -> Test on Chrome (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (Chrome)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (Chrome Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_Chrome",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_Chrome.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_Chrome.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except Chrome -> Test on Chrome (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (206223, 768)  vuln=5743  benign=200480
#       Projects in training pool : 753
#       Test set (Chrome)          : (18310, 768)  vuln=261  benign=18049
#       Training imbalance ratio  : 0.0278
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.027848
#       pi_neg   = 0.972152
#       offset   = -3.5527
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1191
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1156
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1144
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1134
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1127
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1120
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1115
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1110
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1108
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1102
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1099
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1097
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1092
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1089
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1087
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1088
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1082
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1080
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1078
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1078
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1074
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1070
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1069
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1059
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1059
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1063
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.931684, mean: 0.136409, pseudo-labels flagged vulnerable: 1657 / 18310
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1061
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1054
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1047
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1048
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1034
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1031
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1024
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1024
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1013
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1027
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1007
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.1004
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0999
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.1004
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0991
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0993
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0984
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0978
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0968
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0976
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0961
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0957
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0958
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0950
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0944
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0939
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0941
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0927
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0921
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0916
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999995, mean: 0.130778
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1166
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1150
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1139
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1130
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1121
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1114
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1109
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1104
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1102
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1096
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1093
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1090
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1086
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1083
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1081
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1079
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1077
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1074
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1074
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1072
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1067
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1063
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1064
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1062
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1061
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1061
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1061
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1059
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1054
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1062
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1052
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1056
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.978395, mean: 0.141932, pseudo-labels flagged vulnerable: 2003 / 18310
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1055
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1048
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1037
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1036
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1025
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1027
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1018
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1020
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1008
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0999
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.1014
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0986
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0996
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0976
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0970
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0968
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0973
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0960
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0960
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0949
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0947
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0940
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0942
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0931
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0924
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0918
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0916
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0909
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0908
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999998, mean: 0.143917
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1177
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1151
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1141
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1130
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1121
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1114
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1109
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1102
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1098
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1095
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1093
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1088
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1088
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1085
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1081
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1079
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1078
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1074
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1073
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1067
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1064
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1060
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1058
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1060
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1058
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1059
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1054
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1054
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1053
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1048
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1049
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1054
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000000, max: 0.942160, mean: 0.140594, pseudo-labels flagged vulnerable: 1312 / 18310
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1053
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1039
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1030
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1026
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1018
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1017
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1007
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1008
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.1003
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.1005
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0993
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0989
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0987
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0981
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0972
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0971
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0965
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0972
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0971
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0949
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0947
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0943
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0938
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0933
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0938
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0922
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0924
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0918
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0912
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0907
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999996, mean: 0.110854
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.869
# Precision : 0.056
# Recall    : 0.517
# F1-score  : 0.101
# AUC       : 0.802
# G-mean    : 0.672
# PF value  : 0.126
#
# Confusion Matrix:
#   TN: 15778  FP: 2271
#   FN: 126  TP: 135
#
# Results saved to results/logit_adjusted_loss/Chrome/logit_adjusted_loss_no_oversampling_Chrome.json
# Confusion matrix saved as results/logit_adjusted_loss/Chrome/confusion_matrix_logit_adjusted_loss_Chrome.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT qemu -> Test on qemu
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "qemu"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/qemu"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (qemu Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except qemu -> Test on qemu (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (qemu)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (qemu Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_qemu",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_qemu.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_qemu.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except qemu -> Test on qemu (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (218918, 768)  vuln=5855  benign=213063
#       Projects in training pool : 753
#       Test set (qemu)          : (5615, 768)  vuln=149  benign=5466
#       Training imbalance ratio  : 0.0267
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.026745
#       pi_neg   = 0.973255
#       offset   = -3.5943
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1196
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1158
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1146
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1136
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1130
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1125
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1117
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1113
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1109
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1105
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1101
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1097
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1094
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1095
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1089
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1086
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1086
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1082
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1081
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1082
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1077
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1078
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1073
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1072
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1067
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1063
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1066
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1062
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1071
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1067
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1069
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000004, max: 0.913893, mean: 0.282691, pseudo-labels flagged vulnerable: 1623 / 5615
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1056
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1057
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1046
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1043
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1043
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1030
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.1019
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.1021
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.1010
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.1015
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.1002
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0994
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0985
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0983
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0975
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0974
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0957
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0944
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0941
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0941
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0928
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0928
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0925
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0913
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0906
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0891
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0891
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0890
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0878
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999885, mean: 0.359900
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1171
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1153
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1140
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1131
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1124
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1117
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1111
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1106
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1102
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1099
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1094
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1092
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1091
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1085
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1084
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1079
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1078
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1075
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1073
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1072
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1073
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1067
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1066
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1065
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1063
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1062
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1061
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1060
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1069
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1054
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1055
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1052
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1060
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1063
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1060
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1062
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1067
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000019, max: 0.951901, mean: 0.282812, pseudo-labels flagged vulnerable: 1507 / 5615
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1047
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1046
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1038
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1031
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1033
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1027
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.1017
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.1024
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.1008
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.1002
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0987
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0981
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0969
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0963
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0964
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0947
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0944
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0939
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0932
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0931
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0938
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0926
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0914
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0906
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0902
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0901
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0900
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0884
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0878
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999929, mean: 0.337014
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1175
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1147
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1138
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1129
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1120
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1114
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1108
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1104
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1101
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1095
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1092
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1090
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1085
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1082
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1081
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1076
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1071
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1070
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1066
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1063
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1061
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1059
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1058
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1053
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1054
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1053
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1054
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1053
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1051
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1053
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1055
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000016, max: 0.959142, mean: 0.268303, pseudo-labels flagged vulnerable: 1111 / 5615
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1054
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1033
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1030
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1021
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1019
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.1013
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.1011
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.1014
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0996
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0995
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0987
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0984
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0973
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0966
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0964
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0958
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0958
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0944
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0940
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0936
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0924
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0916
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0915
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0912
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0902
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0898
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0894
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0891
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0888
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0885
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999961, mean: 0.311584
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (qemu Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.690
# Precision : 0.064
# Recall    : 0.779
# F1-score  : 0.118
# AUC       : 0.789
# G-mean    : 0.732
# PF value  : 0.312
#
# Confusion Matrix:
#   TN: 3760  FP: 1706
#   FN: 33  TP: 116
#
# Results saved to results/logit_adjusted_loss/qemu/logit_adjusted_loss_no_oversampling_qemu.json
# Confusion matrix saved as results/logit_adjusted_loss/qemu/confusion_matrix_logit_adjusted_loss_qemu.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT gpac -> Test on gpac
Logit-Adjusted Loss (Algorithmic Approach)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED = 42
TEST_PROJ = "gpac"
COMBINED_FILE = "../../../../embedding/primevul/codebert/primevul_embedded.jsonl"
EMB_KEY = "emb"
OUTPUT_DIR = "results/logit_adjusted_loss/gpac"

LOGIT_ADJ_TAU = 1.0
NN_LEARNING_RATE = 1e-5
BATCH_SIZE = 64

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X = np.array([r[EMB_KEY] for r in records], dtype=np.float32)
    y = np.array([r["target"] for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Neural Network
# =========================================================
class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

    def predict_proba(self, x):
        with torch.no_grad():
            return torch.sigmoid(self.forward(x))


# =========================================================
# Logit-Adjusted Loss
# =========================================================
class LogitAdjustedLoss(nn.Module):
    def __init__(self, pi_pos, pi_neg, tau=1.0):
        super().__init__()
        self.offset = tau * float(np.log(pi_pos / pi_neg))
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, raw_logits, targets):
        adjusted_logits = raw_logits.view(-1) + self.offset
        return self.bce(adjusted_logits, targets.view(-1))


# =========================================================
# Training Loop with Validation 
# =========================================================
def train_neural_network(model, dataloader, x_val, y_val,
                          optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            raw_logits = model(x_batch).squeeze()
            loss = criterion(raw_logits, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(x_val).squeeze()
            val_loss = criterion(val_logits, y_val).item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================
def semi_supervised_transfer_learning(x_train, y_train, x_test,
                                       logit_adj_criterion, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train, test_size=0.2, random_state=SEED
    )

    x_tr_t = torch.tensor(x_tr, dtype=torch.float32)
    y_tr_t = torch.tensor(y_tr, dtype=torch.float32)
    x_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    model = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=NN_LEARNING_RATE)

    # Phase 1
    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, logit_adj_criterion, epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    print(f"      [DIAGNOSTIC after Phase 1] y_pred -- min: {y_pred.min():.6f}, "
          f"max: {y_pred.max():.6f}, mean: {y_pred.mean():.6f}, "
          f"pseudo-labels flagged vulnerable: {y_pred_binary.sum()} / {len(y_pred_binary)}")

    # Phase 2
    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))
    x_aug_t = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, logit_adj_criterion, epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model.predict_proba(x_test_t.to(DEVICE)).squeeze().cpu().numpy()

    print(f"      [DIAGNOSTIC after Phase 2] y_pred_final -- min: {y_pred_final.min():.6f}, "
          f"max: {y_pred_final.max():.6f}, mean: {y_pred_final.mean():.6f}")

    return model, y_pred_final


# =========================================================
# Logit-Adjusted objective for XGBoost 
# =========================================================
def make_xgb_logit_adjusted_obj(offset):
    def logit_adj_obj(y_true, y_pred, sample_weight=None):
        y = np.asarray(y_true, dtype=np.float64)
        m = np.asarray(y_pred, dtype=np.float64)
        p = 1.0 / (1.0 + np.exp(-(m + offset)))

        grad = p - y
        hess = p * (1 - p)
        hess = np.clip(hess, 1e-6, None)

        if sample_weight is not None:
            sw = np.asarray(sample_weight, dtype=np.float64)
            grad = grad * sw
            hess = hess * sw

        return grad, hess

    return logit_adj_obj


def train_base_model_xgb(x_train, y_train, offset, sample_weights=None):
    logit_adj_obj = make_xgb_logit_adjusted_obj(offset)
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        objective=logit_adj_obj,
        eval_metric='logloss',
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot 
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (gpac Test Set) - Logit-Adjusted Loss")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except gpac -> Test on gpac (Logit-Adjusted Loss) ===")
    print(f"    Device: {DEVICE}")

    print("\n[1/5] Loading combined embeddings...")
    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb = X_all[train_mask].astype(np.float32)
    train_lbl = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb = X_all[test_mask].astype(np.float32)
    test_lbl = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (gpac)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    print("\n[2/5] Normalizing embeddings...")
    scaler = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb = scaler.transform(test_emb).astype(np.float32)

    print("\n[3/5] Computing Logit-Adjusted Loss offset from training class priors...")
    n_pos = int(train_lbl.sum())
    n_neg = int((train_lbl == 0).sum())
    pi_pos = n_pos / len(train_lbl)
    pi_neg = n_neg / len(train_lbl)
    offset = LOGIT_ADJ_TAU * float(np.log(pi_pos / pi_neg))
    print(f"      tau      = {LOGIT_ADJ_TAU}")
    print(f"      pi_pos   = {pi_pos:.6f}")
    print(f"      pi_neg   = {pi_neg:.6f}")
    print(f"      offset   = {offset:.4f}")

    logit_adj_criterion = LogitAdjustedLoss(pi_pos, pi_neg, tau=LOGIT_ADJ_TAU)

    print("\n[4/5] Running ensemble iterations...")
    num_iterations = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network (Logit-Adjusted Loss)...")
        model_nn, _ = semi_supervised_transfer_learning(
            train_emb, train_lbl, test_emb, logit_adj_criterion, iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost (Logit-Adjusted objective)...")
        model_nn.eval()
        with torch.no_grad():
            x_tr_t = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn.predict_proba(x_tr_t).squeeze().cpu().numpy()

        sample_weights = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb = train_base_model_xgb(train_emb, train_lbl, offset, sample_weights)
        model_xgb_pred = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy = accuracy_score(test_lbl, y_pred_final)
    recall = recall_score(test_lbl, y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc = roc_auc_score(test_lbl, ensemble_avg)
    f1 = f1_score(test_lbl, y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (gpac Test Set) - Logit-Adjusted Loss ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment": "logit_adjusted_loss_no_oversampling",
        "train": "all_except_gpac",
        "test": TEST_PROJ,
        "logit_adj_tau": LOGIT_ADJ_TAU,
        "logit_adj_offset": round(offset, 4),
        "pi_pos": round(pi_pos, 6),
        "pi_neg": round(pi_neg, 6),
        "n_train_projects": int(len(set(proj_all[train_mask]))),
        "n_train_samples": int(len(train_lbl)),
        "n_test_samples": int(len(test_lbl)),
        "n_vuln_train": int(train_lbl.sum()),
        "n_vuln_test": int(test_lbl.sum()),
        "accuracy": round(float(accuracy), 4),
        "precision": round(float(precision), 4),
        "recall": round(float(recall), 4),
        "f1": round(float(f1), 4),
        "auc": round(float(auc), 4),
        "g_mean": round(float(g_mean), 4),
        "pf": round(float(pf), 4),
        "confusion_matrix": {"tn": int(tn), "fp": int(fp), "fn": int(fn), "tp": int(tp)}
    }

    json_path = os.path.join(OUTPUT_DIR, "logit_adjusted_loss_no_oversampling_gpac.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_logit_adjusted_loss_gpac.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except gpac -> Test on gpac (Logit-Adjusted Loss) ===
#     Device: mps
#
# [1/5] Loading combined embeddings...
#       Training pool             : (219013, 768)  vuln=5926  benign=213087
#       Projects in training pool : 753
#       Test set (gpac)          : (5520, 768)  vuln=78  benign=5442
#       Training imbalance ratio  : 0.0271
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing Logit-Adjusted Loss offset from training class priors...
#       tau      = 1.0
#       pi_pos   = 0.027058
#       pi_neg   = 0.972942
#       offset   = -3.5824
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network (Logit-Adjusted Loss)...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.1185
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.1149
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.1136
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.1126
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.1117
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.1110
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.1105
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.1099
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.1096
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.1091
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.1088
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.1084
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.1080
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.1079
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.1075
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.1076
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.1070
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.1068
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.1065
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.1064
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.1061
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.1058
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.1059
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.1055
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.1056
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.1052
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.1057
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.1050
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.1050
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.1057
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.1050
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.1055
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.1054
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.1054
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.1055
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.1053
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.1050
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.1057
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.1051
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.1060
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.1064
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000028, max: 0.919712, mean: 0.155155, pseudo-labels flagged vulnerable: 525 / 5520
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.1036
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.1032
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.1021
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.1019
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.1003
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.1002
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0995
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0990
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0981
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0982
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0974
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0969
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0958
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0956
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0953
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0948
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0933
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0932
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0932
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0926
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0919
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0908
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0911
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0896
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0895
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0892
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0883
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0876
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0874
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0863
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999967, mean: 0.190935
#       [Iteration 1/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network (Logit-Adjusted Loss)...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.1155
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.1141
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.1128
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.1118
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.1110
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.1103
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.1097
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.1093
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.1088
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.1084
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.1081
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.1077
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.1075
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.1071
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.1070
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.1067
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.1064
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.1061
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.1058
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.1052
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.1056
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.1050
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.1046
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.1047
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.1049
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.1043
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.1048
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.1042
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.1046
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.1045
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.1052
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.1048
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.1047
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.1057
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.1053
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.1051
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.1052
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000050, max: 0.941480, mean: 0.173647, pseudo-labels flagged vulnerable: 699 / 5520
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.1030
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.1027
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.1017
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.1008
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.1004
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.1000
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0992
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0982
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0983
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0971
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0964
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0960
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0956
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0954
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0945
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0934
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0934
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0921
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0930
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0917
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0910
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0901
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0912
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0900
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0887
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0879
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0877
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0877
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0863
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0858
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999975, mean: 0.226275
#       [Iteration 2/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network (Logit-Adjusted Loss)...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.1162
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.1140
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.1127
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.1117
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.1108
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.1103
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.1097
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.1092
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.1088
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.1084
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.1080
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.1077
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.1074
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.1072
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.1069
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.1070
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.1066
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.1062
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.1060
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.1056
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.1055
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.1057
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.1052
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.1048
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.1046
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.1046
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.1045
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.1041
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.1041
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.1041
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.1042
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.1043
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.1050
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.1047
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.1045
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.1043
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.1044
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.1052
#       [DIAGNOSTIC after Phase 1] y_pred -- min: 0.000005, max: 0.952335, mean: 0.166084, pseudo-labels flagged vulnerable: 363 / 5520
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.1032
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.1024
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.1016
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.1009
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.1009
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0999
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0995
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0989
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0984
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0971
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0968
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0960
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0960
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0953
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0945
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0933
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0930
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0923
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0922
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0922
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0904
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0900
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0902
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0891
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0880
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0882
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0872
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0881
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0860
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0853
#       [DIAGNOSTIC after Phase 2] y_pred_final -- min: 0.000000, max: 0.999933, mean: 0.189902
#       [Iteration 3/3] Training XGBoost (Logit-Adjusted objective)...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (gpac Test Set) - Logit-Adjusted Loss ===
# Accuracy  : 0.798
# Precision : 0.053
# Recall    : 0.795
# F1-score  : 0.100
# AUC       : 0.863
# G-mean    : 0.796
# PF value  : 0.202
#
# Confusion Matrix:
#   TN: 4343  FP: 1099
#   FN: 16  TP: 62
#
# Results saved to results/logit_adjusted_loss/gpac/logit_adjusted_loss_no_oversampling_gpac.json
# Confusion matrix saved as results/logit_adjusted_loss/gpac/confusion_matrix_logit_adjusted_loss_gpac.png
