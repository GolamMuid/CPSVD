# %%
"""
Cross-Project Vulnerability Detection
--------------------------------------
Train on Debian -> Test on Chrome
Focal Loss (ReVeal)
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0


class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} "
                  f"- val_loss: {val_loss:.4f}")

    return model


def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


def train_base_model_xgb(x_train, y_train, n_neg, n_pos, sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


def main():
    print(f"\n=== Train: Debian  |  Test: Chrome  |  Focal Loss (ReVeal) ===")
    print(f"    Device: {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    print("\n[1/5] Loading embeddings...")
    deb_emb = np.load('../../../../embedding/reveal/codet5/debian_codet5p_embeddings.npy')
    deb_lbl = np.load('../../../../embedding/reveal/codet5/debian_codet5p_labels.npy')
    chr_emb = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_embeddings.npy')
    chr_lbl = np.load('../../../../embedding/reveal/codet5/chrome_codet5p_labels.npy')
    print(f"      Debian (train): {deb_emb.shape} | Chrome (test): {chr_emb.shape}")

    print("\n[2/5] Normalising embeddings...")
    scaler  = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(deb_lbl == 0))
    n_pos = int(np.sum(deb_lbl == 1))
    print(f"      Debian — 0: {n_neg} | 1: {n_pos} | ratio: {n_neg/n_pos:.2f}")
    unique, counts = np.unique(chr_lbl, return_counts=True)
    print(f"      Chrome: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb, deb_lbl,
            chr_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_deb_t      = torch.tensor(deb_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_deb_t).squeeze(-1).cpu().numpy()

        sample_weights = np.where(deb_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(
                             deb_emb, deb_lbl,
                             n_neg, n_pos,
                             sample_weights
                         )
        model_xgb_pred = model_xgb.predict_proba(chr_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(chr_lbl, y_pred_final)
    recall    = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc       = roc_auc_score(chr_lbl, ensemble_avg)
    f1        = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"  : "focal_loss",
        "train"       : "debian",
        "test"        : "chrome",
        "focal_alpha" : FOCAL_ALPHA,
        "focal_gamma" : FOCAL_GAMMA,
        "accuracy"    : round(accuracy,  3),
        "precision"   : round(precision, 3),
        "recall"      : round(recall,    3),
        "f1"          : round(f1,        3),
        "auc"         : round(auc,       3),
        "g_mean"      : round(g_mean,    3),
        "pf"          : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Train: Debian  |  Test: Chrome  |  Focal Loss (ReVeal) ===
#     Device: mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       Debian (train): (18298, 256) | Chrome (test): (4436, 256)
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       Debian — 0: 16883 | 1: 1415 | ratio: 11.93
#       Chrome: {np.int64(0): np.int64(3611), np.int64(1): np.int64(825)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0387
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0376
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0356
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0323
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0294
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0281
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0276
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0273
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0271
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0269
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0268
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0267
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0266
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0264
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0263
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0262
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0262
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0261
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0260
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0259
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0258
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0258
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0257
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0256
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0256
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0255
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0254
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0254
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0253
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0253
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0253
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0252
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0252
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0251
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0251
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0250
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0250
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0250
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0249
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0249
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0249
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0249
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0249
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0248
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0248
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0247
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0246
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0244
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0241
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0239
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0237
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0235
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0234
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0232
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0230
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0228
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0226
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0225
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0223
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0221
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0219
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0218
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0216
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0215
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0212
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0211
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0209
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0207
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0205
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0203
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0201
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0200
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0198
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0196
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0194
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0339
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0331
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0319
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0309
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0299
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0289
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0282
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0278
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0275
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0273
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0271
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0270
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0268
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0267
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0265
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0264
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0263
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0262
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0261
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0260
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0259
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0258
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0257
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0256
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0255
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0254
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0253
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0253
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0252
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0252
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0251
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0250
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0250
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0250
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0249
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0249
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0248
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0247
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0247
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0247
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0247
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0247
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0246
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0245
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0244
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0242
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0240
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0238
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0236
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0234
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0232
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0229
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0228
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0227
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0224
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0222
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0221
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0218
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0216
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0214
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0212
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0211
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0209
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0207
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0205
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0204
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0202
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0200
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0198
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0196
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0195
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0192
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0191
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0350
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0341
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0329
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0314
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0296
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0285
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0279
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0276
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0273
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0272
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0270
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0269
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0267
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0266
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0265
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0264
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0263
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0262
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0261
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0260
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0259
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0258
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0258
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0257
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0256
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0256
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0255
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0254
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0254
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0253
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0253
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0252
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0252
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0251
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0251
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0251
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0250
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0250
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0249
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0249
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0248
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0248
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0248
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0248
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0247
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0248
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0247
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0247
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0246
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0247
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0245
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0243
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0239
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0238
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0235
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0233
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0232
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0230
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0228
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0226
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0224
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0222
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0219
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0218
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0216
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0214
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0213
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0210
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0209
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0206
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0204
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0203
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0201
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0199
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0198
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0195
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0194
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0192
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0190
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0188
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:   0.752
# Precision:  0.244
# Recall:     0.159
# F1-score:   0.192
# AUC:        0.583
# G-mean:     0.375
# PF value:   0.112
#
# Confusion Matrix:
# TN: 3205  FP: 406
# FN: 694  TP: 131
#
# Results saved to results/focal_loss.json
# Confusion matrix saved as results/confusion_matrix_focal_loss.png
