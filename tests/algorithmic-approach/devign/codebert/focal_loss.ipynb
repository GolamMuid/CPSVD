# %%
"""
Cross-Project Vulnerability Detection
--------------------------------------
Train on QEMU -> Test on FFmpeg
Focal Loss (Devign, CodeBERT)
"""
import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    DEVICE = "cpu"

OUTPUT_DIR = "results"

FOCAL_ALPHA = 0.85
FOCAL_GAMMA = 2.0


class FocalLoss(nn.Module):
    def __init__(self, alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, predictions, targets):
        bce     = nn.functional.binary_cross_entropy(
                      predictions, targets, reduction='none'
                  )
        p_t     = predictions * targets + (1 - predictions) * (1 - targets)
        alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
        loss    = alpha_t * (1 - p_t) ** self.gamma * bce
        return loss.mean()


class VulnerabilityClassifier(nn.Module):
    def __init__(self, input_dim):
        super(VulnerabilityClassifier, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)


def train_neural_network(model, dataloader, x_val, y_val,
                         optimizer, criterion, epochs, desc):
    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        model.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            predictions = model(x_batch).squeeze(-1)
            loss        = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(x_val).squeeze(-1)
            val_loss  = criterion(val_preds, y_val).item()
            print(f"      {desc} | Epoch {epoch+1}/{epochs} "
                  f"- val_loss: {val_loss:.4f}")

    return model


def semi_supervised_transfer_learning(x_train, y_train, x_test, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_tr_t   = torch.tensor(x_tr,   dtype=torch.float32)
    y_tr_t   = torch.tensor(y_tr,   dtype=torch.float32)
    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    dataset    = TensorDataset(x_tr_t, y_tr_t)
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

    model     = VulnerabilityClassifier(x_train.shape[1]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA)

    model = train_neural_network(
        model, dataloader, x_val_t, y_val_t,
        optimizer, criterion,
        epochs=50,
        desc=f"Iter {iteration} - Phase 1"
    )

    model.eval()
    with torch.no_grad():
        y_pred        = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    model = train_neural_network(
        model, dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2"
    )

    model.eval()
    with torch.no_grad():
        y_pred_final = model(x_test_t.to(DEVICE)).squeeze(-1).cpu().numpy()

    return model, y_pred_final


def train_base_model_xgb(x_train, y_train, n_neg, n_pos, sample_weights=None):
    scale_pos_weight = n_neg / n_pos
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > cm.max() / 2 else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


def main():
    print(f"\n=== Train: QEMU  |  Test: FFmpeg  |  Focal Loss (Devign) ===")
    print(f"    Device: {DEVICE}")
    print(f"    Focal Loss — alpha: {FOCAL_ALPHA} | gamma: {FOCAL_GAMMA}")

    print("\n[1/5] Loading embeddings...")
    qmu_emb = np.load('../../../../embedding/devign/codebert/qemu_embeddings.npy')
    qmu_lbl = np.load('../../../../embedding/devign/codebert/qemu_labels.npy')
    ffm_emb = np.load('../../../../embedding/devign/codebert/ffmpeg_embeddings.npy')
    ffm_lbl = np.load('../../../../embedding/devign/codebert/ffmpeg_labels.npy')
    print(f"      QEMU (train): {qmu_emb.shape} | FFmpeg (test): {ffm_emb.shape}")

    print("\n[2/5] Normalising embeddings...")
    scaler  = StandardScaler()
    qmu_emb = scaler.fit_transform(qmu_emb)
    ffm_emb = scaler.transform(ffm_emb)

    print("\n[3/5] Class distribution check...")
    n_neg = int(np.sum(qmu_lbl == 0))
    n_pos = int(np.sum(qmu_lbl == 1))
    print(f"      QEMU — 0: {n_neg} | 1: {n_pos} | ratio: {n_neg/n_pos:.2f}")
    unique, counts = np.unique(ffm_lbl, return_counts=True)
    print(f"      FFmpeg: {dict(zip(unique.astype(int), counts))}")

    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(ffm_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training neural network...")
        model_nn, _ = semi_supervised_transfer_learning(
            qmu_emb, qmu_lbl,
            ffm_emb,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        model_nn.eval()
        with torch.no_grad():
            x_qmu_t      = torch.tensor(qmu_emb, dtype=torch.float32).to(DEVICE)
            y_train_pred = model_nn(x_qmu_t).squeeze(-1).cpu().numpy()

        sample_weights = np.where(qmu_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb      = train_base_model_xgb(
                             qmu_emb, qmu_lbl,
                             n_neg, n_pos,
                             sample_weights
                         )
        model_xgb_pred = model_xgb.predict_proba(ffm_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(ffm_lbl, y_pred_final)
    recall    = recall_score(ffm_lbl, y_pred_final)
    precision = precision_score(ffm_lbl, y_pred_final)
    auc       = roc_auc_score(ffm_lbl, ensemble_avg)
    f1        = f1_score(ffm_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(ffm_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn)) * (tn / (tn + fp)))
    pf     = fp / (fp + tn)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy:   {accuracy:.3f}")
    print(f"Precision:  {precision:.3f}")
    print(f"Recall:     {recall:.3f}")
    print(f"F1-score:   {f1:.3f}")
    print(f"AUC:        {auc:.3f}")
    print(f"G-mean:     {g_mean:.3f}")
    print(f"PF value:   {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"TN: {tn}  FP: {fp}")
    print(f"FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"  : "focal_loss",
        "train"       : "qemu",
        "test"        : "ffmpeg",
        "focal_alpha" : FOCAL_ALPHA,
        "focal_gamma" : FOCAL_GAMMA,
        "accuracy"    : round(accuracy,  3),
        "precision"   : round(precision, 3),
        "recall"      : round(recall,    3),
        "f1"          : round(f1,        3),
        "auc"         : round(auc,       3),
        "g_mean"      : round(g_mean,    3),
        "pf"          : round(pf,        3),
        "confusion_matrix": {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "focal_loss.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_focal_loss.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === Train: QEMU  |  Test: FFmpeg  |  Focal Loss (Devign) ===
#     Device: mps
#     Focal Loss — alpha: 0.85 | gamma: 2.0
#
# [1/5] Loading embeddings...
#       QEMU (train): (17549, 768) | FFmpeg (test): (9769, 768)
#
# [2/5] Normalising embeddings...
#
# [3/5] Class distribution check...
#       QEMU — 0: 10070 | 1: 7479 | ratio: 1.35
#       FFmpeg: {np.int64(0): np.int64(4788), np.int64(1): np.int64(4981)}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training neural network...
# Iter 1 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 | Epoch 1/50 - val_loss: 0.0817
#       Iter 1 - Phase 1 | Epoch 2/50 - val_loss: 0.0780
#       Iter 1 - Phase 1 | Epoch 3/50 - val_loss: 0.0727
#       Iter 1 - Phase 1 | Epoch 4/50 - val_loss: 0.0656
#       Iter 1 - Phase 1 | Epoch 5/50 - val_loss: 0.0605
#       Iter 1 - Phase 1 | Epoch 6/50 - val_loss: 0.0587
#       Iter 1 - Phase 1 | Epoch 7/50 - val_loss: 0.0579
#       Iter 1 - Phase 1 | Epoch 8/50 - val_loss: 0.0574
#       Iter 1 - Phase 1 | Epoch 9/50 - val_loss: 0.0570
#       Iter 1 - Phase 1 | Epoch 10/50 - val_loss: 0.0568
#       Iter 1 - Phase 1 | Epoch 11/50 - val_loss: 0.0565
#       Iter 1 - Phase 1 | Epoch 12/50 - val_loss: 0.0563
#       Iter 1 - Phase 1 | Epoch 13/50 - val_loss: 0.0561
#       Iter 1 - Phase 1 | Epoch 14/50 - val_loss: 0.0560
#       Iter 1 - Phase 1 | Epoch 15/50 - val_loss: 0.0558
#       Iter 1 - Phase 1 | Epoch 16/50 - val_loss: 0.0557
#       Iter 1 - Phase 1 | Epoch 17/50 - val_loss: 0.0556
#       Iter 1 - Phase 1 | Epoch 18/50 - val_loss: 0.0555
#       Iter 1 - Phase 1 | Epoch 19/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 20/50 - val_loss: 0.0554
#       Iter 1 - Phase 1 | Epoch 21/50 - val_loss: 0.0553
#       Iter 1 - Phase 1 | Epoch 22/50 - val_loss: 0.0552
#       Iter 1 - Phase 1 | Epoch 23/50 - val_loss: 0.0551
#       Iter 1 - Phase 1 | Epoch 24/50 - val_loss: 0.0551
#       Iter 1 - Phase 1 | Epoch 25/50 - val_loss: 0.0550
#       Iter 1 - Phase 1 | Epoch 26/50 - val_loss: 0.0549
#       Iter 1 - Phase 1 | Epoch 27/50 - val_loss: 0.0549
#       Iter 1 - Phase 1 | Epoch 28/50 - val_loss: 0.0548
#       Iter 1 - Phase 1 | Epoch 29/50 - val_loss: 0.0548
#       Iter 1 - Phase 1 | Epoch 30/50 - val_loss: 0.0547
#       Iter 1 - Phase 1 | Epoch 31/50 - val_loss: 0.0547
#       Iter 1 - Phase 1 | Epoch 32/50 - val_loss: 0.0546
#       Iter 1 - Phase 1 | Epoch 33/50 - val_loss: 0.0546
#       Iter 1 - Phase 1 | Epoch 34/50 - val_loss: 0.0546
#       Iter 1 - Phase 1 | Epoch 35/50 - val_loss: 0.0545
#       Iter 1 - Phase 1 | Epoch 36/50 - val_loss: 0.0545
#       Iter 1 - Phase 1 | Epoch 37/50 - val_loss: 0.0545
#       Iter 1 - Phase 1 | Epoch 38/50 - val_loss: 0.0544
#       Iter 1 - Phase 1 | Epoch 39/50 - val_loss: 0.0543
#       Iter 1 - Phase 1 | Epoch 40/50 - val_loss: 0.0543
#       Iter 1 - Phase 1 | Epoch 41/50 - val_loss: 0.0543
#       Iter 1 - Phase 1 | Epoch 42/50 - val_loss: 0.0543
#       Iter 1 - Phase 1 | Epoch 43/50 - val_loss: 0.0542
#       Iter 1 - Phase 1 | Epoch 44/50 - val_loss: 0.0542
#       Iter 1 - Phase 1 | Epoch 45/50 - val_loss: 0.0542
#       Iter 1 - Phase 1 | Epoch 46/50 - val_loss: 0.0542
#       Iter 1 - Phase 1 | Epoch 47/50 - val_loss: 0.0541
#       Iter 1 - Phase 1 | Epoch 48/50 - val_loss: 0.0541
#       Iter 1 - Phase 1 | Epoch 49/50 - val_loss: 0.0540
#       Iter 1 - Phase 1 | Epoch 50/50 - val_loss: 0.0540
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.0570
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.0566
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.0564
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.0559
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.0554
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.0553
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.0551
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.0548
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.0547
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.0545
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.0543
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.0540
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.0539
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.0536
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.0534
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.0534
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.0532
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.0529
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.0524
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.0522
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.0523
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.0519
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.0520
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.0515
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.0511
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.0512
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.0509
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.0505
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.0503
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training neural network...
# Iter 2 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 | Epoch 1/50 - val_loss: 0.0813
#       Iter 2 - Phase 1 | Epoch 2/50 - val_loss: 0.0769
#       Iter 2 - Phase 1 | Epoch 3/50 - val_loss: 0.0708
#       Iter 2 - Phase 1 | Epoch 4/50 - val_loss: 0.0624
#       Iter 2 - Phase 1 | Epoch 5/50 - val_loss: 0.0590
#       Iter 2 - Phase 1 | Epoch 6/50 - val_loss: 0.0579
#       Iter 2 - Phase 1 | Epoch 7/50 - val_loss: 0.0573
#       Iter 2 - Phase 1 | Epoch 8/50 - val_loss: 0.0568
#       Iter 2 - Phase 1 | Epoch 9/50 - val_loss: 0.0565
#       Iter 2 - Phase 1 | Epoch 10/50 - val_loss: 0.0563
#       Iter 2 - Phase 1 | Epoch 11/50 - val_loss: 0.0561
#       Iter 2 - Phase 1 | Epoch 12/50 - val_loss: 0.0559
#       Iter 2 - Phase 1 | Epoch 13/50 - val_loss: 0.0558
#       Iter 2 - Phase 1 | Epoch 14/50 - val_loss: 0.0556
#       Iter 2 - Phase 1 | Epoch 15/50 - val_loss: 0.0555
#       Iter 2 - Phase 1 | Epoch 16/50 - val_loss: 0.0554
#       Iter 2 - Phase 1 | Epoch 17/50 - val_loss: 0.0553
#       Iter 2 - Phase 1 | Epoch 18/50 - val_loss: 0.0552
#       Iter 2 - Phase 1 | Epoch 19/50 - val_loss: 0.0551
#       Iter 2 - Phase 1 | Epoch 20/50 - val_loss: 0.0550
#       Iter 2 - Phase 1 | Epoch 21/50 - val_loss: 0.0550
#       Iter 2 - Phase 1 | Epoch 22/50 - val_loss: 0.0549
#       Iter 2 - Phase 1 | Epoch 23/50 - val_loss: 0.0549
#       Iter 2 - Phase 1 | Epoch 24/50 - val_loss: 0.0548
#       Iter 2 - Phase 1 | Epoch 25/50 - val_loss: 0.0547
#       Iter 2 - Phase 1 | Epoch 26/50 - val_loss: 0.0547
#       Iter 2 - Phase 1 | Epoch 27/50 - val_loss: 0.0546
#       Iter 2 - Phase 1 | Epoch 28/50 - val_loss: 0.0546
#       Iter 2 - Phase 1 | Epoch 29/50 - val_loss: 0.0545
#       Iter 2 - Phase 1 | Epoch 30/50 - val_loss: 0.0545
#       Iter 2 - Phase 1 | Epoch 31/50 - val_loss: 0.0544
#       Iter 2 - Phase 1 | Epoch 32/50 - val_loss: 0.0544
#       Iter 2 - Phase 1 | Epoch 33/50 - val_loss: 0.0543
#       Iter 2 - Phase 1 | Epoch 34/50 - val_loss: 0.0543
#       Iter 2 - Phase 1 | Epoch 35/50 - val_loss: 0.0542
#       Iter 2 - Phase 1 | Epoch 36/50 - val_loss: 0.0542
#       Iter 2 - Phase 1 | Epoch 37/50 - val_loss: 0.0541
#       Iter 2 - Phase 1 | Epoch 38/50 - val_loss: 0.0541
#       Iter 2 - Phase 1 | Epoch 39/50 - val_loss: 0.0541
#       Iter 2 - Phase 1 | Epoch 40/50 - val_loss: 0.0541
#       Iter 2 - Phase 1 | Epoch 41/50 - val_loss: 0.0540
#       Iter 2 - Phase 1 | Epoch 42/50 - val_loss: 0.0540
#       Iter 2 - Phase 1 | Epoch 43/50 - val_loss: 0.0540
#       Iter 2 - Phase 1 | Epoch 44/50 - val_loss: 0.0539
#       Iter 2 - Phase 1 | Epoch 45/50 - val_loss: 0.0539
#       Iter 2 - Phase 1 | Epoch 46/50 - val_loss: 0.0539
#       Iter 2 - Phase 1 | Epoch 47/50 - val_loss: 0.0538
#       Iter 2 - Phase 1 | Epoch 48/50 - val_loss: 0.0538
#       Iter 2 - Phase 1 | Epoch 49/50 - val_loss: 0.0538
#       Iter 2 - Phase 1 | Epoch 50/50 - val_loss: 0.0537
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.0562
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.0561
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.0556
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.0552
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.0552
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.0548
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.0546
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.0542
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.0541
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.0534
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.0535
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.0530
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.0528
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.0526
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.0526
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.0521
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.0518
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.0516
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.0513
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.0510
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.0506
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.0505
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.0502
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.0499
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.0497
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.0493
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.0490
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.0487
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.0487
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.0482
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training neural network...
# Iter 3 - Phase 1:   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 | Epoch 1/50 - val_loss: 0.0660
#       Iter 3 - Phase 1 | Epoch 2/50 - val_loss: 0.0632
#       Iter 3 - Phase 1 | Epoch 3/50 - val_loss: 0.0597
#       Iter 3 - Phase 1 | Epoch 4/50 - val_loss: 0.0577
#       Iter 3 - Phase 1 | Epoch 5/50 - val_loss: 0.0570
#       Iter 3 - Phase 1 | Epoch 6/50 - val_loss: 0.0566
#       Iter 3 - Phase 1 | Epoch 7/50 - val_loss: 0.0563
#       Iter 3 - Phase 1 | Epoch 8/50 - val_loss: 0.0561
#       Iter 3 - Phase 1 | Epoch 9/50 - val_loss: 0.0559
#       Iter 3 - Phase 1 | Epoch 10/50 - val_loss: 0.0558
#       Iter 3 - Phase 1 | Epoch 11/50 - val_loss: 0.0557
#       Iter 3 - Phase 1 | Epoch 12/50 - val_loss: 0.0556
#       Iter 3 - Phase 1 | Epoch 13/50 - val_loss: 0.0554
#       Iter 3 - Phase 1 | Epoch 14/50 - val_loss: 0.0554
#       Iter 3 - Phase 1 | Epoch 15/50 - val_loss: 0.0553
#       Iter 3 - Phase 1 | Epoch 16/50 - val_loss: 0.0552
#       Iter 3 - Phase 1 | Epoch 17/50 - val_loss: 0.0551
#       Iter 3 - Phase 1 | Epoch 18/50 - val_loss: 0.0551
#       Iter 3 - Phase 1 | Epoch 19/50 - val_loss: 0.0550
#       Iter 3 - Phase 1 | Epoch 20/50 - val_loss: 0.0549
#       Iter 3 - Phase 1 | Epoch 21/50 - val_loss: 0.0549
#       Iter 3 - Phase 1 | Epoch 22/50 - val_loss: 0.0548
#       Iter 3 - Phase 1 | Epoch 23/50 - val_loss: 0.0548
#       Iter 3 - Phase 1 | Epoch 24/50 - val_loss: 0.0547
#       Iter 3 - Phase 1 | Epoch 25/50 - val_loss: 0.0547
#       Iter 3 - Phase 1 | Epoch 26/50 - val_loss: 0.0546
#       Iter 3 - Phase 1 | Epoch 27/50 - val_loss: 0.0545
#       Iter 3 - Phase 1 | Epoch 28/50 - val_loss: 0.0545
#       Iter 3 - Phase 1 | Epoch 29/50 - val_loss: 0.0545
#       Iter 3 - Phase 1 | Epoch 30/50 - val_loss: 0.0544
#       Iter 3 - Phase 1 | Epoch 31/50 - val_loss: 0.0544
#       Iter 3 - Phase 1 | Epoch 32/50 - val_loss: 0.0543
#       Iter 3 - Phase 1 | Epoch 33/50 - val_loss: 0.0543
#       Iter 3 - Phase 1 | Epoch 34/50 - val_loss: 0.0542
#       Iter 3 - Phase 1 | Epoch 35/50 - val_loss: 0.0542
#       Iter 3 - Phase 1 | Epoch 36/50 - val_loss: 0.0541
#       Iter 3 - Phase 1 | Epoch 37/50 - val_loss: 0.0541
#       Iter 3 - Phase 1 | Epoch 38/50 - val_loss: 0.0541
#       Iter 3 - Phase 1 | Epoch 39/50 - val_loss: 0.0540
#       Iter 3 - Phase 1 | Epoch 40/50 - val_loss: 0.0540
#       Iter 3 - Phase 1 | Epoch 41/50 - val_loss: 0.0540
#       Iter 3 - Phase 1 | Epoch 42/50 - val_loss: 0.0539
#       Iter 3 - Phase 1 | Epoch 43/50 - val_loss: 0.0539
#       Iter 3 - Phase 1 | Epoch 44/50 - val_loss: 0.0539
#       Iter 3 - Phase 1 | Epoch 45/50 - val_loss: 0.0538
#       Iter 3 - Phase 1 | Epoch 46/50 - val_loss: 0.0538
#       Iter 3 - Phase 1 | Epoch 47/50 - val_loss: 0.0538
#       Iter 3 - Phase 1 | Epoch 48/50 - val_loss: 0.0537
#       Iter 3 - Phase 1 | Epoch 49/50 - val_loss: 0.0537
#       Iter 3 - Phase 1 | Epoch 50/50 - val_loss: 0.0537
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.0567
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.0559
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.0560
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.0552
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.0553
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.0551
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.0541
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.0542
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.0540
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.0534
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.0534
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.0531
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.0528
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.0525
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.0520
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.0519
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.0517
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.0512
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.0511
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.0508
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.0505
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.0503
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.0499
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.0497
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.0495
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.0491
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.0488
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.0483
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.0486
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.0479
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (FFmpeg Test Set) ===
# Accuracy:   0.534
# Precision:  0.524
# Recall:     0.922
# F1-score:   0.668
# AUC:        0.568
# G-mean:     0.346
# PF value:   0.870
#
# Confusion Matrix:
# TN: 622  FP: 4166
# FN: 390  TP: 4591
#
# Results saved to results/focal_loss.json
# Confusion matrix saved as results/confusion_matrix_focal_loss.png
