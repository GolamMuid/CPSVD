# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT poppler -> Test on poppler
DANN Domain Adaptation, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "poppler"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann/poppler"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training (source classification + source/target domain alignment)
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (poppler)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled poppler
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (poppler Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except poppler -> Test on poppler (DANN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (poppler)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class weights (computed from training pool only)
    # ----------------------------------------------------------
    print("\n[3/5] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (poppler Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann",
        "train"            : "all_except_poppler",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_poppler.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_poppler.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
# Out:
# === PrimeVul | Train on ALL except poppler -> Test on poppler (DANN) ===
#     Device: cpu
#
# [1/5] Loading combined embeddings...
#       Training pool             : (222735, 256)  vuln=5971  benign=216764
#       Projects in training pool : 753
#       Test set (poppler)          : (1798, 256)  vuln=33  benign=1765
#       Training imbalance ratio  : 0.0268
#
# [2/5] Normalizing embeddings...
#
# [3/5] Computing class weights...
#       Class weights: {0: 0.5137730434943072, 1: 18.651398425724334}
#
# [4/5] Running ensemble iterations...
# Ensemble:   0%|          | 0/3 [00:00<?, ?iter/s]
#       [Iteration 1/3] Training DANN neural network...
# Iter 1 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 1 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 1.3030  domain_loss: 1.3972  alpha: 0.100  val_loss: 0.6977
#       Iter 1 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3082  domain_loss: 1.4029  alpha: 0.197  val_loss: 0.6515
#       Iter 1 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 1.1073  domain_loss: 1.3904  alpha: 0.291  val_loss: 0.6147
#       Iter 1 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.3380  domain_loss: 1.3708  alpha: 0.380  val_loss: 0.5944
#       Iter 1 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.9282  domain_loss: 1.4035  alpha: 0.462  val_loss: 0.5779
#       Iter 1 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.4223  domain_loss: 1.3782  alpha: 0.537  val_loss: 0.5685
#       Iter 1 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.3414  domain_loss: 1.3822  alpha: 0.604  val_loss: 0.5637
#       Iter 1 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3811  domain_loss: 1.3829  alpha: 0.664  val_loss: 0.5600
#       Iter 1 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2337  domain_loss: 1.3904  alpha: 0.716  val_loss: 0.5578
#       Iter 1 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.2685  domain_loss: 1.3912  alpha: 0.762  val_loss: 0.5561
#       Iter 1 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.3013  domain_loss: 1.3863  alpha: 0.800  val_loss: 0.5541
#       Iter 1 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.2632  domain_loss: 1.3845  alpha: 0.834  val_loss: 0.5530
#       Iter 1 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.3783  domain_loss: 1.3989  alpha: 0.862  val_loss: 0.5517
#       Iter 1 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3003  domain_loss: 1.3896  alpha: 0.885  val_loss: 0.5496
#       Iter 1 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.7129  domain_loss: 1.3976  alpha: 0.905  val_loss: 0.5491
#       Iter 1 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 1.3976  domain_loss: 1.3905  alpha: 0.922  val_loss: 0.5476
#       Iter 1 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1674  domain_loss: 1.3763  alpha: 0.935  val_loss: 0.5465
#       Iter 1 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1246  domain_loss: 1.4007  alpha: 0.947  val_loss: 0.5456
#       Iter 1 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.6706  domain_loss: 1.3984  alpha: 0.956  val_loss: 0.5442
#       Iter 1 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.1907  domain_loss: 1.3978  alpha: 0.964  val_loss: 0.5436
#       Iter 1 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2862  domain_loss: 1.3964  alpha: 0.970  val_loss: 0.5431
#       Iter 1 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2539  domain_loss: 1.3764  alpha: 0.976  val_loss: 0.5413
#       Iter 1 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.6610  domain_loss: 1.3752  alpha: 0.980  val_loss: 0.5417
#       Iter 1 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.2124  domain_loss: 1.3720  alpha: 0.984  val_loss: 0.5384
#       Iter 1 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.2083  domain_loss: 1.3960  alpha: 0.987  val_loss: 0.5379
#       Iter 1 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1702  domain_loss: 1.3840  alpha: 0.989  val_loss: 0.5395
#       Iter 1 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.2961  domain_loss: 1.3958  alpha: 0.991  val_loss: 0.5375
#       Iter 1 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.5894  domain_loss: 1.3814  alpha: 0.993  val_loss: 0.5372
#       Iter 1 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.5244  domain_loss: 1.3864  alpha: 0.994  val_loss: 0.5366
#       Iter 1 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 2.4010  domain_loss: 1.3795  alpha: 0.995  val_loss: 0.5368
#       Iter 1 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.1474  domain_loss: 1.3933  alpha: 0.996  val_loss: 0.5391
#       Iter 1 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 2.0870  domain_loss: 1.3958  alpha: 0.997  val_loss: 0.5365
#       Iter 1 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.1564  domain_loss: 1.3817  alpha: 0.997  val_loss: 0.5379
#       Iter 1 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 1.7598  domain_loss: 1.3924  alpha: 0.998  val_loss: 0.5378
#       Iter 1 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 1.0650  domain_loss: 1.3892  alpha: 0.998  val_loss: 0.5364
#       Iter 1 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.5929  domain_loss: 1.3948  alpha: 0.999  val_loss: 0.5381
#       Iter 1 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.2498  domain_loss: 1.3877  alpha: 0.999  val_loss: 0.5390
#       Iter 1 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.1619  domain_loss: 1.3860  alpha: 0.999  val_loss: 0.5396
#       Iter 1 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.3671  domain_loss: 1.3927  alpha: 0.999  val_loss: 0.5389
#       Iter 1 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.4997  domain_loss: 1.3899  alpha: 0.999  val_loss: 0.5418
#       Iter 1 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.7107  domain_loss: 1.3895  alpha: 0.999  val_loss: 0.5415
#       Iter 1 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.1949  domain_loss: 1.3866  alpha: 1.000  val_loss: 0.5446
#       Iter 1 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.1818  domain_loss: 1.3802  alpha: 1.000  val_loss: 0.5461
#       Iter 1 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2689  domain_loss: 1.3945  alpha: 1.000  val_loss: 0.5500
#       Iter 1 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.4018  domain_loss: 1.3879  alpha: 1.000  val_loss: 0.5436
#       Iter 1 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.7373  domain_loss: 1.3817  alpha: 1.000  val_loss: 0.5467
#       Iter 1 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.2601  domain_loss: 1.3792  alpha: 1.000  val_loss: 0.5487
#       Iter 1 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 5.3291  domain_loss: 1.3782  alpha: 1.000  val_loss: 0.5487
#       Iter 1 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.2026  domain_loss: 1.3795  alpha: 1.000  val_loss: 0.5469
#       Iter 1 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.1936  domain_loss: 1.3856  alpha: 1.000  val_loss: 0.5587
# Iter 1 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 1 - Phase 2 | Epoch 1/30 - val_loss: 0.5192
#       Iter 1 - Phase 2 | Epoch 2/30 - val_loss: 0.5063
#       Iter 1 - Phase 2 | Epoch 3/30 - val_loss: 0.5030
#       Iter 1 - Phase 2 | Epoch 4/30 - val_loss: 0.4915
#       Iter 1 - Phase 2 | Epoch 5/30 - val_loss: 0.4817
#       Iter 1 - Phase 2 | Epoch 6/30 - val_loss: 0.4745
#       Iter 1 - Phase 2 | Epoch 7/30 - val_loss: 0.4692
#       Iter 1 - Phase 2 | Epoch 8/30 - val_loss: 0.4585
#       Iter 1 - Phase 2 | Epoch 9/30 - val_loss: 0.4554
#       Iter 1 - Phase 2 | Epoch 10/30 - val_loss: 0.4494
#       Iter 1 - Phase 2 | Epoch 11/30 - val_loss: 0.4382
#       Iter 1 - Phase 2 | Epoch 12/30 - val_loss: 0.4337
#       Iter 1 - Phase 2 | Epoch 13/30 - val_loss: 0.4236
#       Iter 1 - Phase 2 | Epoch 14/30 - val_loss: 0.4213
#       Iter 1 - Phase 2 | Epoch 15/30 - val_loss: 0.4118
#       Iter 1 - Phase 2 | Epoch 16/30 - val_loss: 0.4055
#       Iter 1 - Phase 2 | Epoch 17/30 - val_loss: 0.3994
#       Iter 1 - Phase 2 | Epoch 18/30 - val_loss: 0.3954
#       Iter 1 - Phase 2 | Epoch 19/30 - val_loss: 0.3886
#       Iter 1 - Phase 2 | Epoch 20/30 - val_loss: 0.3831
#       Iter 1 - Phase 2 | Epoch 21/30 - val_loss: 0.3772
#       Iter 1 - Phase 2 | Epoch 22/30 - val_loss: 0.3712
#       Iter 1 - Phase 2 | Epoch 23/30 - val_loss: 0.3653
#       Iter 1 - Phase 2 | Epoch 24/30 - val_loss: 0.3621
#       Iter 1 - Phase 2 | Epoch 25/30 - val_loss: 0.3574
#       Iter 1 - Phase 2 | Epoch 26/30 - val_loss: 0.3532
#       Iter 1 - Phase 2 | Epoch 27/30 - val_loss: 0.3479
#       Iter 1 - Phase 2 | Epoch 28/30 - val_loss: 0.3438
#       Iter 1 - Phase 2 | Epoch 29/30 - val_loss: 0.3387
#       Iter 1 - Phase 2 | Epoch 30/30 - val_loss: 0.3364
#       [Iteration 1/3] Training XGBoost...
#       [Iteration 1/3] Done
#
#       [Iteration 2/3] Training DANN neural network...
# Iter 2 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 2 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 0.3783  domain_loss: 1.3884  alpha: 0.100  val_loss: 0.6960
#       Iter 2 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3075  domain_loss: 1.3864  alpha: 0.197  val_loss: 0.6437
#       Iter 2 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 2.4457  domain_loss: 1.3939  alpha: 0.291  val_loss: 0.5908
#       Iter 2 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 0.8397  domain_loss: 1.3954  alpha: 0.380  val_loss: 0.5754
#       Iter 2 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.2181  domain_loss: 1.4029  alpha: 0.462  val_loss: 0.5692
#       Iter 2 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3015  domain_loss: 1.3631  alpha: 0.537  val_loss: 0.5655
#       Iter 2 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.5611  domain_loss: 1.4008  alpha: 0.604  val_loss: 0.5629
#       Iter 2 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.3765  domain_loss: 1.4020  alpha: 0.664  val_loss: 0.5603
#       Iter 2 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2807  domain_loss: 1.3623  alpha: 0.716  val_loss: 0.5583
#       Iter 2 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.1044  domain_loss: 1.3883  alpha: 0.762  val_loss: 0.5583
#       Iter 2 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 1.0427  domain_loss: 1.4219  alpha: 0.800  val_loss: 0.5556
#       Iter 2 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.3516  domain_loss: 1.3698  alpha: 0.834  val_loss: 0.5549
#       Iter 2 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.1594  domain_loss: 1.3782  alpha: 0.862  val_loss: 0.5530
#       Iter 2 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 1.6006  domain_loss: 1.4063  alpha: 0.885  val_loss: 0.5515
#       Iter 2 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.1968  domain_loss: 1.3747  alpha: 0.905  val_loss: 0.5500
#       Iter 2 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.1315  domain_loss: 1.3826  alpha: 0.922  val_loss: 0.5502
#       Iter 2 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.2184  domain_loss: 1.4134  alpha: 0.935  val_loss: 0.5486
#       Iter 2 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.1371  domain_loss: 1.3941  alpha: 0.947  val_loss: 0.5481
#       Iter 2 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.8221  domain_loss: 1.3909  alpha: 0.956  val_loss: 0.5479
#       Iter 2 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.4262  domain_loss: 1.3723  alpha: 0.964  val_loss: 0.5455
#       Iter 2 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 0.2963  domain_loss: 1.3753  alpha: 0.970  val_loss: 0.5451
#       Iter 2 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2543  domain_loss: 1.3778  alpha: 0.976  val_loss: 0.5442
#       Iter 2 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.1993  domain_loss: 1.3949  alpha: 0.980  val_loss: 0.5419
#       Iter 2 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 0.4094  domain_loss: 1.3941  alpha: 0.984  val_loss: 0.5436
#       Iter 2 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.3050  domain_loss: 1.3898  alpha: 0.987  val_loss: 0.5429
#       Iter 2 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.3029  domain_loss: 1.3902  alpha: 0.989  val_loss: 0.5404
#       Iter 2 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.0933  domain_loss: 1.3880  alpha: 0.991  val_loss: 0.5397
#       Iter 2 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.2626  domain_loss: 1.3880  alpha: 0.993  val_loss: 0.5399
#       Iter 2 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 0.2487  domain_loss: 1.3880  alpha: 0.994  val_loss: 0.5411
#       Iter 2 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.7194  domain_loss: 1.3953  alpha: 0.995  val_loss: 0.5393
#       Iter 2 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.2476  domain_loss: 1.3985  alpha: 0.996  val_loss: 0.5410
#       Iter 2 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.3421  domain_loss: 1.3889  alpha: 0.997  val_loss: 0.5389
#       Iter 2 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.5531  domain_loss: 1.3940  alpha: 0.997  val_loss: 0.5393
#       Iter 2 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 0.3733  domain_loss: 1.3824  alpha: 0.998  val_loss: 0.5391
#       Iter 2 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.2222  domain_loss: 1.3882  alpha: 0.998  val_loss: 0.5408
#       Iter 2 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.6816  domain_loss: 1.3840  alpha: 0.999  val_loss: 0.5403
#       Iter 2 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.1363  domain_loss: 1.3932  alpha: 0.999  val_loss: 0.5454
#       Iter 2 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.4122  domain_loss: 1.3822  alpha: 0.999  val_loss: 0.5411
#       Iter 2 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.1176  domain_loss: 1.3970  alpha: 0.999  val_loss: 0.5437
#       Iter 2 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.2941  domain_loss: 1.3818  alpha: 0.999  val_loss: 0.5458
#       Iter 2 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.1928  domain_loss: 1.3864  alpha: 0.999  val_loss: 0.5455
#       Iter 2 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.3978  domain_loss: 1.3813  alpha: 1.000  val_loss: 0.5451
#       Iter 2 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.5746  domain_loss: 1.3806  alpha: 1.000  val_loss: 0.5509
#       Iter 2 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.1057  domain_loss: 1.3831  alpha: 1.000  val_loss: 0.5541
#       Iter 2 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 0.2318  domain_loss: 1.3836  alpha: 1.000  val_loss: 0.5495
#       Iter 2 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.3089  domain_loss: 1.3836  alpha: 1.000  val_loss: 0.5494
#       Iter 2 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 0.1741  domain_loss: 1.3845  alpha: 1.000  val_loss: 0.5550
#       Iter 2 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.3190  domain_loss: 1.3893  alpha: 1.000  val_loss: 0.5511
#       Iter 2 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.4024  domain_loss: 1.3853  alpha: 1.000  val_loss: 0.5598
#       Iter 2 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.3221  domain_loss: 1.3834  alpha: 1.000  val_loss: 0.5564
# Iter 2 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 2 - Phase 2 | Epoch 1/30 - val_loss: 0.5250
#       Iter 2 - Phase 2 | Epoch 2/30 - val_loss: 0.5173
#       Iter 2 - Phase 2 | Epoch 3/30 - val_loss: 0.5043
#       Iter 2 - Phase 2 | Epoch 4/30 - val_loss: 0.4964
#       Iter 2 - Phase 2 | Epoch 5/30 - val_loss: 0.4902
#       Iter 2 - Phase 2 | Epoch 6/30 - val_loss: 0.4784
#       Iter 2 - Phase 2 | Epoch 7/30 - val_loss: 0.4706
#       Iter 2 - Phase 2 | Epoch 8/30 - val_loss: 0.4665
#       Iter 2 - Phase 2 | Epoch 9/30 - val_loss: 0.4561
#       Iter 2 - Phase 2 | Epoch 10/30 - val_loss: 0.4527
#       Iter 2 - Phase 2 | Epoch 11/30 - val_loss: 0.4459
#       Iter 2 - Phase 2 | Epoch 12/30 - val_loss: 0.4439
#       Iter 2 - Phase 2 | Epoch 13/30 - val_loss: 0.4350
#       Iter 2 - Phase 2 | Epoch 14/30 - val_loss: 0.4223
#       Iter 2 - Phase 2 | Epoch 15/30 - val_loss: 0.4147
#       Iter 2 - Phase 2 | Epoch 16/30 - val_loss: 0.4116
#       Iter 2 - Phase 2 | Epoch 17/30 - val_loss: 0.4070
#       Iter 2 - Phase 2 | Epoch 18/30 - val_loss: 0.4010
#       Iter 2 - Phase 2 | Epoch 19/30 - val_loss: 0.3945
#       Iter 2 - Phase 2 | Epoch 20/30 - val_loss: 0.3900
#       Iter 2 - Phase 2 | Epoch 21/30 - val_loss: 0.3868
#       Iter 2 - Phase 2 | Epoch 22/30 - val_loss: 0.3781
#       Iter 2 - Phase 2 | Epoch 23/30 - val_loss: 0.3759
#       Iter 2 - Phase 2 | Epoch 24/30 - val_loss: 0.3693
#       Iter 2 - Phase 2 | Epoch 25/30 - val_loss: 0.3652
#       Iter 2 - Phase 2 | Epoch 26/30 - val_loss: 0.3561
#       Iter 2 - Phase 2 | Epoch 27/30 - val_loss: 0.3541
#       Iter 2 - Phase 2 | Epoch 28/30 - val_loss: 0.3512
#       Iter 2 - Phase 2 | Epoch 29/30 - val_loss: 0.3447
#       Iter 2 - Phase 2 | Epoch 30/30 - val_loss: 0.3401
#       [Iteration 2/3] Training XGBoost...
#       [Iteration 2/3] Done
#
#       [Iteration 3/3] Training DANN neural network...
# Iter 3 - Phase 1 (DANN):   0%|          | 0/50 [00:00<?, ?it/s]
#       Iter 3 - Phase 1 (DANN) | Epoch 1/50 - cls_loss: 1.4253  domain_loss: 1.3848  alpha: 0.100  val_loss: 0.6944
#       Iter 3 - Phase 1 (DANN) | Epoch 2/50 - cls_loss: 0.3616  domain_loss: 1.3801  alpha: 0.197  val_loss: 0.6310
#       Iter 3 - Phase 1 (DANN) | Epoch 3/50 - cls_loss: 1.2395  domain_loss: 1.3954  alpha: 0.291  val_loss: 0.5885
#       Iter 3 - Phase 1 (DANN) | Epoch 4/50 - cls_loss: 1.4861  domain_loss: 1.3873  alpha: 0.380  val_loss: 0.5752
#       Iter 3 - Phase 1 (DANN) | Epoch 5/50 - cls_loss: 0.2508  domain_loss: 1.3811  alpha: 0.462  val_loss: 0.5692
#       Iter 3 - Phase 1 (DANN) | Epoch 6/50 - cls_loss: 0.3358  domain_loss: 1.4112  alpha: 0.537  val_loss: 0.5655
#       Iter 3 - Phase 1 (DANN) | Epoch 7/50 - cls_loss: 0.1914  domain_loss: 1.3803  alpha: 0.604  val_loss: 0.5629
#       Iter 3 - Phase 1 (DANN) | Epoch 8/50 - cls_loss: 0.2496  domain_loss: 1.3890  alpha: 0.664  val_loss: 0.5611
#       Iter 3 - Phase 1 (DANN) | Epoch 9/50 - cls_loss: 0.2115  domain_loss: 1.3984  alpha: 0.716  val_loss: 0.5607
#       Iter 3 - Phase 1 (DANN) | Epoch 10/50 - cls_loss: 0.1891  domain_loss: 1.3917  alpha: 0.762  val_loss: 0.5580
#       Iter 3 - Phase 1 (DANN) | Epoch 11/50 - cls_loss: 0.2362  domain_loss: 1.3898  alpha: 0.800  val_loss: 0.5566
#       Iter 3 - Phase 1 (DANN) | Epoch 12/50 - cls_loss: 0.1818  domain_loss: 1.3912  alpha: 0.834  val_loss: 0.5562
#       Iter 3 - Phase 1 (DANN) | Epoch 13/50 - cls_loss: 0.2331  domain_loss: 1.3864  alpha: 0.862  val_loss: 0.5543
#       Iter 3 - Phase 1 (DANN) | Epoch 14/50 - cls_loss: 0.3345  domain_loss: 1.3803  alpha: 0.885  val_loss: 0.5531
#       Iter 3 - Phase 1 (DANN) | Epoch 15/50 - cls_loss: 0.2512  domain_loss: 1.3792  alpha: 0.905  val_loss: 0.5533
#       Iter 3 - Phase 1 (DANN) | Epoch 16/50 - cls_loss: 0.3665  domain_loss: 1.3819  alpha: 0.922  val_loss: 0.5523
#       Iter 3 - Phase 1 (DANN) | Epoch 17/50 - cls_loss: 0.1869  domain_loss: 1.3860  alpha: 0.935  val_loss: 0.5522
#       Iter 3 - Phase 1 (DANN) | Epoch 18/50 - cls_loss: 0.3167  domain_loss: 1.3770  alpha: 0.947  val_loss: 0.5499
#       Iter 3 - Phase 1 (DANN) | Epoch 19/50 - cls_loss: 0.1983  domain_loss: 1.3756  alpha: 0.956  val_loss: 0.5489
#       Iter 3 - Phase 1 (DANN) | Epoch 20/50 - cls_loss: 0.4371  domain_loss: 1.3903  alpha: 0.964  val_loss: 0.5498
#       Iter 3 - Phase 1 (DANN) | Epoch 21/50 - cls_loss: 2.4146  domain_loss: 1.3762  alpha: 0.970  val_loss: 0.5483
#       Iter 3 - Phase 1 (DANN) | Epoch 22/50 - cls_loss: 0.2815  domain_loss: 1.3910  alpha: 0.976  val_loss: 0.5461
#       Iter 3 - Phase 1 (DANN) | Epoch 23/50 - cls_loss: 0.2024  domain_loss: 1.3939  alpha: 0.980  val_loss: 0.5465
#       Iter 3 - Phase 1 (DANN) | Epoch 24/50 - cls_loss: 2.5358  domain_loss: 1.3902  alpha: 0.984  val_loss: 0.5446
#       Iter 3 - Phase 1 (DANN) | Epoch 25/50 - cls_loss: 0.1855  domain_loss: 1.3816  alpha: 0.987  val_loss: 0.5461
#       Iter 3 - Phase 1 (DANN) | Epoch 26/50 - cls_loss: 0.1929  domain_loss: 1.3824  alpha: 0.989  val_loss: 0.5456
#       Iter 3 - Phase 1 (DANN) | Epoch 27/50 - cls_loss: 0.2375  domain_loss: 1.3832  alpha: 0.991  val_loss: 0.5451
#       Iter 3 - Phase 1 (DANN) | Epoch 28/50 - cls_loss: 0.5818  domain_loss: 1.3909  alpha: 0.993  val_loss: 0.5435
#       Iter 3 - Phase 1 (DANN) | Epoch 29/50 - cls_loss: 2.1507  domain_loss: 1.3928  alpha: 0.994  val_loss: 0.5451
#       Iter 3 - Phase 1 (DANN) | Epoch 30/50 - cls_loss: 0.2106  domain_loss: 1.3905  alpha: 0.995  val_loss: 0.5465
#       Iter 3 - Phase 1 (DANN) | Epoch 31/50 - cls_loss: 0.3159  domain_loss: 1.3822  alpha: 0.996  val_loss: 0.5448
#       Iter 3 - Phase 1 (DANN) | Epoch 32/50 - cls_loss: 0.6464  domain_loss: 1.3943  alpha: 0.997  val_loss: 0.5481
#       Iter 3 - Phase 1 (DANN) | Epoch 33/50 - cls_loss: 0.2100  domain_loss: 1.3789  alpha: 0.997  val_loss: 0.5482
#       Iter 3 - Phase 1 (DANN) | Epoch 34/50 - cls_loss: 1.0640  domain_loss: 1.3817  alpha: 0.998  val_loss: 0.5467
#       Iter 3 - Phase 1 (DANN) | Epoch 35/50 - cls_loss: 0.2407  domain_loss: 1.3978  alpha: 0.998  val_loss: 0.5512
#       Iter 3 - Phase 1 (DANN) | Epoch 36/50 - cls_loss: 0.1313  domain_loss: 1.3900  alpha: 0.999  val_loss: 0.5553
#       Iter 3 - Phase 1 (DANN) | Epoch 37/50 - cls_loss: 0.2771  domain_loss: 1.3855  alpha: 0.999  val_loss: 0.5577
#       Iter 3 - Phase 1 (DANN) | Epoch 38/50 - cls_loss: 0.4698  domain_loss: 1.3986  alpha: 0.999  val_loss: 0.5576
#       Iter 3 - Phase 1 (DANN) | Epoch 39/50 - cls_loss: 0.2775  domain_loss: 1.3928  alpha: 0.999  val_loss: 0.5585
#       Iter 3 - Phase 1 (DANN) | Epoch 40/50 - cls_loss: 0.6691  domain_loss: 1.3828  alpha: 0.999  val_loss: 0.5594
#       Iter 3 - Phase 1 (DANN) | Epoch 41/50 - cls_loss: 0.2284  domain_loss: 1.3783  alpha: 0.999  val_loss: 0.5595
#       Iter 3 - Phase 1 (DANN) | Epoch 42/50 - cls_loss: 0.3943  domain_loss: 1.3777  alpha: 1.000  val_loss: 0.5584
#       Iter 3 - Phase 1 (DANN) | Epoch 43/50 - cls_loss: 0.0932  domain_loss: 1.3916  alpha: 1.000  val_loss: 0.5634
#       Iter 3 - Phase 1 (DANN) | Epoch 44/50 - cls_loss: 0.2561  domain_loss: 1.3851  alpha: 1.000  val_loss: 0.5605
#       Iter 3 - Phase 1 (DANN) | Epoch 45/50 - cls_loss: 2.9672  domain_loss: 1.3929  alpha: 1.000  val_loss: 0.5643
#       Iter 3 - Phase 1 (DANN) | Epoch 46/50 - cls_loss: 0.3835  domain_loss: 1.3848  alpha: 1.000  val_loss: 0.5680
#       Iter 3 - Phase 1 (DANN) | Epoch 47/50 - cls_loss: 1.1123  domain_loss: 1.3835  alpha: 1.000  val_loss: 0.5761
#       Iter 3 - Phase 1 (DANN) | Epoch 48/50 - cls_loss: 0.1675  domain_loss: 1.3859  alpha: 1.000  val_loss: 0.5730
#       Iter 3 - Phase 1 (DANN) | Epoch 49/50 - cls_loss: 0.2401  domain_loss: 1.3791  alpha: 1.000  val_loss: 0.5732
#       Iter 3 - Phase 1 (DANN) | Epoch 50/50 - cls_loss: 0.3750  domain_loss: 1.3870  alpha: 1.000  val_loss: 0.5778
# Iter 3 - Phase 2:   0%|          | 0/30 [00:00<?, ?it/s]
#       Iter 3 - Phase 2 | Epoch 1/30 - val_loss: 0.5344
#       Iter 3 - Phase 2 | Epoch 2/30 - val_loss: 0.5170
#       Iter 3 - Phase 2 | Epoch 3/30 - val_loss: 0.5115
#       Iter 3 - Phase 2 | Epoch 4/30 - val_loss: 0.5037
#       Iter 3 - Phase 2 | Epoch 5/30 - val_loss: 0.4950
#       Iter 3 - Phase 2 | Epoch 6/30 - val_loss: 0.4863
#       Iter 3 - Phase 2 | Epoch 7/30 - val_loss: 0.4793
#       Iter 3 - Phase 2 | Epoch 8/30 - val_loss: 0.4740
#       Iter 3 - Phase 2 | Epoch 9/30 - val_loss: 0.4635
#       Iter 3 - Phase 2 | Epoch 10/30 - val_loss: 0.4598
#       Iter 3 - Phase 2 | Epoch 11/30 - val_loss: 0.4518
#       Iter 3 - Phase 2 | Epoch 12/30 - val_loss: 0.4447
#       Iter 3 - Phase 2 | Epoch 13/30 - val_loss: 0.4380
#       Iter 3 - Phase 2 | Epoch 14/30 - val_loss: 0.4335
#       Iter 3 - Phase 2 | Epoch 15/30 - val_loss: 0.4234
#       Iter 3 - Phase 2 | Epoch 16/30 - val_loss: 0.4189
#       Iter 3 - Phase 2 | Epoch 17/30 - val_loss: 0.4128
#       Iter 3 - Phase 2 | Epoch 18/30 - val_loss: 0.4069
#       Iter 3 - Phase 2 | Epoch 19/30 - val_loss: 0.3997
#       Iter 3 - Phase 2 | Epoch 20/30 - val_loss: 0.3962
#       Iter 3 - Phase 2 | Epoch 21/30 - val_loss: 0.3929
#       Iter 3 - Phase 2 | Epoch 22/30 - val_loss: 0.3865
#       Iter 3 - Phase 2 | Epoch 23/30 - val_loss: 0.3819
#       Iter 3 - Phase 2 | Epoch 24/30 - val_loss: 0.3764
#       Iter 3 - Phase 2 | Epoch 25/30 - val_loss: 0.3723
#       Iter 3 - Phase 2 | Epoch 26/30 - val_loss: 0.3650
#       Iter 3 - Phase 2 | Epoch 27/30 - val_loss: 0.3634
#       Iter 3 - Phase 2 | Epoch 28/30 - val_loss: 0.3573
#       Iter 3 - Phase 2 | Epoch 29/30 - val_loss: 0.3516
#       Iter 3 - Phase 2 | Epoch 30/30 - val_loss: 0.3472
#       [Iteration 3/3] Training XGBoost...
#       [Iteration 3/3] Done
#
# [5/5] Computing metrics...
#
# === Evaluation Results (poppler Test Set) ===
# Accuracy  : 0.754
# Precision : 0.052
# Recall    : 0.727
# F1-score  : 0.098
# AUC       : 0.853
# G-mean    : 0.741
# PF value  : 0.246
#
# Confusion Matrix:
#   TN: 1331  FP: 434
#   FN: 9  TP: 24
#
# Results saved to results/dann/poppler\dann_poppler.json
# Confusion matrix saved as results/dann/poppler\confusion_matrix_dann_poppler.png

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT radare2 -> Test on radare2
DANN Domain Adaptation, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "radare2"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann/radare2"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training (source classification + source/target domain alignment)
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (radare2)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled radare2
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (radare2 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except radare2 -> Test on radare2 (DANN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (radare2)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class weights (computed from training pool only)
    # ----------------------------------------------------------
    print("\n[3/5] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (radare2 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann",
        "train"            : "all_except_radare2",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_radare2.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_radare2.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT linux-2.6 -> Test on linux-2.6
DANN Domain Adaptation, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "linux-2.6"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann/linux-2.6"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training (source classification + source/target domain alignment)
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (linux-2.6)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled linux-2.6
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (linux-2.6 Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except linux-2.6 -> Test on linux-2.6 (DANN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (linux-2.6)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class weights (computed from training pool only)
    # ----------------------------------------------------------
    print("\n[3/5] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (linux-2.6 Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann",
        "train"            : "all_except_linux-2.6",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_linux-2.6.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_linux-2.6.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT vim -> Test on vim
DANN Domain Adaptation, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "vim"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann/vim"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training (source classification + source/target domain alignment)
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (vim)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled vim
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (vim Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except vim -> Test on vim (DANN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (vim)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class weights (computed from training pool only)
    # ----------------------------------------------------------
    print("\n[3/5] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (vim Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann",
        "train"            : "all_except_vim",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_vim.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_vim.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()

# %%
"""
Cross-Project Vulnerability Detection on PrimeVul
--------------------------------------------------
Train on ALL projects EXCEPT FFmpeg -> Test on FFmpeg
DANN Domain Adaptation, With Class Weighting Baseline
"""

import os
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Function
from torch.utils.data import DataLoader, TensorDataset
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score,
    roc_auc_score, f1_score, confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")

# =========================================================
# Config
# =========================================================
SEED        = 42
TEST_PROJ   = "FFmpeg"
COMBINED_FILE = "../../../../embedding/primevul/codet5/primevul_embedded_codet5.jsonl"
EMB_KEY     = "emb"
OUTPUT_DIR  = "results/dann/FFmpeg"

DANN_EPOCHS      = 50
DANN_BATCH_SIZE   = 64
DOMAIN_LOSS_WEIGHT_MAX = 1.0   # max alpha for domain loss ramp

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.backends.mps.is_available():
    DEVICE = "mps"
    torch.mps.manual_seed(SEED)
elif torch.cuda.is_available():
    DEVICE = "cuda"
    torch.cuda.manual_seed_all(SEED)
else:
    DEVICE = "cpu"


# =========================================================
# Data Loading
# =========================================================
def load_jsonl(path):
    records = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    X        = np.array([r[EMB_KEY]   for r in records], dtype=np.float32)
    y        = np.array([r["target"]  for r in records], dtype=np.int32)
    projects = np.array([r["project"] for r in records], dtype=object)
    return X, y, projects


# =========================================================
# Gradient Reversal Layer
# =========================================================
class GradientReversalFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.alpha * grad_output, None


class GradientReversalLayer(nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x, alpha):
        return GradientReversalFunction.apply(x, alpha)


# =========================================================
# Feature Extractor (shared trunk)
# =========================================================
class FeatureExtractor(nn.Module):
    def __init__(self, input_dim):
        super(FeatureExtractor, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU()
        )

    def forward(self, x):
        return self.network(x)


# =========================================================
# Classifier Head (vulnerability label predictor)
# =========================================================
class ClassifierHead(nn.Module):
    def __init__(self, feature_dim=16):
        super(ClassifierHead, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# Domain Discriminator
# =========================================================
class DomainDiscriminator(nn.Module):
    def __init__(self, feature_dim=16):
        super(DomainDiscriminator, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(feature_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, features):
        return self.network(features)


# =========================================================
# DANN Training (Phase 1: joint classification + domain adaptation)
# =========================================================
def train_dann(feature_extractor, classifier_head, domain_discriminator,
                x_source, y_source, x_target,
                x_val, y_val, class_weights,
                epochs, batch_size, desc):

    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    grl = GradientReversalLayer()

    params = (list(feature_extractor.parameters()) +
              list(classifier_head.parameters()) +
              list(domain_discriminator.parameters()))
    optimizer = torch.optim.Adam(params, lr=1e-5)

    cls_criterion    = nn.BCELoss(reduction='none')
    domain_criterion = nn.BCELoss()

    x_source_t = torch.tensor(x_source, dtype=torch.float32)
    y_source_t = torch.tensor(y_source, dtype=torch.float32)
    x_target_t = torch.tensor(x_target, dtype=torch.float32)

    source_dataset = TensorDataset(x_source_t, y_source_t)
    source_loader  = DataLoader(source_dataset, batch_size=batch_size, shuffle=True)

    n_batches = len(source_loader)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        domain_discriminator.train()

        target_loader = DataLoader(
            TensorDataset(x_target_t), batch_size=batch_size, shuffle=True
        )
        target_iter = iter(target_loader)

        for batch_idx, (xs_batch, ys_batch) in enumerate(source_loader):
            p = (epoch * n_batches + batch_idx) / (epochs * n_batches)
            alpha = DOMAIN_LOSS_WEIGHT_MAX * (2.0 / (1.0 + np.exp(-10 * p)) - 1.0)

            try:
                (xt_batch,) = next(target_iter)
            except StopIteration:
                target_iter = iter(target_loader)
                (xt_batch,) = next(target_iter)

            xs_batch = xs_batch.to(DEVICE)
            ys_batch = ys_batch.to(DEVICE)
            xt_batch = xt_batch.to(DEVICE)

            optimizer.zero_grad()

            # --- Classification loss on source ---
            source_features = feature_extractor(xs_batch)
            y_pred = classifier_head(source_features).squeeze()
            weights = torch.where(ys_batch == 1, pos_weight, neg_weight)
            cls_loss = (cls_criterion(y_pred, ys_batch) * weights).mean()

            # --- Domain loss on source + target ---
            target_features = feature_extractor(xt_batch)

            bsz_s = source_features.size(0)
            bsz_t = target_features.size(0)

            source_reversed = grl(source_features, alpha)
            target_reversed = grl(target_features, alpha)

            domain_pred_source = domain_discriminator(source_reversed)
            domain_pred_target = domain_discriminator(target_reversed)

            domain_labels_source = torch.zeros(bsz_s, 1).to(DEVICE)
            domain_labels_target = torch.ones(bsz_t, 1).to(DEVICE)

            domain_loss = (
                domain_criterion(domain_pred_source, domain_labels_source) +
                domain_criterion(domain_pred_target, domain_labels_target)
            )

            total_loss = cls_loss + domain_loss
            total_loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            val_weights  = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (cls_criterion(val_preds, y_val) * val_weights).mean().item()

        print(f"      {desc} | Epoch {epoch+1}/{epochs} - "
              f"cls_loss: {cls_loss.item():.4f}  domain_loss: {domain_loss.item():.4f}  "
              f"alpha: {alpha:.3f}  val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Fine-tuning Loop (Phase 2: pseudo-labeled, classification only)
# =========================================================
def fine_tune_on_pseudo_labels(feature_extractor, classifier_head,
                                dataloader, x_val, y_val,
                                optimizer, criterion, epochs, desc, class_weights):
    pos_weight = torch.tensor(class_weights[1], dtype=torch.float32).to(DEVICE)
    neg_weight = torch.tensor(class_weights[0], dtype=torch.float32).to(DEVICE)

    for epoch in tqdm(range(epochs), desc=desc, leave=False):
        feature_extractor.train()
        classifier_head.train()
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)
            optimizer.zero_grad()
            features    = feature_extractor(x_batch)
            predictions = classifier_head(features).squeeze()
            weights     = torch.where(y_batch == 1, pos_weight, neg_weight)
            loss        = (criterion(predictions, y_batch) * weights).mean()
            loss.backward()
            optimizer.step()

        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            val_features = feature_extractor(x_val)
            val_preds    = classifier_head(val_features).squeeze()
            weights      = torch.where(y_val == 1, pos_weight, neg_weight)
            val_loss     = (criterion(val_preds, y_val) * weights).mean().item()
        print(f"      {desc} | Epoch {epoch+1}/{epochs} - val_loss: {val_loss:.4f}")

    return feature_extractor, classifier_head


# =========================================================
# Semi-supervised Transfer Learning with DANN
# =========================================================
def semi_supervised_transfer_learning_dann(x_train, y_train, x_test,
                                            class_weights, iteration):
    x_tr, x_val, y_tr, y_val = train_test_split(
        x_train, y_train,
        test_size=0.2,
        random_state=SEED
    )

    x_val_t  = torch.tensor(x_val,  dtype=torch.float32).to(DEVICE)
    y_val_t  = torch.tensor(y_val,  dtype=torch.float32).to(DEVICE)
    x_test_t = torch.tensor(x_test, dtype=torch.float32)

    feature_extractor     = FeatureExtractor(x_train.shape[1]).to(DEVICE)
    classifier_head       = ClassifierHead(feature_dim=16).to(DEVICE)
    domain_discriminator  = DomainDiscriminator(feature_dim=16).to(DEVICE)

    # Phase 1: DANN training (source classification + source/target domain alignment)
    feature_extractor, classifier_head = train_dann(
        feature_extractor, classifier_head, domain_discriminator,
        x_source=x_tr, y_source=y_tr, x_target=x_test,
        x_val=x_val_t, y_val=y_val_t,
        class_weights=class_weights,
        epochs=DANN_EPOCHS,
        batch_size=DANN_BATCH_SIZE,
        desc=f"Iter {iteration} - Phase 1 (DANN)"
    )

    # Pseudo-label the test set (FFmpeg)
    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features = feature_extractor(x_test_t.to(DEVICE))
        y_pred        = classifier_head(test_features).squeeze().cpu().numpy()
        y_pred_binary = (y_pred > 0.5).astype(int)

    # Phase 2: Fine-tune on source + pseudo-labelled FFmpeg
    x_train_aug    = np.concatenate((x_train, x_test))
    y_train_aug    = np.concatenate((y_train, y_pred_binary))
    x_aug_t        = torch.tensor(x_train_aug, dtype=torch.float32)
    y_aug_t        = torch.tensor(y_train_aug, dtype=torch.float32)
    x_aug_val_t    = torch.tensor(x_val, dtype=torch.float32).to(DEVICE)
    y_aug_val_t    = torch.tensor(y_val, dtype=torch.float32).to(DEVICE)
    dataset_aug    = TensorDataset(x_aug_t, y_aug_t)
    dataloader_aug = DataLoader(dataset_aug, batch_size=32, shuffle=True)

    optimizer = torch.optim.Adam(
        list(feature_extractor.parameters()) + list(classifier_head.parameters()),
        lr=1e-5
    )
    criterion = nn.BCELoss(reduction='none')

    feature_extractor, classifier_head = fine_tune_on_pseudo_labels(
        feature_extractor, classifier_head,
        dataloader_aug, x_aug_val_t, y_aug_val_t,
        optimizer, criterion,
        epochs=30,
        desc=f"Iter {iteration} - Phase 2",
        class_weights=class_weights
    )

    feature_extractor.eval()
    classifier_head.eval()
    with torch.no_grad():
        test_features_final = feature_extractor(x_test_t.to(DEVICE))
        y_pred_final = classifier_head(test_features_final).squeeze().cpu().numpy()

    return (feature_extractor, classifier_head), y_pred_final


# =========================================================
# XGBoost
# =========================================================
def train_base_model_xgb(x_train, y_train, class_weights, sample_weights=None):
    scale_pos_weight = class_weights[1] / class_weights[0]
    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight,
        random_state=SEED
    )
    model.fit(x_train, y_train, sample_weight=sample_weights)
    return model


# =========================================================
# Confusion Matrix Plot
# =========================================================
def plot_confusion_matrix(tn, fp, fn, tp, save_path):
    cm = np.array([[tn, fp],
                   [fn, tp]])

    fig, ax = plt.subplots(figsize=(6, 5))
    img = ax.imshow(cm, interpolation='nearest')
    ax.set_title("Confusion Matrix (FFmpeg Test Set)")
    plt.colorbar(img, ax=ax)

    tick_marks = np.arange(2)
    ax.set_xticks(tick_marks)
    ax.set_xticklabels(["Non-Vulnerable", "Vulnerable"])
    ax.set_yticks(tick_marks)
    ax.set_yticklabels(["Non-Vulnerable", "Vulnerable"])

    thresh = cm.max() / 2
    for i in range(2):
        for j in range(2):
            color = "black" if cm[i, j] > thresh else "white"
            ax.text(j, i, cm[i, j], ha="center", va="center", color=color)

    ax.set_ylabel("Actual Label")
    ax.set_xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    print(f"Confusion matrix saved as {save_path}")
    plt.show()


# =========================================================
# Main
# =========================================================
def main():
    print(f"\n=== PrimeVul | Train on ALL except FFmpeg -> Test on FFmpeg (DANN) ===")
    print(f"    Device: {DEVICE}")

    # ----------------------------------------------------------
    # [1/5] Load combined embeddings and split by project
    # ----------------------------------------------------------
    print("\n[1/5] Loading combined embeddings...")

    X_all, y_all, proj_all = load_jsonl(COMBINED_FILE)

    train_mask = proj_all != TEST_PROJ
    train_emb  = X_all[train_mask].astype(np.float32)
    train_lbl  = y_all[train_mask].astype(np.int32)

    test_mask = proj_all == TEST_PROJ
    test_emb  = X_all[test_mask].astype(np.float32)
    test_lbl  = y_all[test_mask].astype(np.int32)

    if train_emb.shape[0] == 0:
        raise ValueError("Training pool is empty. Check COMBINED_FILE path.")
    if test_emb.shape[0] == 0:
        raise ValueError(f"No samples found for '{TEST_PROJ}' in {COMBINED_FILE}.")

    print(f"      Training pool             : {train_emb.shape}  "
          f"vuln={train_lbl.sum()}  benign={int((train_lbl == 0).sum())}")
    print(f"      Projects in training pool : {len(set(proj_all[train_mask]))}")
    print(f"      Test set (FFmpeg)          : {test_emb.shape}  "
          f"vuln={test_lbl.sum()}  benign={int((test_lbl == 0).sum())}")
    print(f"      Training imbalance ratio  : {train_lbl.sum() / len(train_lbl):.4f}")

    # ----------------------------------------------------------
    # [2/5] Normalize
    # ----------------------------------------------------------
    print("\n[2/5] Normalizing embeddings...")
    scaler    = StandardScaler()
    train_emb = scaler.fit_transform(train_emb).astype(np.float32)
    test_emb  = scaler.transform(test_emb).astype(np.float32)

    # ----------------------------------------------------------
    # [3/5] Class weights (computed from training pool only)
    # ----------------------------------------------------------
    print("\n[3/5] Computing class weights...")
    classes           = np.unique(train_lbl)
    class_weights_arr = compute_class_weight(
        class_weight='balanced', classes=classes, y=train_lbl
    )
    class_weight_dict = {int(c): float(w) for c, w in zip(classes, class_weights_arr)}
    print(f"      Class weights: {class_weight_dict}")

    # ----------------------------------------------------------
    # [4/5] Ensemble (DANN-NN + XGBoost) x 3 iterations
    # ----------------------------------------------------------
    print("\n[4/5] Running ensemble iterations...")
    num_iterations       = 3
    ensemble_predictions = np.zeros(len(test_lbl))

    for i in tqdm(range(num_iterations), desc="Ensemble", unit="iter"):
        print(f"\n      [Iteration {i+1}/{num_iterations}] Training DANN neural network...")
        (feature_extractor, classifier_head), _ = semi_supervised_transfer_learning_dann(
            train_emb, train_lbl,
            test_emb,
            class_weight_dict,
            iteration=i+1
        )

        print(f"      [Iteration {i+1}/{num_iterations}] Training XGBoost...")
        feature_extractor.eval()
        classifier_head.eval()
        with torch.no_grad():
            x_tr_t       = torch.tensor(train_emb, dtype=torch.float32).to(DEVICE)
            train_features = feature_extractor(x_tr_t)
            y_train_pred   = classifier_head(train_features).squeeze().cpu().numpy()

        sample_weights        = np.where(train_lbl == 1, y_train_pred, 1 - y_train_pred)
        model_xgb             = train_base_model_xgb(
            train_emb, train_lbl, class_weight_dict, sample_weights
        )
        model_xgb_pred        = model_xgb.predict_proba(test_emb)[:, 1]
        ensemble_predictions += model_xgb_pred
        print(f"      [Iteration {i+1}/{num_iterations}] Done")

    # ----------------------------------------------------------
    # [5/5] Metrics
    # ----------------------------------------------------------
    print("\n[5/5] Computing metrics...")
    ensemble_avg = ensemble_predictions / num_iterations
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    accuracy  = accuracy_score(test_lbl,  y_pred_final)
    recall    = recall_score(test_lbl,    y_pred_final, zero_division=0)
    precision = precision_score(test_lbl, y_pred_final, zero_division=0)
    auc       = roc_auc_score(test_lbl,   ensemble_avg)
    f1        = f1_score(test_lbl,        y_pred_final, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(test_lbl, y_pred_final).ravel()
    g_mean = np.sqrt((tp / (tp + fn + 1e-9)) * (tn / (tn + fp + 1e-9)))
    pf     = fp / (fp + tn + 1e-9)

    print("\n=== Evaluation Results (FFmpeg Test Set) ===")
    print(f"Accuracy  : {accuracy:.3f}")
    print(f"Precision : {precision:.3f}")
    print(f"Recall    : {recall:.3f}")
    print(f"F1-score  : {f1:.3f}")
    print(f"AUC       : {auc:.3f}")
    print(f"G-mean    : {g_mean:.3f}")
    print(f"PF value  : {pf:.3f}")
    print("\nConfusion Matrix:")
    print(f"  TN: {tn}  FP: {fp}")
    print(f"  FN: {fn}  TP: {tp}")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    results = {
        "experiment"       : "dann",
        "train"            : "all_except_FFmpeg",
        "test"             : TEST_PROJ,
        "n_train_projects" : int(len(set(proj_all[train_mask]))),
        "n_train_samples"  : int(len(train_lbl)),
        "n_test_samples"   : int(len(test_lbl)),
        "n_vuln_train"     : int(train_lbl.sum()),
        "n_vuln_test"      : int(test_lbl.sum()),
        "accuracy"         : round(float(accuracy),  4),
        "precision"        : round(float(precision), 4),
        "recall"           : round(float(recall),    4),
        "f1"               : round(float(f1),        4),
        "auc"              : round(float(auc),        4),
        "g_mean"           : round(float(g_mean),    4),
        "pf"               : round(float(pf),        4),
        "confusion_matrix" : {
            "tn": int(tn), "fp": int(fp),
            "fn": int(fn), "tp": int(tp)
        }
    }

    json_path = os.path.join(OUTPUT_DIR, "dann_FFmpeg.json")
    with open(json_path, "w") as f:
        json.dump(results, f, indent=2)
    print(f"\nResults saved to {json_path}")

    cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix_dann_FFmpeg.png")
    plot_confusion_matrix(tn, fp, fn, tp, cm_path)


if __name__ == "__main__":
    main()
